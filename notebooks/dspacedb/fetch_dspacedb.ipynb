# %%
import pandas as pd
from datetime import date

# %%
df_item = catalog.load('dspacedb/public/item')
df_metadatavalue = catalog.load('dspacedb/public/metadatavalue')
df_metadatafieldregistry = catalog.load('dspacedb/public/metadatafieldregistry')
df_metadataschemaregistry = catalog.load('dspacedb/public/metadataschemaregistry')
# Out:
#                     INFO     Loading data from dspacedb/public/item (SQLTableDataset)...        ]8;id=373067;file:///home/pablo/.local/lib/python3.10/site-packages/kedro/io/data_catalog.py\data_catalog.py]8;;\:]8;id=91171;file:///home/pablo/.local/lib/python3.10/site-packages/kedro/io/data_catalog.py#539\539]8;;\
# [10/17/24 14:04:25] INFO     Loading data from dspacedb/public/metadatavalue                    ]8;id=574583;file:///home/pablo/.local/lib/python3.10/site-packages/kedro/io/data_catalog.py\data_catalog.py]8;;\:]8;id=74561;file:///home/pablo/.local/lib/python3.10/site-packages/kedro/io/data_catalog.py#539\539]8;;\
#                              (SQLTableDataset)...
# [10/17/24 14:04:30] INFO     Loading data from dspacedb/public/metadatafieldregistry            ]8;id=346414;file:///home/pablo/.local/lib/python3.10/site-packages/kedro/io/data_catalog.py\data_catalog.py]8;;\:]8;id=348408;file:///home/pablo/.local/lib/python3.10/site-packages/kedro/io/data_catalog.py#539\539]8;;\
#                              (SQLTableDataset)...
#                     INFO     Loading data from dspacedb/public/metadataschemaregistry           ]8;id=935261;file:///home/pablo/.local/lib/python3.10/site-packages/kedro/io/data_catalog.py\data_catalog.py]8;;\:]8;id=689086;file:///home/pablo/.local/lib/python3.10/site-packages/kedro/io/data_catalog.py#539\539]8;;\
#                              (SQLTableDataset)...

# %%
def fetch_dspacedb(item, metadatavalue, metadatafieldregistry, metadataschemaregistry):
    df_item = item
    df_metadatavalue = metadatavalue
    df_metadatafieldregistry = metadatafieldregistry
    df_metadataschemaregistry = metadataschemaregistry
    df_item = df_item.convert_dtypes()
    df_metadatavalue = df_metadatavalue.convert_dtypes()
    df_metadatafieldregistry = df_metadatafieldregistry.convert_dtypes()
    df_metadataschemaregistry = df_metadataschemaregistry.convert_dtypes()
    df_item['load_datetime'] = date.today()
    df_metadatavalue['load_datetime'] = date.today()
    df_metadatafieldregistry['load_datetime'] = date.today()
    df_metadataschemaregistry['load_datetime'] = date.today()
    return df_item, df_metadatavalue, df_metadatafieldregistry, df_metadataschemaregistry

# %%
df_item, df_metadatavalue, df_metadatafieldregistry, df_metadataschemaregistry = fetch_dspacedb(df_item, df_metadatavalue, df_metadatafieldregistry, df_metadataschemaregistry)

# %%
df_item.dtypes
# Out:
# item_id                            Int64
# in_archive                       boolean
# withdrawn                        boolean
# last_modified        datetime64[ns, UTC]
# discoverable                     boolean
# uuid                              string
# submitter_id                      string
# owning_collection                 string
# load_datetime                     object
# dtype: object

# %%
df_item
# Out:
# <div>
# <style scoped>
#     .dataframe tbody tr th:only-of-type {
#         vertical-align: middle;
#     }
#
#     .dataframe tbody tr th {
#         vertical-align: top;
#     }
#
#     .dataframe thead th {
#         text-align: right;
#     }
# </style>
# <table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: right;">
#       <th></th>
#       <th>item_id</th>
#       <th>in_archive</th>
#       <th>withdrawn</th>
#       <th>last_modified</th>
#       <th>discoverable</th>
#       <th>uuid</th>
#       <th>submitter_id</th>
#       <th>owning_collection</th>
#       <th>load_datetime</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th>0</th>
#       <td>&lt;NA&gt;</td>
#       <td>True</td>
#       <td>False</td>
#       <td>2016-09-27 15:36:08.400000+00:00</td>
#       <td>True</td>
#       <td>eec9b5ea-c25b-4e6b-b497-0f37ae1d54cb</td>
#       <td>561dd02c-32ec-47d1-b90b-6f80623d23e6</td>
#       <td>4dbf6a13-885d-4935-8efa-db36bc37ada8</td>
#       <td>2024-10-17</td>
#     </tr>
#     <tr>
#       <th>1</th>
#       <td>&lt;NA&gt;</td>
#       <td>True</td>
#       <td>False</td>
#       <td>2016-08-16 11:39:20.309000+00:00</td>
#       <td>True</td>
#       <td>9d82e728-d033-4ac3-a0f2-e1212ea4b9a5</td>
#       <td>561dd02c-32ec-47d1-b90b-6f80623d23e6</td>
#       <td>3692cf0e-5a9d-4bc4-9888-2d4438f77e87</td>
#       <td>2024-10-17</td>
#     </tr>
#     <tr>
#       <th>2</th>
#       <td>3456</td>
#       <td>True</td>
#       <td>False</td>
#       <td>2019-10-30 13:34:33.074000+00:00</td>
#       <td>True</td>
#       <td>bcbdd878-9644-47d9-b5ac-fbe3ffc4cc9e</td>
#       <td>4ee66ac1-a107-411c-9931-387f5f31960d</td>
#       <td>ad3071d2-2357-4804-b560-d9e9b8e86452</td>
#       <td>2024-10-17</td>
#     </tr>
#     <tr>
#       <th>3</th>
#       <td>&lt;NA&gt;</td>
#       <td>True</td>
#       <td>False</td>
#       <td>2017-05-19 12:59:15.728000+00:00</td>
#       <td>True</td>
#       <td>21c1b81a-1a4f-4306-b1f6-5e7b0566c21c</td>
#       <td>561dd02c-32ec-47d1-b90b-6f80623d23e6</td>
#       <td>401abba4-c10e-403d-b012-4200cf5f686a</td>
#       <td>2024-10-17</td>
#     </tr>
#     <tr>
#       <th>4</th>
#       <td>2408</td>
#       <td>True</td>
#       <td>False</td>
#       <td>
td>
#       <td>&lt;NA&gt;</td>
#       <td>0</td>
#       <td>&lt;NA&gt;</td>
#       <td>-1</td>
#       <td>2f1baad7-1b0b-4ecb-9367-36c0bb179ed1</td>
#       <td>2024-10-17</td>
#     </tr>
#     <tr>
#       <th>459373</th>
#       <td>1506818</td>
#       <td>64</td>
#       <td>THUMBNAIL</td>
#       <td>&lt;NA&gt;</td>
#       <td>0</td>
#       <td>&lt;NA&gt;</td>
#       <td>-1</td>
#       <td>45996975-426b-4e75-a86e-2e88bde85e95</td>
#       <td>2024-10-17</td>
#     </tr>
#     <tr>
#       <th>459374</th>
#       <td>1507041</td>
#       <td>64</td>
#       <td>ORIGINAL</td>
#       <td>&lt;NA&gt;</td>
#       <td>0</td>
#       <td>&lt;NA&gt;</td>
#       <td>-1</td>
#       <td>2ff2ef40-2306-42e4-8682-b740805e9f59</td>
#       <td>2024-10-17</td>
#     </tr>
#   </tbody>
# </table>
# <p>459375 rows × 9 columns</p>
# </div>

# %%
df_metadatafieldregistry
# Out:
# <div>
# <style scoped>
#     .dataframe tbody tr th:only-of-type {
#         vertical-align: middle;
#     }
#
#     .dataframe tbody tr th {
#         vertical-align: top;
#     }
#
#     .dataframe thead th {
#         text-align: right;
#     }
# </style>
# <table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: right;">
#       <th></th>
#       <th>metadata_field_id</th>
#       <th>metadata_schema_id</th>
#       <th>element</th>
#       <th>qualifier</th>
#       <th>scope_note</th>
#       <th>load_datetime</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th>0</th>
#       <td>1</td>
#       <td>1</td>
#       <td>contributor</td>
#       <td>&lt;NA&gt;</td>
#       <td>A person, organization, or service responsible...</td>
#       <td>2024-10-17</td>
#     </tr>
#     <tr>
#       <th>1</th>
#       <td>2</td>
#       <td>1</td>
#       <td>contributor</td>
#       <td>advisor</td>
#       <td>Use primarily for thesis advisor.</td>
#       <td>2024-10-17</td>
#     </tr>
#     <tr>
#       <th>2</th>
#       <td>3</td>
#       <td>1</td>
#       <td>contributor</td>
#       <td>author</td>
#       <td>&lt;NA&gt;</td>
#       <td>2024-10-17</td>
#     </tr>
#     <tr>
#       <th>3</th>
#       <td>4</td>
#       <td>1</td>
#       <td>contributor</td>
#       <td>editor</td>
#       <td>&lt;NA&gt;</td>
#       <td>2024-10-17</td>
#     </tr>
#     <tr>
#       <th>4</th>
#       <td>5</td>
#       <td>1</td>
#       <td>contributor</td>
#       <td>illustrator</td>
#       <td>&lt;NA&gt;</td>
#       <td>2024-10-17</td>
#     </tr>
#     <tr>
#       <th>...</th>
#       <td>...</td>
#       <td>...</td>
#       <td>...</td>
#       <td>...</td>
#       <td>...</td>
#       <td>...</td>
#     </tr>
#     <tr>
#       <th>284</th>
#       <td>286</td>
#       <td>7</td>
#       <td>orcid</td>
#       <td>sync-publications</td>
#       <td>Stores the publication synchronization with OR...</td>
#       <td>2024-10-17</td>
#     </tr>
#     <tr>
#       <th>285</th>
#       <td>287</td>
#       <td>7</td>
#       <td>orcid</td>
#       <td>sync-fundings</td>
#       <td>Stores the funding synchronization with ORCID ...</td>
#       <td>2024-10-17</td>
#     </tr>
#     <tr>
#       <th>286</th>
#       <td>288</td>
#       <td>7</td>
#       <td>orcid</td>
#       <td>sync-profile</td>
#       <td>Stores the profile synchronization with ORCID ...</td>
#       <td>2024-10-17</td>
#     </tr>
#     <tr>
#       <th>287</th>
#       <td>289</td>
#       <td>7</td>
#       <td>orcid</td>
#       <td>authenticated</td>
#       <td>Stores the timestamp related to the user authe...</td>
#       <td>2024-10-17</td>
#     </tr>
#     <tr>
#       <th>288</th>
#       <td>290</td>
#       <td>4</td>
#       <td>review</td>
#       <td>&lt;NA&gt;</td>
#       <td>Metadata field used for the score review descr...</td>
#       <td>2024-10-17</td>
#     </tr>
#   </tbody>
# </table>
# <p>289 rows × 6 columns</p>
# </div>

# %%
df_metadataschemaregistry
# Out:
# <div>
# <style scoped>
#     .dataframe tbody tr th:only-of-type {
#         vertical-align: middle;
#     }
#
#     .dataframe tbody tr th {
#         vertical-align: top;
#     }
#
#     .dataframe thead th {
#         text-align: right;
#     }
# </style>
# <table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: right;">
#       <th></th>
#       <th>metadata_schema_id</th>
#       <th>namespace</th>
#       <th>short_id</th>
#       <th>load_datetime</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th>0</th>
#       <td>1</td>
#       <td>http://dublincore.org/documents/dcmi-terms/</td>
#       <td>dc</td>
#       <td>2024-10-17</td>
#     </tr>
#     <tr>
#       <th>1</th>
#       <td>2</td>
#       <td>http://purl.org/dc/terms/</td>
#       <td>dcterms</td>
#       <td>2024-10-17</td>
#     </tr>
#     <tr>
#       <th>2</th>
#       <td>3</td>
#       <td>http://dspace.org/eperson</td>
#       <td>eperson</td>
#       <td>2024-10-17</td>
#     </tr>
#     <tr>
#       <th>3</th>
#       <td>4</td>
#       <td>http://www.dspace.org/workflow</td>
#       <td>workflow</td>
#       <td>2024-10-17</td>
#     </tr>
#     <tr>
#       <th>4</th>
#       <td>5</td>
#       <td>http://digital.cic.gba.gob.ar/cic/terms</td>
#       <td>cic</td>
#       <td>2024-10-17</td>
#     </tr>
#     <tr>
#       <th>5</th>
#       <td>6</td>
#       <td>http://dspace.org/namespace/local/</td>
#       <td>local</td>
#       <td>2024-10-17</td>
#     </tr>
#     <tr>
#       <th>6</th>
#       <td>7</td>
#       <td>http://dspace.org/dspace</td>
#       <td>dspace</td>
#       <td>2024-10-17</td>
#     </tr>
#     <tr>
#       <th>7</th>
#       <td>8</td>
#       <td>http://dspace.org/relation</td>
#       <td>relation</td>
#       <td>2024-10-17</td>
#     </tr>
#     <tr>
#       <th>8</th>
#       <td>9</td>
#       <td>https://schema.org/Person</td>
#       <td>person</td>
#       <td>2024-10-17</td>
#     </tr>
#     <tr>
#       <th>9</th>
#       <td>10</td>
#       <td>https://schema.org/Project</td>
#       <td>project</td>
#       <td>2024-10-17</td>
#     </tr>
#     <tr>
#       <th>10</th>
#       <td>11</td>
#       <td>https://schema.org/Organization</td>
#       <td>organization</td>
#       <td>2024-10-17</td>
#     </tr>
#     <tr>
#       <th>11</th>
#       <td>12</td>
#       <td>https://schema.org/Periodical</td>
#       <td>periodical</td>
#       <td>2024-10-17</td>
#     </tr>
#     <tr>
#       <th>12</th>
#       <td>13</td>
#       <td>https://schema.org/CreativeWork</td>
#       <td>creativework</td>
#       <td>2024-10-17</td>
#     </tr>
#     <tr>
#       <th>13</th>
#       <td>14</td>
#       <td>https://schema.org/CreativeWorkSeries</td>
#       <td>creativeworkseries</td>
#       <td>2024-10-17</td>
#     </tr>
#     <tr>
#       <th>14</th>
#       <td>15</td>
#       <td>https://schema.org/PublicationIssue</td>
#       <td>publicationissue</td>
#       <td>2024-10-17</td>
#     </tr>
#     <tr>
#       <th>15</th>
#       <td>16</td>
#       <td>https://schema.org/PublicationVolume</td>
#       <td>publicationvolume</td>
#       <td>2024-10-17</td>
#     </tr>
#     <tr>
#       <th>16</th>
#       <td>17</td>
#       <td>http://namespace.openaire.eu/schema/oaire/</td>
#       <td>oaire</td>
#       <td>2024-10-17</td>
#     </tr>
#     <tr>
#       <th>17</th>
#       <td>18</td>
#       <td>http://datacite.org/schema/kernel-4</td>
#       <td>datacite</td>
#       <td>2024-10-17</td>
#     </tr>
#     <tr>
#       <th>18</th>
#       <td>19</td>
#       <td>http://dspace.org/iiif</td>
#       <td>iiif</td>
#       <td>2024-10-17</td>
#     </tr>
#   </tbody>
# </table>
# </div>
