# %%
import pandas as pd

# %%
df_item = catalog.load('raw/dspacedb/item#parquet')
df_metadatavalue = catalog.load('raw/dspacedb/metadatavalue#parquet')
df_metadatafieldregistry = catalog.load('raw/dspacedb/metadatafieldregistry#parquet')
df_metadataschemaregistry = catalog.load('raw/dspacedb/metadataschemaregistry#parquet')
# Out:
# [11/11/24 13:28:51] INFO     Loading data from raw/dspacedb/item#parquet (ParquetDataset)...    ]8;id=992871;file:///root/kedro-cic/.venv/lib/python3.10/site-packages/kedro/io/data_catalog.py\data_catalog.py]8;;\:]8;id=557648;file:///root/kedro-cic/.venv/lib/python3.10/site-packages/kedro/io/data_catalog.py#389\389]8;;\
#                     INFO     Loading data from raw/dspacedb/metadatavalue#parquet               ]8;id=89978;file:///root/kedro-cic/.venv/lib/python3.10/site-packages/kedro/io/data_catalog.py\data_catalog.py]8;;\:]8;id=816769;file:///root/kedro-cic/.venv/lib/python3.10/site-packages/kedro/io/data_catalog.py#389\389]8;;\
#                              (ParquetDataset)...
# [11/11/24 13:28:52] INFO     Loading data from raw/dspacedb/metadatafieldregistry#parquet       ]8;id=727788;file:///root/kedro-cic/.venv/lib/python3.10/site-packages/kedro/io/data_catalog.py\data_catalog.py]8;;\:]8;id=68639;file:///root/kedro-cic/.venv/lib/python3.10/site-packages/kedro/io/data_catalog.py#389\389]8;;\
#                              (ParquetDataset)...
#                     INFO     Loading data from raw/dspacedb/metadataschemaregistry#parquet      ]8;id=166076;file:///root/kedro-cic/.venv/lib/python3.10/site-packages/kedro/io/data_catalog.py\data_catalog.py]8;;\:]8;id=129456;file:///root/kedro-cic/.venv/lib/python3.10/site-packages/kedro/io/data_catalog.py#389\389]8;;\
#                              (ParquetDataset)...

# %%
def land_dspacedb(item, metadatavalue, metadatafieldregistry, metadataschemaregistry):
    df_item = item
    df_metadatavalue = metadatavalue
    df_metadatafieldregistry = metadatafieldregistry
    df_metadataschemaregistry = metadataschemaregistry
    return df_item, df_metadatavalue, df_metadatafieldregistry, df_metadataschemaregistry

# %%
df_item, df_metadatavalue, df_metadatafieldregistry, df_metadataschemaregistry = land_dspacedb(df_item, df_metadatavalue, df_metadatafieldregistry, df_metadataschemaregistry)

# %%
df_item
# Out:
# <pre style="white-space:pre;overflow-x:auto;line-height:normal;font-family:Menlo,'DejaVu Sans Mono',consolas,'Courier New',monospace"></pre>
#        item_id  in_archive  withdrawn                    last_modified  \
# 0         <NA>        True      False 2016-09-27 15:36:08.400000+00:00
# 1         <NA>        True      False 2016-08-16 11:39:20.309000+00:00
# 2         3456        True      False 2019-10-30 13:34:33.074000+00:00
# 3         <NA>        True      False 2017-05-19 12:59:15.728000+00:00
# 4         2408        True      False 2016-07-27 23:13:20.278000+00:00
# ...        ...         ...        ...                              ...
# 11841     <NA>        True      False 2024-02-26 20:01:25.078000+00:00
# 11842     <NA>        True      False 2024-02-26 20:02:11.253000+00:00
# 11843     <NA>        True      False 2024-02-26 20:02:23.658000+00:00
# 11844     <NA>        True      False 2024-02-26 20:02:27.421000+00:00
# 11845     <NA>        True      False 2024-02-26 20:02:40.966000+00:00
#
#        discoverable                                  uuid  \
# 0              True  eec9b5ea-c25b-4e6b-b497-0f37ae1d54cb
# 1              True  9d82e728-d033-4ac3-a0f2-e1212ea4b9a5
# 2              True  bcbdd878-9644-47d9-b5ac-fbe3ffc4cc9e
# 3              True  21c1b81a-1a4f-4306-b1f6-5e7b0566c21c
# 4              True  8dc9ee12-e94b-4b6a-9a1b-50d5a81b5067
# ...             ...                                   ...
# 11841          True  148db204-feae-4f9f-b86f-1214d938498a
# 11842          True  8d091de5-b425-4d62-9806-f080e7d36ca7
# 11843          True  a170f458-e5f6-4072-bcb7-c5491601cd5c
# 11844          True  a98a6bbd-6b8b-4eb3-beaa-ab61f18d0c8a
# 11845          True  c969c950-f30e-43ac-bdcf-0b616024c1e6
#
#                                submitter_id  \
# 0      561dd02c-32ec-47d1-b90b-6f80623d23e6
# 1      561dd02c-32ec-47d1-b90b-6f80623d23e6
# 2      4ee66ac1-a107-411c-9931-387f5f31960d
# 3      561dd02c-32ec-47d1-b90b-6f80623d23e6
# 4      561dd02c-32ec-47d1-b90b-6f80623d23e6
# ...                                     ...
# 11841  a2f68af7-65d0-4225-811e-3857c7277c8e
# 11842  a2f68af7-65d0-4225-811e-3857c7277c8e
# 11843  561dd02c-32ec-47d1-b90b-6f80623d23e6
# 11844  a2f68af7-65d0-4225-811e-3857c7277c8e
# 11845  a2f68af7-65d0-4225-811e-3857c7277c8e
#
#                           owning_collection load_datetime
# 0      4dbf6a13-885d-4935-8efa-db36bc37ada8    2024-11-11
# 1      3692cf0e-5a9d-4bc4-9888-2d4438f77e87    2024-11-11
# 2      ad3071d2-2357-4804-b560-d9e9b8e86452    2024-11-11
# 3      401abba4-c10e-403d-b012-4200cf5f686a    2024-11-11
# 4      e93118e0-6757-47fe-beda-7527d087061f    2024-11-11
# ...                                     ...           ...
# 11841  10e2a8c1-a4e7-4eaa-88b5-cf392772bacd    2024-11-11
# 11842  10e2a8c1-a4e7-4eaa-88b5-cf392772bacd    2024-11-11
# 11843  e0f5446a-3a55-4371-8f5c-d6787f91ce5d    2024-11-11
# 11844  10e2a8c1-a4e7-4eaa-88b5-cf392772bacd    2024-11-11
# 11845  10e2a8c1-a4e7-4eaa-88b5-cf392772bacd    2024-11-11
#
# [11846 rows x 9 columns]
