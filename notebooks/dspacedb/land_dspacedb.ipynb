# %%
import pandas as pd

# %%
df_item = catalog.load('raw/dspacedb/item#parquet')
df_metadatavalue = catalog.load('raw/dspacedb/metadatavalue#parquet')
df_metadatafieldregistry = catalog.load('raw/dspacedb/metadatafieldregistry#parquet')
df_metadataschemaregistry = catalog.load('raw/dspacedb/metadataschemaregistry#parquet')
# Out:
# [10/17/24 14:04:11] INFO     Loading data from raw/dspacedb/item#parquet (ParquetDataset)...    ]8;id=277892;file:///home/pablo/.local/lib/python3.10/site-packages/kedro/io/data_catalog.py\data_catalog.py]8;;\:]8;id=428347;file:///home/pablo/.local/lib/python3.10/site-packages/kedro/io/data_catalog.py#539\539]8;;\
#                     INFO     Loading data from raw/dspacedb/metadatavalue#parquet               ]8;id=426950;file:///home/pablo/.local/lib/python3.10/site-packages/kedro/io/data_catalog.py\data_catalog.py]8;;\:]8;id=378488;file:///home/pablo/.local/lib/python3.10/site-packages/kedro/io/data_catalog.py#539\539]8;;\
#                              (ParquetDataset)...
# [10/17/24 14:04:12] INFO     Loading data from raw/dspacedb/metadatafieldregistry#parquet       ]8;id=529261;file:///home/pablo/.local/lib/python3.10/site-packages/kedro/io/data_catalog.py\data_catalog.py]8;;\:]8;id=379254;file:///home/pablo/.local/lib/python3.10/site-packages/kedro/io/data_catalog.py#539\539]8;;\
#                              (ParquetDataset)...
#                     INFO     Loading data from raw/dspacedb/metadataschemaregistry#parquet      ]8;id=992644;file:///home/pablo/.local/lib/python3.10/site-packages/kedro/io/data_catalog.py\data_catalog.py]8;;\:]8;id=904906;file:///home/pablo/.local/lib/python3.10/site-packages/kedro/io/data_catalog.py#539\539]8;;\
#                              (ParquetDataset)...

# %%
def land_dspacedb(item, metadatavalue, metadatafieldregistry, metadataschemaregistry):
    df_item = item
    df_metadatavalue = metadatavalue
    df_metadatafieldregistry = metadatafieldregistry
    df_metadataschemaregistry = metadataschemaregistry
    return df_item, df_metadatavalue, df_metadatafieldregistry, df_metadataschemaregistry

# %%
df_item, df_metadatavalue, df_metadatafieldregistry, df_metadataschemaregistry = land_dspacedb(df_item, df_metadatavalue, df_metadatafieldregistry, df_metadataschemaregistry)

# %%
df_item
# Out:
# <div>
# <style scoped>
#     .dataframe tbody tr th:only-of-type {
#         vertical-align: middle;
#     }
#
#     .dataframe tbody tr th {
#         vertical-align: top;
#     }
#
#     .dataframe thead th {
#         text-align: right;
#     }
# </style>
# <table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: right;">
#       <th></th>
#       <th>item_id</th>
#       <th>in_archive</th>
#       <th>withdrawn</th>
#       <th>last_modified</th>
#       <th>discoverable</th>
#       <th>uuid</th>
#       <th>submitter_id</th>
#       <th>owning_collection</th>
#       <th>load_datetime</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th>0</th>
#       <td>&lt;NA&gt;</td>
#       <td>True</td>
#       <td>False</td>
#       <td>2016-09-27 15:36:08.400000+00:00</td>
#       <td>True</td>
#       <td>eec9b5ea-c25b-4e6b-b497-0f37ae1d54cb</td>
#       <td>561dd02c-32ec-47d1-b90b-6f80623d23e6</td>
#       <td>4dbf6a13-885d-4935-8efa-db36bc37ada8</td>
#       <td>2024-10-17</td>
#     </tr>
#     <tr>
#       <th>1</th>
#       <td>&lt;NA&gt;</td>
#       <td>True</td>
#       <td>False</td>
#       <td>2016-08-16 11:39:20.309000+00:00</td>
#       <td>True</td>
#       <td>9d82e728-d033-4ac3-a0f2-e1212ea4b9a5</td>
#       <td>561dd02c-32ec-47d1-b90b-6f80623d23e6</td>
#       <td>3692cf0e-5a9d-4bc4-9888-2d4438f77e87</td>
#       <td>2024-10-17</td>
#     </tr>
#     <tr>
#       <th>2</th>
#       <td>3456</td>
#       <td>True</td>
#       <td>False</td>
#       <td>2019-10-30 13:34:33.074000+00:00</td>
#       <td>True</td>
#       <td>bcbdd878-9644-47d9-b5ac-fbe3ffc4cc9e</td>
#       <td>4ee66ac1-a107-411c-9931-387f5f31960d</td>
#       <td>ad3071d2-2357-4804-b560-d9e9b8e86452</td>
#       <td>2024-10-17</td>
#     </tr>
#     <tr>
#       <th>3</th>
#       <td>&lt;NA&gt;</td>
#       <td>True</td>
#       <td>False</td>
#       <td>2017-05-19 12:59:15.728000+00:00</td>
#       <td>True</td>
#       <td>21c1b81a-1a4f-4306-b1f6-5e7b0566c21c</td>
#       <td>561dd02c-32ec-47d1-b90b-6f80623d23e6</td>
#       <td>401abba4-c10e-403d-b012-4200cf5f686a</td>
#       <td>2024-10-17</td>
#     </tr>
#     <tr>
#       <th>4</th>
#       <td>2408</td>
#       <td>True</td>
#       <td>False</td>
#       <td>2016-07-27 23:13:20.278000+00:00</td>
#       <td>True</td>
#       <td>8dc9ee12-e94b-4b6a-9a1b-50d5a81b5067</td>
#       <td>561dd02c-32ec-47d1-b90b-6f80623d23e6</td>
#       <td>e93118e0-6757-47fe-beda-7527d087061f</td>
#       <td>2024-10-17</td>
#     </tr>
#     <tr>
#       <th>...</th>
#       <td>...</td>
#       <td>...</td>
#       <td>...</td>
#       <td>...</td>
#       <td>...</td>
#       <td>...</td>
#       <td>...</td>
#       <td>...</td>
#       <td>...</td>
#     </tr>
#     <tr>
#       <th>11848</th>
#       <td>&lt;NA&gt;</td>
#       <td>True</td>
#       <td>False</td>
#       <td>2024-02-26 20:01:25.078000+00:00</td>
#       <td>True</td>
#       <td>148db204-feae-4f9f-b86f-1214d938498a</td>
#       <td>a2f68af7-65d0-4225-811e-3857c7277c8e</td>
#       <td>10e2a8c1-a4e7-4eaa-88b5-cf392772bacd</td>
#       <td>2024-10-17</td>
#     </tr>
#     <tr>
#       <th>11849</th>
#       <td>&lt;NA&gt;</td>
#       <td>True</td>
#       <td>False</td>
#       <td>2024-02-26 20:02:11.253000+00:00</td>
#       <td>True</td>
#       <td>8d091de5-b425-4d62-9806-f080e7d36ca7</td>
#       <td>a2f68af7-65d0-4225-811e-3857c7277c8e</td>
#       <td>10e2a8c1-a4e7-4eaa-88b5-cf392772bacd</td>
#       <td>2024-10-17</td>
#     </tr>
#     <tr>
#       <th>11850</th>
#       <td>&lt;NA&gt;</td>
#       <td>True</td>
#       <td>False</td>
#       <td>2024-02-26 20:02:23.658000+00:00</td>
#       <td>True</td>
#       <td>a170f458-e5f6-4072-bcb7-c5491601cd5c</td>
#       <td>561dd02c-32ec-47d1-b90b-6f80623d23e6</td>
#       <td>e0f5446a-3a55-4371-8f5c-d6787f91ce5d</td>
#       <td>2024-10-17</td>
#     </tr>
#     <tr>
#       <th>11851</th>
#       <td>&lt;NA&gt;</td>
#       <td>True</td>
#       <td>False</td>
#       <td>2024-02-26 20:02:27.421000+00:00</td>
#       <td>True</td>
#       <td>a98a6bbd-6b8b-4eb3-beaa-ab61f18d0c8a</td>
#       <td>a2f68af7-65d0-4225-811e-3857c7277c8e</td>
#       <td>10e2a8c1-a4e7-4eaa-88b5-cf392772bacd</td>
#       <td>2024-10-17</td>
#     </tr>
#     <tr>
#       <th>11852</th>
#       <td>&lt;NA&gt;</td>
#       <td>True</td>
#       <td>False</td>
#       <td>2024-02-26 20:02:40.966000+00:00</td>
#       <td>True</td>
#       <td>c969c950-f30e-43ac-bdcf-0b616024c1e6</td>
#       <td>a2f68af7-65d0-4225-811e-3857c7277c8e</td>
#       <td>10e2a8c1-a4e7-4eaa-88b5-cf392772bacd</td>
#       <td>2024-10-17</td>
#     </tr>
#   </tbody>
# </table>
# <p>11853 rows × 9 columns</p>
# </div>
