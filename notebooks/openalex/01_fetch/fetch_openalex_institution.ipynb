# %%
import requests
import pandas as pd
# %load_ext kedro.ipython
# Out:
# The kedro.ipython extension is already loaded. To reload it, use:
#   %reload_ext kedro.ipython

# %%
institution_ror = catalog.load('params:openalex_fetch_options.institution_ror')
#env = catalog.load('params:fetch_options.env')
env = 'dev'
# Out:
# [03/06/25 09:51:12] INFO     Loading data from params:openalex_fetch_options.institution_ror    ]8;id=376574;file:///home/pablo/.local/lib/python3.10/site-packages/kedro/io/data_catalog.py\data_catalog.py]8;;\:]8;id=137977;file:///home/pablo/.local/lib/python3.10/site-packages/kedro/io/data_catalog.py#389\389]8;;\
#                              (MemoryDataset)...

# %%
env
institution_ror
# Out:
# <pre style="white-space:pre;overflow-x:auto;line-height:normal;font-family:Menlo,'DejaVu Sans Mono',consolas,'Courier New',monospace"></pre>
# 'https://ror.org/02s7sax82'

# %%
def fetch_openalex_institution(institution_ror, env):
    cursor = '*'
    base_url = 'https://api.openalex.org/institutions/ror:{}'

    url = base_url.format(institution_ror, cursor)
    api_response = requests.get(url).json()
    return api_response
    
    keys_to_delete = ['lineage','display_name_acronyms','display_name_alternatives','image_url','image_thumbnail_url','summary_stats','geo','international','associated_institutions','counts_by_year','roles','topics','topic_share','x_concepts','is_super_system','works_api_url']
    institution_dict = {key: value for key, value in api_response.items() if key not in keys_to_delete}
    df = pd.DataFrame.from_dict(institution_dict)

    return df

# %%
api_response = fetch_openalex_institution(institution_ror, env)
api_response
# Out:
# <pre style="white-space:pre;overflow-x:auto;line-height:normal;font-family:Menlo,'DejaVu Sans Mono',consolas,'Courier New',monospace"></pre>
# {
#     'id': 'https://openalex.org/I4210122970',
#     'ror': 'https://ror.org/02s7sax82',
#     'display_name': 'Comisión de Investigaciones Científicas',
#     'country_code': 'AR',
#     'type': 'government',
#     'type_id': 'https://openalex.org/institution-types/government',
#     'lineage': ['https://openalex.org/I4210122970'],
#     'homepage_url': 'https://www.cic.gba.gob.ar',
#     'image_url': None,
#     'image_thumbnail_url': None,
#     'display_name_acronyms': ['CIC'],
#     'display_name_alternatives': [],
#     'repositories': [],
#     'works_count': 3443,
#     'cited_by_count': 54399,
#     'summary_stats': {'2yr_mean_citedness': 1.4574780058651027, 'h_index': 88, 'i10_index': 1264},
#     'ids': {
#         'openalex': 'https://openalex.org/I4210122970',
#         'ror': 'https://ror.org/02s7sax82',
#         'grid': 'grid.452362.4'
#     },
#     'geo': {
#         'city': 'La Plata',
#         'geonames_city_id': '3432043',
#         'region': None,
#         'country_code': 'AR',
#         'country': 'Argentina',
#         'latitude': -34.92145,
#         'longitude': -57.95453
#     },
#     'international': {'display_name': {'en': 'Comisión de Investigaciones Científicas'}},
#     'associated_institutions': [],
#     'counts_by_year': [
#         {'year': 2025, 'works_count': 18, 'cited_by_count': 667},
#         {'year': 2024, 'works_count': 125, 'cited_by_count': 4929},
#         {'year': 2023, 'works_count': 178, 'cited_by_count': 4931},
#         {'year': 2022, 'works_count': 163, 'cited_by_count': 4929},
#         {'year': 2021, 'works_count': 213, 'cited_by_count': 4893},
#         {'year': 2020, 'works_count': 259, 'cited_by_count': 4181},
#         {'year': 2019, 'works_count': 204, 'cited_by_count': 3414},
#         {'year': 2018, 'works_count': 211, 'cited_by_count': 2870},
#         {'year': 2017, 'works_count': 176, 'cited_by_count': 2466},
#         {'year': 2016, 'works_count': 148, 'cited_by_count': 2309},
#         {'year': 2015, 'works_count': 135, 'cited_by_count': 2261},
#         {'year': 2014, 'works_count': 107, 'cited_by_count': 2038},
#         {'year': 2013, 'works_count': 130, 'cited_by_count': 1843},
#         {'year': 2012, 'works_count': 108, 'cited_by_count': 1633}
#     ],
#     'roles': [
#         {'role': 'institution', 'id': 'https://openalex.org/I4210122970', 'works_count': 3443},
#         {'role': 'funder', 'id': 'https://openalex.org/F4320335124', 'works_count': 280}
#     ],
#     'topics': [
#         {
#             'id': 'https://openalex.org/T10825',
#             'display_name': 'Plant Pathogens and Fungal Diseases',
#             'count': 100,
#             'subfield': {'id': 'https://openalex.org/subfields/1307', 'display_name': 'Cell Biology'},
#             'field': {
#                 'id': 'https://openalex.org/fields/13',
#                 'display_name': 'Biochemistry, Genetics and Molecular Biology'
#             },
#             'domain': {'id': 'https://openalex.org/domains/1', 'display_name': 'Life Sciences'}
#         },
#         {
#             'id': 'https://openalex.org/T10520',
#             'display_name': 'Mycotoxins in Agriculture and Food',
#             'count': 83,
#             'subfield': {
#                 'id': 'https://openalex.org/subfields/1110',
#                 'display_name': 'Plant Science'
#             },
#             'field': {
#                 'id': 'https://openalex.org/fields/11',
#                 'display_name': 'Agricultural and Biological Sciences'
#             },
#             'domain': {'id': 'https://openalex.org/domains/1', 'display_name': 'Life Sciences'}
#         },
#         {
#             'id': 'https://openalex.org/T11641',
#             'display_name': 'Insect and Pesticide Research',
#             'count': 80,
#             'subfield': {
#                 'id': 'https://openalex.org/subfields/1109',
#                 'display_name': 'Insect Science'
#             },
#             'field': {
#                 'id': 'https://openalex.org/fields/11',
#                 'display_name': 'Agricultural and Biological Sciences'
#             },
#             'domain': {'id': 'https://openalex.org/domains/1', 'display_name': 'Life Sciences'}
#         },
#         {
#             'id': 'https://openalex.org/T10487',
#             'display_name': 'Plant and animal studies',
#             'count': 73,
#             'subfield': {
#                 'id': 'https://openalex.org/subfields/1105',
#                 'display_name': 'Ecology, Evolution, Behavior and Systematics'
#             },
#             'field': {
#                 'id': 'https://openalex.org/fields/11',
#                 'display_name': 'Agricultural and Biological Sciences'
#             },
#             'domain': {'id': 'https://openalex.org/domains/1', 'display_name': 'Life Sciences'}
#         },
#         {
#             'id': 'https://openalex.org/T10333',
#             'display_name': 'Meat and Animal Product Quality',
#             'count': 70,
#             'subfield': {
#                 'id': 'https://openalex.org/subfields/1103',
#                 'display_name': 'Animal Science and Zoology'
#             },
#             'field': {
#                 'id': 'https://openalex.org/fields/11',
#                 'display_name': 'Agricultural and Biological Sciences'
#             },
#             'domain': {'id': 'https://openalex.org/domains/1', 'display_name': 'Life Sciences'}
#         },
#         {
#             'id': 'https://openalex.org/T10302',
#             'display_name': 'Fish Ecology and Management Studies',
#             'count': 70,
#             'subfield': {
#                 'id': 'https://openalex.org/subfields/2309',
#                 'display_name': 'Nature and Landscape Conservation'
#             },
#             'field': {
#                 'id': 'https://openalex.org/fields/23',
#                 'display_name': 'Environmental Science'
#             },
#             'domain': {'id': 'https://openalex.org/domains/3', 'display_name': 'Physical Sciences'}
#         },
#         {
#             'id': 'https://openalex.org/T10230',
#             'display_name': 'Marine and fisheries research',
#             'count': 67,
#             'subfield': {
#                 'id': 'https://openalex.org/subfields/2306',
#                 'display_name': 'Global and Planetary Change'
#             },
#             'field': {
#                 'id': 'https://openalex.org/fields/23',
#                 'display_name': 'Environmental Science'
#             },
#             'domain': {'id': 'https://openalex.org/domains/3', 'display_name': 'Physical Sciences'}
#         },
#         {
#             'id': 'https://openalex.org/T12014',
#             'display_name': 'Fish biology, ecology, and behavior',
#             'count': 62,
#             'subfield': {
#                 'id': 'https://openalex.org/subfields/2309',
#                 'display_name': 'Nature and Landscape Conservation'
#             },
#             'field': {
#                 'id': 'https://openalex.org/fields/23',
#                 'display_name': 'Environmental Science'
#             },
#             'domain': {'id': 'https://openalex.org/domains/3', 'display_name': 'Physical Sciences'}
#         },
#         {
#             'id': 'https://openalex.org/T10005',
#             'display_name': 'Ecology and Vegetation Dynamics Studies',
#             'count': 56,
#             'subfield': {
#                 'id': 'https://openalex.org/subfields/2309',
#                 'display_name': 'Nature and Landscape Conservation'
#             },
#             'field': {
#                 'id': 'https://openalex.org/fields/23',
#                 'display_name': 'Environmental Science'
#             },
#             'domain': {'id': 'https://openalex.org/domains/3', 'display_name': 'Physical Sciences'}
#         },
#         {
#             'id': 'https://openalex.org/T10004',
#             'display_name': 'Soil Carbon and Nitrogen Dynamics',
#             'count': 55,
#             'subfield': {'id': 'https://openalex.org/subfields/1111', 'display_name': 'Soil Science'},
#             'field': {
#                 'id': 'https://openalex.org/fields/11',
#                 'display_name': 'Agricultural and Biological Sciences'
#             },
#             'domain': {'id': 'https://openalex.org/domains/1', 'display_name': 'Life Sciences'}
#         },
#         {
#             'id': 'https://openalex.org/T10447',
#             'display_name': 'Environmental Toxicology and Ecotoxicology',
#             'count': 55,
#             'subfield': {
#                 'id': 'https://openalex.org/subfields/2307',
#                 'display_name': 'Health, Toxicology and Mutagenesis'
#             },
#             'field': {
#                 'id': 'https://openalex.org/fields/23',
#                 'display_name': 'Environmental Science'
#             },
#             'domain': {'id': 'https://openalex.org/domains/3', 'display_name': 'Physical Sciences'}
#         },
#         {
#             'id': 'https://openalex.org/T12579',
#             'display_name': 'Muon and positron interactions and applications',
#             'count': 53,
#             'subfield': {
#                 'id': 'https://openalex.org/subfields/2211',
#                 'display_name': 'Mechanics of Materials'
#             },
#             'field': {'id': 'https://openalex.org/fields/22', 'display_name': 'Engineering'},
#             'domain': {'id': 'https://openalex.org/domains/3', 'display_name': 'Physical Sciences'}
#         },
#         {
#             'id': 'https://openalex.org/T10266',
#             'display_name': 'Plant Water Relations and Carbon Dynamics',
#             'count': 50,
#             'subfield': {
#                 'id': 'https://openalex.org/subfields/2306',
#                 'display_name': 'Global and Planetary Change'
#             },
#             'field': {
#                 'id': 'https://openalex.org/fields/23',
#                 'display_name': 'Environmental Science'
#             },
#             'domain': {'id': 'https://openalex.org/domains/3', 'display_name': 'Physical Sciences'}
#         },
#         {
#             'id': 'https://openalex.org/T11387',
#             'display_name': 'Ichthyology and Marine Biology',
#             'count': 50,
#             'subfield': {
#                 'id': 'https://openalex.org/subfields/2309',
#                 'display_name': 'Nature and Landscape Conservation'
#             },
#             'field': {
#                 'id': 'https://openalex.org/fields/23',
#                 'display_name': 'Environmental Science'
#             },
#             'domain': {'id': 'https://openalex.org/domains/3', 'display_name': 'Physical Sciences'}
#         },
#         {
#             'id': 'https://openalex.org/T11354',
#             'display_name': 'Evolution and Paleontology Studies',
#             'count': 47,
#             'subfield': {'id': 'https://openalex.org/subfields/1911', 'display_name': 'Paleontology'},
#             'field': {
#                 'id': 'https://openalex.org/fields/19',
#                 'display_name': 'Earth and Planetary Sciences'
#             },
#             'domain': {'id': 'https://openalex.org/domains/3', 'display_name': 'Physical Sciences'}
#         },
#         {
#             'id': 'https://openalex.org/T12319',
#             'display_name': 'Fish Biology and Ecology Studies',
#             'count': 47,
#             'subfield': {
#                 'id': 'https://openalex.org/subfields/1104',
#                 'display_name': 'Aquatic Science'
#             },
#             'field': {
#                 'id': 'https://openalex.org/fields/11',
#                 'display_name': 'Agricultural and Biological Sciences'
#             },
#             'domain': {'id': 'https://openalex.org/domains/1', 'display_name': 'Life Sciences'}
#         },
#         {
#             'id': 'https://openalex.org/T10135',
#             'display_name': 'Insect-Plant Interactions and Control',
#             'count': 47,
#             'subfield': {
#                 'id': 'https://openalex.org/subfields/1109',
#                 'display_name': 'Insect Science'
#             },
#             'field': {
#                 'id': 'https://openalex.org/fields/11',
#                 'display_name': 'Agricultural and Biological Sciences'
#             },
#             'domain': {'id': 'https://openalex.org/domains/1', 'display_name': 'Life Sciences'}
#         },
#         {
#             'id': 'https://openalex.org/T11436',
#             'display_name': 'Entomopathogenic Microorganisms in Pest Control',
#             'count': 46,
#             'subfield': {
#                 'id': 'https://openalex.org/subfields/1109',
#                 'display_name': 'Insect Science'
#             },
#             'field': {
#                 'id': 'https://openalex.org/fields/11',
#                 'display_name': 'Agricultural and Biological Sciences'
#             },
#             'domain': {'id': 'https://openalex.org/domains/1', 'display_name': 'Life Sciences'}
#         },
#         {
#             'id': 'https://openalex.org/T10702',
#             'display_name': 'Insect and Arachnid Ecology and Behavior',
#             'count': 45,
#             'subfield': {'id': 'https://openalex.org/subfields/1311', 'display_name': 'Genetics'},
#             'field': {
#                 'id': 'https://openalex.org/fields/13',
#                 'display_name': 'Biochemistry, Genetics and Molecular Biology'
#             },
#             'domain': {'id': 'https://openalex.org/domains/1', 'display_name': 'Life Sciences'}
#         },
#         {
#             'id': 'https://openalex.org/T10451',
#             'display_name': 'Mycorrhizal Fungi and Plant Interactions',
#             'count': 42,
#             'subfield': {
#                 'id': 'https://openalex.org/subfields/1110',
#                 'display_name': 'Plant Science'
#             },
#             'field': {
#                 'id': 'https://openalex.org/fields/11',
#                 'display_name': 'Agricultural and Biological Sciences'
#             },
#             'domain': {'id': 'https://openalex.org/domains/1', 'display_name': 'Life Sciences'}
#         },
#         {
#             'id': 'https://openalex.org/T10670',
#             'display_name': 'Aluminum Alloy Microstructure Properties',
#             'count': 42,
#             'subfield': {
#                 'id': 'https://openalex.org/subfields/2202',
#                 'display_name': 'Aerospace Engineering'
#             },
#             'field': {'id': 'https://openalex.org/fields/22', 'display_name': 'Engineering'},
#             'domain': {'id': 'https://openalex.org/domains/3', 'display_name': 'Physical Sciences'}
#         },
#         {
#             'id': 'https://openalex.org/T10017',
#             'display_name': 'Geology and Paleoclimatology Research',
#             'count': 41,
#             'subfield': {
#                 'id': 'https://openalex.org/subfields/1902',
#                 'display_name': 'Atmospheric Science'
#             },
#             'field': {
#                 'id': 'https://openalex.org/fields/19',
#                 'display_name': 'Earth and Planetary Sciences'
#             },
#             'domain': {'id': 'https://openalex.org/domains/3', 'display_name': 'Physical Sciences'}
#         },
#         {
#             'id': 'https://openalex.org/T12114',
#             'display_name': 'Sensory Analysis and Statistical Methods',
#             'count': 40,
#             'subfield': {'id': 'https://openalex.org/subfields/1106', 'display_name': 'Food Science'},
#             'field': {
#                 'id': 'https://openalex.org/fields/11',
#                 'display_name': 'Agricultural and Biological Sciences'
#             },
#             'domain': {'id': 'https://openalex.org/domains/1', 'display_name': 'Life Sciences'}
#         },
#         {
#             'id': 'https://openalex.org/T10650',
#             'display_name': 'Food Drying and Modeling',
#             'count': 39,
#             'subfield': {'id': 'https://openalex.org/subfields/1106', 'display_name': 'Food Science'},
#             'field': {
#                 'id': 'https://openalex.org/fields/11',
#                 'display_name': 'Agricultural and Biological Sciences'
#             },
#             'domain': {'id': 'https://openalex.org/domains/1', 'display_name': 'Life Sciences'}
#         },
#         {
#             'id': 'https://openalex.org/T11561',
#             'display_name': 'Protein Hydrolysis and Bioactive Peptides',
#             'count': 38,
#             'subfield': {
#                 'id': 'https://openalex.org/subfields/1312',
#                 'display_name': 'Molecular Biology'
#             },
#             'field': {
#                 'id': 'https://openalex.org/fields/13',
#                 'display_name': 'Biochemistry, Genetics and Molecular Biology'
#             },
#             'domain': {'id': 'https://openalex.org/domains/1', 'display_name': 'Life Sciences'}
#         }
#     ],
#     'topic_share': [
#         {
#             'id': 'https://openalex.org/T10650',
#             'display_name': 'Food Drying and Modeling',
#             'value': 0.001021,
#             'subfield': {'id': 'https://openalex.org/subfields/1106', 'display_name': 'Food Science'},
#             'field': {
#                 'id': 'https://openalex.org/fields/11',
#                 'display_name': 'Agricultural and Biological Sciences'
#             },
#             'domain': {'id': 'https://openalex.org/domains/1', 'display_name': 'Life Sciences'}
#         },
#         {
#             'id': 'https://openalex.org/T12579',
#             'display_name': 'Muon and positron interactions and applications',
#             'value': 0.0007706,
#             'subfield': {
#                 'id': 'https://openalex.org/subfields/2211',
#                 'display_name': 'Mechanics of Materials'
#             },
#             'field': {'id': 'https://openalex.org/fields/22', 'display_name': 'Engineering'},
#             'domain': {'id': 'https://openalex.org/domains/3', 'display_name': 'Physical Sciences'}
#         },
#         {
#             'id': 'https://openalex.org/T10520',
#             'display_name': 'Mycotoxins in Agriculture and Food',
#             'value': 0.0006926,
#             'subfield': {
#                 'id': 'https://openalex.org/subfields/1110',
#                 'display_name': 'Plant Science'
#             },
#             'field': {
#                 'id': 'https://openalex.org/fields/11',
#                 'display_name': 'Agricultural and Biological Sciences'
#             },
#             'domain': {'id': 'https://openalex.org/domains/1', 'display_name': 'Life Sciences'}
#         },
#         {
#             'id': 'https://openalex.org/T13503',
#             'display_name': 'Gender, Health, and Social Inequality',
#             'value': 0.0006638,
#             'subfield': {
#                 'id': 'https://openalex.org/subfields/3312',
#                 'display_name': 'Sociology and Political Science'
#             },
#             'field': {'id': 'https://openalex.org/fields/33', 'display_name': 'Social Sciences'},
#             'domain': {'id': 'https://openalex.org/domains/2', 'display_name': 'Social Sciences'}
#         },
#         {
#             'id': 'https://openalex.org/T12048',
#             'display_name': 'Microencapsulation and Drying Processes',
#             'value': 0.0006242,
#             'subfield': {'id': 'https://openalex.org/subfields/1106', 'display_name': 'Food Science'},
#             'field': {
#                 'id': 'https://openalex.org/fields/11',
#                 'display_name': 'Agricultural and Biological Sciences'
#             },
#             'domain': {'id': 'https://openalex.org/domains/1', 'display_name': 'Life Sciences'}
#         },
#         {
#             'id': 'https://openalex.org/T12742',
#             'display_name': 'Sunflower and Safflower Cultivation',
#             'value': 0.0006115,
#             'subfield': {
#                 'id': 'https://openalex.org/subfields/1110',
#                 'display_name': 'Plant Science'
#             },
#             'field': {
#                 'id': 'https://openalex.org/fields/11',
#                 'display_name': 'Agricultural and Biological Sciences'
#             },
#             'domain': {'id': 'https://openalex.org/domains/1', 'display_name': 'Life Sciences'}
#         },
#         {
#             'id': 'https://openalex.org/T12114',
#             'display_name': 'Sensory Analysis and Statistical Methods',
#             'value': 0.0005636,
#             'subfield': {'id': 'https://openalex.org/subfields/1106', 'display_name': 'Food Science'},
#             'field': {
#                 'id': 'https://openalex.org/fields/11',
#                 'display_name': 'Agricultural and Biological Sciences'
#             },
#             'domain': {'id': 'https://openalex.org/domains/1', 'display_name': 'Life Sciences'}
#         },
#         {
#             'id': 'https://openalex.org/T14422',
#             'display_name': 'Sociology, Governance, and Technology',
#             'value': 0.0004848,
#             'subfield': {
#                 'id': 'https://openalex.org/subfields/3312',
#                 'display_name': 'Sociology and Political Science'
#             },
#             'field': {'id': 'https://openalex.org/fields/33', 'display_name': 'Social Sciences'},
#             'domain': {'id': 'https://openalex.org/domains/2', 'display_name': 'Social Sciences'}
#         },
#         {
#             'id': 'https://openalex.org/T12261',
#             'display_name': 'Statistical Mechanics and Entropy',
#             'value': 0.0004836,
#             'subfield': {
#                 'id': 'https://openalex.org/subfields/3109',
#                 'display_name': 'Statistical and Nonlinear Physics'
#             },
#             'field': {
#                 'id': 'https://openalex.org/fields/31',
#                 'display_name': 'Physics and Astronomy'
#             },
#             'domain': {'id': 'https://openalex.org/domains/3', 'display_name': 'Physical Sciences'}
#         },
#         {
#             'id': 'https://openalex.org/T11887',
#             'display_name': 'Quasicrystal Structures and Properties',
#             'value': 0.0004772,
#             'subfield': {
#                 'id': 'https://openalex.org/subfields/2505',
#                 'display_name': 'Materials Chemistry'
#             },
#             'field': {'id': 'https://openalex.org/fields/25', 'display_name': 'Materials Science'},
#             'domain': {'id': 'https://openalex.org/domains/3', 'display_name': 'Physical Sciences'}
#         },
#         {
#             'id': 'https://openalex.org/T13390',
#             'display_name': 'Cultural and Social Dynamics',
#             'value': 0.0004771,
#             'subfield': {
#                 'id': 'https://openalex.org/subfields/1110',
#                 'display_name': 'Plant Science'
#             },
#             'field': {
#                 'id': 'https://openalex.org/fields/11',
#                 'display_name': 'Agricultural and Biological Sciences'
#             },
#             'domain': {'id': 'https://openalex.org/domains/1', 'display_name': 'Life Sciences'}
#         },
#         {
#             'id': 'https://openalex.org/T14253',
#             'display_name': 'Latin American social science',
#             'value': 0.0004762,
#             'subfield': {
#                 'id': 'https://openalex.org/subfields/3312',
#                 'display_name': 'Sociology and Political Science'
#             },
#             'field': {'id': 'https://openalex.org/fields/33', 'display_name': 'Social Sciences'},
#             'domain': {'id': 'https://openalex.org/domains/2', 'display_name': 'Social Sciences'}
#         },
#         {
#             'id': 'https://openalex.org/T11436',
#             'display_name': 'Entomopathogenic Microorganisms in Pest Control',
#             'value': 0.0004729,
#             'subfield': {
#                 'id': 'https://openalex.org/subfields/1109',
#                 'display_name': 'Insect Science'
#             },
#             'field': {
#                 'id': 'https://openalex.org/fields/11',
#                 'display_name': 'Agricultural and Biological Sciences'
#             },
#             'domain': {'id': 'https://openalex.org/domains/1', 'display_name': 'Life Sciences'}
#         },
#         {
#             'id': 'https://openalex.org/T12014',
#             'display_name': 'Fish biology, ecology, and behavior',
#             'value': 0.00047,
#             'subfield': {
#                 'id': 'https://openalex.org/subfields/2309',
#                 'display_name': 'Nature and Landscape Conservation'
#             },
#             'field': {
#                 'id': 'https://openalex.org/fields/23',
#                 'display_name': 'Environmental Science'
#             },
#             'domain': {'id': 'https://openalex.org/domains/3', 'display_name': 'Physical Sciences'}
#         },
#         {
#             'id': 'https://openalex.org/T11387',
#             'display_name': 'Ichthyology and Marine Biology',
#             'value': 0.0004413,
#             'subfield': {
#                 'id': 'https://openalex.org/subfields/2309',
#                 'display_name': 'Nature and Landscape Conservation'
#             },
#             'field': {
#                 'id': 'https://openalex.org/fields/23',
#                 'display_name': 'Environmental Science'
#             },
#             'domain': {'id': 'https://openalex.org/domains/3', 'display_name': 'Physical Sciences'}
#         },
#         {
#             'id': 'https://openalex.org/T12609',
#             'display_name': 'Latin American socio-political dynamics',
#             'value': 0.0004353,
#             'subfield': {
#                 'id': 'https://openalex.org/subfields/3312',
#                 'display_name': 'Sociology and Political Science'
#             },
#             'field': {'id': 'https://openalex.org/fields/33', 'display_name': 'Social Sciences'},
#             'domain': {'id': 'https://openalex.org/domains/2', 'display_name': 'Social Sciences'}
#         },
#         {
#             'id': 'https://openalex.org/T12134',
#             'display_name': 'Insect symbiosis and bacterial influences',
#             'value': 0.0003803,
#             'subfield': {
#                 'id': 'https://openalex.org/subfields/1109',
#                 'display_name': 'Insect Science'
#             },
#             'field': {
#                 'id': 'https://openalex.org/fields/11',
#                 'display_name': 'Agricultural and Biological Sciences'
#             },
#             'domain': {'id': 'https://openalex.org/domains/1', 'display_name': 'Life Sciences'}
#         },
#         {
#             'id': 'https://openalex.org/T13269',
#             'display_name': 'Orthoptera Research and Taxonomy',
#             'value': 0.000353,
#             'subfield': {
#                 'id': 'https://openalex.org/subfields/1105',
#                 'display_name': 'Ecology, Evolution, Behavior and Systematics'
#             },
#             'field': {
#                 'id': 'https://openalex.org/fields/11',
#                 'display_name': 'Agricultural and Biological Sciences'
#             },
#             'domain': {'id': 'https://openalex.org/domains/1', 'display_name': 'Life Sciences'}
#         },
#         {
#             'id': 'https://openalex.org/T13009',
#             'display_name': 'Agroforestry and silvopastoral systems',
#             'value': 0.0003345,
#             'subfield': {'id': 'https://openalex.org/subfields/1107', 'display_name': 'Forestry'},
#             'field': {
#                 'id': 'https://openalex.org/fields/11',
#                 'display_name': 'Agricultural and Biological Sciences'
#             },
#             'domain': {'id': 'https://openalex.org/domains/1', 'display_name': 'Life Sciences'}
#         },
#         {
#             'id': 'https://openalex.org/T10447',
#             'display_name': 'Environmental Toxicology and Ecotoxicology',
#             'value': 0.0003249,
#             'subfield': {
#                 'id': 'https://openalex.org/subfields/2307',
#                 'display_name': 'Health, Toxicology and Mutagenesis'
#             },
#             'field': {
#                 'id': 'https://openalex.org/fields/23',
#                 'display_name': 'Environmental Science'
#             },
#             'domain': {'id': 'https://openalex.org/domains/3', 'display_name': 'Physical Sciences'}
#         },
#         {
#             'id': 'https://openalex.org/T14100',
#             'display_name': 'Scientific Research and Technology',
#             'value': 0.0003097,
#             'subfield': {
#                 'id': 'https://openalex.org/subfields/1706',
#                 'display_name': 'Computer Science Applications'
#             },
#             'field': {'id': 'https://openalex.org/fields/17', 'display_name': 'Computer Science'},
#             'domain': {'id': 'https://openalex.org/domains/3', 'display_name': 'Physical Sciences'}
#         },
#         {
#             'id': 'https://openalex.org/T12036',
#             'display_name': 'Argentine historical studies',
#             'value': 0.0003036,
#             'subfield': {
#                 'id': 'https://openalex.org/subfields/3316',
#                 'display_name': 'Cultural Studies'
#             },
#             'field': {'id': 'https://openalex.org/fields/33', 'display_name': 'Social Sciences'},
#             'domain': {'id': 'https://openalex.org/domains/2', 'display_name': 'Social Sciences'}
#         },
#         {
#             'id': 'https://openalex.org/T12359',
#             'display_name': 'Fern and Epiphyte Biology',
#             'value': 0.0003032,
#             'subfield': {
#                 'id': 'https://openalex.org/subfields/1105',
#                 'display_name': 'Ecology, Evolution, Behavior and Systematics'
#             },
#             'field': {
#                 'id': 'https://openalex.org/fields/11',
#                 'display_name': 'Agricultural and Biological Sciences'
#             },
#             'domain': {'id': 'https://openalex.org/domains/1', 'display_name': 'Life Sciences'}
#         },
#         {
#             'id': 'https://openalex.org/T11804',
#             'display_name': 'Quantum many-body systems',
#             'value': 0.0002926,
#             'subfield': {
#                 'id': 'https://openalex.org/subfields/3107',
#                 'display_name': 'Atomic and Molecular Physics, and Optics'
#             },
#             'field': {
#                 'id': 'https://openalex.org/fields/31',
#                 'display_name': 'Physics and Astronomy'
#             },
#             'domain': {'id': 'https://openalex.org/domains/3', 'display_name': 'Physical Sciences'}
#         },
#         {
#             'id': 'https://openalex.org/T10324',
#             'display_name': 'Microbial bioremediation and biosurfactants',
#             'value': 0.0002906,
#             'subfield': {'id': 'https://openalex.org/subfields/2310', 'display_name': 'Pollution'},
#             'field': {
#                 'id': 'https://openalex.org/fields/23',
#                 'display_name': 'Environmental Science'
#             },
#             'domain': {'id': 'https://openalex.org/domains/3', 'display_name': 'Physical Sciences'}
#         }
#     ],
#     'x_concepts': [
#         {
#             'id': 'https://openalex.org/C86803240',
#             'wikidata': 'https://www.wikidata.org/wiki/Q420',
#             'display_name': 'Biology',
#             'level': 0,
#             'score': 66.7
#         },
#         {
#             'id': 'https://openalex.org/C185592680',
#             'wikidata': 'https://www.wikidata.org/wiki/Q2329',
#             'display_name': 'Chemistry',
#             'level': 0,
#             'score': 48.9
#         },
#         {
#             'id': 'https://openalex.org/C121332964',
#             'wikidata': 'https://www.wikidata.org/wiki/Q413',
#             'display_name': 'Physics',
#             'level': 0,
#             'score': 40.6
#         },
#         {
#             'id': 'https://openalex.org/C18903297',
#             'wikidata': 'https://www.wikidata.org/wiki/Q7150',
#             'display_name': 'Ecology',
#             'level': 1,
#             'score': 35.9
#         },
#         {
#             'id': 'https://openalex.org/C127313418',
#             'wikidata': 'https://www.wikidata.org/wiki/Q1069',
#             'display_name': 'Geology',
#             'level': 0,
#             'score': 34.7
#         },
#         {
#             'id': 'https://openalex.org/C71924100',
#             'wikidata': 'https://www.wikidata.org/wiki/Q11190',
#             'display_name': 'Medicine',
#             'level': 0,
#             'score': 34.2
#         },
#         {
#             'id': 'https://openalex.org/C178790620',
#             'wikidata': 'https://www.wikidata.org/wiki/Q11351',
#             'display_name': 'Organic chemistry',
#             'level': 1,
#             'score': 30.0
#         },
#         {
#             'id': 'https://openalex.org/C205649164',
#             'wikidata': 'https://www.wikidata.org/wiki/Q1071',
#             'display_name': 'Geography',
#             'level': 0,
#             'score': 28.6
#         },
#         {
#             'id': 'https://openalex.org/C127413603',
#             'wikidata': 'https://www.wikidata.org/wiki/Q11023',
#             'display_name': 'Engineering',
#             'level': 0,
#             'score': 27.8
#         },
#         {
#             'id': 'https://openalex.org/C55493867',
#             'wikidata': 'https://www.wikidata.org/wiki/Q7094',
#             'display_name': 'Biochemistry',
#             'level': 1,
#             'score': 27.3
#         },
#         {
#             'id': 'https://openalex.org/C54355233',
#             'wikidata': 'https://www.wikidata.org/wiki/Q7162',
#             'display_name': 'Genetics',
#             'level': 1,
#             'score': 25.6
#         },
#         {
#             'id': 'https://openalex.org/C138885662',
#             'wikidata': 'https://www.wikidata.org/wiki/Q5891',
#             'display_name': 'Philosophy',
#             'level': 0,
#             'score': 24.8
#         },
#         {
#             'id': 'https://openalex.org/C59822182',
#             'wikidata': 'https://www.wikidata.org/wiki/Q441',
#             'display_name': 'Botany',
#             'level': 1,
#             'score': 24.7
#         },
#         {
#             'id': 'https://openalex.org/C41008148',
#             'wikidata': 'https://www.wikidata.org/wiki/Q21198',
#             'display_name': 'Computer science',
#             'level': 0,
#             'score': 24.5
#         },
#         {
#             'id': 'https://openalex.org/C151730666',
#             'wikidata': 'https://www.wikidata.org/wiki/Q7205',
#             'display_name': 'Paleontology',
#             'level': 1,
#             'score': 24.1
#         },
#         {
#             'id': 'https://openalex.org/C192562407',
#             'wikidata': 'https://www.wikidata.org/wiki/Q228736',
#             'display_name': 'Materials science',
#             'level': 0,
#             'score': 22.9
#         },
#         {
#             'id': 'https://openalex.org/C62520636',
#             'wikidata': 'https://www.wikidata.org/wiki/Q944',
#             'display_name': 'Quantum mechanics',
#             'level': 1,
#             'score': 22.7
#         },
#         {
#             'id': 'https://openalex.org/C142362112',
#             'wikidata': 'https://www.wikidata.org/wiki/Q735',
#             'display_name': 'Art',
#             'level': 0,
#             'score': 21.6
#         },
#         {
#             'id': 'https://openalex.org/C33923547',
#             'wikidata': 'https://www.wikidata.org/wiki/Q395',
#             'display_name': 'Mathematics',
#             'level': 0,
#             'score': 20.6
#         }
#     ],
#     'is_super_system': False,
#     'works_api_url': 'https://api.openalex.org/works?filter=institutions.id:I4210122970',
#     'updated_date': '2025-03-02T10:37:09.780588',
#     'created_date': '2022-02-02'
# }

# %%
keys_to_delete = ['lineage','display_name_acronyms','display_name_alternatives','image_url','image_thumbnail_url','summary_stats','geo','international','associated_institutions','counts_by_year','roles','topics','topic_share','x_concepts','is_super_system','works_api_url']
institution_dict = {key: value for key, value in api_response.items() if key not in keys_to_delete}
pd.DataFrame.from_dict(institution_dict)
# Out:
# ╭─────────────────────────────── Traceback (most recent call last) ────────────────────────────────╮
# │ in <module>:3                                                                                    │
# │                                                                                                  │
# │   1 keys_to_delete = ['image_url','image_thumbnail_url','summary_stats','geo','international     │
# │   2 institution_dict = {key: value for key, value in api_response.items() if key not in keys     │
# │ ❱ 3 pd.DataFrame.from_dict(institution_dict)                                                     │
# │   4                                                                                              │
# │                                                                                                  │
# │ /home/pablo/.local/lib/python3.10/site-packages/pandas/core/frame.py:1917 in from_dict           │
# │                                                                                                  │
# │    1914 │   │   │   )                                                                            │
# │    1915 │   │                                                                                    │
# │    1916 │   │   if orient != "tight":                                                            │
# │ ❱  1917 │   │   │   return cls(data, index=index, columns=columns, dtype=dtype)                  │
# │    1918 │   │   else:                                                                            │
# │    1919 │   │   │   realdata = data["data"]                                                      │
# │    1920                                                                                          │
# │                                                                                                  │
# │ /home/pablo/.local/lib/python3.10/site-packages/pandas/core/frame.py:778 in __init__             │
# │                                                                                                  │
# │     775 │   │                                                                                    │
# │     776 │   │   elif isinstance(data, dict):                                                     │
# │     777 │   │   │   # GH#38939 de facto copy defaults to False only in non-dict cases            │
# │ ❱   778 │   │   │   mgr = dict_to_mgr(data, index, columns, dtype=dtype, copy=copy, typ=manager) │
# │     779 │   │   elif isinstance(data, ma.MaskedArray):                                           │
# │     780 │   │   │   from numpy.ma import mrecords                                                │
# │     781                                                                                          │
# │                                                                                                  │
# │ /home/pablo/.local/lib/python3.10/site-packages/pandas/core/internals/construction.py:503 in     │
# │ dict_to_mgr                                                                                      │
# │                                                                                                  │
# │    500 │   │   │   # dtype check to exclude e.g. range objects, scalars                          │
# │    501 │   │   │   arrays = [x.copy() if hasattr(x, "dtype") else x for x in arrays]             │
# │    502 │                                                                                         │
# │ ❱  503 │   return arrays_to_mgr(arrays, columns, index, dtype=dtype, typ=typ, consolidate=copy)  │
# │    504                                                                                           │
# │    505                                                                                           │
# │    506 def nested_data_to_arrays(                                                                │
# │                                                                                                  │
# │ /home/pablo/.local/lib/python3.10/site-packages/pandas/core/internals/construction.py:114 in     │
# │ arrays_to_mgr                                                                                    │
# │                                                                                                  │
# │    111 │   if verify_integrity:                                                                  │
# │    112 │   │   # figure out the index, if necessary                                              │
# │    113 │   │   if index is None:                                                                 │
# │ ❱  114 │   │   │   index = _extract_index(arrays)                                                │
# │    115 │   │   else:                                                                             │
# │    116 │   │   │   index = ensure_index(index)                                                   │
# │    117                                                                                           │
# │                                                                                                  │
# │ /home/pablo/.local/lib/python3.10/site-packages/pandas/core/internals/construction.py:677 in     │
# │ _extract_index                                                                                   │
# │                                                                                                  │
# │    674 │   if have_raw_arrays:                                                                   │
# │    675 │   │   lengths = list(set(raw_lengths))                                                  │
# │    676 │   │   if len(lengths) > 1:                                                              │
# │ ❱  677 │   │   │   raise ValueError("All arrays must be of the same length")                     │
# │    678 │   │                                                                                     │
# │    679 │   │   if have_dicts:                                                                    │
# │    680 │   │   │   raise ValueError(                                                             │
# ╰──────────────────────────────────────────────────────────────────────────────────────────────────╯
# ValueError: All arrays must be of the same length

# %%
keys_to_delete = ['lineage','display_name_acronyms','display_name_alternatives','image_url','image_thumbnail_url','summary_stats','geo','international','associated_institutions','counts_by_year','roles','topics','topic_share','x_concepts','is_super_system','works_api_url']
institution_dict = {key: value for key, value in api_response.items() if key not in keys_to_delete}
pd.DataFrame.from_dict(institution_dict)
# Out:
# ╭─────────────────────────────── Traceback (most recent call last) ────────────────────────────────╮
# │ in <module>:3                                                                                    │
# │                                                                                                  │
# │   1 keys_to_delete = ['lineage','display_name_acronyms','display_name_alternatives','image_u     │
# │   2 institution_dict = {key: value for key, value in api_response.items() if key not in keys     │
# │ ❱ 3 pd.DataFrame.from_dict(institution_dict)                                                     │
# │   4                                                                                              │
# │                                                                                                  │
# │ /home/pablo/.local/lib/python3.10/site-packages/pandas/core/frame.py:1917 in from_dict           │
# │                                                                                                  │
# │    1914 │   │   │   )                                                                            │
# │    1915 │   │                                                                                    │
# │    1916 │   │   if orient != "tight":                                                            │
# │ ❱  1917 │   │   │   return cls(data, index=index, columns=columns, dtype=dtype)                  │
# │    1918 │   │   else:                                                                            │
# │    1919 │   │   │   realdata = data["data"]                                                      │
# │    1920                                                                                          │
# │                                                                                                  │
# │ /home/pablo/.local/lib/python3.10/site-packages/pandas/core/frame.py:778 in __init__             │
# │                                                                                                  │
# │     775 │   │                                                                                    │
# │     776 │   │   elif isinstance(data, dict):                                                     │
# │     777 │   │   │   # GH#38939 de facto copy defaults to False only in non-dict cases            │
# │ ❱   778 │   │   │   mgr = dict_to_mgr(data, index, columns, dtype=dtype, copy=copy, typ=manager) │
# │     779 │   │   elif isinstance(data, ma.MaskedArray):                                           │
# │     780 │   │   │   from numpy.ma import mrecords                                                │
# │     781                                                                                          │
# │                                                                                                  │
# │ /home/pablo/.local/lib/python3.10/site-packages/pandas/core/internals/construction.py:503 in     │
# │ dict_to_mgr                                                                                      │
# │                                                                                                  │
# │    500 │   │   │   # dtype check to exclude e.g. range objects, scalars                          │
# │    501 │   │   │   arrays = [x.copy() if hasattr(x, "dtype") else x for x in arrays]             │
# │    502 │                                                                                         │
# │ ❱  503 │   return arrays_to_mgr(arrays, columns, index, dtype=dtype, typ=typ, consolidate=copy)  │
# │    504                                                                                           │
# │    505                                                                                           │
# │    506 def nested_data_to_arrays(                                                                │
# │                                                                                                  │
# │ /home/pablo/.local/lib/python3.10/site-packages/pandas/core/internals/construction.py:114 in     │
# │ arrays_to_mgr                                                                                    │
# │                                                                                                  │
# │    111 │   if verify_integrity:                                                                  │
# │    112 │   │   # figure out the index, if necessary                                              │
# │    113 │   │   if index is None:                                                                 │
# │ ❱  114 │   │   │   index = _extract_index(arrays)                                                │
# │    115 │   │   else:                                                                             │
# │    116 │   │   │   index = ensure_index(index)                                                   │
# │    117                                                                                           │
# │                                                                                                  │
# │ /home/pablo/.local/lib/python3.10/site-packages/pandas/core/internals/construction.py:680 in     │
# │ _extract_index                                                                                   │
# │                                                                                                  │
# │    677 │   │   │   raise ValueError("All arrays must be of the same length")                     │
# │    678 │   │                                                                                     │
# │    679 │   │   if have_dicts:                                                                    │
# │ ❱  680 │   │   │   raise ValueError(                                                             │
# │    681 │   │   │   │   "Mixing dicts with non-Series may lead to ambiguous ordering."            │
# │    682 │   │   │   )                                                                             │
# │    683                                                                                           │
# ╰──────────────────────────────────────────────────────────────────────────────────────────────────╯
# ValueError: Mixing dicts with non-Series may lead to ambiguous ordering.

# %%
pd.DataFrame.from_dict(institution_dict)
# Out:
# <pre style="white-space:pre;overflow-x:auto;line-height:normal;font-family:Menlo,'DejaVu Sans Mono',consolas,'Courier New',monospace"></pre>
#                                   id                        ror  \
# 0   https://openalex.org/I4210122970  https://ror.org/02s7sax82
# 1   https://openalex.org/I4210122970  https://ror.org/02s7sax82
# 2   https://openalex.org/I4210122970  https://ror.org/02s7sax82
# 3   https://openalex.org/I4210122970  https://ror.org/02s7sax82
# 4   https://openalex.org/I4210122970  https://ror.org/02s7sax82
# 5   https://openalex.org/I4210122970  https://ror.org/02s7sax82
# 6   https://openalex.org/I4210122970  https://ror.org/02s7sax82
# 7   https://openalex.org/I4210122970  https://ror.org/02s7sax82
# 8   https://openalex.org/I4210122970  https://ror.org/02s7sax82
# 9   https://openalex.org/I4210122970  https://ror.org/02s7sax82
# 10  https://openalex.org/I4210122970  https://ror.org/02s7sax82
# 11  https://openalex.org/I4210122970  https://ror.org/02s7sax82
# 12  https://openalex.org/I4210122970  https://ror.org/02s7sax82
# 13  https://openalex.org/I4210122970  https://ror.org/02s7sax82
# 14  https://openalex.org/I4210122970  https://ror.org/02s7sax82
# 15  https://openalex.org/I4210122970  https://ror.org/02s7sax82
# 16  https://openalex.org/I4210122970  https://ror.org/02s7sax82
# 17  https://openalex.org/I4210122970  https://ror.org/02s7sax82
# 18  https://openalex.org/I4210122970  https://ror.org/02s7sax82
#
#                                display_name country_code        type  \
# 0   Comisión de Investigaciones Científicas           AR  government
# 1   Comisión de Investigaciones Científicas           AR  government
# 2   Comisión de Investigaciones Científicas           AR  government
# 3   Comisión de Investigaciones Científicas           AR  government
# 4   Comisión de Investigaciones Científicas           AR  government
# 5   Comisión de Investigaciones Científicas           AR  government
# 6   Comisión de Investigaciones Científicas           AR  government
# 7   Comisión de Investigaciones Científicas           AR  government
# 8   Comisión de Investigaciones Científicas           AR  government
# 9   Comisión de Investigaciones Científicas           AR  government
# 10  Comisión de Investigaciones Científicas           AR  government
# 11  Comisión de Investigaciones Científicas           AR  government
# 12  Comisión de Investigaciones Científicas           AR  government
# 13  Comisión de Investigaciones Científicas           AR  government
# 14  Comisión de Investigaciones Científicas           AR  government
# 15  Comisión de Investigaciones Científicas           AR  government
# 16  Comisión de Investigaciones Científicas           AR  government
# 17  Comisión de Investigaciones Científicas           AR  government
# 18  Comisión de Investigaciones Científicas           AR  government
#
#                                               type_id  \
# 0   https://openalex.org/institution-types/government
# 1   https://openalex.org/institution-types/government
# 2   https://openalex.org/institution-types/government
# 3   https://openalex.org/institution-types/government
# 4   https://openalex.org/institution-types/government
# 5   https://openalex.org/institution-types/government
# 6   https://openalex.org/institution-types/government
# 7   https://openalex.org/institution-types/government
# 8   https://openalex.org/institution-types/government
# 9   https://openalex.org/institution-types/government
# 10  https://openalex.org/institution-types/government
# 11  https://openalex.org/institution-types/government
# 12  https://openalex.org/institution-types/government
# 13  https://openalex.org/institution-types/government
# 14  https://openalex.org/institution-types/government
# 15  https://openalex.org/institution-types/government
# 16  https://openalex.org/institution-types/government
# 17  https://openalex.org/institution-types/government
# 18  https://openalex.org/institution-types/government
#
#                   homepage_url  works_count  cited_by_count  \
# 0   https://www.cic.gba.gob.ar         3443           54399
# 1   https://www.cic.gba.gob.ar         3443           54399
# 2   https://www.cic.gba.gob.ar         3443           54399
# 3   https://www.cic.gba.gob.ar         3443           54399
# 4   https://www.cic.gba.gob.ar         3443           54399
# 5   https://www.cic.gba.gob.ar         3443           54399
# 6   https://www.cic.gba.gob.ar         3443           54399
# 7   https://www.cic.gba.gob.ar         3443           54399
# 8   https://www.cic.gba.gob.ar         3443           54399
# 9   https://www.cic.gba.gob.ar         3443           54399
# 10  https://www.cic.gba.gob.ar         3443           54399
# 11  https://www.cic.gba.gob.ar         3443           54399
# 12  https://www.cic.gba.gob.ar         3443           54399
# 13  https://www.cic.gba.gob.ar         3443           54399
# 14  https://www.cic.gba.gob.ar         3443           54399
# 15  https://www.cic.gba.gob.ar         3443           54399
# 16  https://www.cic.gba.gob.ar         3443           54399
# 17  https://www.cic.gba.gob.ar         3443           54399
# 18  https://www.cic.gba.gob.ar         3443           54399
#
#                                            x_concepts  \
# 0   {'id': 'https://openalex.org/C86803240', 'wiki...
# 1   {'id': 'https://openalex.org/C185592680', 'wik...
# 2   {'id': 'https://openalex.org/C121332964', 'wik...
# 3   {'id': 'https://openalex.org/C18903297', 'wiki...
# 4   {'id': 'https://openalex.org/C127313418', 'wik...
# 5   {'id': 'https://openalex.org/C71924100', 'wiki...
# 6   {'id': 'https://openalex.org/C178790620', 'wik...
# 7   {'id': 'https://openalex.org/C205649164', 'wik...
# 8   {'id': 'https://openalex.org/C127413603', 'wik...
# 9   {'id': 'https://openalex.org/C55493867', 'wiki...
# 10  {'id': 'https://openalex.org/C54355233', 'wiki...
# 11  {'id': 'https://openalex.org/C138885662', 'wik...
# 12  {'id': 'https://openalex.org/C59822182', 'wiki...
# 13  {'id': 'https://openalex.org/C41008148', 'wiki...
# 14  {'id': 'https://openalex.org/C151730666', 'wik...
# 15  {'id': 'https://openalex.org/C192562407', 'wik...
# 16  {'id': 'https://openalex.org/C62520636', 'wiki...
# 17  {'id': 'https://openalex.org/C142362112', 'wik...
# 18  {'id': 'https://openalex.org/C33923547', 'wiki...
#
#                   updated_date created_date
# 0   2025-03-02T10:37:09.780588   2022-02-02
# 1   2025-03-02T10:37:09.780588   2022-02-02
# 2   2025-03-02T10:37:09.780588   2022-02-02
# 3   2025-03-02T10:37:09.780588   2022-02-02
# 4   2025-03-02T10:37:09.780588   2022-02-02
# 5   2025-03-02T10:37:09.780588   2022-02-02
# 6   2025-03-02T10:37:09.780588   2022-02-02
# 7   2025-03-02T10:37:09.780588   2022-02-02
# 8   2025-03-02T10:37:09.780588   2022-02-02
# 9   2025-03-02T10:37:09.780588   2022-02-02
# 10  2025-03-02T10:37:09.780588   2022-02-02
# 11  2025-03-02T10:37:09.780588   2022-02-02
# 12  2025-03-02T10:37:09.780588   2022-02-02
# 13  2025-03-02T10:37:09.780588   2022-02-02
# 14  2025-03-02T10:37:09.780588   2022-02-02
# 15  2025-03-02T10:37:09.780588   2022-02-02
# 16  2025-03-02T10:37:09.780588   2022-02-02
# 17  2025-03-02T10:37:09.780588   2022-02-02
# 18  2025-03-02T10:37:09.780588   2022-02-02

# %%
pd.DataFrame.from_dict(api_response)
# Out:
# ╭─────────────────────────────── Traceback (most recent call last) ────────────────────────────────╮
# │ in <module>:1                                                                                    │
# │                                                                                                  │
# │ ❱ 1 pd.DataFrame.from_dict(api_response)                                                         │
# │   2                                                                                              │
# │                                                                                                  │
# │ /home/pablo/.local/lib/python3.10/site-packages/pandas/core/frame.py:1917 in from_dict           │
# │                                                                                                  │
# │    1914 │   │   │   )                                                                            │
# │    1915 │   │                                                                                    │
# │    1916 │   │   if orient != "tight":                                                            │
# │ ❱  1917 │   │   │   return cls(data, index=index, columns=columns, dtype=dtype)                  │
# │    1918 │   │   else:                                                                            │
# │    1919 │   │   │   realdata = data["data"]                                                      │
# │    1920                                                                                          │
# │                                                                                                  │
# │ /home/pablo/.local/lib/python3.10/site-packages/pandas/core/frame.py:778 in __init__             │
# │                                                                                                  │
# │     775 │   │                                                                                    │
# │     776 │   │   elif isinstance(data, dict):                                                     │
# │     777 │   │   │   # GH#38939 de facto copy defaults to False only in non-dict cases            │
# │ ❱   778 │   │   │   mgr = dict_to_mgr(data, index, columns, dtype=dtype, copy=copy, typ=manager) │
# │     779 │   │   elif isinstance(data, ma.MaskedArray):                                           │
# │     780 │   │   │   from numpy.ma import mrecords                                                │
# │     781                                                                                          │
# │                                                                                                  │
# │ /home/pablo/.local/lib/python3.10/site-packages/pandas/core/internals/construction.py:503 in     │
# │ dict_to_mgr                                                                                      │
# │                                                                                                  │
# │    500 │   │   │   # dtype check to exclude e.g. range objects, scalars                          │
# │    501 │   │   │   arrays = [x.copy() if hasattr(x, "dtype") else x for x in arrays]             │
# │    502 │                                                                                         │
# │ ❱  503 │   return arrays_to_mgr(arrays, columns, index, dtype=dtype, typ=typ, consolidate=copy)  │
# │    504                                                                                           │
# │    505                                                                                           │
# │    506 def nested_data_to_arrays(                                                                │
# │                                                                                                  │
# │ /home/pablo/.local/lib/python3.10/site-packages/pandas/core/internals/construction.py:114 in     │
# │ arrays_to_mgr                                                                                    │
# │                                                                                                  │
# │    111 │   if verify_integrity:                                                                  │
# │    112 │   │   # figure out the index, if necessary                                              │
# │    113 │   │   if index is None:                                                                 │
# │ ❱  114 │   │   │   index = _extract_index(arrays)                                                │
# │    115 │   │   else:                                                                             │
# │    116 │   │   │   index = ensure_index(index)                                                   │
# │    117                                                                                           │
# │                                                                                                  │
# │ /home/pablo/.local/lib/python3.10/site-packages/pandas/core/internals/construction.py:677 in     │
# │ _extract_index                                                                                   │
# │                                                                                                  │
# │    674 │   if have_raw_arrays:                                                                   │
# │    675 │   │   lengths = list(set(raw_lengths))                                                  │
# │    676 │   │   if len(lengths) > 1:                                                              │
# │ ❱  677 │   │   │   raise ValueError("All arrays must be of the same length")                     │
# │    678 │   │                                                                                     │
# │    679 │   │   if have_dicts:                                                                    │
# │    680 │   │   │   raise ValueError(                                                             │
# ╰──────────────────────────────────────────────────────────────────────────────────────────────────╯
# ValueError: All arrays must be of the same length
