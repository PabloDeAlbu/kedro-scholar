# %%
import pandas as pd
from pandas import json_normalize
from datetime import date
pd.set_option('display.max_columns', None)
import json

# %%
df_work_raw = catalog.load('raw/openalex/work_dev#parquet')
# Out:
# [12/05/24 13:20:42] INFO     Loading data from raw/openalex/work_dev#parquet                    ]8;id=611186;file:///home/pablo/dev/CIC/dw-cic/kedro/kedro-cic/.venv/lib/python3.10/site-packages/kedro/io/data_catalog.py\data_catalog.py]8;;\:]8;id=997954;file:///home/pablo/dev/CIC/dw-cic/kedro/kedro-cic/.venv/lib/python3.10/site-packages/kedro/io/data_catalog.py#389\389]8;;\
#                              (ParquetDataset)...

# %% [markdown]
# # Profiling

# %%
df_work_raw.shape
# Out:
# <pre style="white-space:pre;overflow-x:auto;line-height:normal;font-family:Menlo,'DejaVu Sans Mono',consolas,'Courier New',monospace"></pre>
# (150, 50)

# %%
df_work_raw.head(3)
# Out:
# <pre style="white-space:pre;overflow-x:auto;line-height:normal;font-family:Menlo,'DejaVu Sans Mono',consolas,'Courier New',monospace"></pre>
#                                  id  \
# 0  https://openalex.org/W2089852843
# 1  https://openalex.org/W3037375387
# 2  https://openalex.org/W2032143374
#
#                                              doi  \
# 0  https://doi.org/10.1016/s0378-4371(98)00437-3
# 1   https://doi.org/10.1016/j.envint.2020.105876
# 2  https://doi.org/10.1016/s0023-6438(03)00088-4
#
#                                                title  \
# 0  The role of constraints within generalized non...
# 1  Short-term exposure to particulate matter (PM1...
# 2  Antimicrobial activity of essential oils on th...
#
#                                         display_name  publication_year  \
# 0  The role of constraints within generalized non...              1998
# 1  Short-term exposure to particulate matter (PM1...              2020
# 2  Antimicrobial activity of essential oils on th...              2003
#
#   publication_date                                                ids  \
# 0       1998-12-01  {'doi': 'https://doi.org/10.1016/s0378-4371(98...
# 1       2020-06-23  {'doi': 'https://doi.org/10.1016/j.envint.2020...
# 2       2003-11-01  {'doi': 'https://doi.org/10.1016/s0023-6438(03...
#
#   language                                   primary_location     type  \
# 0       en  {'is_accepted': False, 'is_oa': False, 'is_pub...  article
# 1       en  {'is_accepted': True, 'is_oa': True, 'is_publi...   review
# 2       en  {'is_accepted': False, 'is_oa': False, 'is_pub...  article
#
#      type_crossref                indexed_in  \
# 0  journal-article                [crossref]
# 1  journal-article  [crossref, doaj, pubmed]
# 2  journal-article                [crossref]
#
#                                          open_access  \
# 0  {'any_repository_has_fulltext': False, 'is_oa'...
# 1  {'any_repository_has_fulltext': True, 'is_oa':...
# 2  {'any_repository_has_fulltext': False, 'is_oa'...
#
#                                          authorships institution_assertions  \
# 0  [{'affiliations': [{'institution_ids': array([...                     []
# 1  [{'affiliations': [{'institution_ids': array([...                     []
# 2  [{'affiliations': [{'institution_ids': array([...                     []
#
#    countries_distinct_count  institutions_distinct_count  \
# 0                         3                            6
# 1                         1                            5
# 2                         1                            3
#
#              corresponding_author_ids  \
# 0  [https://openalex.org/A5051451815]
# 1  [https://openalex.org/A5069680875]
# 2                                  []
#
#                        corresponding_institution_ids  \
# 0                 [https://openalex.org/I4210125245]
# 1  [https://openalex.org/I128590013, https://open...
# 2                                                 []
#
#                                             apc_list  \
# 0  {'currency': 'USD', 'provenance': 'doaj', 'val...
# 1  {'currency': 'USD', 'provenance': 'doaj', 'val...
# 2  {'currency': 'USD', 'provenance': 'doaj', 'val...
#
#                                             apc_paid    fwci  has_fulltext  \
# 0                                               None  30.222          True
# 1  {'currency': 'USD', 'provenance': 'doaj', 'val...   8.533          True
# 2                                               None   1.334          True
#
#   fulltext_origin  cited_by_count  \
# 0          ngrams            1330
# 1             pdf             506
# 2          ngrams             435
#
#                       citation_normalized_percentile cited_by_percentile_year  \
# 0  {'is_in_top_10_percent': True, 'is_in_top_1_pe...  {'max': 100, 'min': 99}
# 1  {'is_in_top_10_percent': True, 'is_in_top_1_pe...  {'max': 100, 'min': 99}
# 2  {'is_in_top_10_percent': True, 'is_in_top_1_pe...  {'max': 100, 'min': 99}
#
#                                               biblio  is_retracted  \
# 0  {'first_page': '534', 'issue': '3-4', 'last_pa...         False
# 1  {'first_page': '105876', 'issue': None, 'last_...         False
# 2  {'first_page': '679', 'issue': '7', 'last_page...         False
#
#    is_paratext                                      primary_topic  \
# 0        False  {'display_name': 'Statistical Mechanics with L...
# 1        False  {'display_name': 'Health Effects of Air Pollut...
# 2        False  {'display_name': 'Antimicrobial Properties of ...
#
#                                               topics  \
# 0  [{'display_name': 'Statistical Mechanics with ...
# 1  [{'display_name': 'Health Effects of Air Pollu...
# 2  [{'display_name': 'Antimicrobial Properties of...
#
#                                             keywords  \
# 0  [{'display_name': 'Hamiltonian (control theory...
# 1  [{'display_name': 'Nitrogen dioxide', 'id': 'h...
# 2  [{'display_name': 'Syzygium', 'id': 'https://o...
#
#                                             concepts  \
# 0  [{'display_name': 'Harmonic oscillator', 'id':...
# 1  [{'display_name': 'Nitrogen dioxide', 'id': 'h...
# 2  [{'display_name': 'Antimicrobial', 'id': 'http...
#
#                                                 mesh  locations_count  \
# 0                                                 []                1
# 1  [{'descriptor_name': 'Air Pollutants', 'descri...                4
# 2                                                 []                1
#
#                                            locations  \
# 0  [{'is_accepted': False, 'is_oa': False, 'is_pu...
# 1  [{'is_accepted': True, 'is_oa': True, 'is_publ...
# 2  [{'is_accepted': False, 'is_oa': False, 'is_pu...
#
#                                     best_oa_location  \
# 0                                               None
# 1  {'is_accepted': True, 'is_oa': True, 'is_publi...
# 2                                               None
#
#                        sustainable_development_goals  \
# 0  [{'display_name': 'Affordable and clean energy...
# 1  [{'display_name': 'Good health and well-being'...
# 2                                                 []
#
#                                               grants datasets versions  \
# 0                                                 []       []       []
# 1  [{'award_id': None, 'funder': 'https://openale...       []       []
# 2                                                 []       []       []
#
#    referenced_works_count                                   referenced_works  \
# 0                      74  [https://openalex.org/W1553236419, https://ope...
# 1                      84  [https://openalex.org/W1525116145, https://ope...
# 2                      37  [https://openalex.org/W102433214, https://open...
#
#                                        related_works  \
# 0  [https://openalex.org/W620348747, https://open...
# 1  [https://openalex.org/W4399338999, https://ope...
# 2  [https://openalex.org/W4381740914, https://ope...
#
#                              abstract_inverted_index  \
# 0                                               None
# 1  {'"Best': None, '"Good': None, '"Natural': Non...
# 2                                               None
#
#                                     cited_by_api_url  \
# 0  https://api.openalex.org/works?filter=cites:W2...
# 1  https://api.openalex.org/works?filter=cites:W3...
# 2  https://api.openalex.org/works?filter=cites:W2...
#
#                                       counts_by_year  \
# 0  [{'cited_by_count': 42, 'year': 2024}, {'cited...
# 1  [{'cited_by_count': 154, 'year': 2024}, {'cite...
# 2  [{'cited_by_count': 43, 'year': 2024}, {'cited...
#
#                  updated_date created_date
# 0  2024-11-20T08:52:24.024876   2016-06-24
# 1  2024-12-03T13:35:34.799193   2020-07-02
# 2  2024-11-23T07:07:30.615558   2016-06-24

# %%
df_work_raw = df_work_raw.convert_dtypes()
df_work_raw.dtypes
# Out:
# <pre style="white-space:pre;overflow-x:auto;line-height:normal;font-family:Menlo,'DejaVu Sans Mono',consolas,'Courier New',monospace"></pre>
# id                                string[python]
# doi                               string[python]
# title                             string[python]
# display_name                      string[python]
# publication_year                           Int64
# publication_date                  string[python]
# ids                                       object
# language                          string[python]
# primary_location                          object
# type                              string[python]
# type_crossref                     string[python]
# indexed_in                                object
# open_access                               object
# authorships                               object
# institution_assertions                    object
# countries_distinct_count                   Int64
# institutions_distinct_count                Int64
# corresponding_author_ids                  object
# corresponding_institution_ids             object
# apc_list                                  object
# apc_paid                                  object
# fwci                                     Float64
# has_fulltext                             boolean
# fulltext_origin                   string[python]
# cited_by_count                             Int64
# citation_normalized_percentile            object
# cited_by_percentile_year                  object
# biblio                                    object
# is_retracted                             boolean
# is_paratext                              boolean
# primary_topic                             object
# topics                                    object
# keywords                                  object
# concepts                                  object
# mesh                                      object
# locations_count                            Int64
# locations                                 object
# best_oa_location                          object
# sustainable_development_goals             object
# grants                                    object
# datasets                                  object
# versions                                  object
# referenced_works_count                     Int64
# referenced_works                          object
# related_works                             object
# abstract_inverted_index                   object
# cited_by_api_url                  string[python]
# counts_by_year                            object
# updated_date                      string[python]
# created_date                      string[python]
# dtype: object

# %% [markdown]
# # Nodo

# %%
def land_work2topics_openalex(df_work_raw):
    df_work = df_work_raw.loc[:,['id','topics']]
    df_work = df_work.convert_dtypes()
    
    # Proceso topics
    df_work2topics_exploded = df_work.explode('topics')
    df_work2topics_norm = pd.json_normalize(df_work2topics_exploded['topics'])
    df_work2topics_exploded = df_work2topics_exploded.reset_index(drop=True)
    df_work2topics_norm.rename(columns={'id':'topic_id'}, inplace=True)
   
    # Creación de df con work y sus topics
    df_work2topics = pd.concat((df_work2topics_exploded['id'], df_work2topics_norm), axis=1)

    # Rename de columnas
    df_work2topics.rename(columns=lambda col: col.replace('.', '_'), inplace=True)
    df_work2topics.rename(columns={'id': 'work_id'}, inplace=True)

    return df_work2topics

# %% [markdown]
# ## Ejecuto Nodo

# %%
df_work2topics = land_work2topics_openalex(df_work_raw)

# %% [markdown]
# # Resultados

# %%
df_work2topics
# Out:
# <pre style="white-space:pre;overflow-x:auto;line-height:normal;font-family:Menlo,'DejaVu Sans Mono',consolas,'Courier New',monospace"></pre>
#                