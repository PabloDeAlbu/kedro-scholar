# %%
import pandas as pd
import json
from datetime import datetime
pd.set_option('display.max_columns', None)

# %%
df_work_raw = catalog.load('raw/openalex/work#parquet')
# Out:
# [03/02/25 11:21:26] INFO     Loading data from raw/openalex/work#parquet (ParquetDataset)...    ]8;id=58339;file:///home/pablo/.local/lib/python3.10/site-packages/kedro/io/data_catalog.py\data_catalog.py]8;;\:]8;id=447927;file:///home/pablo/.local/lib/python3.10/site-packages/kedro/io/data_catalog.py#389\389]8;;\

# %% [markdown]
# # Profiling

# %%
df_work_raw.columns
# Out:
# <pre style="white-space:pre;overflow-x:auto;line-height:normal;font-family:Menlo,'DejaVu Sans Mono',consolas,'Courier New',monospace"></pre>
# Index(['id', 'doi', 'title', 'display_name', 'publication_year',
#        'publication_date', 'ids', 'language', 'primary_location', 'type',
#        'type_crossref', 'indexed_in', 'open_access', 'authorships',
#        'institution_assertions', 'countries_distinct_count',
#        'institutions_distinct_count', 'corresponding_author_ids',
#        'corresponding_institution_ids', 'apc_list', 'apc_paid', 'fwci',
#        'is_authors_truncated', 'has_fulltext', 'fulltext_origin',
#        'cited_by_count', 'citation_normalized_percentile',
#        'cited_by_percentile_year', 'biblio', 'is_retracted', 'is_paratext',
#        'primary_topic', 'topics', 'keywords', 'concepts', 'mesh',
#        'locations_count', 'locations', 'best_oa_location',
#        'sustainable_development_goals', 'grants', 'datasets', 'versions',
#        'referenced_works_count', 'referenced_works', 'related_works',
#        'abstract_inverted_index', 'abstract_inverted_index_v3',
#        'cited_by_api_url', 'counts_by_year', 'updated_date', 'created_date'],
#       dtype='object')

# %%
df_work_raw.head(3)
# Out:
# <pre style="white-space:pre;overflow-x:auto;line-height:normal;font-family:Menlo,'DejaVu Sans Mono',consolas,'Courier New',monospace"></pre>
#                                  id  \
# 0  https://openalex.org/W4211046286
# 1  https://openalex.org/W4292403095
# 2  https://openalex.org/W2501864044
#
#                                              doi  \
# 0  https://doi.org/10.1088/1748-0221/3/08/s08003
# 1     https://doi.org/10.1051/0004-6361:20041864
# 2           https://doi.org/10.1093/mnras/stx721
#
#                                                title  \
# 0  The ATLAS Experiment at the CERN Large Hadron ...
# 1  The Leiden/Argentine/Bonn (LAB) Survey of Gala...
# 2  The clustering of galaxies in the completed SD...
#
#                                         display_name  publication_year  \
# 0  The ATLAS Experiment at the CERN Large Hadron ...              2008
# 1  The Leiden/Argentine/Bonn (LAB) Survey of Gala...              2005
# 2  The clustering of galaxies in the completed SD...              2017
#
#   publication_date                                                ids  \
# 0       2008-08-14  {'doi': 'https://doi.org/10.1088/1748-0221/3/0...
# 1       2005-08-29  {'doi': 'https://doi.org/10.1051/0004-6361:200...
# 2       2017-03-24  {'doi': 'https://doi.org/10.1093/mnras/stx721'...
#
#   language                                   primary_location     type  \
# 0       en  {'is_accepted': True, 'is_oa': True, 'is_publi...  article
# 1       en  {'is_accepted': True, 'is_oa': True, 'is_publi...  article
# 2       en  {'is_accepted': True, 'is_oa': True, 'is_publi...  article
#
#      type_crossref                   indexed_in  \
# 0  journal-article                   [crossref]
# 1  journal-article  [arxiv, crossref, datacite]
# 2  journal-article  [arxiv, crossref, datacite]
#
#                                          open_access  \
# 0  {'any_repository_has_fulltext': True, 'is_oa':...
# 1  {'any_repository_has_fulltext': True, 'is_oa':...
# 2  {'any_repository_has_fulltext': True, 'is_oa':...
#
#                                          authorships institution_assertions  \
# 0  [{'affiliations': [{'institution_ids': array([...                     []
# 1  [{'affiliations': [{'institution_ids': array([...                     []
# 2  [{'affiliations': [{'institution_ids': array([...                     []
#
#    countries_distinct_count  institutions_distinct_count  \
# 0                        36                          188
# 1                         2                            4
# 2                        12                           57
#
#                             corresponding_author_ids  \
# 0                                                 []
# 1                                                 []
# 2  [https://openalex.org/A5102897520, https://ope...
#
#                        corresponding_institution_ids  \
# 0                                                 []
# 1                                                 []
# 2  [https://openalex.org/I148283060, https://open...
#
#                                             apc_list apc_paid     fwci  \
# 0                                               None     None   53.846
# 1                                               None     None   20.870
# 2  {'currency': 'GBP', 'provenance': None, 'value...     None  117.883
#
#   is_authors_truncated  has_fulltext fulltext_origin  cited_by_count  \
# 0                 True          True             pdf            3806
# 1                 None          True             pdf            3199
# 2                 None          True             pdf            2582
#
#                       citation_normalized_percentile cited_by_percentile_year  \
# 0  {'is_in_top_10_percent': True, 'is_in_top_1_pe...  {'max': 100, 'min': 99}
# 1  {'is_in_top_10_percent': True, 'is_in_top_1_pe...  {'max': 100, 'min': 99}
# 2  {'is_in_top_10_percent': True, 'is_in_top_1_pe...  {'max': 100, 'min': 99}
#
#                                               biblio  is_retracted  \
# 0  {'first_page': 'S08003', 'issue': '08', 'last_...         False
# 1  {'first_page': '775', 'issue': '2', 'last_page...         False
# 2  {'first_page': '2617', 'issue': '3', 'last_pag...         False
#
#    is_paratext                                      primary_topic  \
# 0        False  {'display_name': 'Particle Detector Developmen...
# 1        False  {'display_name': 'Astrophysics and Cosmic Phen...
# 2        False  {'display_name': 'Galaxies: Formation, Evoluti...
#
#                                               topics  \
# 0  [{'display_name': 'Particle Detector Developme...
# 1  [{'display_name': 'Astrophysics and Cosmic Phe...
# 2  [{'display_name': 'Galaxies: Formation, Evolut...
#
#                                             keywords  \
# 0  [{'display_name': 'Atlas detector', 'id': 'htt...
# 1  [{'display_name': 'Galactic plane', 'id': 'htt...
# 2  [{'display_name': 'Baryon Acoustic Oscillation...
#
#                                             concepts mesh  locations_count  \
# 0  [{'display_name': 'Large Hadron Collider', 'id...   []                9
# 1  [{'display_name': 'Physics', 'id': 'https://op...   []                8
# 2  [{'display_name': 'Physics', 'id': 'https://op...   []               21
#
#                                            locations  \
# 0  [{'is_accepted': True, 'is_oa': True, 'is_publ...
# 1  [{'is_accepted': True, 'is_oa': True, 'is_publ...
# 2  [{'is_accepted': True, 'is_oa': True, 'is_publ...
#
#                                     best_oa_location  \
# 0  {'is_accepted': True, 'is_oa': True, 'is_publi...
# 1  {'is_accepted': True, 'is_oa': True, 'is_publi...
# 2  {'is_accepted': True, 'is_oa': True, 'is_publi...
#
#   sustainable_development_goals grants datasets  \
# 0                            []     []       []
# 1                            []     []       []
# 2                            []     []       []
#
#                              versions  referenced_works_count  \
# 0                                  []                     154
# 1  [https://openalex.org/W4292403095]                       7
# 2  [https://openalex.org/W2501864044]                     234
#
#                                     referenced_works  \
# 0  [https://openalex.org/W1578925023, https://ope...
# 1  [https://openalex.org/W1539512060, https://ope...
# 2  [https://openalex.org/W1483545773, https://ope...
#
#                                        related_works  \
# 0  [https://openalex.org/W4385358068, https://ope...
# 1  [https://openalex.org/W4296758524, https://ope...
# 2  [https://openalex.org/W3148180306, https://ope...
#
#                              abstract_inverted_index  \
# 0  {'"ankle"': None, '"away-side"': None, '"hard"...
# 1  {'"ankle"': None, '"away-side"': None, '"hard"...
# 2  {'"ankle"': None, '"away-side"': None, '"hard"...
#
#   abstract_inverted_index_v3  \
# 0                       None
# 1                       None
# 2                       None
#
#                                     cited_by_api_url  \
# 0  https://api.openalex.org/works?filter=cites:W4...
# 1  https://api.openalex.org/works?filter=cites:W4...
# 2  https://api.openalex.org/works?filter=cites:W2...
#
#                                       counts_by_year  \
# 0  [{'cited_by_count': 9, 'year': 2025}, {'cited_...
# 1  [{'cited_by_count': 6, 'year': 2025}, {'cited_...
# 2  [{'cited_by_count': 22, 'year': 2025}, {'cited...
#
#                  updated_date created_date
# 0  2025-02-11T08:28:18.092160   2022-02-13
# 1  2025-02-01T09:28:17.860708   2022-08-20
# 2  2025-02-06T09:24:35.713288   2016-08-23

# %% [markdown]
# # Nodo

# %%
def land_openalex_work(df_work_raw):
    """Limpia y transforma los datos de OpenAlex para su almacenamiento en una base de datos relacional."""
    
    expected_columns = [
        'id',
        # 'doi', # doi existe en ids
        'title',
        'display_name',
        'publication_year',
        'publication_date',
        'ids',
        'language',
        'primary_location',
        'type',
        'type_crossref',
        # 'indexed_in',
        'open_access',
        # 'authorships',
        # 'institution_assertions',
        'countries_distinct_count',
        'institutions_distinct_count',
        # 'corresponding_author_ids',
        # 'corresponding_institution_ids',
        'apc_list',
        'apc_paid',
        'fwci',
        'has_fulltext',
        'fulltext_origin',
        'cited_by_count',
        'citation_normalized_percentile',
        'cited_by_percentile_year',
        'biblio',
        'is_retracted',
        'is_paratext',
        'primary_topic',
        # 'topics',
        # 'keywords',
        # 'concepts',
        # 'mesh',
        'locations_count',
        # 'locations',
        'best_oa_location',
        # 'sustainable_development_goals',
        # 'grants',
        # 'datasets',
        # 'versions',
        'referenced_works_count',
        # 'referenced_works',
        # 'related_works',
        # 'abstract_inverted_index',
        # 'abstract_inverted_index_v3',
        'cited_by_api_url',
        # 'counts_by_year',
        'updated_date',
        'created_date'
    ]

    df_work = df_work_raw.loc[:,expected_columns].reset_index(drop=True).copy()

    # Agregar columnas faltantes con NaN
    for col in expected_columns:
        if col not in df_work.columns:
            df_work[col] = pd.NA

    # ids
    df_ids = pd.json_normalize(df_work['ids']).reset_index(drop=True)
    df_work = pd.concat([df_work, df_ids], axis=1)
    df_work.drop(columns=['ids'], inplace=True)    

    # primary_location
    df_primary_location = pd.json_normalize(df_work['primary_location']).reset_index(drop=True)
    df_primary_location.rename(columns=lambda col: f'primary_location.{col}', inplace=True)
    df_primary_location.drop(columns=[
        'primary_location.source.issn',
        'primary_location.source.host_organization_lineage',
        'primary_location.source.host_organization_lineage_names'
        ],
        inplace=True)

    df_work = pd.concat([df_work, df_primary_location], axis=1)
    df_work.drop(columns=['primary_location'], inplace=True)    

    # openacess
    df_openaccess_expanded = pd.json_normalize(df_work['open_access'])
    df_work = pd.concat([df_work, df_openaccess_expanded], axis=1)
    df_work.drop(columns=['open_access'], inplace=True)    

    # apc_list
    df_apc_list = pd.json_normalize(df_work['apc_list'])
    df_apc_list.rename(columns=lambda col: f'apc_list.{col}', inplace=True)
    df_work = pd.concat([df_work, df_apc_list], axis=1)
    df_work.drop(columns=['apc_list'], inplace=True)    
 
    # apc_paid
    df_apc_paid = pd.json_normalize(df_work['apc_paid'])
    df_apc_paid.rename(columns=lambda col: f'apc_paid.{col}', inplace=True)
    df_work = pd.concat([df_work, df_apc_paid], axis=1)
    df_work.drop(columns=['apc_paid'], inplace=True)    
 
    # citation_normalized_percentile
    df_citation_normalized_percentile = pd.json_normalize(df_work['citation_normalized_percentile'])
    df_citation_normalized_percentile.rename(columns=lambda col: f'citation_normalized_percentile.{col}', inplace=True)
    df_work = pd.concat([df_work, df_citation_normalized_percentile], axis=1)
    df_work.drop(columns=['citation_normalized_percentile'], inplace=True)    

    # cited_by_percentile_year
    df_cited_by_percentile_year = pd.json_normalize(df_work['cited_by_percentile_year'])
    df_cited_by_percentile_year.rename(columns=lambda col: f'cited_by_percentile_year.{col}', inplace=True)
    df_work = pd.concat([df_work, df_cited_by_percentile_year], axis=1)
    df_work.drop(columns=['cited_by_percentile_year'], inplace=True)    

    # biblio
    df_biblio = pd.json_normalize(df_work['biblio'])
    df_biblio.rename(columns=lambda col: f'biblio.{col}', inplace=True)
    df_work = pd.concat([df_work, df_biblio], axis=1)
    df_work.drop(columns=['biblio'], inplace=True)

    # primary_topic
    df_primary_topic = pd.json_normalize(df_work['primary_topic'])
    df_primary_topic.rename(columns=lambda col: f'primary_topic.{col}', inplace=True)
    df_work = pd.concat([df_work, df_primary_topic], axis=1)
    df_work.drop(columns=['primary_topic'], inplace=True)    

    # best_oa_location
    df_best_oa_location = pd.json_normalize(df_work['best_oa_location'])
    df_best_oa_location.rename(columns=lambda col: f'best_oa_location.{col}', inplace=True)
    df_best_oa_location.drop(columns=[
        'best_oa_location.source.host_organization_lineage',
        'best_oa_location.source.host_organization_lineage_names',
        'best_oa_location.source.issn',
    ], inplace=True)
    
    df_work = pd.concat([df_work, df_best_oa_location], axis=1)
    df_work.drop(columns=['best_oa_location'], inplace=True)    

    # Agregar la fecha de carga con formato datetime
    df_work['load_datetime'] = pd.to_datetime(datetime.today())

    # Convertir tipos de datos automáticamente
    df_work = df_work.convert_dtypes()

    return df_work

# %% [markdown]
# ## Ejecuto Nodo

# %%
df_work = land_openalex_work(df_work_raw)

# %% [markdown]
# # Resultados

# %%
df_work
# Out:
# <pre style="white-space:pre;overflow-x:auto;line-height:normal;font-family:Menlo,'DejaVu Sans Mono',consolas,'Courier New',monospace"></pre>
#                                      id  \
# 0      https://openalex.org/W4211046286
# 1      https://openalex.org/W4292403095
# 2      https://openalex.org/W2501864044
# 3      https://openalex.org/W2098406858
# 4      https://openalex.org/W2012331775
# ...                                 ...
# 50087   https://openalex.org/W945140665
# 50088    https://openalex.org/W97783533
# 50089   https://openalex.org/W978244029
# 50090   https://openalex.org/W986533171
# 50091   https://openalex.org/W991652025
#
#                                                    title  \
# 0      The ATLAS Experiment at the CERN Large Hadron ...
# 1      The Leiden/Argentine/Bonn (LAB) Survey of Gala...
# 2      The clustering of galaxies in the completed SD...
# 3      The ATLAS Experiment at the CERN Large Hadron ...
# 4      Genome sequence and analysis of the tuber crop...
# ...                                                  ...
# 50087  Information Theory-Based Variational Approach ...
# 50088    EHRENFEST APPROXIMATION FOR NON LINEAR PROBLEMS
# 50089  High Temperature Superconductivity in an Exact...
# 50090  El metamorfismo de Las Sierras Australes Provi...
# 50091  adonde va el excedente economico que se genera...
#
#                                             display_name  publication_year  \
# 0      The ATLAS Experiment at the CERN Large Hadron ...              2008
# 1      The Leiden/Argentine/Bonn (LAB) Survey of Gala...              2005
# 2      The clustering of galaxies in the completed SD...              2017
# 3      The ATLAS Experiment at the CERN Large Hadron ...              2020
# 4      Genome sequence and analysis of the tuber crop...              2011
# ...                                                  ...               ...
# 50087  Information Theory-Based Variational Approach ...              1993
# 50088    EHRENFEST APPROXIMATION FOR NON LINEAR PROBLEMS              1989
# 50089  High Temperature Superconductivity in an Exact...              1991
# 50090  El metamorfismo de Las Sierras Australes Provi...              1991
# 50091  adonde va el excedente economico que se genera...              1988
#
#       publication_date language          type    type_crossref  \
# 0           2008-08-14       en       article  journal-article
# 1           2005-08-29       en       article  journal-article
# 2           2017-03-24       en       article  journal-article
# 3           2020-02-23       en          book             book
# 4           2011-07-01       en       article  journal-article
# ...                ...      ...           ...              ...
# 50087       1993-01-01       en  book-chapter     book-chapter
# 50088       1989-01-01       en  book-chapter     book-chapter
# 50089       1991-01-01       en  book-chapter     book-chapter
# 50090       1991-01-01       en       article  journal-article
# 50091       1988-01-01       es       article  journal-article
#
#        countries_distinct_count  institutions_distinct_count     fwci  \
# 0                            36                          188   53.846
# 1                             2                            4    20.87
# 2                            12                           57  117.883
# 3                            32                          170   19.933
# 4                            12                           19  148.592
# ...                         ...                          ...      ...
# 50087                         1                            1      0.0
# 50088                         1                            1      0.0
# 50089                         2                            2      0.0
# 50090                         1                            1      0.0
# 50091                         1                            1      0.0
#
#        has_fulltext fulltext_origin  cited_by_count  is_retracted  \
# 0              True             pdf            3806         False
# 1              True             pdf            3199         False
# 2              True             pdf            2582         False
# 3             False            <NA>            2468         False
# 4              True          ngrams            1979         False
# ...             ...             ...             ...           ...
# 50087         False            <NA>               0         False
# 50088         False            <NA>               0         False
# 50089         False            <NA>               0         False
# 50090         False            <NA>               0         False
# 50091         False            <NA>               0         False
#
#        is_paratext  locations_count  referenced_works_count  \
# 0            False                9                     154
# 1            False                8                       7
# 2            False               21                     234
# 3            False                1                     220
# 4            False                5                      55
# ...            ...              ...                     ...
# 50087        False                1                      23
# 50088        False                1                       1
# 50089        False                1                       7
# 50090        False                1                       0
# 50091        False                1                       0
#
#                                         cited_by_api_url  \
# 0      https://api.openalex.org/works?filter=cites:W4...
# 1      https://api.openalex.org/works?filter=cites:W4...
# 2      https://api.openalex.org/works?filter=cites:W2...
# 3      https://api.openalex.org/works?filter=cites:W2...
# 4      https://api.openalex.org/works?filter=cites:W2...
# ...                                                  ...
# 50087  https://api.openalex.org/works?filter=cites:W9...
# 50088  https://api.openalex.org/works?filter=cites:W9...
# 50089  https://api.openalex.org/works?filter=cites:W9...
# 50090  https://api.openalex.org/works?filter=cites:W9...
# 50091  https://api.openalex.org/works?filter=cites:W9...
#
#                      updated_date created_date  \
# 0      2025-02-11T08:28:18.092160   2022-02-13
# 1      2025-02-01T09:28:17.860708   2022-08-20
# 2      2025-02-06T09:24:35.713288   2016-08-23
# 3      2025-02-11T09:25:04.384530   2016-06-24
# 4      2025-02-05T03:25:02.121213   2016-06-24
# ...                           ...          ...
# 50087  2025-02-01T22:06:21.894173   2016-06-24
# 50088  2025-01-28T13:25:51.115305   2016-06-24
# 50089  2025-01-27T23:20:03.223658   2016-06-24
# 50090  2025-02-02T12:30:28.809579   2016-06-24
# 50091  2025-02-02T12:30:44.225680   2016-06-24
#
#                                                      doi         mag  \
# 0          https://doi.org/10.1088/1748-0221/3/08/s08003        <NA>
# 1             https://doi.org/10.1051/0004-6361:20041864        <NA>
# 2                   https://doi.org/10.1093/mnras/stx721  2501864044
# 3                                                   <NA>  2098406858
# 4                    https://doi.org/10.1038/nature10158  2012331775
# ...                                                  ...         ...
# 50087       https://doi.org/10.1007/978-1-4615-2934-7_28   945140665
# 50088  https://doi.org/10.1016/b978-0-444-88035-2.500...    97783533
# 50089       https://doi.org/10.1007/978-1-4615-3686-4_17   978244029
# 50090                                               <NA>   986533171
# 50091                                               <NA>   991652025
#
#                                openalex pmcid  \
# 0      https://openalex.org/W4211046286  <NA>
# 1      https://openalex.org/W4292403095  <NA>
# 2      https://openalex.org/W2501864044  <NA>
# 3      https://openalex.org/W2098406858  <NA>
# 4      https://openalex.org/W2012331775  <NA>
# ...                                 ...   ...
# 50087   https://openalex.org/W945140665  <NA>
# 50088    https://openalex.org/W97783533  <NA>
# 50089   https://openalex.org/W978244029  <NA>
# 50090   https://openalex.org/W986533171  <NA>
# 50091   https://openalex.org/W991652025  <NA>
#
#                                            pmid  primary_location.is_accepted  \
# 0                                          <NA>                          True
# 1                                          <NA>                          True
# 2                                          <NA>                          True
# 3                                          <NA>                         False
# 4      https://pubmed.ncbi.nlm.nih.gov/21743474                          True
# ...                                         ...                           ...
# 50087                                      <NA>                         False
# 50088                                      <NA>                         False
# 50089                                      <NA>                         False
# 50090                                      <NA>                         False
# 50091                                      <NA>                         False
#
#        primary_location.is_oa  primary_location.is_published  \
# 0                        True                           True
# 1                        True                           True
# 2                        True                           True
# 3                       False                          False
# 4                        True                           True
# ...                       ...                            ...
# 50087                   False                          False
# 50088                   False                          False
# 50089                   False                          False
# 50090                   False                          False
# 50091                   False                          False
#
#                        primary_location.landing_page_url  \
# 0          https://doi.org/10.1088/1748-0221/3/08/s08003
# 1             https://doi.org/10.1051/0004-6361:20041864
# 2                   https://doi.org/10.1093/mnras/stx721
# 3          https://doi.org/10.1088/1748-0221/3/08/S08003
# 4                    https://doi.org/10.1038/nature10158
# ...                                                  ...
# 50087       https://doi.org/10.1007/978-1-4615-2934-7_28
# 50088  https://doi.org/10.1016/b978-0-444-88035-2.500...
# 50089       https://doi.org/10.1007/978-1-4615-3686-4_17
# 50090  https://biblat.unam.mx/es/revista/revista-del-...
# 50091  https://biblat.unam.mx/es/revista/realidad-eco...
#
#       primary_location.license                primary_location.license_id  \
# 0                         <NA>                                       <NA>
# 1                         <NA>                                       <NA>
# 2                         <NA>                                       <NA>
# 3                         <NA>                                       <NA>
# 4                  cc-by-nc-sa  https://openalex.org/licenses/cc-by-nc-sa
# ...                        ...                                        ...
# 50087                     <NA>                                       <NA>
# 50088                     <NA>                                       <NA>
# 50089                     <NA>                                       <NA>
# 50090                     <NA>                                       <NA>
# 50091                     <NA>                                       <NA>
#
#                                 primary_location.pdf_url  \
# 0                                                   <NA>
# 1      https://www.aanda.org/articles/aa/pdf/2005/35/...
# 2      https://academic.oup.com/mnras/article-pdf/470...
# 3                                                   <NA>
# 4        https://www.nature.com/articles/nature10158.pdf
# ...                                                  ...
# 50087                                               <NA>
# 50088                                               <NA>
# 50089                                               <NA>
# 50090                                               <NA>
# 50091                                               <NA>
#
#       primary_location.version  \
# 0             publishedVersion
# 1             publishedVersion
# 2             publishedVersion
# 3                         <NA>
# 4             publishedVersion
# ...                        ...
# 50087                     <NA>
# 50088                     <NA>
# 50089                     <NA>
# 50090                     <NA>
# 50091                     <NA>
#
#                     primary_location.source.display_name  \
# 0                             Journal of Instrumentation
# 1                             Astronomy and Astrophysics
# 2      Monthly Notices of the Royal Astronomical Society
# 3                                                   <NA>
# 4                                                 Nature
# ...                                                  ...
# 50087                                    Springer eBooks
# 50088                                    Elsevier eBooks
# 50089                                    Springer eBooks
# 50090                                               <NA>
# 50091                  Realidad económica (Buenos Aires)
#
#       primary_location.source.host_organization  \
# 0              https://openalex.org/P4310311669
# 1              https://openalex.org/P4310319748
# 2              https://openalex.org/P4310311648
# 3                                          <NA>
# 4              https://openalex.org/P4310319908
# ...                                         ...
# 50087          https://openalex.org/P4310319965
# 50088          https://openalex.org/P4310320990
# 50089          https://openalex.org/P4310319965
# 50090                                      <NA>
# 50091                                      <NA>
#
#       primary_location.source.host_organization_name  \
# 0                               Institute of Physics
# 1                                       EDP Sciences
# 2                            Oxford University Press
# 3                                               <NA>
# 4                                   Nature Portfolio
# ...                                              ...
# 50087                                Springer Nature
# 50088                                    Elsevier BV
# 50089                                Springer Nature
# 50090                                           <NA>
# 50091                                           <NA>
#
#              primary_location.source.id  primary_location.source.is_core  \
# 0       https://openalex.org/S116045149                             True
# 1       https://openalex.org/S205231332                             True
# 2       https://openalex.org/S195663288                             True
# 3                                  <NA>                             <NA>
# 4       https://openalex.org/S137773608                             True
# ...                                 ...                              ...
# 50087  https://openalex.org/S4306463937                            False
# 50088  https://openalex.org/S4306463230                            False
# 50089  https://openalex.org/S4306463937                            False
# 50090                              <NA>                             <NA>
# 50091  https://openalex.org/S4306525427                            False
#
#        primary_location.source.is_in_doaj  \
# 0                                   False
# 1                                   False
# 2                                   False
# 3                                    <NA>
# 4                                   False
# ...                                   ...
# 50087                               False
# 50088                               False
# 50089                               False
# 50090                                <NA>
# 50091                               False
#
#        primary_location.source.is_indexed_in_scopus  \
# 0                                              True
# 1                                              True
# 2                                              True
# 3                                              <NA>
# 4                                              True
# ...                                             ...
# 50087                                         False
# 50088                                         False
# 50089                                         False
# 50090                                          <NA>
# 50091                                         False
#
#        primary_location.source.is_oa primary_location.source.issn_l  \
# 0                              False                      1748-0221
# 1                              False                      0004-6361
# 2                              False                      0035-8711
# 3                               <NA>                           <NA>
# 4                              False                      0028-0836
# ...                              ...                            ...
# 50087                          False                           <NA>
# 50088                          False                           <NA>
# 50089                          False                           <NA>
# 50090                           <NA>                           <NA>
# 50091                          False                           <NA>
#
#       primary_location.source.type  primary_location.source  \
# 0                          journal                     <NA>
# 1                          journal                     <NA>
# 2                          journal                     <NA>
# 3                             <NA>                     <NA>
# 4                          journal                     <NA>
# ...                            ...                      ...
# 50087               ebook platform                     <NA>
# 50088               ebook platform                     <NA>
# 50089               ebook platform                     <NA>
# 50090                         <NA>                     <NA>
# 50091                      journal                     <NA>
#
#        any_repository_has_fulltext  is_oa oa_status  \
# 0                             True   True     green
# 1                             True   True    bronze
# 2                             True   True    bronze
# 3                            False  False    closed
# 4                             True   True    hybrid
# ...                            ...    ...       ...
# 50087                        False  False    closed
# 50088                        False  False    closed
# 50089                        False  False    closed
# 50090                        False  False    closed
# 50091                        False  False    closed
#
#                                                   oa_url apc_list.currency  \
# 0          https://doi.org/10.1088/1748-0221/3/08/s08003              <NA>
# 1      https://www.aanda.org/articles/aa/pdf/2005/35/...              <NA>
# 2      https://academic.oup.com/mnras/article-pdf/470...               GBP
# 3                                                   <NA>              <NA>
# 4        https://www.nature.com/articles/nature10158.pdf               EUR
# ...                                                  ...               ...
# 50087                                               <NA>              <NA>
# 50088                                               <NA>              <NA>
# 50089                                               <NA>              <NA>
# 50090                                               <NA>              <NA>
# 50091                                               <NA>              <NA>
#
#       apc_list.provenance  apc_list.value  apc_list.value_usd  \
# 0                    <NA>            <NA>                <NA>
# 1                    <NA>            <NA>                <NA>
# 2                    <NA>            2310                2833
# 3                    <NA>            <NA>                <NA>
# 4                    <NA>            9750               11690
# ...                   ...             ...                 ...
# 50087                <NA>            <NA>                <NA>
# 50088                <NA>            <NA>                <NA>
# 50089                <NA>            <NA>                <NA>
# 50090                <NA>            <NA>                <NA>
# 50091                <NA>            <NA>                <NA>
#
#       apc_paid.currency apc_paid.provenance  apc_paid.value  \
# 0                  <NA>                <NA>            <NA>
# 1                  <NA>                <NA>            <NA>
# 2                  <NA>                <NA>            <NA>
# 3                  <NA>                <NA>            <NA>
# 4                   EUR                <NA>            9750
# ...                 ...                 ...             ...
# 50087              <NA>                <NA>            <NA>
# 50088              <NA>                <NA>            <NA>
# 50089              <NA>                <NA>            <NA>
# 50090              <NA>                <NA>            <NA>
# 50091              <NA>                <NA>            <NA>
#
#        apc_paid.value_usd  \
# 0                    <NA>
# 1                    <NA>
# 2                    <NA>
# 3                    <NA>
# 4                   11690
# ...                   ...
# 50087                <NA>
# 50088                <NA>
# 50089                <NA>
# 50090                <NA>
# 50091                <NA>
#
#        citation_normalized_percentile.is_in_top_10_percent  \
# 0                                                   True
# 1                                                   True
# 2                                                   True
# 3                                                  False
# 4                                                   True
# ...                                                  ...
# 50087                                              False
# 50088                                              False
# 50089                                              False
# 50090                                              False
# 50091                                              False
#
#        citation_normalized_percentile.is_in_top_1_percent  \
# 0                                                   True
# 1                                                   True
# 2                                                   True
# 3                                                  False
# 4                                                  False
# ...                                                  ...
# 50087                                              False
# 50088                                              False
# 50089                                              False
# 50090                                              False
# 50091                                              False
#
#        citation_normalized_percentile.value  cited_by_percentile_year.max  \
# 0                                  0.999911                           100
# 1                                  0.999905                           100
# 2                                  0.999955                           100
# 3                                  0.597403                           100
# 4                                  0.961554                           100
# ...                                     ...                           ...
# 50087                                   0.0                            53
# 50088                                   0.0                            53
# 50089                                   0.0                            53
# 50090                                   0.0                            53
# 50091                                   0.0                            53
#
#        cited_by_percentile_year.min biblio.first_page biblio.issue  \
# 0                                99            S08003           08
# 1                                99               775            2
# 2                                99              2617            3
# 3                                99              <NA>         <NA>
# 4                                99               189         7355
# ...                             ...               ...          ...
# 50087                             0               331         <NA>
# 50088                             0               215         <NA>
# 50089                             0               203         <NA>
# 50090                             0               233           92
# 50091                             0               125         <NA>
#
#       biblio.last_page biblio.volume  \
# 0               S08003             3
# 1                  782           440
# 2                 2652           470
# 3                 <NA>          <NA>
# 4                  195           475
# ...                ...           ...
# 50087              337          <NA>
# 50088              219          <NA>
# 50089              217          <NA>
# 50090              242            10
# 50091              136          <NA>
#
#                               primary_topic.display_name  \
# 0          Particle Detector Development and Performance
# 1                      Astrophysics and Cosmic Phenomena
# 2              Galaxies: Formation, Evolution, Phenomena
# 3      Particle physics theoretical and experimental ...
# 4                         Plant Pathogens and Resistance
# ...                                                  ...
# 50087                          Quantum many-body systems
# 50088                       Matrix Theory and Algorithms
# 50089         Physics of Superconductivity and Magnetism
# 50090   Geological and Tectonic Studies in Latin America
# 50091                         Economic Theory and Policy
#
#                   primary_topic.id  primary_topic.score  \
# 0      https://openalex.org/T11044                  1.0
# 1      https://openalex.org/T10818               0.9999
# 2      https://openalex.org/T10026               0.9998
# 3      https://openalex.org/T10048               0.9999
# 4      https://openalex.org/T11771               0.9998
# ...                            ...                  ...
# 50087  https://openalex.org/T11804               0.9975
# 50088  https://openalex.org/T10792               0.9994
# 50089  https://openalex.org/T10037                  1.0
# 50090  https://openalex.org/T13404               0.9901
# 50091  https://openalex.org/T11742               0.6047
#
#       primary_topic.domain.display_name         primary_topic.domain.id  \
# 0                     Physical Sciences  https://openalex.org/domains/3
# 1                     Physical Sciences  https://openalex.org/domains/3
# 2                     Physical Sciences  https://openalex.org/domains/3
# 3                     Physical Sciences  https://openalex.org/domains/3
# 4                         Life Sciences  https://openalex.org/domains/1
# ...                                 ...                             ...
# 50087                 Physical Sciences  https://openalex.org/domains/3
# 50088                 Physical Sciences  https://openalex.org/domains/3
# 50089                 Physical Sciences  https://openalex.org/domains/3
# 50090                 Physical Sciences  https://openalex.org/domains/3
# 50091                   Social Sciences  https://openalex.org/domains/2
#
#            primary_topic.field.display_name          primary_topic.field.id  \
# 0                     Physics and Astronomy  https://openalex.org/fields/31
# 1                     Physics and Astronomy  https://openalex.org/fields/31
# 2                     Physics and Astronomy  https://openalex.org/fields/31
# 3                     Physics and Astronomy  https://openalex.org/fields/31
# 4      Agricultural and Biological Sciences  https://openalex.org/fields/11
# ...                                     ...                             ...
# 50087                 Physics and Astronomy  https://openalex.org/fields/31
# 50088                      Computer Science  https://openalex.org/fields/17
# 50089                 Physics and Astronomy  https://openalex.org/fields/31
# 50090          Earth and Planetary Sciences  https://openalex.org/fields/19
# 50091   Economics, Econometrics and Finance  https://openalex.org/fields/20
#
#                primary_topic.subfield.display_name  \
# 0                  Nuclear and High Energy Physics
# 1                  Nuclear and High Energy Physics
# 2                       Astronomy and Astrophysics
# 3                  Nuclear and High Energy Physics
# 4                                    Plant Science
# ...                                            ...
# 50087     Atomic and Molecular Physics, and Optics
# 50088         Computational Theory and Mathematics
# 50089                     Condensed Matter Physics
# 50090                                   Geophysics
# 50091  General Economics, Econometrics and Finance
#
#                  primary_topic.subfield.id  best_oa_location.is_accepted  \
# 0      https://openalex.org/subfields/3106                          True
# 1      https://openalex.org/subfields/3106                          True
# 2      https://openalex.org/subfields/3103                          True
# 3      https://openalex.org/subfields/3106                          <NA>
# 4      https://openalex.org/subfields/1110                          True
# ...                                    ...                           ...
# 50087  https://openalex.org/subfields/3107                          <NA>
# 50088  https://openalex.org/subfields/1703                          <NA>
# 50089  https://openalex.org/subfields/3104                          <NA>
# 50090  https://openalex.org/subfields/1908                          <NA>
# 50091  https://openalex.org/subfields/2000                          <NA>
#
#        best_oa_location.is_oa  best_oa_location.is_published  \
# 0                        True                           True
# 1                        True                           True
# 2                        True                           True
# 3                        <NA>                           <NA>
# 4                        True                           True
# ...                       ...                            ...
# 50087                    <NA>                           <NA>
# 50088                    <NA>                           <NA>
# 50089                    <NA>                           <NA>
# 50090                    <NA>                           <NA>
# 50091                    <NA>                           <NA>
#
#                    best_oa_location.landing_page_url best_oa_location.license  \
# 0      https://doi.org/10.1088/1748-0221/3/08/s08003                     <NA>
# 1         https://doi.org/10.1051/0004-6361:20041864                     <NA>
# 2               https://doi.org/10.1093/mnras/stx721                     <NA>
# 3                                               <NA>                     <NA>
# 4                https://doi.org/10.1038/nature10158              cc-by-nc-sa
# ...                                              ...                      ...
# 50087                                           <NA>                     <NA>
# 50088                                           <NA>                     <NA>
# 50089                                           <NA>                     <NA>
# 50090                                           <NA>                     <NA>
# 50091                                           <NA>                     <NA>
#
#                      best_oa_location.license_id  \
# 0                                           <NA>
# 1                                           <NA>
# 2                                           <NA>
# 3                                           <NA>
# 4      https://openalex.org/licenses/cc-by-nc-sa
# ...                                          ...
# 50087                                       <NA>
# 50088                                       <NA>
# 50089                                       <NA>
# 50090                                       <NA>
# 50091                                       <NA>
#
#                                 best_oa_location.pdf_url  \
# 0                                                   <NA>
# 1      https://www.aanda.org/articles/aa/pdf/2005/35/...
# 2      https://academic.oup.com/mnras/article-pdf/470...
# 3                                                   <NA>
# 4        https://www.nature.com/articles/nature10158.pdf
# ...                                                  ...
# 50087                                               <NA>
# 50088                                               <NA>
# 50089                                               <NA>
# 50090                                               <NA>
# 50091                                               <NA>
#
#       best_oa_location.version  \
# 0             publishedVersion
# 1             publishedVersion
# 2             publishedVersion
# 3                         <NA>
# 4             publishedVersion
# ...                        ...
# 50087                     <NA>
# 50088                     <NA>
# 50089                     <NA>
# 50090                     <NA>
# 50091                     <NA>
#
#                     best_oa_location.source.display_name  \
# 0                             Journal of Instrumentation
# 1                             Astronomy and Astrophysics
# 2      Monthly Notices of the Royal Astronomical Society
# 3                                                   <NA>
# 4                                                 Nature
# ...                                                  ...
# 50087                                               <NA>
# 50088                                               <NA>
# 50089                                               <NA>
# 50090                                               <NA>
# 50091                                               <NA>
#
#       best_oa_location.source.host_organization  \
# 0              https://openalex.org/P4310311669
# 1              https://openalex.org/P4310319748
# 2              https://openalex.org/P4310311648
# 3                                          <NA>
# 4              https://openalex.org/P4310319908
# ...                                         ...
# 50087                                      <NA>
# 50088                                      <NA>
# 50089                                      <NA>
# 50090                                      <NA>
# 50091                                      <NA>
#
#       best_oa_location.source.host_organization_name  \
# 0                               Institute of Physics
# 1                                       EDP Sciences
# 2                            Oxford University Press
# 3                                               <NA>
# 4                                   Nature Portfolio
# ...                                              ...
# 50087                                           <NA>
# 50088                                           <NA>
# 50089                                           <NA>
# 50090                                           <NA>
# 50091                                           <NA>
#
#             best_oa_location.source.id  best_oa_location.source.is_core  \
# 0      https://openalex.org/S116045149                             True
# 1      https://openalex.org/S205231332                             True
# 2      https://openalex.org/S195663288                             True
# 3                                 <NA>                             <NA>
# 4      https://openalex.org/S137773608                             True
# ...                                ...                              ...
# 50087                             <NA>                             <NA>
# 50088                             <NA>                             <NA>
# 50089                             <NA>                             <NA>
# 50090                             <NA>                             <NA>
# 50091                             <NA>                             <NA>
#
#        best_oa_location.source.is_in_doaj  \
# 0                                   False
# 1                                   False
# 2                                   False
# 3                                    <NA>
# 4                                   False
# ...                                   ...
# 50087                                <NA>
# 50088                                <NA>
# 50089                                <NA>
# 50090                                <NA>
# 50091                                <NA>
#
#        best_oa_location.source.is_indexed_in_scopus  \
# 0                                              True
# 1                                              True
# 2                                              True
# 3                                              <NA>
# 4                                              True
# ...                                             ...
# 50087                                          <NA>
# 50088                                          <NA>
# 50089                                          <NA>
# 50090                                          <NA>
# 50091                                          <NA>
#
#        best_oa_location.source.is_oa       best_oa_location.source.issn  \
# 0                              False                        [1748-0221]
# 1                              False             [0004-6361, 1432-0746]
# 2                              False  [0035-8711, 1365-8711, 1365-2966]
# 3                               <NA>                                NaN
# 4                              False             [0028-0836, 1476-4687]
# ...                              ...                                ...
# 50087                           <NA>                                NaN
# 50088                           <NA>                                NaN
# 50089                           <NA>                                NaN
# 50090                           <NA>                                NaN
# 50091                           <NA>                                NaN
#
#       best_oa_location.source.issn_l best_oa_location.source.type  \
# 0                          1748-0221                      journal
# 1                          0004-6361                      journal
# 2                          0035-8711                      journal
# 3                               <NA>                         <NA>
# 4                          0028-0836                      journal
# ...                              ...                          ...
# 50087                           <NA>                         <NA>
# 50088                           <NA>                         <NA>
# 50089                           <NA>                         <NA>
# 50090                           <NA>                         <NA>
# 50091                           <NA>                         <NA>
#
#        best_oa_location.source              load_datetime
# 0                         <NA> 2025-03-02 18:16:04.238744
# 1                         <NA> 2025-03-02 18:16:04.238744
# 2                         <NA> 2025-03-02 18:16:04.238744
# 3                         <NA> 2025-03-02 18:16:04.238744
# 4                         <NA> 2025-03-02 18:16:04.238744
# ...                        ...                        ...
# 50087                     <NA> 2025-03-02 18:16:04.238744
# 50088                     <NA> 2025-03-02 18:16:04.238744
# 50089                     <NA> 2025-03-02 18:16:04.238744
# 50090                     <NA> 2025-03-02 18:16:04.238744
# 50091                     <NA> 2025-03-02 18:16:04.238744
#
# [50092 rows x 96 columns]
