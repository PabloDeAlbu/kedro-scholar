# %%
import pandas as pd
from pandas import json_normalize
from datetime import date
pd.set_option('display.max_columns', None)
import pyarrow.dataset as ds

# %%
df_work_raw = catalog.load('raw/openalex/work#parquet')
# Out:
# ╭─────────────────────────────── Traceback (most recent call last) ────────────────────────────────╮
# │ in <module>:1                                                                                    │
# │                                                                                                  │
# │ ❱ 1 catalog.datasets.raw/openalex/work#parquet._get_load_path()                                  │
# │   2                                                                                              │
# ╰──────────────────────────────────────────────────────────────────────────────────────────────────╯
# AttributeError: '_FrozenDatasets' object has no attribute 'raw'

# %% [markdown]
# # Profiling

# %%
df_work_raw.shape

# %%
df_work_raw.head(3)

# %%
df_work_raw = df_work_raw.convert_dtypes()
df_work_raw.dtypes

# %% [markdown]
# # Nodo

# %%
def land_work_openalex(df_work_raw):
    df_work = df_work_raw.loc[:,['id','ids']]
    df_work = df_work.convert_dtypes()
    df_work
    return df_work

# %% [markdown]
# ## Ejecuto Nodo

# %%
df_work = land_work_openalex(df_work_raw)

# %% [markdown]
# # Resultados

# %%
df_work
