# %%
import pandas as pd
from ydata_profiling import ProfileReport

df = catalog.load('stg/openaire/fact_publication_openaire')
profile = ProfileReport(df, title="Perfilamiento de Datos recuperados de OpenAIRE Graph - fact_publication")
profile.to_notebook_iframe()  # Genera un reporte interactivo
# Out:
# [12/12/24 11:15:52] INFO     Loading data from stg/openaire/fact_publication_openaire           ]8;id=524993;file:///root/kedro-cic/.venv/lib/python3.10/site-packages/kedro/io/data_catalog.py\data_catalog.py]8;;\:]8;id=124107;file:///root/kedro-cic/.venv/lib/python3.10/site-packages/kedro/io/data_catalog.py#389\389]8;;\
#                              (SQLTableDataset)...
# ...
# Render HTML:   0%|          | 0/1 [00:00<?, ?it/s]
# <pre style="white-space:pre;overflow-x:auto;line-height:normal;font-family:Menlo,'DejaVu Sans Mono',consolas,'Courier New',monospace"></pre>
# <IPython.core.display.HTML object>
