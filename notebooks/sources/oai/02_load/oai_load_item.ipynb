# %%
from datetime import date
import pandas as pd

pd.set_option('display.max_columns', None)
pd.set_option('display.max_rows', 5)

df_item_raw = catalog.load('raw/oai/item#parquet')
# Out:
#                     INFO     Loading data from raw/oai/item#parquet (ParquetDataset)...         ]8;id=670682;file:///home/pablo/.local/lib/python3.10/site-packages/kedro/io/data_catalog.py\data_catalog.py]8;;\:]8;id=807398;file:///home/pablo/.local/lib/python3.10/site-packages/kedro/io/data_catalog.py#389\389]8;;\

# %%
df_item_raw
# Out:
# <pre style="white-space:pre;overflow-x:auto;line-height:normal;font-family:Menlo,'DejaVu Sans Mono',consolas,'Courier New',monospace"></pre>
#                                 item_id         col_id  \
# 0    oai:ri.conicet.gov.ar:11336/215406  col_11336_279
# 1    oai:ri.conicet.gov.ar:11336/140529  col_11336_279
# ..                                  ...            ...
# 195  oai:ri.conicet.gov.ar:11336/235556  col_11336_279
# 196    oai:ri.conicet.gov.ar:11336/7132  col_11336_279
#
#                                                  title date_issued  \
# 0    Estrategias de fertilización nitrogenada para ...     2019-07
# 1    3D litho-constrained inversion model of southe...  2019-04-05
# ..                                                 ...         ...
# 195  Cultural Liminality and the Construction of a ...     2021-05
# 196  Simulating Behaviours to Face up an  Emergency...     2014-02
#
#                                               creators  \
# 0    [Dillchneider Loza, Alexandra, Frasier, Ileana...
# 1    [Christiansen, Rodolfo Omar, Morosini, Augusto...
# ..                                                 ...
# 195                       [Puchmüller, Andrea Bibiana]
# 196  [Tissera, Pablo Cristian, Castro, Alicia, Prin...
#
#                                                  types  \
# 0    [info:eu-repo/semantics/article, info:ar-repo/...
# 1    [info:eu-repo/semantics/article, info:ar-repo/...
# ..                                                 ...
# 195  [info:eu-repo/semantics/article, info:ar-repo/...
# 196  [info:eu-repo/semantics/article, info:ar-repo/...
#
#                                            identifiers languages  \
# 0    [http://hdl.handle.net/11336/215406, Dillchnei...     [spa]
# 1    [http://hdl.handle.net/11336/140529, Christian...     [eng]
# ..                                                 ...       ...
# 195  [http://hdl.handle.net/11336/235556, Puchmülle...     [eng]
# 196  [http://hdl.handle.net/11336/7132, Tissera, Pa...     [eng]
#
#                                               subjects  \
# 0    [TEXTURA DEL SUELO, EFICIENCIA DE USO DEL NITR...
# 1    [DOUBLY-VERGENT STRUCTURE, FAMATINIAN COLLISIO...
# ..                                                 ...
# 195  [THE COURTER, RUSHDIE, HYBRIDITY, DIFFERENCE, ...
# 196  [EVACUATION SIMULATION, BEHAVIORS, CELLULAR AU...
#
#                                             publishers  \
# 0    [Universidad Nacional de La Pampa. Facultad de...
# 1                                   [Elsevier Science]
# ..                                                 ...
# 195                      [Acharya Nagarjuna Unversity]
# 196                      [Advanced Academic Publisher]
#
#                                              relations  \
# 0    [info:eu-repo/semantics/altIdentifier/url/http...
# 1    [info:eu-repo/semantics/altIdentifier/url/http...
# ..                                                 ...
# 195  [info:eu-repo/semantics/altIdentifier/url/http...
# 196  [info:eu-repo/semantics/altIdentifier/doi/10.7...
#
#                                                 rights  \
# 0    [info:eu-repo/semantics/openAccess, https://cr...
# 1    [info:eu-repo/semantics/openAccess, https://cr...
# ..                                                 ...
# 195  [info:eu-repo/semantics/openAccess, https://cr...
# 196  [info:eu-repo/semantics/openAccess, https://cr...
#
#              extract_datetime             load_datetime
# 0   2025-11-25 00:00:00+00:00 2025-11-25 00:00:00+00:00
# 1   2025-11-25 00:00:00+00:00 2025-11-25 00:00:00+00:00
# ..                        ...                       ...
# 195 2025-11-25 00:00:00+00:00 2025-11-25 00:00:00+00:00
# 196 2025-11-25 00:00:00+00:00 2025-11-25 00:00:00+00:00
#
# [197 rows x 14 columns]

# %% [markdown]
# ## Paso 1: Convierto tipos y selecciono columnas con cardinalidad 1 con respecto a cada research product
# + info en https://graph.openaire.eu/docs/data-model/entities/research-product

# %%
def oai_load_item(df_item_raw: pd.DataFrame)-> pd.DataFrame:

    df_item = df_item_raw[['item_id','col_id','title','date_issued', 'extract_datetime']]
    df_item_creators = df_item_raw[['item_id','creators', 'extract_datetime']]
    df_item_types = df_item_raw[['item_id','types', 'extract_datetime']]
    df_item_identifiers = df_item_raw[['item_id','identifiers', 'extract_datetime']]
    df_item_languages = df_item_raw[['item_id','languages', 'extract_datetime']]
    df_item_subjects = df_item_raw[['item_id','subjects', 'extract_datetime']]
    df_item_publishers = df_item_raw[['item_id','publishers', 'extract_datetime']]
    df_item_relations = df_item_raw[['item_id','relations', 'extract_datetime']]
    df_item_rights = df_item_raw[['item_id','rights', 'extract_datetime']]

    df_item_creators = df_item_creators.explode('creators')
    df_item_types = df_item_types.explode('types')
    df_item_identifiers = df_item_identifiers.explode('identifiers')
    df_item_languages = df_item_languages.explode('languages')
    df_item_subjects = df_item_subjects.explode('subjects')
    df_item_publishers = df_item_publishers.explode('publishers')
    df_item_relations = df_item_relations.explode('relations')
    df_item_rights = df_item_rights.explode('rights')

    df_item['load_datetime'] =  pd.Timestamp.now(tz="UTC").normalize()
    df_item_creators['load_datetime'] = pd.Timestamp.now(tz="UTC").normalize()
    df_item_types['load_datetime'] = pd.Timestamp.now(tz="UTC").normalize()
    df_item_identifiers['load_datetime'] = pd.Timestamp.now(tz="UTC").normalize()
    df_item_languages['load_datetime'] = pd.Timestamp.now(tz="UTC").normalize()
    df_item_subjects['load_datetime'] = pd.Timestamp.now(tz="UTC").normalize()
    df_item_publishers['load_datetime'] = pd.Timestamp.now(tz="UTC").normalize()
    df_item_relations['load_datetime'] = pd.Timestamp.now(tz="UTC").normalize()
    df_item_rights['load_datetime'] = pd.Timestamp.now(tz="UTC").normalize()

    return df_item, df_item_creators, df_item_types, df_item_identifiers, df_item_languages, df_item_subjects, df_item_publishers, df_item_relations, df_item_rights

# %%
df_item, df_item_creators, df_item_types, \
    df_item_identifiers, df_item_languages, df_item_subjects, \
        df_item_publishers, df_item_relations, df_item_rights = oai_load_item(df_item_raw)
# Out:
# [11/25/25 10:10:29] WARNING  /tmp/ipykernel_95668/261600149.py:22: SettingWithCopyWarning:          ]8;id=265593;file:///usr/lib/python3.10/warnings.py\warnings.py]8;;\:]8;id=901913;file:///usr/lib/python3.10/warnings.py#109\109]8;;\
#                              A value is trying to be set on a copy of a slice from a DataFrame.
#                              Try using .loc[row_indexer,col_indexer] = value instead
#
#                              See the caveats in the documentation:
#                              https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#
#                              returning-a-view-versus-a-copy
#                                df_item['load_datetime'] =  pd.Timestamp.now(tz="UTC").normalize()

# %%
df_item
# Out:
# <pre style="white-space:pre;overflow-x:auto;line-height:normal;font-family:Menlo,'DejaVu Sans Mono',consolas,'Courier New',monospace"></pre>
#                                 item_id         col_id  \
# 0    oai:ri.conicet.gov.ar:11336/215406  col_11336_279
# 1    oai:ri.conicet.gov.ar:11336/140529  col_11336_279
# ..                                  ...            ...
# 195  oai:ri.conicet.gov.ar:11336/235556  col_11336_279
# 196    oai:ri.conicet.gov.ar:11336/7132  col_11336_279
#
#                                                  title date_issued  \
# 0    Estrategias de fertilización nitrogenada para ...     2019-07
# 1    3D litho-constrained inversion model of southe...  2019-04-05
# ..                                                 ...         ...
# 195  Cultural Liminality and the Construction of a ...     2021-05
# 196  Simulating Behaviours to Face up an  Emergency...     2014-02
#
#              extract_datetime             load_datetime
# 0   2025-11-25 00:00:00+00:00 2025-11-25 00:00:00+00:00
# 1   2025-11-25 00:00:00+00:00 2025-11-25 00:00:00+00:00
# ..                        ...                       ...
# 195 2025-11-25 00:00:00+00:00 2025-11-25 00:00:00+00:00
# 196 2025-11-25 00:00:00+00:00 2025-11-25 00:00:00+00:00
#
# [197 rows x 6 columns]

# %%
df_item_creators
# Out:
# <pre style="white-space:pre;overflow-x:auto;line-height:normal;font-family:Menlo,'DejaVu Sans Mono',consolas,'Courier New',monospace"></pre>
#                                 item_id                      creators  \
# 0    oai:ri.conicet.gov.ar:11336/215406  Dillchneider Loza, Alexandra
# 0    oai:ri.conicet.gov.ar:11336/215406               Frasier, Ileana
# ..                                  ...                           ...
# 196    oai:ri.conicet.gov.ar:11336/7132     Printista, Alicia Marcela
# 196    oai:ri.conicet.gov.ar:11336/7132                 Luque, Emilio
#
#              extract_datetime             load_datetime
# 0   2025-11-25 00:00:00+00:00 2025-11-25 00:00:00+00:00
# 0   2025-11-25 00:00:00+00:00 2025-11-25 00:00:00+00:00
# ..                        ...                       ...
# 196 2025-11-25 00:00:00+00:00 2025-11-25 00:00:00+00:00
# 196 2025-11-25 00:00:00+00:00 2025-11-25 00:00:00+00:00
#
# [777 rows x 4 columns]

# %%
df_item_types
# Out:
# <pre style="white-space:pre;overflow-x:auto;line-height:normal;font-family:Menlo,'DejaVu Sans Mono',consolas,'Courier New',monospace"></pre>
#                                 item_id  \
# 0    oai:ri.conicet.gov.ar:11336/215406
# 0    oai:ri.conicet.gov.ar:11336/215406
# ..                                  ...
# 196    oai:ri.conicet.gov.ar:11336/7132
# 196    oai:ri.conicet.gov.ar:11336/7132
#
#                                        types          extract_datetime  \
# 0             info:eu-repo/semantics/article 2025-11-25 00:00:00+00:00
# 0            info:ar-repo/semantics/artículo 2025-11-25 00:00:00+00:00
# ..                                       ...                       ...
# 196          info:ar-repo/semantics/artículo 2025-11-25 00:00:00+00:00
# 196  info:eu-repo/semantics/publishedVersion 2025-11-25 00:00:00+00:00
#
#                 load_datetime
# 0   2025-11-25 00:00:00+00:00
# 0   2025-11-25 00:00:00+00:00
# ..                        ...
# 196 2025-11-25 00:00:00+00:00
# 196 2025-11-25 00:00:00+00:00
#
# [591 rows x 4 columns]

# %%
df_item_identifiers
# Out:
# <pre style="white-space:pre;overflow-x:auto;line-height:normal;font-family:Menlo,'DejaVu Sans Mono',consolas,'Courier New',monospace"></pre>
#                                 item_id  \
# 0    oai:ri.conicet.gov.ar:11336/215406
# 0    oai:ri.conicet.gov.ar:11336/215406
# ..                                  ...
# 196    oai:ri.conicet.gov.ar:11336/7132
# 196    oai:ri.conicet.gov.ar:11336/7132
#
#                                            identifiers  \
# 0                   http://hdl.handle.net/11336/215406
# 0    Dillchneider Loza, Alexandra; Frasier, Ileana;...
# ..                                                 ...
# 196  Tissera, Pablo Cristian; Castro, Alicia; Print...
# 196                                          2251-7545
#
#              extract_datetime             load_datetime
# 0   2025-11-25 00:00:00+00:00 2025-11-25 00:00:00+00:00
# 0   2025-11-25 00:00:00+00:00 2025-11-25 00:00:00+00:00
# ..                        ...                       ...
# 196 2025-11-25 00:00:00+00:00 2025-11-25 00:00:00+00:00
# 196 2025-11-25 00:00:00+00:00 2025-11-25 00:00:00+00:00
#
# [970 rows x 4 columns]

# %%
df_item_languages
# Out:
# <pre style="white-space:pre;overflow-x:auto;line-height:normal;font-family:Menlo,'DejaVu Sans Mono',consolas,'Courier New',monospace"></pre>
#                                 item_id languages          extract_datetime  \
# 0    oai:ri.conicet.gov.ar:11336/215406       spa 2025-11-25 00:00:00+00:00
# 1    oai:ri.conicet.gov.ar:11336/140529       eng 2025-11-25 00:00:00+00:00
# ..                                  ...       ...                       ...
# 195  oai:ri.conicet.gov.ar:11336/235556       eng 2025-11-25 00:00:00+00:00
# 196    oai:ri.conicet.gov.ar:11336/7132       eng 2025-11-25 00:00:00+00:00
#
#                 load_datetime
# 0   2025-11-25 00:00:00+00:00
# 1   2025-11-25 00:00:00+00:00
# ..                        ...
# 195 2025-11-25 00:00:00+00:00
# 196 2025-11-25 00:00:00+00:00
#
# [197 rows x 4 columns]

# %%
df_item_subjects
# Out:
# <pre style="white-space:pre;overflow-x:auto;line-height:normal;font-family:Menlo,'DejaVu Sans Mono',consolas,'Courier New',monospace"></pre>
#                                 item_id                         subjects  \
# 0    oai:ri.conicet.gov.ar:11336/215406                TEXTURA DEL SUELO
# 0    oai:ri.conicet.gov.ar:11336/215406  EFICIENCIA DE USO DEL NITRÓGENO
# ..                                  ...                              ...
# 196    oai:ri.conicet.gov.ar:11336/7132  https://purl.org/becyt/ford/1.2
# 196    oai:ri.conicet.gov.ar:11336/7132    https://purl.org/becyt/ford/1
#
#              extract_datetime             load_datetime
# 0   2025-11-25 00:00:00+00:00 2025-11-25 00:00:00+00:00
# 0   2025-11-25 00:00:00+00:00 2025-11-25 00:00:00+00:00
# ..                        ...                       ...
# 196 2025-11-25 00:00:00+00:00 2025-11-25 00:00:00+00:00
# 196 2025-11-25 00:00:00+00:00 2025-11-25 00:00:00+00:00
#
# [1267 rows x 4 columns]

# %%
df_item_publishers
# Out:
# <pre style="white-space:pre;overflow-x:auto;line-height:normal;font-family:Menlo,'DejaVu Sans Mono',consolas,'Courier New',monospace"></pre>
#                                 item_id  \
# 0    oai:ri.conicet.gov.ar:11336/215406
# 1    oai:ri.conicet.gov.ar:11336/140529
# ..                                  ...
# 195  oai:ri.conicet.gov.ar:11336/235556
# 196    oai:ri.conicet.gov.ar:11336/7132
#
#                                             publishers  \
# 0    Universidad Nacional de La Pampa. Facultad de ...
# 1                                     Elsevier Science
# ..                                                 ...
# 195                        Acharya Nagarjuna Unversity
# 196                        Advanced Academic Publisher
#
#              extract_datetime             load_datetime
# 0   2025-11-25 00:00:00+00:00 2025-11-25 00:00:00+00:00
# 1   2025-11-25 00:00:00+00:00 2025-11-25 00:00:00+00:00
# ..                        ...                       ...
# 195 2025-11-25 00:00:00+00:00 2025-11-25 00:00:00+00:00
# 196 2025-11-25 00:00:00+00:00 2025-11-25 00:00:00+00:00
#
# [197 rows x 4 columns]

# %%
df_item_relations
# Out:
# <pre style="white-space:pre;overflow-x:auto;line-height:normal;font-family:Menlo,'DejaVu Sans Mono',consolas,'Courier New',monospace"></pre>
#                                 item_id  \
# 0    oai:ri.conicet.gov.ar:11336/215406
# 1    oai:ri.conicet.gov.ar:11336/140529
# ..                                  ...
# 196    oai:ri.conicet.gov.ar:11336/7132
# 196    oai:ri.conicet.gov.ar:11336/7132
#
#                                              relations  \
# 0    info:eu-repo/semantics/altIdentifier/url/https...
# 1    info:eu-repo/semantics/altIdentifier/url/https...
# ..                                                 ...
# 196  info:eu-repo/semantics/altIdentifier/arxiv/140...
# 196  info:eu-repo/semantics/altIdentifier/url/http:...
#
#              extract_datetime             load_datetime
# 0   2025-11-25 00:00:00+00:00 2025-11-25 00:00:00+00:00
# 1   2025-11-25 00:00:00+00:00 2025-11-25 00:00:00+00:00
# ..                        ...                       ...
# 196 2025-11-25 00:00:00+00:00 2025-11-25 00:00:00+00:00
# 196 2025-11-25 00:00:00+00:00 2025-11-25 00:00:00+00:00
#
# [358 rows x 4 columns]

# %%
df_item_rights
# Out:
# <pre style="white-space:pre;overflow-x:auto;line-height:normal;font-family:Menlo,'DejaVu Sans Mono',consolas,'Courier New',monospace"></pre>
#                                 item_id  \
# 0    oai:ri.conicet.gov.ar:11336/215406
# 0    oai:ri.conicet.gov.ar:11336/215406
# ..                                  ...
# 196    oai:ri.conicet.gov.ar:11336/7132
# 196    oai:ri.conicet.gov.ar:11336/7132
#
#                                                 rights  \
# 0                    info:eu-repo/semantics/openAccess
# 0    https://creativecommons.org/licenses/by-nc-sa/...
# ..                                                 ...
# 196                  info:eu-repo/semantics/openAccess
# 196    https://creativecommons.org/licenses/by/2.5/ar/
#
#              extract_datetime             load_datetime
# 0   2025-11-25 00:00:00+00:00 2025-11-25 00:00:00+00:00
# 0   2025-11-25 00:00:00+00:00 2025-11-25 00:00:00+00:00
# ..                        ...                       ...
# 196 2025-11-25 00:00:00+00:00 2025-11-25 00:00:00+00:00
# 196 2025-11-25 00:00:00+00:00 2025-11-25 00:00:00+00:00
#
# [396 rows x 4 columns]
