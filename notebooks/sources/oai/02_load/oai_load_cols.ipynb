# %%
from datetime import date
import pandas as pd

pd.set_option('display.max_columns', None)
pd.set_option('display.max_rows', 5)

df_cols = catalog.load('primary/oai/cols#parquet')
# Out:
#                     INFO     Loading data from primary/oai/cols#parquet (ParquetDataset)...     ]8;id=547396;file:///home/pablo/.local/lib/python3.10/site-packages/kedro/io/data_catalog.py\data_catalog.py]8;;\:]8;id=800049;file:///home/pablo/.local/lib/python3.10/site-packages/kedro/io/data_catalog.py#389\389]8;;\

# %%
df_cols
# Out:
# <pre style="white-space:pre;overflow-x:auto;line-height:normal;font-family:Menlo,'DejaVu Sans Mono',consolas,'Courier New',monospace"></pre>
#               setSpec            setName           extract_datetime  \
# 0       col_11336_373  Articulos(BIOMED)  2025-11-28 00:00:00+00:00
# 1       col_11336_466   Articulos(CADIC)  2025-11-28 00:00:00+00:00
# ...               ...                ...                        ...
# 2071  col_11336_48181          undefined  2025-11-28 00:00:00+00:00
# 2072  col_11336_64752          undefined  2025-11-28 00:00:00+00:00
#
#       is_col_set  is_com_set  completeListSize
# 0           True       False             377.0
# 1           True       False            1615.0
# ...          ...         ...               ...
# 2071        True       False               NaN
# 2072        True       False               NaN
#
# [2073 rows x 6 columns]

# %%
def oai_load_cols(df_cols: pd.DataFrame)-> pd.DataFrame:

    df_cols['load_datetime'] = pd.Timestamp.now(tz="UTC").normalize()

    return df_cols

# %%
df_cols = oai_load_cols(df_cols)

# %%
df_cols
# Out:
# <pre style="white-space:pre;overflow-x:auto;line-height:normal;font-family:Menlo,'DejaVu Sans Mono',consolas,'Courier New',monospace"></pre>
#               setSpec            setName           extract_datetime  \
# 0       col_11336_373  Articulos(BIOMED)  2025-11-28 00:00:00+00:00
# 1       col_11336_466   Articulos(CADIC)  2025-11-28 00:00:00+00:00
# ...               ...                ...                        ...
# 2071  col_11336_48181          undefined  2025-11-28 00:00:00+00:00
# 2072  col_11336_64752          undefined  2025-11-28 00:00:00+00:00
#
#       is_col_set  is_com_set  completeListSize             load_datetime
# 0           True       False             377.0 2025-11-28 00:00:00+00:00
# 1           True       False            1615.0 2025-11-28 00:00:00+00:00
# ...          ...         ...               ...                       ...
# 2071        True       False               NaN 2025-11-28 00:00:00+00:00
# 2072        True       False               NaN 2025-11-28 00:00:00+00:00
#
# [2073 rows x 7 columns]
