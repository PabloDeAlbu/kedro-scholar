# %%
import pandas as pd
from datetime import date

# %%
df_item_raw = catalog.load('raw/oai/item_by_set#parquet')
# Out:
# [06/09/25 19:24:21] INFO     Loading data from raw/oai/item_by_set#parquet (ParquetDataset)...  ]8;id=550404;file:///home/pablo/.local/lib/python3.10/site-packages/kedro/io/data_catalog.py\data_catalog.py]8;;\:]8;id=532172;file:///home/pablo/.local/lib/python3.10/site-packages/kedro/io/data_catalog.py#389\389]8;;\

# %%
df_item_raw
# Out:
# <pre style="white-space:pre;overflow-x:auto;line-height:normal;font-family:Menlo,'DejaVu Sans Mono',consolas,'Courier New',monospace"></pre>
# Empty DataFrame
# Columns: []
# Index: []

# %%
# Helper to safely get nth element from lists or tuples

def get_nth(x, n):
    try:
        if x is not None and len(x) > n:
            return x[n]
    except Exception:
        pass
    return None

# Helper to explode a column into its own dataframe

def explode_column(df_raw, col, new_col_name):
    df = df_raw[['handle', col]] \
        .dropna(subset=[col]) \
        .explode(col) 
    df = df.rename(columns={col: new_col_name})
    df['load_datetime'] = date.today()
    return df

# %%
def land_oai_item_by_set(df_item_raw):
    # Compute handle once
    df = df_item_raw.copy()
    df['handle'] = df_item_raw['identifiers'].apply(lambda x: x[0] if x is not None and len(x) > 0 else None)

    # Main item table
    df_item = pd.DataFrame({
        'item_id': df['item_id'],
        'handle':      df['handle'],
        'col_id':      df['col_id'],
        'title':       df['title'],
        'date_issued': df['date'],
        'type_openaire':    df['types'].apply(lambda x: get_nth(x, 0)),
        'type_snrd':        df['types'].apply(lambda x: get_nth(x, 1)),
        'version':          df['types'].apply(lambda x: get_nth(x, 2)),
        'access_right':     df['rights'].apply(lambda x: get_nth(x, 0)),
        'license_condition':df['rights'].apply(lambda x: get_nth(x, 1)),
    })
    df_item['load_datetime'] = date.today()

    # Explode multivalued fields
    df_item_creator   = explode_column(df, 'creators',  'creator')
    df_item_language  = explode_column(df, 'languages', 'language_iso')
    df_item_subject   = explode_column(df, 'subjects',  'subject')
    df_item_publisher = explode_column(df, 'publishers','publisher')
    df_item_relation  = explode_column(df, 'relations','relation')
    
    # Clean up relation URLs
    df_item_relation['relation'] = df_item_relation['relation'] \
        .str.replace('info:eu-repo/semantics/altIdentifier/url/', '', regex=False)

    return (
        df_item,
        df_item_creator,
        df_item_language,
        df_item_subject,
        df_item_relation,
        df_item_publisher
    )

# %%
df_item, df_item_creator, df_item_language, df_item_subject, df_item_relation, df_item_publisher = land_oai_item_by_set(df_item_raw)

# %%
df_item
# Out:
# <pre style="white-space:pre;overflow-x:auto;line-height:normal;font-family:Menlo,'DejaVu Sans Mono',consolas,'Courier New',monospace"></pre>
#                             item_oai_id                              handle  \
# 0    oai:ri.conicet.gov.ar:11336/181613  http://hdl.handle.net/11336/181613
# 1    oai:ri.conicet.gov.ar:11336/242335  http://hdl.handle.net/11336/242335
# 2    oai:ri.conicet.gov.ar:11336/255685  http://hdl.handle.net/11336/255685
# 3    oai:ri.conicet.gov.ar:11336/224725  http://hdl.handle.net/11336/224725
# 4    oai:ri.conicet.gov.ar:11336/123737  http://hdl.handle.net/11336/123737
# ..                                  ...                                 ...
# 350  oai:ri.conicet.gov.ar:11336/216872  http://hdl.handle.net/11336/216872
# 351  oai:ri.conicet.gov.ar:11336/216757  http://hdl.handle.net/11336/216757
# 352  oai:ri.conicet.gov.ar:11336/123896  http://hdl.handle.net/11336/123896
# 353  oai:ri.conicet.gov.ar:11336/181755  http://hdl.handle.net/11336/181755
# 354  oai:ri.conicet.gov.ar:11336/216310  http://hdl.handle.net/11336/216310
#
#                col_id                                              title  \
# 0    col_11336_109892  Hydrophilization of magnetic nanoparticles wit...
# 1    col_11336_109892  Structure of Zn x Fe3− x O4 nanoparticles stud...
# 2    col_11336_109892  Programa de Acompañamiento del Sueño en la Inf...
# 3    col_11336_109892  Flexible NbTiN thin films for superconducting ...
# 4    col_11336_109892  Self-calibrated double luminescent thermometer...
# ..                ...                                                ...
# 350  col_11336_109892  Low-temperature thermal expansion of the topol...
# 351  col_11336_109892  Response of the chiral soliton lattice to spin...
# 352  col_11336_109892  Study of BaCe0.4Zr0.4Y0.2O3-δ/BaCe0.8Pr0.2O3-δ...
# 353  col_11336_109892  Iron phthalocyanine on Au(111) is a “non-Landa...
# 354  col_11336_109892  Neutron imaging based on transfer foil activat...
#
#     date_issued                   type_openaire  \
# 0       2021-12  info:eu-repo/semantics/article
# 1       2024-07  info:eu-repo/semantics/article
# 2       2024-02  info:eu-repo/semantics/article
# 3       2023-03  info:eu-repo/semantics/article
# 4       2019-04  info:eu-repo/semantics/article
# ..          ...                             ...
# 350     2022-06  info:eu-repo/semantics/article
# 351     2022-09  info:eu-repo/semantics/article
# 352     2020-02  info:eu-repo/semantics/article
# 353     2021-10  info:eu-repo/semantics/article
# 354     2022-02  info:eu-repo/semantics/article
#
#                            type_snrd                                  version  \
# 0    info:ar-repo/semantics/artículo  info:eu-repo/semantics/publishedVersion
# 1    info:ar-repo/semantics/artículo  info:eu-repo/semantics/publishedVersion
# 2    info:ar-repo/semantics/artículo  info:eu-repo/semantics/publishedVersion
# 3    info:ar-repo/semantics/artículo  info:eu-repo/semantics/publishedVersion
# 4    info:ar-repo/semantics/artículo  info:eu-repo/semantics/publishedVersion
# ..                               ...                                      ...
# 350  info:ar-repo/semantics/artículo  info:eu-repo/semantics/publishedVersion
# 351  info:ar-repo/semantics/artículo  info:eu-repo/semantics/publishedVersion
# 352  info:ar-repo/semantics/artículo  info:eu-repo/semantics/publishedVersion
# 353  info:ar-repo/semantics/artículo  info:eu-repo/semantics/publishedVersion
# 354  info:ar-repo/semantics/artículo  info:eu-repo/semantics/publishedVersion
#
#                                 access_right  \
# 0    info:eu-repo/semantics/restrictedAccess
# 1          info:eu-repo/semantics/openAccess
# 2          info:eu-repo/semantics/openAccess
# 3    info:eu-repo/semantics/restrictedAccess
# 4          info:eu-repo/semantics/openAccess
# ..                                       ...
# 350  info:eu-repo/semantics/restrictedAccess
# 351        info:eu-repo/semantics/openAccess
# 352  info:eu-repo/semantics/restrictedAccess
# 353        info:eu-repo/semantics/openAccess
# 354  info:eu-repo/semantics/restrictedAccess
#
#                                      license_condition load_datetime
# 0    https://creativecommons.org/licenses/by-nc-nd/...    2025-05-30
# 1    https://creativecommons.org/licenses/by-nc-sa/...    2025-05-30
# 2    https://creativecommons.org/licenses/by-nc-nd/...    2025-05-30
# 3    https://creativecommons.org/licenses/by-nc-nd/...    2025-05-30
# 4      https://creativecommons.org/licenses/by/2.5/ar/    2025-05-30
# ..                                                 ...           ...
# 350  https://creativecommons.org/licenses/by-nc-sa/...    2025-05-30
# 351  https://creativecommons.org/licenses/by-nc-sa/...    2025-05-30
# 352  https://creativecommons.org/licenses/by-nc-sa/...    2025-05-30
# 353    https://creativecommons.org/licenses/by/2.5/ar/    2025-05-30
# 354  https://creativecommons.org/licenses/by-nc-sa/...    2025-05-30
#
# [355 rows x 11 columns]

# %%
df_item_creator
# Out:
# <pre style="white-space:pre;overflow-x:auto;line-height:normal;font-family:Menlo,'DejaVu Sans Mono',consolas,'Courier New',monospace"></pre>
#                                  handle                      creator  \
# 0    http://hdl.handle.net/11336/181613     Lavorato, Gabriel Carlos
# 0    http://hdl.handle.net/11336/181613        Azcárate, Julio César
# 0    http://hdl.handle.net/11336/181613    Rivas Aiello, Maria Belen
# 0    http://hdl.handle.net/11336/181613    Orozco Henao, Juan Manuel
# 0    http://hdl.handle.net/11336/181613         Mendoza Zélis, Pedro
# ..                                  ...                          ...
# 354  http://hdl.handle.net/11336/216310               Sánchez, F. A.
# 354  http://hdl.handle.net/11336/216310  Sofo Haro, Miguel Francisco
# 354  http://hdl.handle.net/11336/216310        Longhino, Juan Manuel
# 354  http://hdl.handle.net/11336/216310       Gomez Berisso, Mariano
# 354  http://hdl.handle.net/11336/216310      Blostein, Juan Jeronimo
#
#     load_datetime
# 0      2025-05-30
# 0      2025-05-30
# 0      2025-05-30
# 0      2025-05-30
# 0      2025-05-30
# ..            ...
# 354    2025-05-30
# 354    2025-05-30
# 354    2025-05-30
# 354    2025-05-30
# 354    2025-05-30
#
# [2216 rows x 3 columns]

# %%
df_item_language
# Out:
# <pre style="white-space:pre;overflow-x:auto;line-height:normal;font-family:Menlo,'DejaVu Sans Mono',consolas,'Courier New',monospace"></pre>
#                                  handle language_iso load_datetime
# 0    http://hdl.handle.net/11336/181613          eng    2025-05-30
# 1    http://hdl.handle.net/11336/242335          eng    2025-05-30
# 2    http://hdl.handle.net/11336/255685          eng    2025-05-30
# 3    http://hdl.handle.net/11336/224725          eng    2025-05-30
# 4    http://hdl.handle.net/11336/123737          eng    2025-05-30
# ..                                  ...          ...           ...
# 350  http://hdl.handle.net/11336/216872          eng    2025-05-30
# 351  http://hdl.handle.net/11336/216757          eng    2025-05-30
# 352  http://hdl.handle.net/11336/123896          eng    2025-05-30
# 353  http://hdl.handle.net/11336/181755          eng    2025-05-30
# 354  http://hdl.handle.net/11336/216310          eng    2025-05-30
#
# [355 rows x 3 columns]

# %%
df_item_subject
# Out:
# <pre style="white-space:pre;overflow-x:auto;line-height:normal;font-family:Menlo,'DejaVu Sans Mono',consolas,'Courier New',monospace"></pre>
#                                  handle  \
# 0    http://hdl.handle.net/11336/181613
# 0    http://hdl.handle.net/11336/181613
# 0    http://hdl.handle.net/11336/181613
# 0    http://hdl.handle.net/11336/181613
# 0    http://hdl.handle.net/11336/181613
# ..                                  ...
# 353  http://hdl.handle.net/11336/181755
# 354  http://hdl.handle.net/11336/216310
# 354  http://hdl.handle.net/11336/216310
# 354  http://hdl.handle.net/11336/216310
# 354  http://hdl.handle.net/11336/216310
#
#                                      subject load_datetime
# 0                        FE3O4 NANOPARTICLES    2025-05-30
# 0        INTERPARTICLE MAGNETIC INTERACTIONS    2025-05-30
# 0                     OLEATE CAPPING DENSITY    2025-05-30
# 0    POLY(MALEIC ANHYDRIDE ALT-1-OCTADECENE)    2025-05-30
# 0            POLYMER-NANOPARTICLE ASSEMBLIES    2025-05-30
# ..                                       ...           ...
# 353            https://purl.org/becyt/ford/1    2025-05-30
# 354                 INSPECTION WITH NEUTRONS    2025-05-30
# 354                      NEUTRON RADIOGRAPHY    2025-05-30
# 354          https://purl.org/becyt/ford/1.3    2025-05-30
# 354            https://purl.org/becyt/ford/1    2025-05-30
#
# [2191 rows x 3 columns]

# %%
df_item_relation
# Out:
# <pre style="white-space:pre;overflow-x:auto;line-height:normal;font-family:Menlo,'DejaVu Sans Mono',consolas,'Courier New',monospace"></pre>
#                                  handle  \
# 0    http://hdl.handle.net/11336/181613
# 0    http://hdl.handle.net/11336/181613
# 1    http://hdl.handle.net/11336/242335
# 1    http://hdl.handle.net/11336/242335
# 2    http://hdl.handle.net/11336/255685
# ..                                  ...
# 352  http://hdl.handle.net/11336/123896
# 353  http://hdl.handle.net/11336/181755
# 353  http://hdl.handle.net/11336/181755
# 354  http://hdl.handle.net/11336/216310
# 354  http://hdl.handle.net/11336/216310
#
#                                               relation load_datetime
# 0    https://www.sciencedirect.com/science/article/...    2025-05-30
# 0    info:eu-repo/semantics/altIdentifier/doi/10.10...    2025-05-30
# 1    https://pubs.aip.org/jap/article/136/4/043905/...    2025-05-30
# 1    info:eu-repo/semantics/altIdentifier/doi/10.10...    2025-05-30
# 2    https://www.sap.org.ar/docs/publicaciones/arch...    2025-05-30
# ..                                                 ...           ...
# 352  info:eu-repo/semantics/altIdentifier/doi/10.10...    2025-05-30
# 353  https://www.nature.com/articles/s41467-021-263...    2025-05-30
# 353  info:eu-repo/semantics/altIdentifier/doi/10.10...    2025-05-30
# 354     https://doi.org/10.1088/1748-0221/17/02/P02004    2025-05-30
# 354  info:eu-repo/semantics/altIdentifier/doi/10.10...    2025-05-30
#
# [669 rows x 3 columns]

# %%
df_item_publisher
# Out:
# <pre style="white-space:pre;overflow-x:auto;line-height:normal;font-family:Menlo,'DejaVu Sans Mono',consolas,'Courier New',monospace"></pre>
#                                  handle                        publisher  \
# 0    http://hdl.handle.net/11336/181613                 Elsevier Science
# 1    http://hdl.handle.net/11336/242335    American Institute of Physics
# 2    http://hdl.handle.net/11336/255685  Sociedad Argentina de Pediatría
# 3    http://hdl.handle.net/11336/224725                 Elsevier Science
# 4    http://hdl.handle.net/11336/123737             Frontiers Media S.A.
# ..                                  ...                              ...
# 350  http://hdl.handle.net/11336/216872                 Elsevier Science
# 351  http://hdl.handle.net/11336/216757        American Physical Society
# 352  http://hdl.handle.net/11336/123896    Pergamon-Elsevier Science Ltd
# 353  http://hdl.handle.net/11336/181755                         Springer
# 354  http://hdl.handle.net/11336/216310                   IOP Publishing
#
#     load_datetime
# 0      2025-05-30
# 1      2025-05-30
# 2      2025-05-30
# 3      2025-05-30
# 4      2025-05-30
# ..            ...
# 350    2025-05-30
# 351    2025-05-30
# 352    2025-05-30
# 353    2025-05-30
# 354    2025-05-30
#
# [355 rows x 3 columns]
