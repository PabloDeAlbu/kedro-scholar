# %%
import os
import time
import certifi
import requests
import pandas as pd
import xml.etree.ElementTree as ET

# %%
base_url = catalog.load('params:oai_extract_options.base_url')
context = catalog.load('params:oai_extract_options.context')

env = 'dev'

print("base_url: ", base_url)
print("context: ", context)
# Out:
#                     INFO     Loading data from params:oai_extract_options.base_url              ]8;id=841576;file:///home/pablo/.local/lib/python3.10/site-packages/kedro/io/data_catalog.py\data_catalog.py]8;;\:]8;id=245683;file:///home/pablo/.local/lib/python3.10/site-packages/kedro/io/data_catalog.py#389\389]8;;\
#                              (MemoryDataset)...
#                     INFO     Loading data from params:oai_extract_options.context               ]8;id=15616;file:///home/pablo/.local/lib/python3.10/site-packages/kedro/io/data_catalog.py\data_catalog.py]8;;\:]8;id=460741;file:///home/pablo/.local/lib/python3.10/site-packages/kedro/io/data_catalog.py#389\389]8;;\
#                              (MemoryDataset)...
# base_url:  https://ri.conicet.gov.ar/oai/
# context:  request

# %%
def get_oai_response(base_url, verify=None, max_retries=3, backoff_factor=1.0):

    # Usa el bundle de certifi para evitar errores de certificado en requests
    os.environ.setdefault("REQUESTS_CA_BUNDLE", certifi.where())
    os.environ.setdefault("SSL_CERT_FILE", certifi.where())
    VERIFY_SSL = os.getenv("OAI_VERIFY_SSL", "false").lower() == "true"
    CA_BUNDLE = os.getenv("OAI_CA_BUNDLE") or certifi.where()

    verify_param = CA_BUNDLE if VERIFY_SSL else False
    if verify is not None:
        verify_param = verify

    for attempt in range(1, max_retries + 1):
        start_time = time.time()
        response = None
        try:
            response = requests.get(base_url, verify=verify_param)
            elapsed_time = time.time() - start_time
        except requests.RequestException as exc:
            elapsed_time = time.time() - start_time
            print(f"Error en request (intento {attempt}/{max_retries}): {exc}")
        sleep_time = max(elapsed_time, 0.1)
        print(f"Sleeping for {sleep_time:.2f} seconds")
        time.sleep(sleep_time)

        if response and response.status_code == 200:
            return response

        status = response.status_code if response else "sin respuesta"
        print(f"Error: {status} (intento {attempt}/{max_retries})")

        if attempt < max_retries:
            backoff = backoff_factor * attempt
            print(f"Reintentando en {backoff:.2f} segundos...")
            time.sleep(backoff)
    return None

# %%
def oai_extract_sets(base_url, context, env, verify=None, iteration_limit=None):

    if iteration_limit is None and env == "dev":
        iteration_limit = 2

    resumption_token = 0
    all_sets = []

    while True:

        if env == 'dev' and iteration_count >= iteration_limit:
            break

        params = f'/{context}?verb=ListSets&resumptionToken=////{resumption_token}'
        url = base_url + params

        print(f"Consultando: {url}")

        response = get_oai_response(url, verify=verify)
        if not response:
            break

        xml_content = response.text
        root = ET.fromstring(xml_content)
        ns = {'oai': 'http://www.openarchives.org/OAI/2.0/'}

        sets_data = []
        for set_elem in root.findall('.//oai:set', ns):
            set_spec = set_elem.find('oai:setSpec', ns).text if set_elem.find('oai:setSpec', ns) is not None else None
            set_name = set_elem.find('oai:setName', ns).text if set_elem.find('oai:setName', ns) is not None else None
            sets_data.append({'setSpec': set_spec, 'setName': set_name})

        if not sets_data:
            print("No se encontraron más sets.")
            break

        all_sets.extend(sets_data)
        resumption_token += 100  # avanzar manualmente
        iteration_count += 1

    df_sets = pd.DataFrame(all_sets)
    return df_sets

# %%
if catalog.exists("raw/oai/sets#csv"):
    df_sets = catalog.load("raw/oai/sets#csv")
else:
    df_sets =  oai_extract_sets(base_url, context, env)
df_sets
# Out:
#                     INFO     Loading data from raw/oai/sets#csv (CSVDataset)...                 ]8;id=982924;file:///home/pablo/.local/lib/python3.10/site-packages/kedro/io/data_catalog.py\data_catalog.py]8;;\:]8;id=427627;file:///home/pablo/.local/lib/python3.10/site-packages/kedro/io/data_catalog.py#389\389]8;;\
# <pre style="white-space:pre;overflow-x:auto;line-height:normal;font-family:Menlo,'DejaVu Sans Mono',consolas,'Courier New',monospace"></pre>
#               setSpec                                            setName  \
# 0                snrd         Sistema Nacional de Repositorios Digitales
# 1        com_11336_73  AREA DE INFLUENCIA CENTRO CIENTÍFICO TECNOLÓGI...
# 2       com_11336_116  AREA DE INFLUENCIA CENTRO CIENTÍFICO TECNOLÓGI...
# 3       com_11336_169  AREA DE INFLUENCIA CENTRO CIENTÍFICO TECNOLÓGI...
# 4       com_11336_184  AREA DE INFLUENCIA CENTRO CIENTÍFICO TECNOLÓGI...
# ...               ...                                                ...
# 2439  col_11336_73920                                      Tesis(UNIHDO)
# 2440  col_11336_73921                                     Tesis(UNITEFA)
# 2441  col_11336_48286                                          undefined
# 2442  col_11336_48181                                          undefined
# 2443  col_11336_64752                                          undefined
#
#                extract_datetime
# 0     2025-11-26 00:00:00+00:00
# 1     2025-11-26 00:00:00+00:00
# 2     2025-11-26 00:00:00+00:00
# 3     2025-11-26 00:00:00+00:00
# 4     2025-11-26 00:00:00+00:00
# ...                         ...
# 2439  2025-11-26 00:00:00+00:00
# 2440  2025-11-26 00:00:00+00:00
# 2441  2025-11-26 00:00:00+00:00
# 2442  2025-11-26 00:00:00+00:00
# 2443  2025-11-26 00:00:00+00:00
#
# [2444 rows x 3 columns]

# %%
def oai_intermediate_sets(df_sets):
    
    df_sets["col_set"] = df_sets["setSpec"].str.startswith("col_")
    df_sets["com_set"] = df_sets["setSpec"].str.startswith("com_")

    return df_sets

# %%
if catalog.exists("intermediate/oai/sets#csv"):
    df_sets = catalog.load("intermediate/oai/sets#csv")
else:
    df_sets =  oai_intermediate_sets(df_sets)

df_sets
# Out:
# <pre style="white-space:pre;overflow-x:auto;line-height:normal;font-family:Menlo,'DejaVu Sans Mono',consolas,'Courier New',monospace"></pre>
#               setSpec                                            setName  \
# 0                snrd         Sistema Nacional de Repositorios Digitales
# 1        com_11336_73  AREA DE INFLUENCIA CENTRO CIENTÍFICO TECNOLÓGI...
# 2       com_11336_116  AREA DE INFLUENCIA CENTRO CIENTÍFICO TECNOLÓGI...
# 3       com_11336_169  AREA DE INFLUENCIA CENTRO CIENTÍFICO TECNOLÓGI...
# 4       com_11336_184  AREA DE INFLUENCIA CENTRO CIENTÍFICO TECNOLÓGI...
# ...               ...                                                ...
# 2439  col_11336_73920                                      Tesis(UNIHDO)
# 2440  col_11336_73921                                     Tesis(UNITEFA)
# 2441  col_11336_48286                                          undefined
# 2442  col_11336_48181                                          undefined
# 2443  col_11336_64752                                          undefined
#
#                extract_datetime  col_set  com_set
# 0     2025-11-26 00:00:00+00:00    False    False
# 1     2025-11-26 00:00:00+00:00    False     True
# 2     2025-11-26 00:00:00+00:00    False     True
# 3     2025-11-26 00:00:00+00:00    False     True
# 4     2025-11-26 00:00:00+00:00    False     True
# ...                         ...      ...      ...
# 2439  2025-11-26 00:00:00+00:00     True    False
# 2440  2025-11-26 00:00:00+00:00     True    False
# 2441  2025-11-26 00:00:00+00:00     True    False
# 2442  2025-11-26 00:00:00+00:00     True    False
# 2443  2025-11-26 00:00:00+00:00     True    False
#
# [2444 rows x 5 columns]

# %%
def oai_filter_col(df_sets):
    
    col_filter = df_sets['col_set'] == True

    df_col = df_sets[col_filter]#.loc[:, "setSpec"]
    
    return df_col

# %%
df_col = oai_filter_col(df_sets)
df_col
# Out:
# <pre style="white-space:pre;overflow-x:auto;line-height:normal;font-family:Menlo,'DejaVu Sans Mono',consolas,'Courier New',monospace"></pre>
#                setSpec                setName           extract_datetime  \
# 371      col_11336_373      Articulos(BIOMED)  2025-11-26 00:00:00+00:00
# 372      col_11336_466       Articulos(CADIC)  2025-11-26 00:00:00+00:00
# 373      col_11336_445      Articulos(CAICYT)  2025-11-26 00:00:00+00:00
# 374       col_11336_11      Articulos(CASLEO)  2025-11-26 00:00:00+00:00
# 375   col_11336_138773  Articulos (CCONFINES)  2025-11-26 00:00:00+00:00
# ...                ...                    ...                        ...
# 2439   col_11336_73920          Tesis(UNIHDO)  2025-11-26 00:00:00+00:00
# 2440   col_11336_73921         Tesis(UNITEFA)  2025-11-26 00:00:00+00:00
# 2441   col_11336_48286              undefined  2025-11-26 00:00:00+00:00
# 2442   col_11336_48181              undefined  2025-11-26 00:00:00+00:00
# 2443   col_11336_64752              undefined  2025-11-26 00:00:00+00:00
#
#       col_set  com_set
# 371      True    False
# 372      True    False
# 373      True    False
# 374      True    False
# 375      True    False
# ...       ...      ...
# 2439     True    False
# 2440     True    False
# 2441     True    False
# 2442     True    False
# 2443     True    False
#
# [2073 rows x 5 columns]

# %%
def oai_list_identifiers(base_url: str, context: str, env: str, df_set: pd.DataFrame, verify=None) -> pd.DataFrame:
    records = []
    iteration_limit = 1

    col_ids = df_set.head(iteration_limit).iloc[:, 0].tolist()

    if not col_ids:
        print("No se encontraron colecciones pendientes con processed=False.")

    for set_id in col_ids:
        resumption_token = 0
        iteration_count = 0


        while True:
            if env == 'dev' and iteration_count >= iteration_limit:
                break

            params = f'/{context}?verb=ListIdentifiers&resumptionToken=oai_dc///{set_id}/{resumption_token}'
            url = base_url + params

            print(f"Consultando: {url}")

            response = get_oai_response(url, verify=verify)

            resumption_token += 100
            iteration_count += 1

            if not response or not response.ok:
                print(f"Error al consultar: {url}")
                break

            xml_content = response.text

            root = ET.fromstring(xml_content)
            ns = {
                'oai': 'http://www.openarchives.org/OAI/2.0/',
                'dc': 'http://purl.org/dc/elements/1.1/'
            }

        #    return root, ns
        
            record_nodes = root.findall('.//oai:header', ns)


            if not record_nodes:
                print("No se encontraron más registros.")
                break

#            return record_nodes
            for record in record_nodes:
                
                # Valores simples
                record_id = record.find('.//oai:identifier', ns)
                record_datestamp = record.find('.//oai:datestamp', ns)
                
                # Multivaluados
                setspec = [e.text for e in record.findall('.//oai:setSpec', ns)]


                records.append({
                    'record_id': record_id.text if record_id is not None else None,
                    'datestamp': record_datestamp.text if record_datestamp is not None else None,
                    'set_id': setspec,
                })

    df = pd.DataFrame(records)

    return df, df.head(100)

# %%
df_identifiers, df_dev = oai_list_identifiers(base_url, context, env, df_col)
# Out:
# Consultando: https://ri.conicet.gov.ar/oai//request?verb=ListIdentifiers&resumptionToken=oai_dc///col_11336_373/0
#                     WARNING  /home/pablo/.local/lib/python3.10/site-packages/urllib3/connectionpool ]8;id=570598;file:///usr/lib/python3.10/warnings.py\warnings.py]8;;\:]8;id=369920;file:///usr/lib/python3.10/warnings.py#109\109]8;;\
#                              .py:1099: InsecureRequestWarning: Unverified HTTPS request is being
#                              made to host 'ri.conicet.gov.ar'. Adding certificate verification is
#                              strongly advised. See:
#                              https://urllib3.readthedocs.io/en/latest/advanced-usage.html#tls-warni
#                              ngs
#                                warnings.warn(
# Sleeping for 0.21 seconds

# %%
df_identifiers
# Out:
# <pre style="white-space:pre;overflow-x:auto;line-height:normal;font-family:Menlo,'DejaVu Sans Mono',consolas,'Courier New',monospace"></pre>
#                              record_id             datestamp  \
# 0    oai:ri.conicet.gov.ar:11336/15260  2023-03-09T02:44:18Z
# 1   oai:ri.conicet.gov.ar:11336/266352  2025-07-17T11:08:26Z
# 2    oai:ri.conicet.gov.ar:11336/15225  2024-09-20T17:52:07Z
# 3   oai:ri.conicet.gov.ar:11336/133626  2021-12-17T12:37:25Z
# 4    oai:ri.conicet.gov.ar:11336/15215  2023-03-09T02:44:18Z
# ..                                 ...                   ...
# 95   oai:ri.conicet.gov.ar:11336/15191  2017-04-11T21:07:06Z
# 96   oai:ri.conicet.gov.ar:11336/48762  2018-06-15T14:40:23Z
# 97  oai:ri.conicet.gov.ar:11336/227745  2024-02-21T13:13:13Z
# 98  oai:ri.conicet.gov.ar:11336/141716  2021-09-28T14:49:51Z
# 99   oai:ri.conicet.gov.ar:11336/15116  2023-02-16T13:22:10Z
#
#                                                set_id
# 0   [com_11336_390, com_11336_371, com_11336_372, ...
# 1   [com_11336_372, com_11336_371, com_11336_394, ...
# 2   [com_11336_372, com_11336_371, com_11336_390, ...
# 3   [com_11336_372, com_11336_371, col_11336_373, ...
# 4   [com_11336_390, com_11336_371, com_11336_100, ...
# ..                                                ...
# 95  [com_11336_414, com_11336_371, com_11336_372, ...
# 96  [com_11336_372, com_11336_371, col_11336_373, ...
# 97  [com_11336_372, com_11336_371, col_11336_373, ...
# 98  [com_11336_372, com_11336_371, col_11336_373, ...
# 99  [com_11336_390, com_11336_371, com_11336_372, ...
#
# [100 rows x 3 columns]

# %%
def oai_list_records(base_url: str, context: str, env: str, df_set: pd.DataFrame, verify=None) -> pd.DataFrame:
    records = []
    iteration_limit = 1

    col_ids = df_set.head(iteration_limit).iloc[:, 0].tolist()

    if not col_ids:
        print("No se encontraron colecciones pendientes con processed=False.")

    for set_id in col_ids:
        resumption_token = 0
        iteration_count = 0

        while True:
            if env == 'dev' and iteration_count >= iteration_limit:
                break

            params = f'/{context}?verb=ListRecords&resumptionToken=oai_dc///{set_id}/{resumption_token}'
            url = base_url + params

            print(f"Consultando: {url}")

            response = get_oai_response(url, verify=verify)

            resumption_token += 100
            iteration_count += 1

            if not response or not response.ok:
                print(f"Error al consultar: {url}")
                break

            xml_content = response.text
            root = ET.fromstring(xml_content)
            ns = {
                'oai': 'http://www.openarchives.org/OAI/2.0/',
                'dc': 'http://purl.org/dc/elements/1.1/'
            }

            record_nodes = root.findall('.//oai:record', ns)

            if not record_nodes:
                print("No se encontraron más registros.")
                break

            for record in record_nodes:
                identifier = record.find('.//oai:identifier', ns)
                item_id = identifier.text if identifier is not None else None
                metadata = record.find('.//oai:metadata', ns)

                if metadata is None:
                    continue

                # Valores simples
                title = metadata.find('.//dc:title', ns)
                date_issued = metadata.find('.//dc:date', ns)

                # Multivaluados
                creators = [e.text for e in metadata.findall('.//dc:creator', ns)]
                types = [e.text for e in metadata.findall('.//dc:type', ns)]
                identifiers = [e.text for e in metadata.findall('.//dc:identifier', ns)]
                languages = [e.text for e in metadata.findall('.//dc:language', ns)]
                publishers = [e.text for e in metadata.findall('.//dc:publisher', ns)]
                subjects = [e.text for e in metadata.findall('.//dc:subject', ns)]
                relations = [e.text for e in metadata.findall('.//dc:relation', ns)]
                rights = [e.text for e in metadata.findall('.//dc:rights', ns)]

                records.append({
                    'item_id': item_id,
                    'col_id': set_id,
                    'title': title.text if title is not None else None,
                    'date_issued': date_issued.text if date_issued is not None else None,
                    'creators': creators,
                    'types': types,
                    'identifiers': identifiers,
                    'languages': languages,
                    'subjects': subjects,
                    'publishers': publishers,
                    'relations': relations,
                    'rights': rights
                })

    df = pd.DataFrame(records)

    timestamp = pd.Timestamp.now(tz="UTC").normalize()
    df['extract_datetime'] = timestamp
    df['load_datetime'] = timestamp

    return df, df.head(100)

# %%
df = oai_list_records(base_url, context, env, df_col)
# Out:
# Consultando: https://ri.conicet.gov.ar/oai//request?verb=ListRecords&resumptionToken=oai_dc///col_11336_373/0
# [11/26/25 17:55:41] WARNING  /home/pablo/.local/lib/python3.10/site-packages/urllib3/connectionpool ]8;id=531942;file:///usr/lib/python3.10/warnings.py\warnings.py]8;;\:]8;id=325734;file:///usr/lib/python3.10/warnings.py#109\109]8;;\
#                              .py:1099: InsecureRequestWarning: Unverified HTTPS request is being
#                              made to host 'ri.conicet.gov.ar'. Adding certificate verification is
#                              strongly advised. See:
#                              https://urllib3.readthedocs.io/en/latest/advanced-usage.html#tls-warni
#                              ngs
#                                warnings.warn(
# Sleeping for 12.47 seconds
# Consultando: https://ri.conicet.gov.ar/oai//request?verb=ListRecords&resumptionToken=oai_dc///col_11336_373/100
# [11/26/25 17:56:06] WARNING  /home/pablo/.local/lib/python3.10/site-packages/urllib3/connectionpool ]8;id=40899;file:///usr/lib/python3.10/warnings.py\warnings.py]8;;\:]8;id=972145;file:///usr/lib/python3.10/warnings.py#109\109]8;;\
#                              .py:1099: InsecureRequestWarning: Unverified HTTPS request is being
#                              made to host 'ri.conicet.gov.ar'. Adding certificate verification is
#                              strongly advised. See:
#                              https://urllib3.readthedocs.io/en/latest/advanced-usage.html#tls-warni
#                              ngs
#                                warnings.warn(
# Sleeping for 10.25 seconds
# Error: sin respuesta (intento 1/3)
# Reintentando en 1.00 segundos...
# [11/26/25 17:56:28] WARNING  /home/pablo/.local/lib/python3.10/site-packages/urllib3/connectionpool ]8;id=53087;file:///usr/lib/python3.10/warnings.py\warnings.py]8;;\:]8;id=328051;file:///usr/lib/python3.10/warnings.py#109\109]8;;\
#                              .py:1099: InsecureRequestWarning: Unverified HTTPS request is being
#                              made to host 'ri.conicet.gov.ar'. Adding certificate verification is
#                              strongly advised. See:
#                              https://urllib3.readthedocs.io/en/latest/advanced-usage.html#tls-warni
#                              ngs
#                                warnings.warn(
# Sleeping for 10.96 seconds
# Error: sin respuesta (intento 2/3)
# Reintentando en 2.00 segundos...
# [11/26/25 17:56:51] WARNING  /home/pablo/.local/lib/python3.10/site-packages/urllib3/connectionpool ]8;id=928655;file:///usr/lib/python3.10/warnings.py\warnings.py]8;;\:]8;id=834971;file:///usr/lib/python3.10/warnings.py#109\109]8;;\
#                              .py:1099: InsecureRequestWarning: Unverified HTTPS request is being
#                              made to host 'ri.conicet.gov.ar'. Adding certificate verification is
#                              strongly advised. See:
#                              https://urllib3.readthedocs.io/en/latest/advanced-usage.html#tls-warni
#                              ngs
#                                warnings.warn(
# ╭─────────────────────────────── Traceback (most recent call last) ────────────────────────────────╮
# │ in <module>:1                                                                                    │
# │                                                                                                  │
# │ ❱ 1 df = oai_list_records(base_url, context, env, df_col)                                        │
# │   2                                                                                              │
# │                                                                                                  │
# │ in oai_list_records:23                                                                           │
# │                                                                                                  │
# │   20 │   │   │                                                                                   │
# │   21 │   │   │   print(f"Consultando: {url}")                                                    │
# │   22 │   │   │                                                                                   │
# │ ❱ 23 │   │   │   response = get_oai_response(url, verify=verify)                                 │
# │   24 │   │   │                                                                                   │
# │   25 │   │   │   resumption_token += 100                                                         │
# │   26 │   │   │   iteration_count += 1                                                            │
# │                                                                                                  │
# │ in get_oai_response:17                                                                           │
# │                                                                                                  │
# │   14 │   │   start_time = time.time()                                                            │
# │   15 │   │   response = None                                                                     │
# │   16 │   │   try:                                                                                │
# │ ❱ 17 │   │   │   response = requests.get(base_url, verify=verify_param)                          │
# │   18 │   │   │   elapsed_time = time.time() - start_time                                         │
# │   19 │   │   except requests.RequestException as exc:                                            │
# │   20 │   │   │   elapsed_time = time.time() - start_time                                         │
# │                                                                                                  │
# │ /home/pablo/.local/lib/python3.10/site-packages/requests/api.py:73 in get                        │
# │                                                                                                  │
# │    70 │   :rtype: requests.Response                                                              │
# │    71 │   """                                                                                    │
# │    72 │                                                                                          │
# │ ❱  73 │   return request("get", url, params=params, **kwargs)                                    │
# │    74                                                                                            │
# │    75                                                                                            │
# │    76 def options(url, **kwargs):                                                                │
# │                                                                                                  │
# │ /home/pablo/.local/lib/python3.10/site-packages/requests/api.py:59 in request                    │
# │                                                                                                  │
# │    56 │   # avoid leaving sockets open which can trigger a ResourceWarning in some               │
# │    57 │   # cases, and look like a memory leak in others.                                        │
# │    58 │   with sessions.Session() as session:                                                    │
# │ ❱  59 │   │   return session.request(method=method, url=url, **kwargs)                           │
# │    60                                                                                            │
# │    61                                                                                            │
# │    62 def get(url, params=None, **kwargs):                                                       │
# │                                                                                                  │
# │ /home/pablo/.local/lib/python3.10/site-packages/requests/sessions.py:589 in request              │
# │                                                                                                  │
# │   586 │   │   │   "allow_redirects": allow_redirects,                                            │
# │   587 │   │   }                                                                                  │
# │   588 │   │   send_kwargs.update(settings)                                                       │
# │ ❱ 589 │   │   resp = self.send(prep, **send_kwargs)                                              │
# │   590 │   │                                                                                      │
# │   591 │   │   return resp                                                                        │
# │   592                                                                                            │
# │                                                                                                  │
# │ /home/pablo/.local/lib/python3.10/site-packages/requests/sessions.py:703 in send                 │
# │                                                                                                  │
# │   700 │   │   start = preferred_clock()                                                          │
# │   701 │   │                                                                                      │
# │   702 │   │   # Send the request                                                                 │
# │ ❱ 703 │   │   r = adapter.send(request, **kwargs)                                                │
# │   704 │   │                                                                                      │
# │   705 │   │   # Total elapsed time of the request (approximately)                                │
# │   706 │   │   elapsed = preferred_clock() - start                                                │
# │                                                                                                  │
# │ /home/pablo/.local/lib/python3.10/site-packages/requests/adapters.py:667 in send                 │
# │                                                                                                  │
# │   664 │   │   │   timeout = TimeoutSauce(connect=timeout, read=timeout)                          │
# │   665 │   │                                                                                      │
# │   666 │   │   try:                                                                               │
# │ ❱ 667 │   │   │   resp = conn.urlopen(                                                           │
# │   668 │   │   │   │   method=request.method,                                                     │
# │   669 │   │   │   │   url=url,                                                                   │
# │   670 │   │   │   │   body=request.body,                                                         │
# │                                                                                                  │
# │ /home/pablo/.local/lib/python3.10/site-packages/urllib3/connectionpool.py:789 in urlopen         │
# │                                                                                                  │
# │    786 │   │   │   response_conn = conn if not release_conn else None                            │
# │    787 │   │   │                                                                                 │
# │    788 │   │   │   # Make the request on the HTTPConnection object                               │
# │ ❱  789 │   │   │   response = self._make_request(                                                │
# │    790 │   │   │   │   conn,                                                                     │
# │    791 │   │   │   │   method,                                                                   │
# │    792 │   │   │   │   url,                                                                      │
# │                                                                                                  │
# │ /home/pablo/.local/lib/python3.10/site-packages/urllib3/connectionpool.py:536 in _make_request   │
# │                                                                                                  │
# │    533 │   │                                                                                     │
# │    534 │   │   # Receive the response from the server                                            │
# │    535 │   │   try:                                                                              │
# │ ❱  536 │   │   │   response = conn.getresponse()                                                 │
# │    537 │   │   except (BaseSSLError, OSError) as e:                                              │
# │    538 │   │   │   self._raise_timeout(err=e, url=url, timeout_value=read_timeout)               │
# │    539 │   │   │   raise                                                                         │
# │                                                                                                  │
# │ /home/pablo/.local/lib/python3.10/site-packages/urllib3/connection.py:507 in getresponse         │
# │                                                                                                  │
# │    504 │   │   from .response import HTTPResponse                                                │
# │    505 │   │                                                                                     │
# │    506 │   │   # Get the response from http.client.HTTPConnection                                │
# │ ❱  507 │   │   httplib_response = super().getresponse()                                          │
# │    508 │   │                                                                                     │
# │    509 │   │   try:                                                                              │
# │    510 │   │   │   assert_header_parsing(httplib_response.msg)                                   │
# │                                                                                                  │
# │ /usr/lib/python3.10/http/client.py:1375 in getresponse                                           │
# │                                                                                                  │
# │   1372 │   │                                                                                     │
# │   1373 │   │   try:                                                                              │
# │   1374 │   │   │   try:                                                                          │
# │ ❱ 1375 │   │   │   │   response.begin()                                                          │
# │   1376 │   │   │   except ConnectionError:                                                       │
# │   1377 │   │   │   │   self.close()                                                              │
# │   1378 │   │   │   │   raise                                                                     │
# │                                                                                                  │
# │ /usr/lib/python3.10/http/client.py:318 in begin                                                  │
# │                                                                                                  │
# │    315 │   │                                                                                     │
# │    316 │   │   # read until we get a non-100 response                                            │
# │    317 │   │   while True:                                                                       │
# │ ❱  318 │   │   │   version, status, reason = self._read_status()                                 │
# │    319 │   │   │   if status != CONTINUE:                                                        │
# │    320 │   │   │   │   break                                                                     │
# │    321 │   │   │   # skip the header from the 100 response                                       │
# │                                                                                                  │
# │ /usr/lib/python3.10/http/client.py:279 in _read_status                                           │
# │                                                                                                  │
# │    276 │   │   self.will_close = _UNKNOWN      # conn will close at end of response              │
# │    277 │                                                                                         │
# │    278 │   def _read_status(self):                                                               │
# │ ❱  279 │   │   line = str(self.fp.readline(_MAXLINE + 1), "iso-8859-1")                          │
# │    280 │   │   if len(line) > _MAXLINE:                                                          │
# │    281 │   │   │   raise LineTooLong("status line")                                              │
# │    282 │   │   if self.debuglevel > 0:                                                           │
# │                                                                                                  │
# │ /usr/lib/python3.10/socket.py:705 in readinto                                                    │
# │                                                                                                  │
# │   702 │   │   │   raise OSError("cannot read from timed out object")                             │
# │   703 │   │   while True:                                                                        │
# │   704 │   │   │   try:                                                                           │
# │ ❱ 705 │   │   │   │   return self._sock.recv_into(b)                                             │
# │   706 │   │   │   except timeout:                                                                │
# │   707 │   │   │   │   self._timeout_occurred = True                                              │
# │   708 │   │   │   │   raise                                                                      │
# │                                                                                                  │
# │ /usr/lib/python3.10/ssl.py:1303 in recv_into                                                     │
# │                                                                                                  │
# │   1300 │   │   │   │   raise ValueError(                                                         │
# │   1301 │   │   │   │     "non-zero flags not allowed in calls to recv_into() on %s" %            │
# │   1302 │   │   │   │     self.__class__)                                                         │
# │ ❱ 1303 │   │   │   return self.read(nbytes, buffer)                                              │
# │   1304 │   │   else:                                                                             │
# │   1305 │   │   │   return super().recv_into(buffer, nbytes, flags)                               │
# │   1306                                                                                           │
# │                                                                                                  │
# │ /usr/lib/python3.10/ssl.py:1159 in read                                                          │
# │                                                                                                  │
# │   1156 │   │   │   raise ValueError("Read on closed or unwrapped SSL socket.")                   │
# │   1157 │   │   try:                                                                              │
# │   1158 │   │   │   if buffer is not None:                                                        │
# │ ❱ 1159 │   │   │   │   return self._sslobj.read(len, buffer)                                     │
# │   1160 │   │   │   else:                                                                         │
# │   1161 │   │   │   │   return self._sslobj.read(len)                                             │
# │   1162 │   │   except SSLError as x:                                                             │
# ╰──────────────────────────────────────────────────────────────────────────────────────────────────╯
# KeyboardInterrupt

# %%
df
# Out:
# <pre style="white-space:pre;overflow-x:auto;line-height:normal;font-family:Menlo,'DejaVu Sans Mono',consolas,'Courier New',monospace"></pre>
#                                             identifier  \
# 0    [http://hdl.handle.net/11336/179477, Cassiodor...
# 1    [http://hdl.handle.net/11336/116972, Nuñez, Pa...
# 2    [http://hdl.handle.net/11336/23263, Lipoma, Ma...
# 3    [http://hdl.handle.net/11336/215533, Marchetti...
# 4    [http://hdl.handle.net/11336/109802, Giovambat...
# ..                                                 ...
# 290  [http://hdl.handle.net/11336/88817, Martin, An...
# 291  [http://hdl.handle.net/11336/11072, Espinosa, ...
# 292  [http://hdl.handle.net/11336/173007, Schaller,...
# 293  [http://hdl.handle.net/11336/134034, Ames, Mar...
# 294  [http://hdl.handle.net/11336/181752, Urioste, ...
#
#                                                  title  \
# 0    [Paisajes mesetarios en Patagonia: Tecnología ...
# 1    [Distancias entre la ecología y la praxis ambi...
# 2    [Plant community resilience in the face of fir...
# 3    [La puesta en acto de las políticas de formaci...
# 4       [Introducción a la Genética Forense No-Humana]
# ..                                                 ...
# 290  [Prospective multicentre evaluation of the dir...
# 291  [Una iglesia primitiva e internacional: el per...
# 292  [Reorganización agraria y expansión territoria...
# 293  [Los límites de la tolerancia religiosa en la ...
# 294  [Inflamación sistémica y desregulación inmune:...
#
#                                                creator  \
# 0                             [Cassiodoro, Gisela Eva]
# 1                              [Nuñez, Paula Gabriela]
# 2    [Lipoma, Maria Lucrecia, Gurvich, Diego Ezequi...
# 3                    [Marchetti, Braian, Bazán, Sonia]
# 4    [Giovambattista, Guillermo, Barrientos, Laura ...
# ..                                                 ...
# 290  [Martin, Anandi, Imperiale, Belén Rocío, Ravol...
# 291                         [Espinosa, Mariana Esther]
# 292  [Schaller, Enrique Cesar, Almiron, Adrian Alej...
# 293                              [Ames, Maria Cecilia]
# 294  [Urioste, Alejandra, Polo, Maria Laura, Trifon...
#
#                                                subject  \
# 0    [MESETAS, TECNOLOGÍA, USO DEL ESPACIO, LOGÍSTI...
# 1    [ECOLOGÍA, PRAXIS AMBIENTAL, ECOFEMINISMO, TEO...
# 2    [Firefire, Functional Redundancy, Plan Functio...
# 3    [POLÍTICAS PÚBLICAS EDUCATIVAS, FORMACIÓN DOCE...
# 4    [GENÉTICA FORENSE, IDENTIFICACIÓN GENÉTICA, ID...
# ..                                                 ...
# 290  [MULTIDRUG RESISTANCE, MYCOBACTERIUM TUBERCULO...
# 291  [HERMANOS LIBRES, MISIONES, INTERNACIONALISMO,...
# 292  [Tierras fiscales, Tenencia de la tierra, Chac...
# 293  [RELIGIÓN ROMANA, CULTURA CLÁSICA, CONTROL SOC...
# 294  [VIH, Inflamación sistémica, Disfunción inmune...
#
#                                            description       date  \
# 0    [La disponibilidad de recursos hídricos en Pat...  [2016-12]
# 1    [Este libro recorre un problema que cotidianam...     [2011]
# 2    [The ability of communities or ecosystems to r...  [2016-02]
# 3    [El presente artículo recupera las conclusione...  [2022-11]
# 4    [El presente libro nace como producto de una c...     [2015]
# ..                                                 ...        ...
# 290  [Objectives: To perform a multicentre study ev...  [2014-02]
# 291  [Este artículo busca aportar conocimiento sobr...  [2014-01]
# 292  [En el trabajo se analiza la política de tierr...     [2021]
# 293  [En el año 186 a.C. fueron duramente reprimido...  [2008-12]
# 294  [La disfunción inmune asociada a la infección ...  [2020-10]
#
#                                                   type language  \
# 0    [info:eu-repo/semantics/article, info:ar-repo/...    [spa]
# 1    [info:eu-repo/semantics/publishedVersion, info...    [spa]
# 2    [info:eu-repo/semantics/article, info:ar-repo/...    [eng]
# 3    [info:eu-repo/semantics/article, info:ar-repo/...    [spa]
# 4    [info:eu-repo/semantics/publishedVersion, info...    [spa]
# ..                                                 ...      ...
# 290  [info:eu-repo/semantics/article, info:ar-repo/...    [eng]
# 291  [info:eu-repo/semantics/article, info:ar-repo/...    [spa]
# 292  [info:eu-repo/semantics/publishedVersion, info...    [spa]
# 293  [info:eu-repo/semantics/article, info:ar-repo/...    [spa]
# 294  [info:eu-repo/semantics/article, info:ar-repo/...    [spa]
#
#                                               relation  \
# 0    [info:eu-repo/semantics/altIdentifier/url/http...
# 1    [info:eu-repo/semantics/altIdentifier/url/http...
# 2    [info:eu-repo/semantics/altIdentifier/url/http...
# 3    [info:eu-repo/semantics/altIdentifier/doi/10.3...
# 4    [info:eu-repo/semantics/altIdentifier/url/http...
# ..                                                 ...
# 290  [info:eu-repo/semantics/altIdentifier/doi/10.1...
# 291  [info:eu-repo/semantics/altIdentifier/url/http...
# 292  [info:eu-repo/semantics/altIdentifier/url/http...
# 293  [info:eu-repo/semantics/altIdentifier/url/http...
# 294  [info:eu-repo/semantics/altIdentifier/url/http...
#
#                                                 rights  \
# 0    [info:eu-repo/semantics/openAccess, https://cr...
# 1    [info:eu-repo/semantics/openAccess, https://cr...
# 2    [info:eu-repo/semantics/openAccess, https://cr...
# 3    [info:eu-repo/semantics/openAccess, https://cr...
# 4    [info:eu-repo/semantics/openAccess, https://cr...
# ..                                                 ...
# 290  [info:eu-repo/semantics/openAccess, https://cr...
# 291  [info:eu-repo/semantics/openAccess, https://cr...
# 292  [info:eu-repo/semantics/openAccess, https://cr...
# 293  [info:eu-repo/semantics/openAccess, https://cr...
# 294  [info:eu-repo/semantics/openAccess, https://cr...
#
#                                                 format  \
# 0                   [application/pdf, application/pdf]
# 1    [application/pdf, application/pdf, application...
# 2    [application/pdf, application/pdf, application...
# 3                   [application/pdf, application/pdf]
# 4    [application/pdf, application/pdf, application...
# ..                                                 ...
# 290                 [application/pdf, application/pdf]
# 291                 [application/pdf, application/pdf]
# 292                 [application/pdf, application/pdf]
# 293  [application/pdf, application/msword, applicat...
# 294                 [application/pdf, application/pdf]
#
#                                              publisher  \
# 0    [Instituto Nacional de Antropología y Pensamie...
# 1                   [Universidad Nacional de La Plata]
# 2                    [Wiley Blackwell Publishing, Inc]
# 3    [Universidad de Buenos Aires. Facultad de Filo...
# 4    [Universidad Nacional de La Plata. Facultad de...
# ..                                                 ...
# 290                          [Oxford University Press]
# 291  [Asociación de Cientistas Sociales de la Relig...
# 292                               [Imprenta Corintios]
# 293                                           [Trotta]
# 294                                [Fundación Huésped]
#
#                                            contributor coverage source
# 0                                                  NaN      NaN    NaN
# 1                                                  NaN      NaN    NaN
# 2                                                  NaN      NaN    NaN
# 3                                                  NaN      NaN    NaN
# 4    [Peral Garcia, Pilar, Giovambattista, Guillerm...      NaN    NaN
# ..                                                 ...      ...    ...
# 290                                                NaN      NaN    NaN
# 291                                                NaN      NaN    NaN
# 292  [Carini, Gabriel Fernando, Poggetti, Rocío Sol...      NaN    NaN
# 293                                                NaN      NaN    NaN
# 294                                                NaN      NaN    NaN
#
# [295 rows x 15 columns]
