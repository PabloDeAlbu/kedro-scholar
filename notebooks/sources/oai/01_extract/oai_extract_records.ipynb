# %%
import os
import time
import certifi
import requests
import pandas as pd
import xml.etree.ElementTree as ET
from requests.packages.urllib3.exceptions import InsecureRequestWarning

# %%
base_url = catalog.load('params:oai_extract_options.base_url')
context = catalog.load('params:oai_extract_options.context')

env = 'dev'

print("base_url: ", base_url)
print("context: ", context)
# Out:
# [12/12/25 10:21:15] INFO     Loading data from params:oai_extract_options.base_url             ]8;id=762362;file:///home/pablo/dev/scholar/kedro-scholar/.venv/lib/python3.10/site-packages/kedro/io/data_catalog.py\data_catalog.py]8;;\:]8;id=34349;file:///home/pablo/dev/scholar/kedro-scholar/.venv/lib/python3.10/site-packages/kedro/io/data_catalog.py#1048\1048]8;;\
#                              (MemoryDataset)...
#                     INFO     Loading data from params:oai_extract_options.context              ]8;id=390907;file:///home/pablo/dev/scholar/kedro-scholar/.venv/lib/python3.10/site-packages/kedro/io/data_catalog.py\data_catalog.py]8;;\:]8;id=57415;file:///home/pablo/dev/scholar/kedro-scholar/.venv/lib/python3.10/site-packages/kedro/io/data_catalog.py#1048\1048]8;;\
#                              (MemoryDataset)...
# base_url:  https://ri.conicet.gov.ar/oai/
# context:  request

# %%
def get_oai_response(base_url, verify=None, max_retries=3, backoff_factor=1.0, min_interval=0.0):

    # Usa el bundle de certifi para evitar errores de certificado en requests
    os.environ.setdefault("REQUESTS_CA_BUNDLE", certifi.where())
    os.environ.setdefault("SSL_CERT_FILE", certifi.where())
    VERIFY_SSL = os.getenv("OAI_VERIFY_SSL", "false").lower() == "true"
    CA_BUNDLE = os.getenv("OAI_CA_BUNDLE") or certifi.where()
    requests.packages.urllib3.disable_warnings(category=InsecureRequestWarning)

    verify_param = CA_BUNDLE if VERIFY_SSL else False
    if verify is not None:
        verify_param = verify

    for attempt in range(1, max_retries + 1):
        start_time = time.time()
        response = None
        error = None
        try:
            response = requests.get(base_url, verify=verify_param)
        except requests.RequestException as exc:
            error = exc
        elapsed_time = time.time() - start_time

        if min_interval > 0:
            wait_time = max(min_interval - elapsed_time, 0)
            if wait_time > 0:
                print(f"Pausando {wait_time:.2f} segundos para no saturar el servidor")
                time.sleep(wait_time)

        if error:
            print(f"Error en request (intento {attempt}/{max_retries}): {error}")

        if response and response.status_code == 200:
            return response

        status = response.status_code if response else "sin respuesta"
        print(f"Error: {status} (intento {attempt}/{max_retries})")

        if attempt < max_retries:
            backoff = backoff_factor * attempt
            print(f"Reintentando en {backoff:.2f} segundos...")
            time.sleep(backoff)
    return None

def log_oai_progress(token_elem, total_processed: int):
    """Muestra el avance usando completeListSize y los registros acumulados."""
    if token_elem is None:
        return
    total = token_elem.get('completeListSize')
    try:
        total_int = int(total) if total is not None else None
        if total_int is not None and total_processed is not None:
            remaining = total_int - total_processed
            print(f"Progreso OAI: {total_processed}/{total_int} (faltan ~{remaining})")
    except ValueError:
        # Si el servidor devuelve valores no numéricos, ignora el progreso.
        pass

# %% [markdown]
# ## Extract identifiers

# %%
def oai_extract_records(base_url: str, context: str, env: str, verify=None) -> pd.DataFrame:
    records = []
    
    iteration_limit = 2 if env == "dev" else None
    resumption_token = None
    iteration_count = 0

    total_processed = 0

    while True:
        if iteration_limit is not None and iteration_count >= iteration_limit:
            break

        if resumption_token:
            params = f'/{context}?verb=ListRecords&resumptionToken={resumption_token}'
        else:
            params = f'/{context}?verb=ListRecords&metadataPrefix=oai_dc'

        url = base_url + params

        print(f"Consultando: {url}")

        response = get_oai_response(url, verify=verify)

        iteration_count += 1

        if not response or not response.ok:
            print(f"Error al consultar: {url}")
            break

        xml_content = response.text
        root = ET.fromstring(xml_content)
        ns = {
            'oai': 'http://www.openarchives.org/OAI/2.0/',
            'dc': 'http://purl.org/dc/elements/1.1/'
        }

        record_nodes = root.findall('.//oai:record', ns)

        if not record_nodes:
            print("No se encontraron más registros.")
            break

        for record in record_nodes:
            header = record.find('.//oai:header', ns)
            identifier_node = header.find('.//oai:identifier', ns) if header is not None else None
            datestamp_node = header.find('.//oai:datestamp', ns) if header is not None else None
            setspec = [e.text for e in header.findall('.//oai:setSpec', ns)] if header is not None else []

            metadata = record.find('.//oai:metadata', ns)

            if metadata is None:
                continue

            # Valores simples
            title = metadata.find('.//dc:title', ns)
            date_issued = metadata.find('.//dc:date', ns)

            # Multivaluados
            setspec = [e.text for e in record.findall('.//oai:setSpec', ns)]

            creators = [e.text for e in metadata.findall('.//dc:creator', ns)]
            description = [e.text for e in metadata.findall('.//dc:description', ns)]
            types = [e.text for e in metadata.findall('.//dc:type', ns)]
            identifiers = [e.text for e in metadata.findall('.//dc:identifier', ns)]
            languages = [e.text for e in metadata.findall('.//dc:language', ns)]
            publishers = [e.text for e in metadata.findall('.//dc:publisher', ns)]
            subjects = [e.text for e in metadata.findall('.//dc:subject', ns)]
            relations = [e.text for e in metadata.findall('.//dc:relation', ns)]
            rights = [e.text for e in metadata.findall('.//dc:rights', ns)]
            formats = [e.text for e in metadata.findall('.//dc:format', ns)]

            records.append({
                'record_id': identifier_node.text if identifier_node is not None else None,
                'datestamp': datestamp_node.text if datestamp_node is not None else None,
                'set_id': setspec,
                'col_id': setspec[0] if setspec else None,
                'title': title.text if title is not None else None,
                'date_issued': date_issued.text if date_issued is not None else None,
                'creators': creators,
                'description': description,
                'types': types,
                'identifiers': identifiers,
                'languages': languages,
                'subjects': subjects,
                'publishers': publishers,
                'relations': relations,
                'rights': rights,
                'formats': formats
            })

        total_processed += len(record_nodes)

        token_elem = root.find('.//oai:resumptionToken', ns)
        resumption_token = token_elem.text if token_elem is not None else None
        log_oai_progress(token_elem, total_processed)

        if not resumption_token:
            break

    df = pd.DataFrame(records)

    timestamp = pd.Timestamp.now(tz="UTC").normalize()
    df['extract_datetime'] = timestamp

    return df, df.head(100)

# %%
df_records, df_dev = oai_extract_records(base_url, context, env)
# Out:
# Consultando: https://ri.conicet.gov.ar/oai//request?verb=ListRecords&metadataPrefix=oai_dc
# Progreso OAI: 100/257187 (faltan ~257087)
# Consultando: https://ri.conicet.gov.ar/oai//request?verb=ListRecords&resumptionToken=oai_dc////100
# Progreso OAI: 200/257187 (faltan ~256987)

# %%
df_records
# Out:
# <pre style="white-space:pre;overflow-x:auto;line-height:normal;font-family:Menlo,'DejaVu Sans Mono',consolas,'Courier New',monospace"></pre>
#                               record_id             datestamp  \
# 0    oai:ri.conicet.gov.ar:11336/179477  2024-01-12T04:51:20Z
# 1    oai:ri.conicet.gov.ar:11336/116972  2020-10-27T20:15:28Z
# 2     oai:ri.conicet.gov.ar:11336/23263  2024-04-25T19:52:43Z
# 3    oai:ri.conicet.gov.ar:11336/215533  2023-10-20T13:49:47Z
# 4    oai:ri.conicet.gov.ar:11336/109802  2020-10-08T23:12:10Z
# ..                                  ...                   ...
# 193  oai:ri.conicet.gov.ar:11336/182926  2023-01-02T17:03:17Z
# 194  oai:ri.conicet.gov.ar:11336/261962  2025-05-19T12:55:53Z
# 195  oai:ri.conicet.gov.ar:11336/265488  2025-07-08T10:16:35Z
# 196  oai:ri.conicet.gov.ar:11336/144165  2021-10-18T20:30:01Z
# 197   oai:ri.conicet.gov.ar:11336/54764  2023-02-16T13:22:10Z
#
#                                                 set_id         col_id  \
# 0     [com_11336_35, com_11336_14, col_11336_36, snrd]   com_11336_35
# 1    [com_11336_219, com_11336_218, col_11336_89919...  com_11336_219
# 2    [com_11336_106, com_11336_75, col_11336_107, s...  com_11336_106
# 3    [com_11336_184, com_11336_171, col_11336_185, ...  com_11336_184
# 4    [com_11336_153, com_11336_118, col_11336_90213...  com_11336_153
# ..                                                 ...            ...
# 193  [com_11336_339, com_11336_332, col_11336_340, ...  com_11336_339
# 194  [com_11336_460, com_11336_443, col_11336_461, ...  com_11336_460
# 195   [com_11336_35, com_11336_14, col_11336_36, snrd]   com_11336_35
# 196  [com_11336_238, com_11336_231, col_11336_239, ...  com_11336_238
# 197  [com_11336_345, com_11336_332, col_11336_346, ...  com_11336_345
#
#                                                  title date_issued  \
# 0    Paisajes mesetarios en Patagonia: Tecnología d...     2016-12
# 1    Distancias entre la ecología y la praxis ambie...        2011
# 2    Plant community resilience in the face of fire...     2016-02
# 3    La puesta en acto de las políticas de formació...     2022-11
# 4         Introducción a la Genética Forense No-Humana        2015
# ..                                                 ...         ...
# 193  Larval morphology of Megaporus Brinck, 1943 (C...     2020-04
# 194  “Los propósitos de Caseros no se han cumplido ...     2024-07
# 195  The two synthetic cannabinoid compounds 4′‐ F‐...     2023-11
# 196  Simultaneous Determination of Human Erythrocyt...     2020-10
# 197  Two-dimensional geoelectrical modeling using a...     2000-05
#
#                                               creators  \
# 0                             [Cassiodoro, Gisela Eva]
# 1                              [Nuñez, Paula Gabriela]
# 2    [Lipoma, Maria Lucrecia, Gurvich, Diego Ezequi...
# 3                    [Marchetti, Braian, Bazán, Sonia]
# 4    [Giovambattista, Guillermo, Barrientos, Laura ...
# ..                                                 ...
# 193  [Alarie, Yves, Michat, Mariano Cruz, Watts, Ch...
# 194                                  [Herrero, Fabian]
# 195  [dos Santos Pereira, Maurício, Maitan Santos, ...
# 196  [Londero, Carolina María, Riquelme, Bibiana Do...
# 197  [Osella, Ana Maria, Martinelli, Hilda Patricia...
#
#                                            description  \
# 0    [La disponibilidad de recursos hídricos en Pat...
# 1    [Este libro recorre un problema que cotidianam...
# 2    [The ability of communities or ecosystems to r...
# 3    [El presente artículo recupera las conclusione...
# 4    [El presente libro nace como producto de una c...
# ..                                                 ...
# 193  [The larvae of the Australian endemic species ...
# 194  [Durante el año 1863, cuando todavía se viven ...
# 195  [To study the anti-inflammatory potential of t...
# 196  [The simultaneous determination of adhesion an...
# 197  [In this paper, we present a new method for DC...
#
#                                                  types  \
# 0    [info:eu-repo/semantics/article, info:ar-repo/...
# 1    [info:eu-repo/semantics/publishedVersion, info...
# 2    [info:eu-repo/semantics/article, info:ar-repo/...
# 3    [info:eu-repo/semantics/article, info:ar-repo/...
# 4    [info:eu-repo/semantics/publishedVersion, info...
# ..                                                 ...
# 193  [info:eu-repo/semantics/article, info:ar-repo/...
# 194  [info:eu-repo/semantics/article, info:ar-repo/...
# 195  [info:eu-repo/semantics/article, info:ar-repo/...
# 196  [info:eu-repo/semantics/article, info:ar-repo/...
# 197  [info:eu-repo/semantics/article, info:ar-repo/...
#
#                                            identifiers languages  \
# 0    [http://hdl.handle.net/11336/179477, Cassiodor...     [spa]
# 1    [http://hdl.handle.net/11336/116972, Nuñez, Pa...     [spa]
# 2    [http://hdl.handle.net/11336/23263, Lipoma, Ma...     [eng]
# 3    [http://hdl.handle.net/11336/215533, Marchetti...     [spa]
# 4    [http://hdl.handle.net/11336/109802, Giovambat...     [spa]
# ..                                                 ...       ...
# 193  [http://hdl.handle.net/11336/182926, Alarie, Y...     [eng]
# 194  [http://hdl.handle.net/11336/261962, Herrero, ...     [spa]
# 195  [http://hdl.handle.net/11336/265488, dos Santo...     [eng]
# 196  [http://hdl.handle.net/11336/144165, Londero, ...     [eng]
# 197  [http://hdl.handle.net/11336/54764, Osella, An...     [eng]
#
#                                               subjects  \
# 0    [MESETAS, TECNOLOGÍA, USO DEL ESPACIO, LOGÍSTI...
# 1    [ECOLOGÍA, PRAXIS AMBIENTAL, ECOFEMINISMO, TEO...
# 2    [Firefire, Functional Redundancy, Plan Functio...
# 3    [POLÍTICAS PÚBLICAS EDUCATIVAS, FORMACIÓN DOCE...
# 4    [GENÉTICA FORENSE, IDENTIFICACIÓN GENÉTICA, ID...
# ..                                                 ...
# 193  [AUSTRALASIA, HYDROPORINAE, LARVAE, PHYLOGENY,...
# 194  [PRENSA, JOSÉ HERNANDEZ, JUSTO JOSE DE URQUIZA...
# 195  [ASTROCYTES, MICROGLIA, NEUROINFLAMMATION, OXI...
# 196  [HEMORHEOLOGY, MICROFLUIDIC CHAMBER, RED BLOOD...
# 197  [Dc Resistivity Method, Geoelectrical Prospect...
#
#                                             publishers  \
# 0    [Instituto Nacional de Antropología y Pensamie...
# 1                   [Universidad Nacional de La Plata]
# 2                    [Wiley Blackwell Publishing, Inc]
# 3    [Universidad de Buenos Aires. Facultad de Filo...
# 4    [Universidad Nacional de La Plata. Facultad de...
# ..                                                 ...
# 193                            [Coleopterists Society]
# 194  [Pontificia Universidad Católica Argentina "Sa...
# 195           [Wiley-liss, div John Wiley & Sons Inc.]
# 196                                     [Humana Press]
# 197  [Institute of Electrical and Electronics Engin...
#
#                                              relations  \
# 0    [info:eu-repo/semantics/altIdentifier/url/http...
# 1    [info:eu-repo/semantics/altIdentifier/url/http...
# 2    [info:eu-repo/semantics/altIdentifier/url/http...
# 3    [info:eu-repo/semantics/altIdentifier/doi/10.3...
# 4    [info:eu-repo/semantics/altIdentifier/url/http...
# ..                                                 ...
# 193  [info:eu-repo/semantics/altIdentifier/url/http...
# 194  [info:eu-repo/semantics/altIdentifier/url/http...
# 195  [info:eu-repo/semantics/altIdentifier/url/http...
# 196  [info:eu-repo/semantics/altIdentifier/doi/10.1...
# 197  [info:eu-repo/semantics/altIdentifier/doi/10.1...
#
#                                                 rights  \
# 0    [info:eu-repo/semantics/openAccess, https://cr...
# 1    [info:eu-repo/semantics/openAccess, https://cr...
# 2    [info:eu-repo/semantics/openAccess, https://cr...
# 3    [info:eu-repo/semantics/openAccess, https://cr...
# 4    [info:eu-repo/semantics/openAccess, https://cr...
# ..                                                 ...
# 193  [info:eu-repo/semantics/restrictedAccess, http...
# 194  [info:eu-repo/semantics/openAccess, https://cr...
# 195  [info:eu-repo/semantics/openAccess, https://cr...
# 196  [info:eu-repo/semantics/restrictedAccess, http...
# 197  [info:eu-repo/semantics/openAccess, https://cr...
#
#                                                formats  \
# 0                   [application/pdf, application/pdf]
# 1    [application/pdf, application/pdf, application...
# 2    [application/pdf, application/pdf, application...
# 3                   [application/pdf, application/pdf]
# 4    [application/pdf, application/pdf, application...
# ..                                                 ...
# 193                 [application/pdf, application/pdf]
# 194                 [application/pdf, application/pdf]
# 195                 [application/pdf, application/pdf]
# 196                 [application/pdf, application/pdf]
# 197                 [application/pdf, application/pdf]
#
#              extract_datetime
# 0   2025-12-12 00:00:00+00:00
# 1   2025-12-12 00:00:00+00:00
# 2   2025-12-12 00:00:00+00:00
# 3   2025-12-12 00:00:00+00:00
# 4   2025-12-12 00:00:00+00:00
# ..                        ...
# 193 2025-12-12 00:00:00+00:00
# 194 2025-12-12 00:00:00+00:00
# 195 2025-12-12 00:00:00+00:00
# 196 2025-12-12 00:00:00+00:00
# 197 2025-12-12 00:00:00+00:00
#
# [198 rows x 17 columns]
