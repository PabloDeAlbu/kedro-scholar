# %%
from datetime import date
import requests
import pandas as pd
import time
pd.set_option('display.max_columns', None)

# %%
institution_ror = catalog.load('params:openalex_fetch_options.institution_ror')
#env = catalog.load('params:fetch_options.env')
env = 'dev'
# Out:
#                     INFO     Loading data from params:openalex_fetch_options.institution_ror    ]8;id=285849;file:///root/kedro-unlp/.venv/lib/python3.10/site-packages/kedro/io/data_catalog.py\data_catalog.py]8;;\:]8;id=18563;file:///root/kedro-unlp/.venv/lib/python3.10/site-packages/kedro/io/data_catalog.py#389\389]8;;\
#                              (MemoryDataset)...

# %%
env
# Out:
# <pre style="white-space:pre;overflow-x:auto;line-height:normal;font-family:Menlo,'DejaVu Sans Mono',consolas,'Courier New',monospace"></pre>
# 'dev'

# %%
def clean_work_dataframe(df):
    """Elimina columnas innecesarias si están presentes."""
    columns_to_drop = {"abstract_inverted_index", "abstract_inverted_index_v3"}
    return df.drop(columns=columns_to_drop.intersection(df.columns), inplace=False)

def fetch_openalex_work(institution_ror, env):
    session = requests.Session()  # Reutilizar la sesión para eficiencia
    base_url = 'https://api.openalex.org/works?filter=institutions.ror:{}&cursor={}&per-page=200'
    cursor = '*'
    iteration_limit = 5
    iteration_count = 0
    all_dataframes = []  # Lista para almacenar los DataFrames antes de concatenar

    while True:
        url = base_url.format(institution_ror, cursor)
        print(f'Iteration count: {iteration_count}')
        print(f'GET {url}')

        try:
            response = session.get(url, timeout=10)
            response.raise_for_status()
            api_response = response.json()
        except requests.RequestException as e:
            print(f"Error en la solicitud: {e}")
            break
        except ValueError:
            print("Error al decodificar JSON.")
            break

        # Si no hay resultados, se termina el bucle
        if 'results' not in api_response or not api_response['results']:
            print("No hay más datos disponibles.")
            break

        df_tmp = pd.DataFrame.from_dict(api_response['results'])
        df_tmp = clean_work_dataframe(df_tmp)
        all_dataframes.append(df_tmp)

        # Actualizar cursor
        cursor = api_response.get('meta', {}).get('next_cursor')
        if not cursor:
            break

        # Control de iteraciones en entorno 'dev'
        iteration_count += 1
        if env == 'dev' and iteration_count >= iteration_limit:
            break

        time.sleep(1)  # Respetar límites de la API

    # Concatenar todos los DataFrames en uno solo
    df = pd.concat(all_dataframes, ignore_index=True) if all_dataframes else pd.DataFrame()

    df['load_datetime'] = date.today()

    return df, df.head(1000)

# %%
df, df_dev = fetch_openalex_work(institution_ror, env)
# Out:
# Iteration count: 0
# GET https://api.openalex.org/works?filter=institutions.ror:https://ror.org/01tjs6929&cursor=*&per-page=200
# Iteration count: 1
# GET https://api.openalex.org/works?filter=institutions.ror:https://ror.org/01tjs6929&cursor=IlsxMDAuMCwgMjIyLCAnaHR0cHM6Ly9vcGVuYWxleC5vcmcvVzIxNDIxMTk3NjMnXSI=&per-page=200
# Iteration count: 2
# GET https://api.openalex.org/works?filter=institutions.ror:https://ror.org/01tjs6929&cursor=Ils5OS4wLCAyMDksICdodHRwczovL29wZW5hbGV4Lm9yZy9XMjAxODcwMjkyNSddIg==&per-page=200
# Iteration count: 3
# GET https://api.openalex.org/works?filter=institutions.ror:https://ror.org/01tjs6929&cursor=Ils5OS4wLCAxNDAsICdodHRwczovL29wZW5hbGV4Lm9yZy9XMzA0MTIzMDQyMyddIg==&per-page=200
# Iteration count: 4
# GET https://api.openalex.org/works?filter=institutions.ror:https://ror.org/01tjs6929&cursor=Ils5OS4wLCAxMDYsICdodHRwczovL29wZW5hbGV4Lm9yZy9XMjc0ODE1NjAxNSddIg==&per-page=200

# %%
df.head(5)
# Out:
# <pre style="white-space:pre;overflow-x:auto;line-height:normal;font-family:Menlo,'DejaVu Sans Mono',consolas,'Courier New',monospace"></pre>
#                                  id  \
# 0  https://openalex.org/W4211046286
# 1  https://openalex.org/W4292403095
# 2  https://openalex.org/W2501864044
# 3  https://openalex.org/W2098406858
# 4  https://openalex.org/W2012331775
#
#                                              doi  \
# 0  https://doi.org/10.1088/1748-0221/3/08/s08003
# 1     https://doi.org/10.1051/0004-6361:20041864
# 2           https://doi.org/10.1093/mnras/stx721
# 3                                           None
# 4            https://doi.org/10.1038/nature10158
#
#                                                title  \
# 0  The ATLAS Experiment at the CERN Large Hadron ...
# 1  The Leiden/Argentine/Bonn (LAB) Survey of Gala...
# 2  The clustering of galaxies in the completed SD...
# 3  The ATLAS Experiment at the CERN Large Hadron ...
# 4  Genome sequence and analysis of the tuber crop...
#
#                                         display_name  publication_year  \
# 0  The ATLAS Experiment at the CERN Large Hadron ...              2008
# 1  The Leiden/Argentine/Bonn (LAB) Survey of Gala...              2005
# 2  The clustering of galaxies in the completed SD...              2017
# 3  The ATLAS Experiment at the CERN Large Hadron ...              2020
# 4  Genome sequence and analysis of the tuber crop...              2011
#
#   publication_date                                                ids  \
# 0       2008-08-14  {'openalex': 'https://openalex.org/W4211046286...
# 1       2005-08-29  {'openalex': 'https://openalex.org/W4292403095...
# 2       2017-03-24  {'openalex': 'https://openalex.org/W2501864044...
# 3       2020-02-23  {'openalex': 'https://openalex.org/W2098406858...
# 4       2011-07-01  {'openalex': 'https://openalex.org/W2012331775...
#
#   language                                   primary_location     type  \
# 0       en  {'is_oa': True, 'landing_page_url': 'https://d...  article
# 1       en  {'is_oa': True, 'landing_page_url': 'https://d...  article
# 2       en  {'is_oa': True, 'landing_page_url': 'https://d...  article
# 3       en  {'is_oa': False, 'landing_page_url': 'https://...     book
# 4       en  {'is_oa': True, 'landing_page_url': 'https://d...  article
#
#      type_crossref                   indexed_in  \
# 0  journal-article                   [crossref]
# 1  journal-article  [arxiv, crossref, datacite]
# 2  journal-article  [arxiv, crossref, datacite]
# 3             book                           []
# 4  journal-article           [crossref, pubmed]
#
#                                          open_access  \
# 0  {'is_oa': True, 'oa_status': 'green', 'oa_url'...
# 1  {'is_oa': True, 'oa_status': 'bronze', 'oa_url...
# 2  {'is_oa': True, 'oa_status': 'bronze', 'oa_url...
# 3  {'is_oa': False, 'oa_status': 'closed', 'oa_ur...
# 4  {'is_oa': True, 'oa_status': 'hybrid', 'oa_url...
#
#                                          authorships institution_assertions  \
# 0  [{'author_position': 'first', 'author': {'id':...                     []
# 1  [{'author_position': 'first', 'author': {'id':...                     []
# 2  [{'author_position': 'first', 'author': {'id':...                     []
# 3  [{'author_position': 'first', 'author': {'id':...                     []
# 4  [{'author_position': 'first', 'author': {'id':...                     []
#
#    countries_distinct_count  institutions_distinct_count  \
# 0                        36                          188
# 1                         2                            4
# 2                        12                           57
# 3                        32                          170
# 4                        12                           19
#
#                             corresponding_author_ids  \
# 0                                                 []
# 1                                                 []
# 2  [https://openalex.org/A5102897520, https://ope...
# 3                                                 []
# 4                                                 []
#
#                        corresponding_institution_ids  \
# 0                                                 []
# 1                                                 []
# 2  [https://openalex.org/I148283060, https://open...
# 3                                                 []
# 4                                                 []
#
#                                             apc_list  \
# 0                                               None
# 1                                               None
# 2  {'value': 2310, 'currency': 'GBP', 'value_usd'...
# 3                                               None
# 4  {'value': 9750, 'currency': 'EUR', 'value_usd'...
#
#                                             apc_paid     fwci  \
# 0                                               None   53.865
# 1                                               None   20.876
# 2                                               None  118.100
# 3                                               None   19.933
# 4  {'value': 9750, 'currency': 'EUR', 'value_usd'...  148.969
#
#   is_authors_truncated  has_fulltext fulltext_origin  cited_by_count  \
# 0                 True          True             pdf            3903
# 1                  NaN          True             pdf            3232
# 2                  NaN          True             pdf            2768
# 3                 True         False             NaN            2468
# 4                  NaN          True          ngrams            2028
#
#                       citation_normalized_percentile cited_by_percentile_year  \
# 0  {'value': 0.999907, 'is_in_top_1_percent': Tru...  {'min': 99, 'max': 100}
# 1  {'value': 0.999902, 'is_in_top_1_percent': Tru...  {'min': 99, 'max': 100}
# 2  {'value': 0.999951, 'is_in_top_1_percent': Tru...  {'min': 99, 'max': 100}
# 3  {'value': 0.671875, 'is_in_top_1_percent': Fal...  {'min': 99, 'max': 100}
# 4  {'value': 0.999978, 'is_in_top_1_percent': Tru...  {'min': 99, 'max': 100}
#
#                                               biblio  is_retracted  \
# 0  {'volume': '3', 'issue': '08', 'first_page': '...         False
# 1  {'volume': '440', 'issue': '2', 'first_page': ...         False
# 2  {'volume': '470', 'issue': '3', 'first_page': ...         False
# 3  {'volume': None, 'issue': None, 'first_page': ...         False
# 4  {'volume': '475', 'issue': '7355', 'first_page...         False
#
#    is_paratext                                      primary_topic  \
# 0        False  {'id': 'https://openalex.org/T11044', 'display...
# 1        False  {'id': 'https://openalex.org/T10818', 'display...
# 2        False  {'id': 'https://openalex.org/T10026', 'display...
# 3        False  {'id': 'https://openalex.org/T10048', 'display...
# 4        False  {'id': 'https://openalex.org/T11771', 'display...
#
#                                               topics  \
# 0  [{'id': 'https://openalex.org/T11044', 'displa...
# 1  [{'id': 'https://openalex.org/T10818', 'displa...
# 2  [{'id': 'https://openalex.org/T10026', 'displa...
# 3  [{'id': 'https://openalex.org/T10048', 'displa...
# 4  [{'id': 'https://openalex.org/T11771', 'displa...
#
#                                             keywords  \
# 0  [{'id': 'https://openalex.org/keywords/atlas-d...
# 1  [{'id': 'https://openalex.org/keywords/galacti...
# 2  [{'id': 'https://openalex.org/keywords/baryon-...
# 3  [{'id': 'https://openalex.org/keywords/atlas-d...
# 4  [{'id': 'https://openalex.org/keywords/sequenc...
#
#                                             concepts  \
# 0  [{'id': 'https://openalex.org/C87668248', 'wik...
# 1  [{'id': 'https://openalex.org/C121332964', 'wi...
# 2  [{'id': 'https://openalex.org/C121332964', 'wi...
# 3  [{'id': 'https://openalex.org/C87668248', 'wik...
# 4  [{'id': 'https://openalex.org/C137580998', 'wi...
#
#                                                 mesh  locations_count  \
# 0                                                 []                9
# 1                                                 []                8
# 2                                                 []               21
# 3                                                 []                1
# 4  [{'descriptor_ui': 'D018745', 'descriptor_name...                6
#
#                                            locations  \
# 0  [{'is_oa': True, 'landing_page_url': 'https://...
# 1  [{'is_oa': True, 'landing_page_url': 'https://...
# 2  [{'is_oa': True, 'landing_page_url': 'https://...
# 3  [{'is_oa': False, 'landing_page_url': 'https:/...
# 4  [{'is_oa': True, 'landing_page_url': 'https://...
#
#                                     best_oa_location  \
# 0  {'is_oa': True, 'landing_page_url': 'https://d...
# 1  {'is_oa': True, 'landing_page_url': 'https://d...
# 2  {'is_oa': True, 'landing_page_url': 'https://d...
# 3                                               None
# 4  {'is_oa': True, 'landing_page_url': 'https://d...
#
#                        sustainable_development_goals grants datasets  \
# 0                                                 []     []       []
# 1                                                 []     []       []
# 2                                                 []     []       []
# 3                                                 []     []       []
# 4  [{'id': 'https://metadata.un.org/sdg/2', 'disp...     []       []
#
#                              versions  referenced_works_count  \
# 0                                  []                     154
# 1  [https://openalex.org/W4292403095]                       7
# 2  [https://openalex.org/W2501864044]                     234
# 3                                  []                     220
# 4                                  []                      55
#
#                                     referenced_works  \
# 0  [https://openalex.org/W1578925023, https://ope...
# 1  [https://openalex.org/W1539512060, https://ope...
# 2  [https://openalex.org/W1483545773, https://ope...
# 3  [https://openalex.org/W1578925023, https://ope...
# 4  [https://openalex.org/W1214546200, https://ope...
#
#                                        related_works  \
# 0  [https://openalex.org/W4385358068, https://ope...
# 1  [https://openalex.org/W4296758524, https://ope...
# 2  [https://openalex.org/W3148180306, https://ope...
# 3  [https://openalex.org/W3121642222, https://ope...
# 4  [https://openalex.org/W3178279768, https://ope...
#
#                                     cited_by_api_url  \
# 0  https://api.openalex.org/works?filter=cites:W4...
# 1  https://api.openalex.org/works?filter=cites:W4...
# 2  https://api.openalex.org/works?filter=cites:W2...
# 3  https://api.openalex.org/works?filter=cites:W2...
# 4  https://api.openalex.org/works?filter=cites:W2...
#
#                                       counts_by_year  \
# 0  [{'year': 2025, 'cited_by_count': 95}, {'year'...
# 1  [{'year': 2025, 'cited_by_count': 37}, {'year'...
# 2  [{'year': 2025, 'cited_by_count': 209}, {'year...
# 3  [{'year': 2022, 'cited_by_count': 12}, {'year'...
# 4  [{'year': 2025, 'cited_by_count': 53}, {'year'...
#
#                  updated_date created_date load_datetime
# 0  2025-09-06T09:41:56.891629   2022-02-13    2025-09-08
# 1  2025-09-01T06:55:20.685347   2022-08-20    2025-09-08
# 2  2025-09-02T08:13:28.728906   2016-08-23    2025-09-08
# 3  2025-09-08T09:47:59.233631   2016-06-24    2025-09-08
# 4  2025-09-01T11:16:46.729607   2016-06-24    2025-09-08
