# %%
import pandas as pd
from pandas import json_normalize
from datetime import date
pd.set_option('display.max_columns', None)

# %%
df_author_raw = catalog.load('raw/openalex/author#parquet')
# Out:
#                     INFO     Loading data from raw/openalex/author#parquet (ParquetDataset)...  ]8;id=309464;file:///root/kedro-cic/.venv/lib/python3.10/site-packages/kedro/io/data_catalog.py\data_catalog.py]8;;\:]8;id=327934;file:///root/kedro-cic/.venv/lib/python3.10/site-packages/kedro/io/data_catalog.py#389\389]8;;\

# %% [markdown]
# # Profiling

# %%
df_author_raw.dtypes
# Out:
# <pre style="white-space:pre;overflow-x:auto;line-height:normal;font-family:Menlo,'DejaVu Sans Mono',consolas,'Courier New',monospace"></pre>
# id                           object
# orcid                        object
# display_name                 object
# display_name_alternatives    object
# works_count                   int64
# cited_by_count                int64
# summary_stats                object
# ids                          object
# affiliations                 object
# last_known_institutions      object
# topics                       object
# topic_share                  object
# x_concepts                   object
# counts_by_year               object
# works_api_url                object
# updated_date                 object
# created_date                 object
# dtype: object

# %%
df_author_raw
# Out:
# <pre style="white-space:pre;overflow-x:auto;line-height:normal;font-family:Menlo,'DejaVu Sans Mono',consolas,'Courier New',monospace"></pre>
#                                   id                                  orcid  \
# 0   https://openalex.org/A5003447605  https://orcid.org/0000-0002-5260-1807
# 1   https://openalex.org/A5053874532                                   None
# 2   https://openalex.org/A5112709549                                   None
# 3   https://openalex.org/A5019186384  https://orcid.org/0000-0001-6247-0428
# 4   https://openalex.org/A5062756128  https://orcid.org/0000-0002-1030-4492
# ..                               ...                                    ...
# 0   https://openalex.org/A5113511507                                   None
# 1   https://openalex.org/A5113910833                                   None
# 2   https://openalex.org/A5113933053                                   None
# 3   https://openalex.org/A5114742604  https://orcid.org/0009-0002-9034-3949
# 4   https://openalex.org/A5114742605  https://orcid.org/0009-0008-8181-1601
#
#                 display_name  \
# 0          Gustavo E. Romero
# 1          Guillermo Soberón
# 2            Hugo Luis López
# 3   Guillermo Ricardo Simari
# 4                 Peter Vogt
# ..                       ...
# 0                 Dra Araujo
# 1                 Dras María
# 2         Rodríguez Graciela
# 3      Ana Paula Sanguinetti
# 4     Magalí Rocío Di Meglio
#
#                             display_name_alternatives  works_count  \
# 0   [Gladis Graciela Romero, Gustavo Romero, Gusta...          760
# 1   [Guillermo R Soberon, Guillermo Soberon, G. So...          629
# 2   [Hugo L. López, Hugo Luis López, Hugo L. Lopez...          480
# 3   [Guillermo Ricardo Simari, G. Simari, Guillerm...          467
# 4   [Peter Vogt, P.R Vogt, P. Vogt, V. Peter, P. R...          420
# ..                                                ...          ...
# 0                                        [Dra Araujo]            1
# 1                                        [Dras María]            1
# 2                                [Rodríguez Graciela]            1
# 3                             [Ana Paula Sanguinetti]            0
# 4                            [Magalí Rocío Di Meglio]            0
#
#     cited_by_count                                      summary_stats  \
# 0             9045  {'2yr_mean_citedness': 1.2045454545454546, 'h_...
# 1             1120  {'2yr_mean_citedness': 0.0, 'h_index': 14, 'i1...
# 2             3300  {'2yr_mean_citedness': 0.3333333333333333, 'h_...
# 3             5900  {'2yr_mean_citedness': 1.2857142857142858, 'h_...
# 4            15770  {'2yr_mean_citedness': 0.8888888888888888, 'h_...
# ..             ...                                                ...
# 0                3  {'2yr_mean_citedness': 0.0, 'h_index': 1, 'i10...
# 1                3  {'2yr_mean_citedness': 0.0, 'h_index': 1, 'i10...
# 2                0  {'2yr_mean_citedness': 0.0, 'h_index': 0, 'i10...
# 3                0  {'2yr_mean_citedness': 0.0, 'h_index': 0, 'i10...
# 4                0  {'2yr_mean_citedness': 0.0, 'h_index': 0, 'i10...
#
#                                                   ids  \
# 0   {'openalex': 'https://openalex.org/A5003447605...
# 1   {'openalex': 'https://openalex.org/A5053874532...
# 2   {'openalex': 'https://openalex.org/A5112709549...
# 3   {'openalex': 'https://openalex.org/A5019186384...
# 4   {'openalex': 'https://openalex.org/A5062756128...
# ..                                                ...
# 0   {'openalex': 'https://openalex.org/A5113511507...
# 1   {'openalex': 'https://openalex.org/A5113910833...
# 2   {'openalex': 'https://openalex.org/A5113933053...
# 3   {'openalex': 'https://openalex.org/A5114742604...
# 4   {'openalex': 'https://openalex.org/A5114742605...
#
#                                          affiliations  \
# 0   [{'institution': {'country_code': 'AR', 'displ...
# 1   [{'institution': {'country_code': 'MX', 'displ...
# 2   [{'institution': {'country_code': 'AR', 'displ...
# 3   [{'institution': {'country_code': 'AR', 'displ...
# 4   [{'institution': {'country_code': 'IT', 'displ...
# ..                                                ...
# 0   [{'institution': {'country_code': 'AR', 'displ...
# 1   [{'institution': {'country_code': 'AR', 'displ...
# 2   [{'institution': {'country_code': 'AR', 'displ...
# 3   [{'institution': {'country_code': 'AR', 'displ...
# 4   [{'institution': {'country_code': 'AR', 'displ...
#
#                               last_known_institutions  \
# 0   [{'country_code': 'AR', 'display_name': 'Insti...
# 1   [{'country_code': 'MX', 'display_name': 'Mexfa...
# 2   [{'country_code': 'AR', 'display_name': 'Unive...
# 3   [{'country_code': 'AR', 'display_name': 'Unive...
# 4   [{'country_code': 'IT', 'display_name': 'Joint...
# ..                                                ...
# 0   [{'country_code': 'AR', 'display_name': 'Comis...
# 1   [{'country_code': 'AR', 'display_name': 'Comis...
# 2   [{'country_code': 'AR', 'display_name': 'Natio...
# 3   [{'country_code': 'AR', 'display_name': 'Conse...
# 4   [{'country_code': 'AR', 'display_name': 'Conse...
#
#                                                topics  \
# 0   [{'count': 384, 'display_name': 'High-Energy A...
# 1   [{'count': 146, 'display_name': 'University So...
# 2   [{'count': 138, 'display_name': 'Discourse Ana...
# 3   [{'count': 331, 'display_name': 'Methods and T...
# 4   [{'count': 71, 'display_name': 'Tectonic and G...
# ..                                                ...
# 0   [{'count': 1, 'display_name': 'Pharmacological...
# 1   [{'count': 1, 'display_name': 'Global Trends i...
# 2   [{'count': 1, 'display_name': 'Sensory Analysi...
# 3                                                  []
# 4                                                  []
#
#                                           topic_share  \
# 0   [{'display_name': 'High-Energy Astrophysics an...
# 1   [{'display_name': 'Higher Education and Knowle...
# 2   [{'display_name': 'Discourse Analysis and Soci...
# 3   [{'display_name': 'Methods and Techniques for ...
# 4   [{'display_name': 'Water Resource Management a...
# ..                                                ...
# 0   [{'display_name': 'Pharmacological Management ...
# 1   [{'display_name': 'Sustainable Diets and Envir...
# 2   [{'display_name': 'Sensory Analysis in Food Sc...
# 3                                                  []
# 4                                                  []
#
#                                            x_concepts  \
# 0   [{'display_name': 'Physics', 'id': 'https://op...
# 1   [{'display_name': 'Philosophy', 'id': 'https:/...
# 2   [{'display_name': 'Art', 'id': 'https://openal...
# 3   [{'display_name': 'Philosophy', 'id': 'https:/...
# 4   [{'display_name': 'Biology', 'id': 'https://op...
# ..                                                ...
# 0   [{'display_name': 'Biochemistry', 'id': 'https...
# 1   [{'display_name': 'Psychology', 'id': 'https:/...
# 2   [{'display_name': 'Ecology', 'id': 'https://op...
# 3                                                  []
# 4                                                  []
#
#                                        counts_by_year  \
# 0   [{'cited_by_count': 745, 'works_count': 23, 'y...
# 1   [{'cited_by_count': 17, 'works_count': 0, 'yea...
# 2   [{'cited_by_count': 183, 'works_count': 0, 'ye...
# 3   [{'cited_by_count': 180, 'works_count': 1, 'ye...
# 4   [{'cited_by_count': 590, 'works_count': 4, 'ye...
# ..                                                ...
# 0   [{'cited_by_count': 8, 'works_count': 0, 'year...
# 1   [{'cited_by_count': 16, 'works_count': 0, 'yea...
# 2   [{'cited_by_count': 0, 'works_count': 1, 'year...
# 3   [{'cited_by_count': 0, 'works_count': 1, 'year...
# 4   [{'cited_by_count': 0, 'works_count': 1, 'year...
#
#                                         works_api_url  \
# 0   https://api.openalex.org/works?filter=author.i...
# 1   https://api.openalex.org/works?filter=author.i...
# 2   https://api.openalex.org/works?filter=author.i...
# 3   https://api.openalex.org/works?filter=author.i...
# 4   https://api.openalex.org/works?filter=author.i...
# ..                                                ...
# 0   https://api.openalex.org/works?filter=author.i...
# 1   https://api.openalex.org/works?filter=author.i...
# 2   https://api.openalex.org/works?filter=author.i...
# 3   https://api.openalex.org/works?filter=author.i...
# 4   https://api.openalex.org/works?filter=author.i...
#
#                   updated_date created_date
# 0   2024-11-27T02:59:56.541657   2023-07-21
# 1   2024-11-27T21:11:57.848498   2023-07-21
# 2   2024-11-22T12:03:52.544346   2024-10-15
# 3   2024-11-29T07:57:46.761250   2023-07-21
# 4   2024-11-29T10:57:56.410709   2023-07-21
# ..                         ...          ...
# 0   2024-11-22T23:27:44.644648   2024-10-15
# 1   2024-11-22T23:51:06.492822   2024-10-15
# 2   2024-11-23T00:11:37.906627   2024-10-15
# 3   2024-11-23T09:51:02.930224   2024-11-23
# 4   2024-11-23T09:51:02.698831   2024-11-23
#
# [2330 rows x 17 columns]

# %% [markdown]
# # Nodo

# %%
def land_openalex_author(df: pd.DataFrame)-> pd.DataFrame:
    
    df_author = df.drop(
        columns=[
            'display_name_alternatives', 
            'summary_stats', 
            'ids', 
            'affiliations', 
            'last_known_institutions', 
            'topics', 
            'topic_share', 
            'x_concepts', 
            'counts_by_year', 
            'works_api_url'
        ]
    )

    df_author = df_author.convert_dtypes()
    df_author['load_datetime'] = date.today()
    
    return df_author

# %% [markdown]
# # Ejecuto nodo

# %%
df_author = land_openalex_author(df_author_raw)

# %% [markdown]
# # Resultados

# %%
df_author
# Out:
# <pre style="white-space:pre;overflow-x:auto;line-height:normal;font-family:Menlo,'DejaVu Sans Mono',consolas,'Courier New',monospace"></pre>
#                                   id                                  orcid  \
# 0   https://openalex.org/A5003447605  https://orcid.org/0000-0002-5260-1807
# 1   https://openalex.org/A5053874532                                   <NA>
# 2   https://openalex.org/A5112709549                                   <NA>
# 3   https://openalex.org/A5019186384  https://orcid.org/0000-0001-6247-0428
# 4   https://openalex.org/A5062756128  https://orcid.org/0000-0002-1030-4492
# ..                               ...                                    ...
# 0   https://openalex.org/A5113511507                                   <NA>
# 1   https://openalex.org/A5113910833                                   <NA>
# 2   https://openalex.org/A5113933053                                   <NA>
# 3   https://openalex.org/A5114742604  https://orcid.org/0009-0002-9034-3949
# 4   https://openalex.org/A5114742605  https://orcid.org/0009-0008-8181-1601
#
#                 display_name  works_count  cited_by_count  \
# 0          Gustavo E. Romero          760            9045
# 1          Guillermo Soberón          629            1120
# 2            Hugo Luis López          480            3300
# 3   Guillermo Ricardo Simari          467            5900
# 4                 Peter Vogt          420           15770
# ..                       ...          ...             ...
# 0                 Dra Araujo            1               3
# 1                 Dras María            1               3
# 2         Rodríguez Graciela            1               0
# 3      Ana Paula Sanguinetti            0               0
# 4     Magalí Rocío Di Meglio            0               0
#
#                   updated_date created_date load_datetime
# 0   2024-11-27T02:59:56.541657   2023-07-21    2024-12-03
# 1   2024-11-27T21:11:57.848498   2023-07-21    2024-12-03
# 2   2024-11-22T12:03:52.544346   2024-10-15    2024-12-03
# 3   2024-11-29T07:57:46.761250   2023-07-21    2024-12-03
# 4   2024-11-29T10:57:56.410709   2023-07-21    2024-12-03
# ..                         ...          ...           ...
# 0   2024-11-22T23:27:44.644648   2024-10-15    2024-12-03
# 1   2024-11-22T23:51:06.492822   2024-10-15    2024-12-03
# 2   2024-11-23T00:11:37.906627   2024-10-15    2024-12-03
# 3   2024-11-23T09:51:02.930224   2024-11-23    2024-12-03
# 4   2024-11-23T09:51:02.698831   2024-11-23    2024-12-03
#
# [2330 rows x 8 columns]
