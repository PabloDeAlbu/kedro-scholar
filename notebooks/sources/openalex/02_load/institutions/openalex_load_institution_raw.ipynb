# %%
import pandas as pd
import json
from datetime import datetime
pd.set_option('display.max_columns', None)

# %%
df_institution_raw = catalog.load('raw/openalex/institution#parquet')
# Out:
#                     INFO     Loading data from raw/openalex/institution#parquet                 ]8;id=765073;file:///home/pablo/dev/conicet/kedro-conicet/.venv/lib/python3.10/site-packages/kedro/io/data_catalog.py\data_catalog.py]8;;\:]8;id=204269;file:///home/pablo/dev/conicet/kedro-conicet/.venv/lib/python3.10/site-packages/kedro/io/data_catalog.py#389\389]8;;\
#                              (ParquetDataset)...

# %% [markdown]
# # Profiling

# %%
df_institution_raw.columns
# Out:
# <pre style="white-space:pre;overflow-x:auto;line-height:normal;font-family:Menlo,'DejaVu Sans Mono',consolas,'Courier New',monospace"></pre>
# Index(['id', 'ror', 'display_name', 'country_code', 'type', 'type_id',
#        'lineage', 'homepage_url', 'image_url', 'image_thumbnail_url',
#        'display_name_acronyms', 'display_name_alternatives', 'repositories',
#        'works_count', 'cited_by_count', 'summary_stats', 'ids', 'geo',
#        'international', 'associated_institutions', 'counts_by_year', 'roles',
#        'topics', 'topic_share', 'x_concepts', 'is_super_system',
#        'works_api_url', 'updated_date', 'created_date', 'extract_datetime'],
#       dtype='object')

# %%
df_institution_raw.head(3)
# Out:
# <pre style="white-space:pre;overflow-x:auto;line-height:normal;font-family:Menlo,'DejaVu Sans Mono',consolas,'Courier New',monospace"></pre>
#                                  id                        ror  \
# 0  https://openalex.org/I4210122970  https://ror.org/02s7sax82
#
#                               display_name country_code        type  \
# 0  Comisión de Investigaciones Científicas           AR  government
#
#                                              type_id  \
# 0  https://openalex.org/institution-types/government
#
#                               lineage                homepage_url image_url  \
# 0  [https://openalex.org/I4210122970]  https://www.cic.gba.gob.ar      None
#
#   image_thumbnail_url display_name_acronyms display_name_alternatives  \
# 0                None                 [CIC]                        []
#
#   repositories  works_count  cited_by_count  \
# 0           []         3510           56910
#
#                                        summary_stats  \
# 0  {'2yr_mean_citedness': 1.4695652173913043, 'h_...
#
#                                                  ids  \
# 0  {'grid': 'grid.452362.4', 'openalex': 'https:/...
#
#                                                  geo  \
# 0  {'city': 'La Plata', 'country': 'Argentina', '...
#
#                                        international  \
# 0  {'display_name': {'en': 'Comisión de Investiga...
#
#                              associated_institutions  \
# 0  [{'country_code': None, 'display_name': 'Labor...
#
#                                       counts_by_year  \
# 0  [{'cited_by_count': 3070, 'oa_works_count': 21...
#
#                                                roles  \
# 0  [{'id': 'https://openalex.org/F4320335124', 'r...
#
#                                               topics  \
# 0  [{'count': 100, 'display_name': 'Plant Pathoge...
#
#                                          topic_share  \
# 0  [{'display_name': 'Food Drying and Modeling', ...
#
#                                           x_concepts  is_super_system  \
# 0  [{'display_name': 'Biology', 'id': 'https://op...            False
#
#                                        works_api_url  \
# 0  https://api.openalex.org/works?filter=institut...
#
#                  updated_date created_date extract_datetime
# 0  2025-09-25T10:26:50.738232   2022-02-02       2025-09-28

# %% [markdown]
# # Nodo

# %%
def openalex_load_institution(df_institution_raw):

    expected_columns = [
        'id',
        'ror',
        'display_name',
        'country_code',
        'type',
        'type_id',
        'lineage',
        'homepage_url',
        'image_url',
        'image_thumbnail_url',
        'display_name_acronyms',
        'display_name_alternatives',
        'repositories',
        'works_count',
        'cited_by_count',
        'summary_stats',
        'ids',
        'geo',
        'international',
        'associated_institutions',
        'counts_by_year',
        'roles',
        'topics',
        'topic_share',
        'x_concepts',
        'is_super_system',
        'works_api_url',
        'updated_date',
        'created_date',
        'extract_datetime'
    ]
    df_institution = df_institution_raw.loc[:,expected_columns].reset_index(drop=True).copy()

    df_institution['load_datetime'] = pd.to_datetime(datetime.today())

    # Convertir tipos de datos automáticamente
    df_institution = df_institution.astype(str)

    return df_institution

# %% [markdown]
# ## Ejecuto Nodo

# %%
df_institution = openalex_load_institution(df_institution_raw)

# %% [markdown]
# # Resultados

# %%
df_institution
# Out:
# <pre style="white-space:pre;overflow-x:auto;line-height:normal;font-family:Menlo,'DejaVu Sans Mono',consolas,'Courier New',monospace"></pre>
#                                  id                        ror  \
# 0  https://openalex.org/I4210122970  https://ror.org/02s7sax82
#
#                               display_name country_code        type  \
# 0  Comisión de Investigaciones Científicas           AR  government
#
#                                              type_id  \
# 0  https://openalex.org/institution-types/government
#
#                  homepage_url image_url image_thumbnail_url  \
# 0  https://www.cic.gba.gob.ar      None                None
#
#   display_name_acronyms  works_count  cited_by_count  \
# 0                 [CIC]         3510           56910
#
#                                                roles  \
# 0  [{'id': 'https://openalex.org/F4320335124', 'r...
#
#                                               topics  \
# 0  [{'count': 100, 'display_name': 'Plant Pathoge...
#
#                                          topic_share  \
# 0  [{'display_name': 'Food Drying and Modeling', ...
#
#                                           x_concepts  is_super_system  \
# 0  [{'display_name': 'Biology', 'id': 'https://op...            False
#
#                                        works_api_url  \
# 0  https://api.openalex.org/works?filter=institut...
#
#                  updated_date created_date extract_datetime           grid  \
# 0  2025-09-25T10:26:50.738232   2022-02-02       2025-09-28  grid.452362.4
#
#                            openalex                        ror  \
# 0  https://openalex.org/I4210122970  https://ror.org/02s7sax82
#
#    summary_stats.2yr_mean_citedness  summary_stats.h_index  \
# 0                          1.469565                     90
#
#    summary_stats.i10_index  geo.city geo.country geo.country_code  \
# 0                     1319  La Plata   Argentina               AR
#
#   geo.geonames_city_id  geo.latitude  geo.longitude geo.region  \
# 0              3432043     -34.92126      -57.95442       None
#
#              international.display_name.en              load_datetime
# 0  Comisión de Investigaciones Científicas 2025-09-28 21:12:20.917536
