# %%
from datetime import date
import pandas as pd
pd.set_option('display.max_columns', None)

# %%
df_worktype = catalog.load('raw/openalex/worktype#parquet')
df_language = catalog.load('raw/openalex/language#parquet')
df_license = catalog.load('raw/openalex/license#parquet')
# Out:
#                     INFO     Loading data from raw/openalex/worktype#parquet                    ]8;id=729477;file:///home/pablo/dev/SEDICI/dw/.venv/lib/python3.10/site-packages/kedro/io/data_catalog.py\data_catalog.py]8;;\:]8;id=658603;file:///home/pablo/dev/SEDICI/dw/.venv/lib/python3.10/site-packages/kedro/io/data_catalog.py#482\482]8;;\
#                              (ParquetDataset)...
# [10/14/24 14:13:35] INFO     Loading data from raw/openalex/language#parquet                    ]8;id=909485;file:///home/pablo/dev/SEDICI/dw/.venv/lib/python3.10/site-packages/kedro/io/data_catalog.py\data_catalog.py]8;;\:]8;id=43010;file:///home/pablo/dev/SEDICI/dw/.venv/lib/python3.10/site-packages/kedro/io/data_catalog.py#482\482]8;;\
#                              (ParquetDataset)...
#                     INFO     Loading data from raw/openalex/license#parquet (ParquetDataset)... ]8;id=683043;file:///home/pablo/dev/SEDICI/dw/.venv/lib/python3.10/site-packages/kedro/io/data_catalog.py\data_catalog.py]8;;\:]8;id=982207;file:///home/pablo/dev/SEDICI/dw/.venv/lib/python3.10/site-packages/kedro/io/data_catalog.py#482\482]8;;\

# %%
def work_load_dimensions(df_worktype, df_language, df_license):
    df_worktype['load_datetime'] = date.today()
    df_language['load_datetime'] = date.today()
    df_license['load_datetime'] = date.today()

    df_worktype.rename(columns={'key':'worktype_id','key_display_name':'worktype_display_name'}, inplace=True)
    df_language.rename(columns={'key':'language_id','key_display_name':'language_display_name'}, inplace=True)
    df_license.rename(columns={'key':'license_id','key_display_name':'license_display_name'}, inplace=True)

    return df_worktype, df_language, df_license

# %%
df_worktype, df_language, df_license = work_load_dimensions(df_worktype, df_language, df_license)

# %%
df_worktype
# Out:
#                                           worktype_id  \
# 0                  https://openalex.org/types/article
# 1             https://openalex.org/types/book-chapter
# 2                  https://openalex.org/types/dataset
# 3                 https://openalex.org/types/preprint
# 4             https://openalex.org/types/dissertation
# 5                     https://openalex.org/types/book
# 6                   https://openalex.org/types/review
# 7                 https://openalex.org/types/paratext
# 8                https://openalex.org/types/libguides
# 9                   https://openalex.org/types/letter
# 10                   https://openalex.org/types/other
# 11         https://openalex.org/types/reference-entry
# 12                  https://openalex.org/types/report
# 13               https://openalex.org/types/editorial
# 14             https://openalex.org/types/peer-review
# 15                https://openalex.org/types/standard
# 16                 https://openalex.org/types/erratum
# 17                   https://openalex.org/types/grant
# 18  https://openalex.org/types/supplementary-mater...
# 19              https://openalex.org/types/retraction
#
#       worktype_display_name      count load_datetime
# 0                   article  196546329    2024-10-14
# 1              book-chapter   22195522    2024-10-14
# 2                   dataset    7552194    2024-10-14
# 3                  preprint    6334494    2024-10-14
# 4              dissertation    6074694    2024-10-14
# 5                      book    5610076    2024-10-14
# 6                    review    3838574    2024-10-14
# 7                  paratext    3298022    2024-10-14
# 8                 libguides    1808673    2024-10-14
# 9                    letter    1683692    2024-10-14
# 10                    other    1602210    2024-10-14
# 11          reference-entry     885068    2024-10-14
# 12                   report     811122    2024-10-14
# 13                editorial     748885    2024-10-14
# 14              peer-review     580838    2024-10-14
# 15                 standard     535694    2024-10-14
# 16                  erratum     388623    2024-10-14
