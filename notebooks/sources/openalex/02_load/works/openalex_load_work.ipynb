# %%
import pandas as pd
import json
from datetime import datetime
pd.set_option('display.max_columns', None)

# %%
df_work_raw = catalog.load('raw/openalex/work#parquet')
# Out:
#                     INFO     Loading data from raw/openalex/work#parquet (ParquetDataset)...    ]8;id=76217;file:///home/pablo/.local/lib/python3.10/site-packages/kedro/io/data_catalog.py\data_catalog.py]8;;\:]8;id=33963;file:///home/pablo/.local/lib/python3.10/site-packages/kedro/io/data_catalog.py#389\389]8;;\

# %% [markdown]
# # Profiling

# %%
df_work_raw.columns
# Out:
# <pre style="white-space:pre;overflow-x:auto;line-height:normal;font-family:Menlo,'DejaVu Sans Mono',consolas,'Courier New',monospace"></pre>
# Index(['id', 'doi', 'title', 'display_name', 'publication_year',
#        'publication_date', 'ids', 'language', 'primary_location', 'type',
#        'indexed_in', 'open_access', 'authorships', 'institutions',
#        'countries_distinct_count', 'institutions_distinct_count',
#        'corresponding_author_ids', 'corresponding_institution_ids', 'apc_list',
#        'apc_paid', 'fwci', 'has_fulltext', 'cited_by_count',
#        'citation_normalized_percentile', 'cited_by_percentile_year', 'biblio',
#        'is_retracted', 'is_paratext', 'is_xpac', 'primary_topic', 'topics',
#        'keywords', 'concepts', 'mesh', 'locations_count', 'locations',
#        'best_oa_location', 'sustainable_development_goals', 'grants', 'awards',
#        'funders', 'has_content', 'referenced_works_count', 'referenced_works',
#        'related_works', 'abstract_inverted_index', 'counts_by_year',
#        'updated_date', 'created_date', 'extract_datetime'],
#       dtype='object')

# %%
df_work_raw.head(3)
# Out:
# <pre style="white-space:pre;overflow-x:auto;line-height:normal;font-family:Menlo,'DejaVu Sans Mono',consolas,'Courier New',monospace"></pre>
#                                  id  \
# 0  https://openalex.org/W2089852843
# 1  https://openalex.org/W3037375387
# 2  https://openalex.org/W2032143374
#
#                                              doi  \
# 0  https://doi.org/10.1016/s0378-4371(98)00437-3
# 1   https://doi.org/10.1016/j.envint.2020.105876
# 2  https://doi.org/10.1016/s0023-6438(03)00088-4
#
#                                                title  \
# 0  The role of constraints within generalized non...
# 1  Short-term exposure to particulate matter (PM1...
# 2  Antimicrobial activity of essential oils on th...
#
#                                         display_name  publication_year  \
# 0  The role of constraints within generalized non...              1998
# 1  Short-term exposure to particulate matter (PM1...              2020
# 2  Antimicrobial activity of essential oils on th...              2003
#
#   publication_date                                                ids  \
# 0       1998-12-01  {'doi': 'https://doi.org/10.1016/s0378-4371(98...
# 1       2020-06-23  {'doi': 'https://doi.org/10.1016/j.envint.2020...
# 2       2003-11-01  {'doi': 'https://doi.org/10.1016/s0023-6438(03...
#
#   language                                   primary_location     type  \
# 0       en  {'id': 'doi:10.1016/s0378-4371(98)00437-3', 'i...  article
# 1       en  {'id': 'doi:10.1016/j.envint.2020.105876', 'is...   review
# 2       en  {'id': 'doi:10.1016/s0023-6438(03)00088-4', 'i...  article
#
#                  indexed_in  \
# 0                [crossref]
# 1  [crossref, doaj, pubmed]
# 2          [crossref, doaj]
#
#                                          open_access  \
# 0  {'any_repository_has_fulltext': False, 'is_oa'...
# 1  {'any_repository_has_fulltext': False, 'is_oa'...
# 2  {'any_repository_has_fulltext': False, 'is_oa'...
#
#                                          authorships institutions  \
# 0  [{'affiliations': [{'institution_ids': array([...           []
# 1  [{'affiliations': [{'institution_ids': array([...           []
# 2  [{'affiliations': [{'institution_ids': array([...           []
#
#    countries_distinct_count  institutions_distinct_count  \
# 0                         3                            3
# 1                         1                            5
# 2                         1                            4
#
#              corresponding_author_ids  \
# 0  [https://openalex.org/A5051451815]
# 1  [https://openalex.org/A5069680875]
# 2  [https://openalex.org/A5113848554]
#
#                        corresponding_institution_ids  \
# 0                 [https://openalex.org/I4210125245]
# 1  [https://openalex.org/I128590013, https://open...
# 2  [https://openalex.org/I4210122970, https://ope...
#
#                                             apc_list  \
# 0  {'currency': 'USD', 'value': 3320.0, 'value_us...
# 1  {'currency': 'USD', 'value': 3500.0, 'value_us...
# 2  {'currency': 'USD', 'value': 2250.0, 'value_us...
#
#                                             apc_paid       fwci  has_fulltext  \
# 0                                               None  34.310449         False
# 1  {'currency': 'USD', 'value': 3500.0, 'value_us...  40.813687          True
# 2                                               None   1.850633         False
#
#    cited_by_count                     citation_normalized_percentile  \
# 0            1376  {'is_in_top_10_percent': True, 'is_in_top_1_pe...
# 1             682  {'is_in_top_10_percent': True, 'is_in_top_1_pe...
# 2             477  {'is_in_top_10_percent': False, 'is_in_top_1_p...
#
#   cited_by_percentile_year                                             biblio  \
# 0  {'max': 100, 'min': 99}  {'first_page': '534', 'issue': '3-4', 'last_pa...
# 1  {'max': 100, 'min': 99}  {'first_page': '105876', 'issue': None, 'last_...
# 2  {'max': 100, 'min': 99}  {'first_page': '679', 'issue': '7', 'last_page...
#
#    is_retracted  is_paratext  is_xpac  \
# 0         False        False    False
# 1         False        False    False
# 2         False        False    False
#
#                                        primary_topic  \
# 0  {'display_name': 'Statistical Mechanics and En...
# 1  {'display_name': 'Air Quality and Health Impac...
# 2  {'display_name': 'Essential Oils and Antimicro...
#
#                                               topics  \
# 0  [{'display_name': 'Statistical Mechanics and E...
# 1  [{'display_name': 'Air Quality and Health Impa...
# 2  [{'display_name': 'Essential Oils and Antimicr...
#
#                                             keywords  \
# 0  [{'display_name': 'Harmonic oscillator', 'id':...
# 1  [{'display_name': 'Nitrogen dioxide', 'id': 'h...
# 2  [{'display_name': 'Antimicrobial', 'id': 'http...
#
#                                             concepts  \
# 0  [{'display_name': 'Harmonic oscillator', 'id':...
# 1  [{'display_name': 'Nitrogen dioxide', 'id': 'h...
# 2  [{'display_name': 'Antimicrobial', 'id': 'http...
#
#                                                 mesh  locations_count  \
# 0                                                 []                1
# 1  [{'descriptor_name': 'Air Pollutants', 'descri...                4
# 2                                                 []                1
#
#                                            locations  \
# 0  [{'id': 'doi:10.1016/s0378-4371(98)00437-3', '...
# 1  [{'id': 'doi:10.1016/j.envint.2020.105876', 'i...
# 2  [{'id': 'doi:10.1016/s0023-6438(03)00088-4', '...
#
#                                     best_oa_location  \
# 0                                               None
# 1  {'id': 'doi:10.1016/j.envint.2020.105876', 'is...
# 2                                               None
#
#                        sustainable_development_goals  \
# 0  [{'display_name': 'Affordable and clean energy...
# 1  [{'display_name': 'Good health and well-being'...
# 2                                                 []
#
#                                               grants awards  \
# 0                                                 []     []
# 1  [{'award_id': None, 'funder': 'https://openale...     []
# 2                                                 []     []
#
#                                              funders  \
# 0  [{'display_name': 'Conselho Nacional de Desenv...
# 1  [{'display_name': 'World Health Organization',...
# 2                                                 []
#
#                            has_content  referenced_works_count  \
# 0  {'grobid_xml': False, 'pdf': False}                      75
# 1    {'grobid_xml': True, 'pdf': True}                      90
# 2  {'grobid_xml': False, 'pdf': False}                      41
#
#                                     referenced_works  \
# 0  [https://openalex.org/W1976332187, https://ope...
# 1  [https://openalex.org/W2762816612, https://ope...
# 2  [https://openalex.org/W2000715013, https://ope...
#
#                                        related_works  \
# 0  [https://openalex.org/W2510367851, https://ope...
# 1  [https://openalex.org/W2912161332, https://ope...
# 2  [https://openalex.org/W2553161426, https://ope...
#
#                              abstract_inverted_index  \
# 0                                               None
# 1  {'"Este': None, '"best': None, '"futuro': None...
# 2                                               None
#
#                                       counts_by_year  \
# 0  [{'cited_by_count': 41, 'year': 2025}, {'cited...
# 1  [{'cited_by_count': 125, 'year': 2025}, {'cite...
# 2  [{'cited_by_count': 34, 'year': 2025}, {'cited...
#
#                  updated_date         created_date extract_datetime
# 0  2025-11-06T03:46:38.306776  2025-10-10T00:00:00       2025-11-23
# 1  2025-11-06T03:46:38.306776  2020-07-02T00:00:00       2025-11-23
# 2  2025-11-06T03:46:38.306776  2025-10-10T00:00:00       2025-11-23

# %%
df_work_raw.dtypes
# Out:
# <pre style="white-space:pre;overflow-x:auto;line-height:normal;font-family:Menlo,'DejaVu Sans Mono',consolas,'Courier New',monospace"></pre>
# id                                 object
# doi                                object
# title                              object
# display_name                       object
# publication_year                    int64
# publication_date                   object
# ids                                object
# language                           object
# primary_location                   object
# type                               object
# indexed_in                         object
# open_access                        object
# authorships                        object
# institutions                       object
# countries_distinct_count            int64
# institutions_distinct_count         int64
# corresponding_author_ids           object
# corresponding_institution_ids      object
# apc_list                           object
# apc_paid                           object
# fwci                              float64
# has_fulltext                         bool
# cited_by_count                      int64
# citation_normalized_percentile     object
# cited_by_percentile_year           object
# biblio                             object
# is_retracted                         bool
# is_paratext                          bool
# is_xpac                              bool
# primary_topic                      object
# topics                             object
# keywords                           object
# concepts                           object
# mesh                               object
# locations_count                     int64
# locations                          object
# best_oa_location                   object
# sustainable_development_goals      object
# grants                             object
# awards                             object
# funders                            object
# has_content                        object
# referenced_works_count              int64
# referenced_works                   object
# related_works                      object
# abstract_inverted_index            object
# counts_by_year                     object
# updated_date                       object
# created_date                       object
# extract_datetime                   object
# dtype: object

# %% [markdown]
# # Nodo

# %%
def openalex_load_work(df_work_raw):
    """Limpia y transforma los datos de OpenAlex para su almacenamiento en una base de datos relacional."""
    
    expected_columns = [
        'id',
        # 'doi', # doi existe en ids
        'title',
        'display_name',
        'publication_year',
        'publication_date',
        'ids',
        'language',
        'primary_location',
        'type',
        'type_crossref',
        # 'indexed_in',
        'open_access',
        # 'authorships',
        # 'institution_assertions',
        'countries_distinct_count',
        'institutions_distinct_count',
        # 'corresponding_author_ids',
        # 'corresponding_institution_ids',
        'apc_list',
        'apc_paid',
        'fwci',
        'has_fulltext',
        'fulltext_origin',
        'cited_by_count',
        'citation_normalized_percentile',
        'cited_by_percentile_year',
        'biblio',
        'is_retracted',
        'is_paratext',
        'primary_topic',
        # 'topics',
        # 'keywords',
        # 'concepts',
        # 'mesh',
        'locations_count',
        # 'locations',
        'best_oa_location',
        # 'sustainable_development_goals',
        # 'grants',
        # 'datasets',
        # 'versions',
        'referenced_works_count',
        # 'referenced_works',
        # 'related_works',
        # 'abstract_inverted_index',
        # 'abstract_inverted_index_v3',
        'cited_by_api_url',
        # 'counts_by_year',
        'updated_date',
        'created_date',
        'extract_datetime'
    ]

    df_work = df_work_raw.reindex(columns=expected_columns).reset_index(drop=True).copy()

    # Agregar columnas faltantes con NaN
    for col in expected_columns:
        if col not in df_work.columns:
            df_work[col] = pd.NA

    # ids
    df_ids = pd.json_normalize(df_work['ids']).reset_index(drop=True)
    df_work = pd.concat([df_work, df_ids], axis=1)
    df_work.drop(columns=['ids'], inplace=True)    

    # primary_location
    df_primary_location = pd.json_normalize(df_work['primary_location']).reset_index(drop=True)
    df_primary_location.rename(columns=lambda col: f'primary_location.{col}', inplace=True)
    df_primary_location.drop(columns=[
        'primary_location.source.issn',
        'primary_location.source.host_organization_lineage',
        'primary_location.source.host_organization_lineage_names'
        ],
        inplace=True)

    df_work = pd.concat([df_work, df_primary_location], axis=1)
    df_work.drop(columns=['primary_location'], inplace=True)    

    # openacess
    df_openaccess_expanded = pd.json_normalize(df_work['open_access'])
    df_work = pd.concat([df_work, df_openaccess_expanded], axis=1)
    df_work.drop(columns=['open_access'], inplace=True)    

    # apc_list
    df_apc_list = pd.json_normalize(df_work['apc_list'])
    df_apc_list.rename(columns=lambda col: f'apc_list.{col}', inplace=True)
    df_work = pd.concat([df_work, df_apc_list], axis=1)
    df_work.drop(columns=['apc_list'], inplace=True)    
 
    # apc_paid
    df_apc_paid = pd.json_normalize(df_work['apc_paid'])
    df_apc_paid.rename(columns=lambda col: f'apc_paid.{col}', inplace=True)
    df_work = pd.concat([df_work, df_apc_paid], axis=1)
    df_work.drop(columns=['apc_paid'], inplace=True)    
 
    # citation_normalized_percentile
    df_citation_normalized_percentile = pd.json_normalize(df_work['citation_normalized_percentile'])
    df_citation_normalized_percentile.rename(columns=lambda col: f'citation_normalized_percentile.{col}', inplace=True)
    df_work = pd.concat([df_work, df_citation_normalized_percentile], axis=1)
    df_work.drop(columns=['citation_normalized_percentile'], inplace=True)    

    # cited_by_percentile_year
    df_cited_by_percentile_year = pd.json_normalize(df_work['cited_by_percentile_year'])
    df_cited_by_percentile_year.rename(columns=lambda col: f'cited_by_percentile_year.{col}', inplace=True)
    df_work = pd.concat([df_work, df_cited_by_percentile_year], axis=1)
    df_work.drop(columns=['cited_by_percentile_year'], inplace=True)    

    # biblio
    df_biblio = pd.json_normalize(df_work['biblio'])
    df_biblio.rename(columns=lambda col: f'biblio.{col}', inplace=True)
    df_work = pd.concat([df_work, df_biblio], axis=1)
    df_work.drop(columns=['biblio'], inplace=True)

    # primary_topic
    df_primary_topic = pd.json_normalize(df_work['primary_topic'])
    df_primary_topic.rename(columns=lambda col: f'primary_topic.{col}', inplace=True)
    df_work = pd.concat([df_work, df_primary_topic], axis=1)
    df_work.drop(columns=['primary_topic'], inplace=True)    

    # best_oa_location
    df_best_oa_location = pd.json_normalize(df_work['best_oa_location'])
    df_best_oa_location.rename(columns=lambda col: f'best_oa_location.{col}', inplace=True)
    df_best_oa_location.drop(columns=[
        'best_oa_location.source.host_organization_lineage',
        'best_oa_location.source.host_organization_lineage_names',
        'best_oa_location.source.issn',
    ], inplace=True)
    
    df_work = pd.concat([df_work, df_best_oa_location], axis=1)
    df_work.drop(columns=['best_oa_location'], inplace=True)    

    # Agregar la fecha de carga con formato datetime
    df_work['load_datetime'] = pd.to_datetime(datetime.today())

    # Convertir tipos de datos automáticamente
    df_work = df_work.convert_dtypes()

    return df_work

# %% [markdown]
# ## Ejecuto Nodo

# %%
df_work = openalex_load_work(df_work_raw)

# %% [markdown]
# # Resultados

# %%
df_work
# Out:
# <pre style="white-space:pre;overflow-x:auto;line-height:normal;font-family:Menlo,'DejaVu Sans Mono',consolas,'Courier New',monospace"></pre>
#                                    id  \
# 0    https://openalex.org/W2089852843
# 1    https://openalex.org/W3037375387
# 2    https://openalex.org/W2032143374
# 3    https://openalex.org/W2021071494
# 4    https://openalex.org/W2154507013
# ..                                ...
# 195  https://openalex.org/W2072634766
# 196  https://openalex.org/W2592868344
# 197  https://openalex.org/W2892467442
# 198  https://openalex.org/W2015061845
# 199  https://openalex.org/W2052279806
#
#                                                  title  \
# 0    The role of constraints within generalized non...
# 1    Short-term exposure to particulate matter (PM1...
# 2    Antimicrobial activity of essential oils on th...
# 3    Evaluating Bayesian networks’ precision for de...
# 4    Formation of a Nematic Fluid at High Fields in...
# ..                                                 ...
# 195  Deterioro ambiental y micromamíferos durante e...
# 196  Improvement of copper stress tolerance in pepp...
# 197  Ghrelin Recruits Specific Subsets of Dopamine ...
# 198  Effect of the bread making process on wheat fl...
# 199  Measurement of the Young's modulus in particul...
#
#                                           display_name  publication_year  \
# 0    The role of constraints within generalized non...              1998
# 1    Short-term exposure to particulate matter (PM1...              2020
# 2    Antimicrobial activity of essential oils on th...              2003
# 3    Evaluating Bayesian networks’ precision for de...              2005
# 4    Formation of a Nematic Fluid at High Fields in...              2006
# ..                                                 ...               ...
# 195  Deterioro ambiental y micromamíferos durante e...              2000
# 196  Improvement of copper stress tolerance in pepp...              2017
# 197  Ghrelin Recruits Specific Subsets of Dopamine ...              2018
# 198  Effect of the bread making process on wheat fl...              2009
# 199  Measurement of the Young's modulus in particul...              2010
#
#     publication_date language     type  type_crossref  \
# 0         1998-12-01       en  article           <NA>
# 1         2020-06-23       en   review           <NA>
# 2         2003-11-01       en  article           <NA>
# 3         2005-12-28       en  article           <NA>
# 4         2006-11-24       en  article           <NA>
# ..               ...      ...      ...            ...
# 195       2000-03-01       es  article           <NA>
# 196       2017-02-27       en  article           <NA>
# 197       2018-09-27       en  article           <NA>
# 198       2009-07-31       en  article           <NA>
# 199       2010-05-05       en  article           <NA>
#
#      countries_distinct_count  institutions_distinct_count       fwci  \
# 0                           3                            3  34.310449
# 1                           1                            5  40.813687
# 2                           1                            4   1.850633
# 3                           1                            4  11.055551
# 4                           3                            9  18.490612
# ..                        ...                          ...        ...
# 195                         1                            4   2.036333
# 196                         1                            3   4.910198
# 197                         1                            6   4.059389
# 198                         1                            5   3.434737
# 199                         1                            4   1.288003
#
#      has_fulltext  fulltext_origin  cited_by_count  is_retracted  is_paratext  \
# 0           False             <NA>            1376         False        False
# 1            True             <NA>             682         False        False
# 2           False             <NA>             477         False        False
# 3           False             <NA>             430         False        False
# 4           False             <NA>             429         False        False
# ..            ...              ...             ...           ...          ...
# 195         False             <NA>              58         False        False
# 196          True             <NA>              58         False        False
# 197          True             <NA>              58         False        False
# 198         False             <NA>              57         False        False
# 199         False             <NA>              57         False        False
#
#      locations_count  referenced_works_count  cited_by_api_url  \
# 0                  1                      75              <NA>
# 1                  4                      90              <NA>
# 2                  1                      41              <NA>
# 3                  1                      31              <NA>
# 4                  5                      34              <NA>
# ..               ...                     ...               ...
# 195                1                      13              <NA>
# 196                2                      62              <NA>
# 197                2                      70              <NA>
# 198                1                      22              <NA>
# 199                1                      18              <NA>
#
#                    updated_date         created_date extract_datetime  \
# 0    2025-11-06T03:46:38.306776  2025-10-10T00:00:00       2025-11-23
# 1    2025-11-06T03:46:38.306776  2020-07-02T00:00:00       2025-11-23
# 2    2025-11-06T03:46:38.306776  2025-10-10T00:00:00       2025-11-23
# 3    2025-11-06T03:46:38.306776  2025-10-10T00:00:00       2025-11-23
# 4    2025-11-06T03:46:38.306776  2016-06-24T00:00:00       2025-11-23
# ..                          ...                  ...              ...
# 195  2025-11-06T03:46:38.306776  2025-10-10T00:00:00       2025-11-23
# 196  2025-11-06T03:46:38.306776  2025-10-10T00:00:00       2025-11-23
# 197  2025-11-06T03:46:38.306776  2025-10-10T00:00:00       2025-11-23
# 198  2025-11-06T03:46:38.306776  2025-10-10T00:00:00       2025-11-23
# 199  2025-11-06T03:46:38.306776  2025-10-10T00:00:00       2025-11-23
#
#                                                    doi         mag  \
# 0        https://doi.org/10.1016/s0378-4371(98)00437-3  2089852843
# 1         https://doi.org/10.1016/j.envint.2020.105876  3037375387
# 2        https://doi.org/10.1016/s0023-6438(03)00088-4  2032143374
# 3        https://doi.org/10.1016/j.compedu.2005.11.017  2021071494
# 4              https://doi.org/10.1126/science.1134796  2154507013
# ..                                                 ...         ...
# 195    https://doi.org/10.4067/s0716-078x2000000100002  2072634766
# 196          https://doi.org/10.1007/s40626-016-0081-7  2592868344
# 197  https://doi.org/10.1016/j.neuroscience.2018.09...  2892467442
# 198     https://doi.org/10.1016/j.foodcont.2009.07.012  2015061845
# 199         https://doi.org/10.1016/j.msea.2010.04.083  2052279806
#
#                              openalex  \
# 0    https://openalex.org/W2089852843
# 1    https://openalex.org/W3037375387
# 2    https://openalex.org/W2032143374
# 3    https://openalex.org/W2021071494
# 4    https://openalex.org/W2154507013
# ..                                ...
# 195  https://openalex.org/W2072634766
# 196  https://openalex.org/W2592868344
# 197  https://openalex.org/W2892467442
# 198  https://openalex.org/W2015061845
# 199  https://openalex.org/W2052279806
#
#                                          pmid  \
# 0                                        <NA>
# 1    https://pubmed.ncbi.nlm.nih.gov/32590284
# 2                                        <NA>
# 3                                        <NA>
# 4    https://pubmed.ncbi.nlm.nih.gov/17124288
# ..                                        ...
# 195                                      <NA>
# 196                                      <NA>
# 197  https://pubmed.ncbi.nlm.nih.gov/30268780
# 198                                      <NA>
# 199                                      <NA>
#
#                         primary_location.id  primary_location.is_accepted  \
# 0         doi:10.1016/s0378-4371(98)00437-3                          True
# 1          doi:10.1016/j.envint.2020.105876                          True
# 2         doi:10.1016/s0023-6438(03)00088-4                          True
# 3         doi:10.1016/j.compedu.2005.11.017                          True
# 4               doi:10.1126/science.1134796                          True
# ..                                      ...                           ...
# 195     doi:10.4067/s0716-078x2000000100002                          True
# 196           doi:10.1007/s40626-016-0081-7                          True
# 197  doi:10.1016/j.neuroscience.2018.09.027                          True
# 198      doi:10.1016/j.foodcont.2009.07.012                          True
# 199          doi:10.1016/j.msea.2010.04.083                          True
#
#      primary_location.is_oa  primary_location.is_published  \
# 0                     False                           True
# 1                      True                           True
# 2                     False                           True
# 3                     False                           True
# 4                     False                           True
# ..                      ...                            ...
# 195                    True                           True
# 196                    True                           True
# 197                    True                           True
# 198                   False                           True
# 199                   False                           True
#
#                      primary_location.landing_page_url  \
# 0        https://doi.org/10.1016/s0378-4371(98)00437-3
# 1         https://doi.org/10.1016/j.envint.2020.105876
# 2        https://doi.org/10.1016/s0023-6438(03)00088-4
# 3        https://doi.org/10.1016/j.compedu.2005.11.017
# 4              https://doi.org/10.1126/science.1134796
# ..                                                 ...
# 195    https://doi.org/10.4067/s0716-078x2000000100002
# 196          https://doi.org/10.1007/s40626-016-0081-7
# 197  https://doi.org/10.1016/j.neuroscience.2018.09...
# 198     https://doi.org/10.1016/j.foodcont.2009.07.012
# 199         https://doi.org/10.1016/j.msea.2010.04.083
#
#     primary_location.license                primary_location.license_id  \
# 0                       <NA>                                       <NA>
# 1                cc-by-nc-nd  https://openalex.org/licenses/cc-by-nc-nd
# 2                       <NA>                                       <NA>
# 3                       <NA>                                       <NA>
# 4                       <NA>                                       <NA>
# ..                       ...                                        ...
# 195                    cc-by        https://openalex.org/licenses/cc-by
# 196                     <NA>                                       <NA>
# 197                     <NA>                                       <NA>
# 198                     <NA>                                       <NA>
# 199                     <NA>                                       <NA>
#
#                               primary_location.pdf_url  \
# 0                                                 <NA>
# 1    https://ars.els-cdn.com/content/image/1-s2.0-S...
# 2                                                 <NA>
# 3                                                 <NA>
# 4                                                 <NA>
# ..                                                 ...
# 195    http://www.scielo.cl/pdf/rchnat/v73n1/art02.pdf
# 196  https://link.springer.com/content/pdf/10.1007/...
# 197  https://www.sciencedirect.com/science/article/...
# 198                                               <NA>
# 199                                               <NA>
#
#                       primary_location.raw_source_name  \
# 0    Physica A: Statistical Mechanics and its Appli...
# 1                            Environment International
# 2                    LWT - Food Science and Technology
# 3                            Computers &amp; Education
# 4                                              Science
# ..                                                 ...
# 195                Revista chilena de historia natural
# 196      Theoretical and Experimental Plant Physiology
# 197                                       Neuroscience
# 198                                       Food Control
# 199               Materials Science and Engineering: A
#
#     primary_location.raw_type primary_location.version  \
# 0             journal-article         publishedVersion
# 1             journal-article         publishedVersion
# 2             journal-article         publishedVersion
# 3             journal-article         publishedVersion
# 4             journal-article         publishedVersion
# ..                        ...                      ...
# 195           journal-article         publishedVersion
# 196           journal-article         publishedVersion
# 197           journal-article         publishedVersion
# 198           journal-article         publishedVersion
# 199           journal-article         publishedVersion
#
#                   primary_location.source.display_name  \
# 0    Physica A Statistical Mechanics and its Applic...
# 1                            Environment International
# 2                                                  LWT
# 3                                Computers & Education
# 4                                              Science
# ..                                                 ...
# 195                Revista chilena de historia natural
# 196      Theoretical and Experimental Plant Physiology
# 197                                       Neuroscience
# 198                                       Food Control
# 199                Materials Science and Engineering A
#
#     primary_location.source.host_organization  \
# 0            https://openalex.org/P4310320990
# 1            https://openalex.org/P4310320990
# 2            https://openalex.org/P4310320990
# 3            https://openalex.org/P4310320990
# 4            https://openalex.org/P4310315823
# ..                                        ...
# 195          https://openalex.org/P4310320256
# 196          https://openalex.org/P4310319900
# 197          https://openalex.org/P4310320990
# 198          https://openalex.org/P4310320990
# 199          https://openalex.org/P4310320990
#
#         primary_location.source.host_organization_name  \
# 0                                          Elsevier BV
# 1                                          Elsevier BV
# 2                                          Elsevier BV
# 3                                          Elsevier BV
# 4    American Association for the Advancement of Sc...
# ..                                                 ...
# 195                                     BioMed Central
# 196                    Springer Science+Business Media
# 197                                        Elsevier BV
# 198                                        Elsevier BV
# 199                                        Elsevier BV
#
#            primary_location.source.id  primary_location.source.is_core  \
# 0      https://openalex.org/S24688465                             True
# 1     https://openalex.org/S143381477                             True
# 2      https://openalex.org/S26760650                             True
# 3    https://openalex.org/S4210172634                             True
# 4       https://openalex.org/S3880285                             True
# ..                                ...                              ...
# 195    https://openalex.org/S48572832                             True
# 196  https://openalex.org/S2764357854                             True
# 197    https://openalex.org/S30122339                             True
# 198   https://openalex.org/S119525064                             True
# 199   https://openalex.org/S154732359                             True
#
#      primary_location.source.is_in_doaj  primary_location.source.is_oa  \
# 0                                 False                          False
# 1                                  True                           True
# 2                                  True                          False
# 3                                 False                          False
# 4                                 False                          False
# ..                                  ...                            ...
# 195                                True                           True
# 196                               False                          False
# 197                               False                          False
# 198                               False                          False
# 199                               False                          False
#
#     primary_location.source.issn_l primary_location.source.type  \
# 0                        0378-4371                      journal
# 1                        0160-4120                      journal
# 2                        0023-6438                      journal
# 3                        0360-1315                      journal
# 4                        0036-8075                      journal
# ..                             ...                          ...
# 195                      0716-078X                      journal
# 196                      2197-0025                      journal
# 197                      0306-4522                      journal
# 198                      0956-7135                      journal
# 199                      0921-5093                      journal
#
#      any_repository_has_fulltext  is_oa oa_status  \
# 0                          False  False    closed
# 1                          False   True      gold
# 2                          False  False    closed
# 3                          False  False    closed
# 4                          False   True     green
# ..                           ...    ...       ...
# 195                        False   True      gold
# 196                        False   True    bronze
# 197                        False   True    bronze
# 198                        False  False    closed
# 199                        False  False    closed
#
#                                                 oa_url apc_list.currency  \
# 0                                                 <NA>               USD
# 1    https://ars.els-cdn.com/content/image/1-s2.0-S...               USD
# 2                                                 <NA>               USD
# 3                                                 <NA>               USD
# 4               https://arxiv.org/pdf/cond-mat/0612599              <NA>
# ..                                                 ...               ...
# 195    http://www.scielo.cl/pdf/rchnat/v73n1/art02.pdf               GBP
# 196  https://link.springer.com/content/pdf/10.1007/...               EUR
# 197  https://www.sciencedirect.com/science/article/...               USD
# 198                                               <NA>               USD
# 199                                               <NA>               USD
#
#      apc_list.value  apc_list.value_usd apc_paid.currency  apc_paid.value  \
# 0              3320                3320              <NA>            <NA>
# 1              3500                3500               USD            3500
# 2              2250                2250              <NA>            <NA>
# 3              4220                4220              <NA>            <NA>
# 4              <NA>                <NA>              <NA>            <NA>
# ..              ...                 ...               ...             ...
# 195            1570                1925               GBP            1570
# 196            2790                3590              <NA>            <NA>
# 197            3000                3000              <NA>            <NA>
# 198            4430                4430              <NA>            <NA>
# 199            3500                3500              <NA>            <NA>
#
#      apc_paid.value_usd  citation_normalized_percentile.is_in_top_10_percent  \
# 0                  <NA>                                               True
# 1                  3500                                               True
# 2                  <NA>                                              False
# 3                  <NA>                                               True
# 4                  <NA>                                               True
# ..                  ...                                                ...
# 195                1925                                              False
# 196                <NA>                                               True
# 197                <NA>                                               True
# 198                <NA>                                               True
# 199                <NA>                                              False
#
#      citation_normalized_percentile.is_in_top_1_percent  \
# 0                                                 True
# 1                                                 True
# 2                                                False
# 3                                                False
# 4                                                 True
# ..                                                 ...
# 195                                              False
# 196                                              False
# 197                                              False
# 198                                              False
# 199                                              False
#
#      citation_normalized_percentile.value  cited_by_percentile_year.max  \
# 0                                0.999009                           100
# 1                                0.998797                           100
# 2                                0.841969                           100
# 3                                0.986616                           100
# 4                                 0.99838                           100
# ..                                    ...                           ...
# 195                              0.906363                            99
# 196                              0.971758                            99
# 197                              0.922622                            99
# 198                              0.923829                            99
# 199                              0.808859                            99
#
#      cited_by_percentile_year.min biblio.first_page biblio.issue  \
# 0                              99               534          3-4
# 1                              99            105876         <NA>
# 2                              99               679            7
# 3                              98               794            3
# 4                              99               214         5809
# ..                            ...               ...          ...
# 195                            89              <NA>            1
# 196                            96                37            1
# 197                            90               107         <NA>
# 198                            89               492            4
# 199                            89              4619        18-19
#
#     biblio.last_page biblio.volume                 primary_topic.display_name  \
# 0                554           261          Statistical Mechanics and Entropy
# 1             105876           142             Air Quality and Health Impacts
# 2                684            36  Essential Oils and Antimicrobial Activity
# 3                808            49  Learning Styles and Cognitive Differences
# 4                217           315          Advanced Condensed Matter Physics
# ..               ...           ...                                        ...
# 195             <NA>            73         Evolution and Paleontology Studies
# 196               49            29   Mycorrhizal Fungi and Plant Interactions
# 197              120           392         Regulation of Appetite and Obesity
# 198              495            21         Mycotoxins in Agriculture and Food
# 199             4623           527          Mechanical Behavior of Composites
#
#                 primary_topic.id  primary_topic.score  \
# 0    https://openalex.org/T12261               0.9998
# 1    https://openalex.org/T10190                  1.0
# 2    https://openalex.org/T10225               0.9999
# 3    https://openalex.org/T11820               0.9988
# 4    https://openalex.org/T11682                  1.0
# ..                           ...                  ...
# 195  https://openalex.org/T11354               0.9945
# 196  https://openalex.org/T10451               0.9994
# 197  https://openalex.org/T10489               0.9999
# 198  https://openalex.org/T10520                  1.0
# 199  https://openalex.org/T10219               0.9994
#
#     primary_topic.domain.display_name         primary_topic.domain.id  \
# 0                   Physical Sciences  https://openalex.org/domains/3
# 1                   Physical Sciences  https://openalex.org/domains/3
# 2                       Life Sciences  https://openalex.org/domains/1
# 3                     Social Sciences  https://openalex.org/domains/2
# 4                   Physical Sciences  https://openalex.org/domains/3
# ..                                ...                             ...
# 195                 Physical Sciences  https://openalex.org/domains/3
# 196                     Life Sciences  https://openalex.org/domains/1
# 197                     Life Sciences  https://openalex.org/domains/1
# 198                     Life Sciences  https://openalex.org/domains/1
# 199                 Physical Sciences  https://openalex.org/domains/3
#
#          primary_topic.field.display_name          primary_topic.field.id  \
# 0                   Physics and Astronomy  https://openalex.org/fields/31
# 1                   Environmental Science  https://openalex.org/fields/23
# 2    Agricultural and Biological Sciences  https://openalex.org/fields/11
# 3                              Psychology  https://openalex.org/fields/32
# 4                   Physics and Astronomy  https://openalex.org/fields/31
# ..                                    ...                             ...
# 195          Earth and Planetary Sciences  https://openalex.org/fields/19
# 196  Agricultural and Biological Sciences  https://openalex.org/fields/11
# 197                          Neuroscience  https://openalex.org/fields/28
# 198  Agricultural and Biological Sciences  https://openalex.org/fields/11
# 199                           Engineering  https://openalex.org/fields/22
#
#           primary_topic.subfield.display_name  \
# 0           Statistical and Nonlinear Physics
# 1          Health, Toxicology and Mutagenesis
# 2                                Food Science
# 3    Developmental and Educational Psychology
# 4                    Condensed Matter Physics
# ..                                        ...
# 195                              Paleontology
# 196                             Plant Science
# 197           Endocrine and Autonomic Systems
# 198                             Plant Science
# 199                    Mechanics of Materials
#
#                primary_topic.subfield.id  \
# 0    https://openalex.org/subfields/3109
# 1    https://openalex.org/subfields/2307
# 2    https://openalex.org/subfields/1106
# 3    https://openalex.org/subfields/3204
# 4    https://openalex.org/subfields/3104
# ..                                   ...
# 195  https://openalex.org/subfields/1911
# 196  https://openalex.org/subfields/1110
# 197  https://openalex.org/subfields/2807
# 198  https://openalex.org/subfields/1110
# 199  https://openalex.org/subfields/2211
#
#                         best_oa_location.id  best_oa_location.is_accepted  \
# 0                                      <NA>                          <NA>
# 1          doi:10.1016/j.envint.2020.105876                          True
# 2                                      <NA>                          <NA>
# 3                                      <NA>                          <NA>
# 4        pmh:oai:arXiv.org:cond-mat/0612599                         False
# ..                                      ...                           ...
# 195     doi:10.4067/s0716-078x2000000100002                          True
# 196           doi:10.1007/s40626-016-0081-7                          True
# 197  doi:10.1016/j.neuroscience.2018.09.027                          True
# 198                                    <NA>                          <NA>
# 199                                    <NA>                          <NA>
#
#      best_oa_location.is_oa  best_oa_location.is_published  \
# 0                      <NA>                           <NA>
# 1                      True                           True
# 2                      <NA>                           <NA>
# 3                      <NA>                           <NA>
# 4                      True                          False
# ..                      ...                            ...
# 195                    True                           True
# 196                    True                           True
# 197                    True                           True
# 198                    <NA>                           <NA>
# 199                    <NA>                           <NA>
#
#                      best_oa_location.landing_page_url  \
# 0                                                 <NA>
# 1         https://doi.org/10.1016/j.envint.2020.105876
# 2                                                 <NA>
# 3                                                 <NA>
# 4                http://arxiv.org/abs/cond-mat/0612599
# ..                                                 ...
# 195    https://doi.org/10.4067/s0716-078x2000000100002
# 196          https://doi.org/10.1007/s40626-016-0081-7
# 197  https://doi.org/10.1016/j.neuroscience.2018.09...
# 198                                               <NA>
# 199                                               <NA>
#
#     best_oa_location.license                best_oa_location.license_id  \
# 0                       <NA>                                       <NA>
# 1                cc-by-nc-nd  https://openalex.org/licenses/cc-by-nc-nd
# 2                       <NA>                                       <NA>
# 3                       <NA>                                       <NA>
# 4                       <NA>                                       <NA>
# ..                       ...                                        ...
# 195                    cc-by        https://openalex.org/licenses/cc-by
# 196                     <NA>                                       <NA>
# 197                     <NA>                                       <NA>
# 198                     <NA>                                       <NA>
# 199                     <NA>                                       <NA>
#
#                               best_oa_location.pdf_url  \
# 0                                                 <NA>
# 1    https://ars.els-cdn.com/content/image/1-s2.0-S...
# 2                                                 <NA>
# 3                                                 <NA>
# 4               https://arxiv.org/pdf/cond-mat/0612599
# ..                                                 ...
# 195    http://www.scielo.cl/pdf/rchnat/v73n1/art02.pdf
# 196  https://link.springer.com/content/pdf/10.1007/...
# 197  https://www.sciencedirect.com/science/article/...
# 198                                               <NA>
# 199                                               <NA>
#
#                   best_oa_location.raw_source_name best_oa_location.raw_type  \
# 0                                             <NA>                      <NA>
# 1                        Environment International           journal-article
# 2                                             <NA>                      <NA>
# 3                                             <NA>                      <NA>
# 4                                             <NA>                      text
# ..                                             ...                       ...
# 195            Revista chilena de historia natural           journal-article
# 196  Theoretical and Experimental Plant Physiology           journal-article
# 197                                   Neuroscience           journal-article
# 198                                           <NA>                      <NA>
# 199                                           <NA>                      <NA>
#
#     best_oa_location.version           best_oa_location.source.display_name  \
# 0                       <NA>                                           <NA>
# 1           publishedVersion                      Environment International
# 2                       <NA>                                           <NA>
# 3                       <NA>                                           <NA>
# 4           submittedVersion                     arXiv (Cornell University)
# ..                       ...                                            ...
# 195         publishedVersion            Revista chilena de historia natural
# 196         publishedVersion  Theoretical and Experimental Plant Physiology
# 197         publishedVersion                                   Neuroscience
# 198                     <NA>                                           <NA>
# 199                     <NA>                                           <NA>
#
#     best_oa_location.source.host_organization  \
# 0                                        <NA>
# 1            https://openalex.org/P4310320990
# 2                                        <NA>
# 3                                        <NA>
# 4             https://openalex.org/I205783295
# ..                                        ...
# 195          https://openalex.org/P4310320256
# 196          https://openalex.org/P4310319900
# 197          https://openalex.org/P4310320990
# 198                                      <NA>
# 199                                      <NA>
#
#     best_oa_location.source.host_organization_name  \
# 0                                             <NA>
# 1                                      Elsevier BV
# 2                                             <NA>
# 3                                             <NA>
# 4                               Cornell University
# ..                                             ...
# 195                                 BioMed Central
# 196                Springer Science+Business Media
# 197                                    Elsevier BV
# 198                                           <NA>
# 199                                           <NA>
#
#            best_oa_location.source.id  best_oa_location.source.is_core  \
# 0                                <NA>                             <NA>
# 1     https://openalex.org/S143381477                             True
# 2                                <NA>                             <NA>
# 3                                <NA>                             <NA>
# 4    https://openalex.org/S4306400194                            False
# ..                                ...                              ...
# 195    https://openalex.org/S48572832                             True
# 196  https://openalex.org/S2764357854                             True
# 197    https://openalex.org/S30122339                             True
# 198                              <NA>                             <NA>
# 199                              <NA>                             <NA>
#
#      best_oa_location.source.is_in_doaj  best_oa_location.source.is_oa  \
# 0                                  <NA>                           <NA>
# 1                                  True                           True
# 2                                  <NA>                           <NA>
# 3                                  <NA>                           <NA>
# 4                                 False                           True
# ..                                  ...                            ...
# 195                                True                           True
# 196                               False                          False
# 197                               False                          False
# 198                                <NA>                           <NA>
# 199                                <NA>                           <NA>
#
#     best_oa_location.source.issn_l best_oa_location.source.type  \
# 0                             <NA>                         <NA>
# 1                        0160-4120                      journal
# 2                             <NA>                         <NA>
# 3                             <NA>                         <NA>
# 4                             <NA>                   repository
# ..                             ...                          ...
# 195                      0716-078X                      journal
# 196                      2197-0025                      journal
# 197                      0306-4522                      journal
# 198                           <NA>                         <NA>
# 199                           <NA>                         <NA>
#
#                  load_datetime
# 0   2025-11-23 19:47:49.622368
# 1   2025-11-23 19:47:49.622368
# 2   2025-11-23 19:47:49.622368
# 3   2025-11-23 19:47:49.622368
# 4   2025-11-23 19:47:49.622368
# ..                         ...
# 195 2025-11-23 19:47:49.622368
# 196 2025-11-23 19:47:49.622368
# 197 2025-11-23 19:47:49.622368
# 198 2025-11-23 19:47:49.622368
# 199 2025-11-23 19:47:49.622368
#
# [200 rows x 95 columns]
