# %%
import pandas as pd
import json
from datetime import datetime
pd.set_option('display.max_columns', None)

# %%
df_work_raw = catalog.load('raw/openalex/work#parquet')
# Out:
#                     INFO     Loading data from raw/openalex/work#parquet (ParquetDataset)...    ]8;id=310377;file:///home/pablo/dev/conicet/kedro-conicet/.venv/lib/python3.10/site-packages/kedro/io/data_catalog.py\data_catalog.py]8;;\:]8;id=635121;file:///home/pablo/dev/conicet/kedro-conicet/.venv/lib/python3.10/site-packages/kedro/io/data_catalog.py#389\389]8;;\

# %% [markdown]
# # Profiling

# %%
df_work_raw.columns
# Out:
# <pre style="white-space:pre;overflow-x:auto;line-height:normal;font-family:Menlo,'DejaVu Sans Mono',consolas,'Courier New',monospace"></pre>
# Index(['id', 'doi', 'title', 'display_name', 'publication_year',
#        'publication_date', 'ids', 'language', 'primary_location', 'type',
#        'type_crossref', 'indexed_in', 'open_access', 'authorships',
#        'institution_assertions', 'countries_distinct_count',
#        'institutions_distinct_count', 'corresponding_author_ids',
#        'corresponding_institution_ids', 'apc_list', 'apc_paid', 'fwci',
#        'has_fulltext', 'fulltext_origin', 'cited_by_count',
#        'citation_normalized_percentile', 'cited_by_percentile_year', 'biblio',
#        'is_retracted', 'is_paratext', 'primary_topic', 'topics', 'keywords',
#        'concepts', 'mesh', 'locations_count', 'locations', 'best_oa_location',
#        'sustainable_development_goals', 'grants', 'datasets', 'versions',
#        'referenced_works_count', 'referenced_works', 'related_works',
#        'abstract_inverted_index', 'cited_by_api_url', 'counts_by_year',
#        'updated_date', 'created_date', 'extract_datetime'],
#       dtype='object')

# %%
df_work_raw.head(3)
# Out:
# <pre style="white-space:pre;overflow-x:auto;line-height:normal;font-family:Menlo,'DejaVu Sans Mono',consolas,'Courier New',monospace"></pre>
#                                  id  \
# 0  https://openalex.org/W2089852843
# 1  https://openalex.org/W3037375387
# 2  https://openalex.org/W2032143374
#
#                                              doi  \
# 0  https://doi.org/10.1016/s0378-4371(98)00437-3
# 1   https://doi.org/10.1016/j.envint.2020.105876
# 2  https://doi.org/10.1016/s0023-6438(03)00088-4
#
#                                                title  \
# 0  The role of constraints within generalized non...
# 1  Short-term exposure to particulate matter (PM1...
# 2  Antimicrobial activity of essential oils on th...
#
#                                         display_name  publication_year  \
# 0  The role of constraints within generalized non...              1998
# 1  Short-term exposure to particulate matter (PM1...              2020
# 2  Antimicrobial activity of essential oils on th...              2003
#
#   publication_date                                                ids  \
# 0       1998-12-01  {'doi': 'https://doi.org/10.1016/s0378-4371(98...
# 1       2020-06-23  {'doi': 'https://doi.org/10.1016/j.envint.2020...
# 2       2003-11-01  {'doi': 'https://doi.org/10.1016/s0023-6438(03...
#
#   language                                   primary_location     type  \
# 0       en  {'is_accepted': False, 'is_oa': False, 'is_pub...  article
# 1       en  {'is_accepted': True, 'is_oa': True, 'is_publi...   review
# 2       en  {'is_accepted': False, 'is_oa': False, 'is_pub...  article
#
#      type_crossref                indexed_in  \
# 0  journal-article                [crossref]
# 1  journal-article  [crossref, doaj, pubmed]
# 2  journal-article                [crossref]
#
#                                          open_access  \
# 0  {'any_repository_has_fulltext': False, 'is_oa'...
# 1  {'any_repository_has_fulltext': True, 'is_oa':...
# 2  {'any_repository_has_fulltext': False, 'is_oa'...
#
#                                          authorships institution_assertions  \
# 0  [{'affiliations': [{'institution_ids': array([...                     []
# 1  [{'affiliations': [{'institution_ids': array([...                     []
# 2  [{'affiliations': [{'institution_ids': array([...                     []
#
#    countries_distinct_count  institutions_distinct_count  \
# 0                         3                            6
# 1                         1                            5
# 2                         1                            3
#
#              corresponding_author_ids  \
# 0  [https://openalex.org/A5051451815]
# 1  [https://openalex.org/A5069680875]
# 2  [https://openalex.org/A5113848554]
#
#                        corresponding_institution_ids  \
# 0                 [https://openalex.org/I4210125245]
# 1  [https://openalex.org/I151201029, https://open...
# 2  [https://openalex.org/I4210159174, https://ope...
#
#                                             apc_list  \
# 0  {'currency': 'USD', 'value': 3320.0, 'value_us...
# 1  {'currency': 'USD', 'value': 3500.0, 'value_us...
# 2  {'currency': 'USD', 'value': 2250.0, 'value_us...
#
#                                             apc_paid    fwci  has_fulltext  \
# 0                                               None  30.138          True
# 1  {'currency': 'USD', 'value': 3500.0, 'value_us...   8.608          True
# 2                                               None   1.333          True
#
#   fulltext_origin  cited_by_count  \
# 0          ngrams            1366
# 1             pdf             621
# 2          ngrams             468
#
#                       citation_normalized_percentile cited_by_percentile_year  \
# 0  {'is_in_top_10_percent': True, 'is_in_top_1_pe...  {'max': 100, 'min': 99}
# 1  {'is_in_top_10_percent': True, 'is_in_top_1_pe...  {'max': 100, 'min': 99}
# 2  {'is_in_top_10_percent': True, 'is_in_top_1_pe...  {'max': 100, 'min': 99}
#
#                                               biblio  is_retracted  \
# 0  {'first_page': '534', 'issue': '3-4', 'last_pa...         False
# 1  {'first_page': '105876', 'issue': None, 'last_...         False
# 2  {'first_page': '679', 'issue': '7', 'last_page...         False
#
#    is_paratext                                      primary_topic  \
# 0        False  {'display_name': 'Statistical Mechanics and En...
# 1        False  {'display_name': 'Air Quality and Health Impac...
# 2        False  {'display_name': 'Essential Oils and Antimicro...
#
#                                               topics  \
# 0  [{'display_name': 'Statistical Mechanics and E...
# 1  [{'display_name': 'Air Quality and Health Impa...
# 2  [{'display_name': 'Essential Oils and Antimicr...
#
#                                             keywords  \
# 0  [{'display_name': 'Hamiltonian (control theory...
# 1  [{'display_name': 'Nitrogen dioxide', 'id': 'h...
# 2  [{'display_name': 'Syzygium', 'id': 'https://o...
#
#                                             concepts  \
# 0  [{'display_name': 'Harmonic oscillator', 'id':...
# 1  [{'display_name': 'Nitrogen dioxide', 'id': 'h...
# 2  [{'display_name': 'Antimicrobial', 'id': 'http...
#
#                                                 mesh  locations_count  \
# 0                                                 []                1
# 1  [{'descriptor_name': 'Air Pollutants', 'descri...                4
# 2                                                 []                1
#
#                                            locations  \
# 0  [{'is_accepted': False, 'is_oa': False, 'is_pu...
# 1  [{'is_accepted': True, 'is_oa': True, 'is_publ...
# 2  [{'is_accepted': False, 'is_oa': False, 'is_pu...
#
#                                     best_oa_location  \
# 0                                               None
# 1  {'is_accepted': True, 'is_oa': True, 'is_publi...
# 2                                               None
#
#                        sustainable_development_goals  \
# 0  [{'display_name': 'Affordable and clean energy...
# 1  [{'display_name': 'Good health and well-being'...
# 2                                                 []
#
#                                               grants datasets versions  \
# 0                                                 []       []       []
# 1  [{'award_id': None, 'funder': 'https://openale...       []       []
# 2                                                 []       []       []
#
#    referenced_works_count                                   referenced_works  \
# 0                      74  [https://openalex.org/W1553236419, https://ope...
# 1                      85  [https://openalex.org/W1525116145, https://ope...
# 2                      38  [https://openalex.org/W102433214, https://open...
#
#                                        related_works  \
# 0  [https://openalex.org/W620348747, https://open...
# 1  [https://openalex.org/W4399338999, https://ope...
# 2  [https://openalex.org/W4381740914, https://ope...
#
#                              abstract_inverted_index  \
# 0                                               None
# 1  {'
# La': None, '
# Se': None, '!m': None, '"A"': ...
# 2                                               None
#
#                                     cited_by_api_url  \
# 0  https://api.openalex.org/works?filter=cites:W2...
# 1  https://api.openalex.org/works?filter=cites:W3...
# 2  https://api.openalex.org/works?filter=cites:W2...
#
#                                       counts_by_year  \
# 0  [{'cited_by_count': 25, 'year': 2025}, {'cited...
# 1  [{'cited_by_count': 93, 'year': 2025}, {'cited...
# 2  [{'cited_by_count': 21, 'year': 2025}, {'cited...
#
#                  updated_date created_date extract_datetime
# 0  2025-09-21T03:36:10.930753   2016-06-24       2025-09-28
# 1  2025-09-23T04:37:08.866086   2020-07-02       2025-09-28
# 2  2025-09-21T01:40:52.801087   2016-06-24       2025-09-28

# %% [markdown]
# # Nodo

# %%
def openalex_load_work(df_work_raw):
    """Limpia y transforma los datos de OpenAlex para su almacenamiento en una base de datos relacional."""
    
    expected_columns = [
        'id',
        # 'doi', # doi existe en ids
        'title',
        'display_name',
        'publication_year',
        'publication_date',
        'ids',
        'language',
        'primary_location',
        'type',
        'type_crossref',
        # 'indexed_in',
        'open_access',
        # 'authorships',
        # 'institution_assertions',
        'countries_distinct_count',
        'institutions_distinct_count',
        # 'corresponding_author_ids',
        # 'corresponding_institution_ids',
        'apc_list',
        'apc_paid',
        'fwci',
        'has_fulltext',
        'fulltext_origin',
        'cited_by_count',
        'citation_normalized_percentile',
        'cited_by_percentile_year',
        'biblio',
        'is_retracted',
        'is_paratext',
        'primary_topic',
        # 'topics',
        # 'keywords',
        # 'concepts',
        # 'mesh',
        'locations_count',
        # 'locations',
        'best_oa_location',
        # 'sustainable_development_goals',
        # 'grants',
        # 'datasets',
        # 'versions',
        'referenced_works_count',
        # 'referenced_works',
        # 'related_works',
        # 'abstract_inverted_index',
        # 'abstract_inverted_index_v3',
        'cited_by_api_url',
        # 'counts_by_year',
        'updated_date',
        'created_date',
        'extract_datetime'
    ]

    df_work = df_work_raw.loc[:,expected_columns].reset_index(drop=True).copy()

    # Agregar columnas faltantes con NaN
    for col in expected_columns:
        if col not in df_work.columns:
            df_work[col] = pd.NA

    # ids
    df_ids = pd.json_normalize(df_work['ids']).reset_index(drop=True)
    df_work = pd.concat([df_work, df_ids], axis=1)
    df_work.drop(columns=['ids'], inplace=True)    

    # primary_location
    df_primary_location = pd.json_normalize(df_work['primary_location']).reset_index(drop=True)
    df_primary_location.rename(columns=lambda col: f'primary_location.{col}', inplace=True)
    df_primary_location.drop(columns=[
        'primary_location.source.issn',
        'primary_location.source.host_organization_lineage',
        'primary_location.source.host_organization_lineage_names'
        ],
        inplace=True)

    df_work = pd.concat([df_work, df_primary_location], axis=1)
    df_work.drop(columns=['primary_location'], inplace=True)    

    # openacess
    df_openaccess_expanded = pd.json_normalize(df_work['open_access'])
    df_work = pd.concat([df_work, df_openaccess_expanded], axis=1)
    df_work.drop(columns=['open_access'], inplace=True)    

    # apc_list
    df_apc_list = pd.json_normalize(df_work['apc_list'])
    df_apc_list.rename(columns=lambda col: f'apc_list.{col}', inplace=True)
    df_work = pd.concat([df_work, df_apc_list], axis=1)
    df_work.drop(columns=['apc_list'], inplace=True)    
 
    # apc_paid
    df_apc_paid = pd.json_normalize(df_work['apc_paid'])
    df_apc_paid.rename(columns=lambda col: f'apc_paid.{col}', inplace=True)
    df_work = pd.concat([df_work, df_apc_paid], axis=1)
    df_work.drop(columns=['apc_paid'], inplace=True)    
 
    # citation_normalized_percentile
    df_citation_normalized_percentile = pd.json_normalize(df_work['citation_normalized_percentile'])
    df_citation_normalized_percentile.rename(columns=lambda col: f'citation_normalized_percentile.{col}', inplace=True)
    df_work = pd.concat([df_work, df_citation_normalized_percentile], axis=1)
    df_work.drop(columns=['citation_normalized_percentile'], inplace=True)    

    # cited_by_percentile_year
    df_cited_by_percentile_year = pd.json_normalize(df_work['cited_by_percentile_year'])
    df_cited_by_percentile_year.rename(columns=lambda col: f'cited_by_percentile_year.{col}', inplace=True)
    df_work = pd.concat([df_work, df_cited_by_percentile_year], axis=1)
    df_work.drop(columns=['cited_by_percentile_year'], inplace=True)    

    # biblio
    df_biblio = pd.json_normalize(df_work['biblio'])
    df_biblio.rename(columns=lambda col: f'biblio.{col}', inplace=True)
    df_work = pd.concat([df_work, df_biblio], axis=1)
    df_work.drop(columns=['biblio'], inplace=True)

    # primary_topic
    df_primary_topic = pd.json_normalize(df_work['primary_topic'])
    df_primary_topic.rename(columns=lambda col: f'primary_topic.{col}', inplace=True)
    df_work = pd.concat([df_work, df_primary_topic], axis=1)
    df_work.drop(columns=['primary_topic'], inplace=True)    

    # best_oa_location
    df_best_oa_location = pd.json_normalize(df_work['best_oa_location'])
    df_best_oa_location.rename(columns=lambda col: f'best_oa_location.{col}', inplace=True)
    df_best_oa_location.drop(columns=[
        'best_oa_location.source.host_organization_lineage',
        'best_oa_location.source.host_organization_lineage_names',
        'best_oa_location.source.issn',
    ], inplace=True)
    
    df_work = pd.concat([df_work, df_best_oa_location], axis=1)
    df_work.drop(columns=['best_oa_location'], inplace=True)    

    # Agregar la fecha de carga con formato datetime
    df_work['load_datetime'] = pd.to_datetime(datetime.today())

    # Convertir tipos de datos automáticamente
    df_work = df_work.convert_dtypes()

    return df_work

# %% [markdown]
# ## Ejecuto Nodo

# %%
df_work = openalex_load_work(df_work_raw)

# %% [markdown]
# # Resultados

# %%
df_work
# Out:
# <pre style="white-space:pre;overflow-x:auto;line-height:normal;font-family:Menlo,'DejaVu Sans Mono',consolas,'Courier New',monospace"></pre>
#                                    id  \
# 0    https://openalex.org/W2089852843
# 1    https://openalex.org/W3037375387
# 2    https://openalex.org/W2032143374
# 3    https://openalex.org/W2021071494
# 4    https://openalex.org/W2154507013
# ..                                ...
# 995  https://openalex.org/W2018147890
# 996  https://openalex.org/W2105314474
# 997  https://openalex.org/W1972746868
# 998  https://openalex.org/W1983613813
# 999  https://openalex.org/W2002797015
#
#                                                doi  \
# 0    https://doi.org/10.1016/s0378-4371(98)00437-3
# 1     https://doi.org/10.1016/j.envint.2020.105876
# 2    https://doi.org/10.1016/s0023-6438(03)00088-4
# 3    https://doi.org/10.1016/j.compedu.2005.11.017
# 4          https://doi.org/10.1126/science.1134796
# ..                                             ...
# 995      https://doi.org/10.1007/s11270-009-0163-0
# 996            https://doi.org/10.46989/001c.20546
# 997      https://doi.org/10.1016/j.pce.2010.12.002
# 998   https://doi.org/10.1016/j.vetpar.2012.06.033
# 999      https://doi.org/10.1007/s00705-012-1302-2
#
#                                                  title  \
# 0    The role of constraints within generalized non...
# 1    Short-term exposure to particulate matter (PM1...
# 2    Antimicrobial activity of essential oils on th...
# 3    Evaluating Bayesian networks’ precision for de...
# 4    Formation of a Nematic Fluid at High Fields in...
# ..                                                 ...
# 995  Air Pollutant Transport Analysis Based on Hour...
# 996  Partial Substitution of Fishmeal by Meat and B...
# 997  Evapotranspiration in the Pampean Region using...
# 998  Experimental infection with Cryptosporidium pa...
# 999  First record of a mosquito iridescent virus in...
#
#                                           display_name  publication_year  \
# 0    The role of constraints within generalized non...              1998
# 1    Short-term exposure to particulate matter (PM1...              2020
# 2    Antimicrobial activity of essential oils on th...              2003
# 3    Evaluating Bayesian networks’ precision for de...              2005
# 4    Formation of a Nematic Fluid at High Fields in...              2006
# ..                                                 ...               ...
# 995  Air Pollutant Transport Analysis Based on Hour...              2009
# 996  Partial Substitution of Fishmeal by Meat and B...              2009
# 997  Evapotranspiration in the Pampean Region using...              2010
# 998  Experimental infection with Cryptosporidium pa...              2012
# 999  First record of a mosquito iridescent virus in...              2012
#
#     publication_date                                                ids  \
# 0         1998-12-01  {'doi': 'https://doi.org/10.1016/s0378-4371(98...
# 1         2020-06-23  {'doi': 'https://doi.org/10.1016/j.envint.2020...
# 2         2003-11-01  {'doi': 'https://doi.org/10.1016/s0023-6438(03...
# 3         2005-12-28  {'doi': 'https://doi.org/10.1016/j.compedu.200...
# 4         2006-11-24  {'doi': 'https://doi.org/10.1126/science.11347...
# ..               ...                                                ...
# 995       2009-08-05  {'doi': 'https://doi.org/10.1007/s11270-009-01...
# 996       2009-01-01  {'doi': 'https://doi.org/10.46989/001c.20546',...
# 997       2010-12-14  {'doi': 'https://doi.org/10.1016/j.pce.2010.12...
# 998       2012-07-03  {'doi': 'https://doi.org/10.1016/j.vetpar.2012...
# 999       2012-04-27  {'doi': 'https://doi.org/10.1007/s00705-012-13...
#
#     language                                   primary_location     type  \
# 0         en  {'is_accepted': False, 'is_oa': False, 'is_pub...  article
# 1         en  {'is_accepted': True, 'is_oa': True, 'is_publi...   review
# 2         en  {'is_accepted': False, 'is_oa': False, 'is_pub...  article
# 3         en  {'is_accepted': False, 'is_oa': False, 'is_pub...  article
# 4         en  {'is_accepted': True, 'is_oa': True, 'is_publi...  article
# ..       ...                                                ...      ...
# 995       en  {'is_accepted': False, 'is_oa': False, 'is_pub...  article
# 996       en  {'is_accepted': True, 'is_oa': True, 'is_publi...  article
# 997       en  {'is_accepted': False, 'is_oa': False, 'is_pub...  article
# 998       en  {'is_accepted': False, 'is_oa': False, 'is_pub...  article
# 999       en  {'is_accepted': False, 'is_oa': False, 'is_pub...  article
#
#        type_crossref                           indexed_in  \
# 0    journal-article                           [crossref]
# 1    journal-article             [crossref, doaj, pubmed]
# 2    journal-article                           [crossref]
# 3    journal-article                           [crossref]
# 4    journal-article  [arxiv, crossref, datacite, pubmed]
# ..               ...                                  ...
# 995  journal-article                           [crossref]
# 996  journal-article                           [crossref]
# 997  journal-article                           [crossref]
# 998  journal-article                   [crossref, pubmed]
# 999  journal-article                   [crossref, pubmed]
#
#                                            open_access  \
# 0    {'any_repository_has_fulltext': False, 'is_oa'...
# 1    {'any_repository_has_fulltext': True, 'is_oa':...
# 2    {'any_repository_has_fulltext': False, 'is_oa'...
# 3    {'any_repository_has_fulltext': False, 'is_oa'...
# 4    {'any_repository_has_fulltext': True, 'is_oa':...
# ..                                                 ...
# 995  {'any_repository_has_fulltext': False, 'is_oa'...
# 996  {'any_repository_has_fulltext': True, 'is_oa':...
# 997  {'any_repository_has_fulltext': False, 'is_oa'...
# 998  {'any_repository_has_fulltext': False, 'is_oa'...
# 999  {'any_repository_has_fulltext': True, 'is_oa':...
#
#                                            authorships institution_assertions  \
# 0    [{'affiliations': [{'institution_ids': array([...                     []
# 1    [{'affiliations': [{'institution_ids': array([...                     []
# 2    [{'affiliations': [{'institution_ids': array([...                     []
# 3    [{'affiliations': [{'institution_ids': array([...                     []
# 4    [{'affiliations': [{'institution_ids': array([...                     []
# ..                                                 ...                    ...
# 995  [{'affiliations': [{'institution_ids': array([...                     []
# 996  [{'affiliations': [], 'author': {'display_name...                     []
# 997  [{'affiliations': [{'institution_ids': array([...                     []
# 998  [{'affiliations': [{'institution_ids': array([...                     []
# 999  [{'affiliations': [{'institution_ids': array([...                     []
#
#      countries_distinct_count  institutions_distinct_count  \
# 0                           3                            6
# 1                           1                            5
# 2                           1                            3
# 3                           1                            2
# 4                           3                            9
# ..                        ...                          ...
# 995                         2                            5
# 996                         1                            3
# 997                         1                            2
# 998                         2                            5
# 999                         2                            5
#
#                               corresponding_author_ids  \
# 0                   [https://openalex.org/A5051451815]
# 1                   [https://openalex.org/A5069680875]
# 2                   [https://openalex.org/A5113848554]
# 3                   [https://openalex.org/A5050049360]
# 4    [https://openalex.org/A5042819546, https://ope...
# ..                                                 ...
# 995                                                 []
# 996                                                 []
# 997                 [https://openalex.org/A5087872040]
# 998                 [https://openalex.org/A5086693325]
# 999                 [https://openalex.org/A5070736743]
#
#                          corresponding_institution_ids  \
# 0                   [https://openalex.org/I4210125245]
# 1    [https://openalex.org/I151201029, https://open...
# 2    [https://openalex.org/I4210159174, https://ope...
# 3    [https://openalex.org/I4210122970, https://ope...
# 4    [https://openalex.org/I16835326, https://opena...
# ..                                                 ...
# 995                                                 []
# 996                                                 []
# 997                 [https://openalex.org/I4210122970]
# 998  [https://openalex.org/I4210122970, https://ope...
# 999                  [https://openalex.org/I151201029]
#
#                                               apc_list  \
# 0    {'currency': 'USD', 'value': 3320.0, 'value_us...
# 1    {'currency': 'USD', 'value': 3500.0, 'value_us...
# 2    {'currency': 'USD', 'value': 2250.0, 'value_us...
# 3    {'currency': 'USD', 'value': 4220.0, 'value_us...
# 4                                                 None
# ..                                                 ...
# 995                                               None
# 996                                               None
# 997  {'currency': 'USD', 'value': 2820.0, 'value_us...
# 998  {'currency': 'USD', 'value': 3300.0, 'value_us...
# 999  {'currency': 'EUR', 'value': 3390.0, 'value_us...
#
#                                               apc_paid    fwci  has_fulltext  \
# 0                                                 None  30.138          True
# 1    {'currency': 'USD', 'value': 3500.0, 'value_us...   8.608          True
# 2                                                 None   1.333          True
# 3                                                 None  10.619          True
# 4                                                 None  15.826          True
# ..                                                 ...     ...           ...
# 995                                               None   1.723          True
# 996                                               None   0.473          True
# 997                                               None     0.4          True
# 998                                               None   0.585          True
# 999                                               None   0.634          True
#
#     fulltext_origin  cited_by_count  \
# 0            ngrams            1366
# 1               pdf             621
# 2            ngrams             468
# 3            ngrams             430
# 4               pdf             429
# ..              ...             ...
# 995          ngrams              16
# 996             pdf              16
# 997          ngrams              15
# 998          ngrams              15
# 999             pdf              15
#
#                         citation_normalized_percentile  \
# 0    {'is_in_top_10_percent': True, 'is_in_top_1_pe...
# 1    {'is_in_top_10_percent': True, 'is_in_top_1_pe...
# 2    {'is_in_top_10_percent': True, 'is_in_top_1_pe...
# 3    {'is_in_top_10_percent': True, 'is_in_top_1_pe...
# 4    {'is_in_top_10_percent': True, 'is_in_top_1_pe...
# ..                                                 ...
# 995  {'is_in_top_10_percent': True, 'is_in_top_1_pe...
# 996  {'is_in_top_10_percent': False, 'is_in_top_1_p...
# 997  {'is_in_top_10_percent': False, 'is_in_top_1_p...
# 998  {'is_in_top_10_percent': False, 'is_in_top_1_p...
# 999  {'is_in_top_10_percent': False, 'is_in_top_1_p...
#
#     cited_by_percentile_year  \
# 0    {'max': 100, 'min': 99}
# 1    {'max': 100, 'min': 99}
# 2    {'max': 100, 'min': 99}
# 3    {'max': 100, 'min': 99}
# 4    {'max': 100, 'min': 99}
# ..                       ...
# 995   {'max': 88, 'min': 87}
# 996   {'max': 88, 'min': 87}
# 997   {'max': 88, 'min': 87}
# 998   {'max': 88, 'min': 87}
# 999   {'max': 88, 'min': 87}
#
#                                                 biblio  is_retracted  \
# 0    {'first_page': '534', 'issue': '3-4', 'last_pa...         False
# 1    {'first_page': '105876', 'issue': None, 'last_...         False
# 2    {'first_page': '679', 'issue': '7', 'last_page...         False
# 3    {'first_page': '794', 'issue': '3', 'last_page...         False
# 4    {'first_page': '214', 'issue': '5809', 'last_p...         False
# ..                                                 ...           ...
# 995  {'first_page': '243', 'issue': '1-4', 'last_pa...         False
# 996  {'first_page': None, 'issue': None, 'last_page...         False
# 997  {'first_page': '27', 'issue': None, 'last_page...         False
# 998  {'first_page': '411', 'issue': '3-4', 'last_pa...         False
# 999  {'first_page': '1569', 'issue': '8', 'last_pag...         False
#
#      is_paratext                                      primary_topic  \
# 0          False  {'display_name': 'Statistical Mechanics and En...
# 1          False  {'display_name': 'Air Quality and Health Impac...
# 2          False  {'display_name': 'Essential Oils and Antimicro...
# 3          False  {'display_name': 'Learning Styles and Cognitiv...
# 4          False  {'display_name': 'Advanced Condensed Matter Ph...
# ..           ...                                                ...
# 995        False  {'display_name': 'Vehicle emissions and perfor...
# 996        False  {'display_name': 'Aquaculture Nutrition and Gr...
# 997        False  {'display_name': 'Plant Water Relations and Ca...
# 998        False  {'display_name': 'Parasitic Infections and Dia...
# 999        False  {'display_name': 'Mosquito-borne diseases and ...
#
#                                                 topics  \
# 0    [{'display_name': 'Statistical Mechanics and E...
# 1    [{'display_name': 'Air Quality and Health Impa...
# 2    [{'display_name': 'Essential Oils and Antimicr...
# 3    [{'display_name': 'Learning Styles and Cogniti...
# 4    [{'display_name': 'Advanced Condensed Matter P...
# ..                                                 ...
# 995  [{'display_name': 'Vehicle emissions and perfo...
# 996  [{'display_name': 'Aquaculture Nutrition and G...
# 997  [{'display_name': 'Plant Water Relations and C...
# 998  [{'display_name': 'Parasitic Infections and Di...
# 999  [{'display_name': 'Mosquito-borne diseases and...
#
#                                               keywords  \
# 0    [{'display_name': 'Hamiltonian (control theory...
# 1    [{'display_name': 'Nitrogen dioxide', 'id': 'h...
# 2    [{'display_name': 'Syzygium', 'id': 'https://o...
# 3                                                   []
# 4                                                   []
# ..                                                 ...
# 995  [{'display_name': 'Prevailing winds', 'id': 'h...
# 996  [{'display_name': 'Digestion', 'id': 'https://...
# 997  [{'display_name': 'Thematic Mapper', 'id': 'ht...
# 998  [{'display_name': 'Cryptosporidium parvum', 'i...
# 999  [{'display_name': 'Iridescence', 'id': 'https:...
#
#                                               concepts  \
# 0    [{'display_name': 'Harmonic oscillator', 'id':...
# 1    [{'display_name': 'Nitrogen dioxide', 'id': 'h...
# 2    [{'display_name': 'Antimicrobial', 'id': 'http...
# 3    [{'display_name': 'Learning styles', 'id': 'ht...
# 4    [{'display_name': 'Liquid crystal', 'id': 'htt...
# ..                                                 ...
# 995  [{'display_name': 'Pollutant', 'id': 'https://...
# 996  [{'display_name': 'Fish meal', 'id': 'https://...
# 997  [{'display_name': 'Evapotranspiration', 'id': ...
# 998  [{'display_name': 'Cryptosporidium parvum', 'i...
# 999  [{'display_name': 'Biology', 'id': 'https://op...
#
#                                                   mesh  locations_count  \
# 0                                                   []                1
# 1    [{'descriptor_name': 'Air Pollutants', 'descri...                4
# 2                                                   []                1
# 3                                                   []                1
# 4                                                   []                5
# ..                                                 ...              ...
# 995                                                 []                1
# 996                                                 []                2
# 997                                                 []                1
# 998  [{'descriptor_name': 'Cryptosporidiosis', 'des...                2
# 999  [{'descriptor_name': 'Culex', 'descriptor_ui':...                4
#
#                                              locations  \
# 0    [{'is_accepted': False, 'is_oa': False, 'is_pu...
# 1    [{'is_accepted': True, 'is_oa': True, 'is_publ...
# 2    [{'is_accepted': False, 'is_oa': False, 'is_pu...
# 3    [{'is_accepted': False, 'is_oa': False, 'is_pu...
# 4    [{'is_accepted': True, 'is_oa': True, 'is_publ...
# ..                                                 ...
# 995  [{'is_accepted': False, 'is_oa': False, 'is_pu...
# 996  [{'is_accepted': True, 'is_oa': True, 'is_publ...
# 997  [{'is_accepted': False, 'is_oa': False, 'is_pu...
# 998  [{'is_accepted': False, 'is_oa': False, 'is_pu...
# 999  [{'is_accepted': False, 'is_oa': False, 'is_pu...
#
#                                       best_oa_location  \
# 0                                                 None
# 1    {'is_accepted': True, 'is_oa': True, 'is_publi...
# 2                                                 None
# 3                                                 None
# 4    {'is_accepted': True, 'is_oa': True, 'is_publi...
# ..                                                 ...
# 995                                               None
# 996  {'is_accepted': True, 'is_oa': True, 'is_publi...
# 997                                               None
# 998                                               None
# 999  {'is_accepted': True, 'is_oa': True, 'is_publi...
#
#                          sustainable_development_goals  \
# 0    [{'display_name': 'Affordable and clean energy...
# 1    [{'display_name': 'Good health and well-being'...
# 2                                                   []
# 3    [{'display_name': 'Quality education', 'id': '...
# 4                                                   []
# ..                                                 ...
# 995  [{'display_name': 'Affordable and clean energy...
# 996                                                 []
# 997  [{'display_name': 'Clean water and sanitation'...
# 998  [{'display_name': 'Good health and well-being'...
# 999  [{'display_name': 'Sustainable cities and comm...
#
#                                                 grants datasets  \
# 0                                                   []       []
# 1    [{'award_id': None, 'funder': 'https://openale...       []
# 2                                                   []       []
# 3                                                   []       []
# 4                                                   []       []
# ..                                                 ...      ...
# 995                                                 []       []
# 996                                                 []       []
# 997                                                 []       []
# 998                                                 []       []
# 999                                                 []       []
#
#                                versions  referenced_works_count  \
# 0                                    []                      74
# 1                                    []                      85
# 2                                    []                      38
# 3                                    []                      26
# 4    [https://openalex.org/W2154507013]                      34
# ..                                  ...                     ...
# 995                                  []                      17
# 996                                  []                      24
# 997                                  []                      31
# 998                                  []                      36
# 999                                  []                      12
#
#                                       referenced_works  \
# 0    [https://openalex.org/W1553236419, https://ope...
# 1    [https://openalex.org/W1525116145, https://ope...
# 2    [https://openalex.org/W102433214, https://open...
# 3    [https://openalex.org/W139006800, https://open...
# 4    [https://openalex.org/W1523859489, https://ope...
# ..                                                 ...
# 995  [https://openalex.org/W1480174420, https://ope...
# 996  [https://openalex.org/W1546962148, https://ope...
# 997  [https://openalex.org/W1487923163, https://ope...
# 998  [https://openalex.org/W1480831516, https://ope...
# 999  [https://openalex.org/W1520740528, https://ope...
#
#                                          related_works  \
# 0    [https://openalex.org/W620348747, https://open...
# 1    [https://openalex.org/W4399338999, https://ope...
# 2    [https://openalex.org/W4381740914, https://ope...
# 3    [https://openalex.org/W581389233, https://open...
# 4    [https://openalex.org/W54078636, https://opena...
# ..                                                 ...
# 995  [https://openalex.org/W4321492268, https://ope...
# 996  [https://openalex.org/W78793023, https://opena...
# 997  [https://openalex.org/W4234849036, https://ope...
# 998  [https://openalex.org/W4286283863, https://ope...
# 999  [https://openalex.org/W4362672714, https://ope...
#
#                                abstract_inverted_index  \
# 0                                                 None
# 1    {'
# La': None, '
# Se': None, '!m': None, '"A"': ...
# 2                                                 None
# 3                                                 None
# 4    {'
# La': None, '
# Se': None, '!m': None, '"A"': ...
# ..                                                 ...
# 995                                               None
# 996  {'
# La': None, '
# Se': None, '!m': None, '"A"': ...
# 997                                               None
# 998                                               None
# 999                                               None
#
#                                       cited_by_api_url  \
# 0    https://api.openalex.org/works?filter=cites:W2...
# 1    https://api.openalex.org/works?filter=cites:W3...
# 2    https://api.openalex.org/works?filter=cites:W2...
# 3    https://api.openalex.org/works?filter=cites:W2...
# 4    https://api.openalex.org/works?filter=cites:W2...
# ..                                                 ...
# 995  https://api.openalex.org/works?filter=cites:W2...
# 996  https://api.openalex.org/works?filter=cites:W2...
# 997  https://api.openalex.org/works?filter=cites:W1...
# 998  https://api.openalex.org/works?filter=cites:W1...
# 999  https://api.openalex.org/works?filter=cites:W2...
#
#                                         counts_by_year  \
# 0    [{'cited_by_count': 25, 'year': 2025}, {'cited...
# 1    [{'cited_by_count': 93, 'year': 2025}, {'cited...
# 2    [{'cited_by_count': 21, 'year': 2025}, {'cited...
# 3    [{'cited_by_count': 18, 'year': 2024}, {'cited...
# 4    [{'cited_by_count': 6, 'year': 2025}, {'cited_...
# ..                                                 ...
# 995  [{'cited_by_count': 1, 'year': 2023}, {'cited_...
# 996  [{'cited_by_count': 1, 'year': 2019}, {'cited_...
# 997  [{'cited_by_count': 1, 'year': 2025}, {'cited_...
# 998  [{'cited_by_count': 2, 'year': 2025}, {'cited_...
# 999  [{'cited_by_count': 2, 'year': 2024}, {'cited_...
#
#                    updated_date created_date extract_datetime  \
# 0    2025-09-21T03:36:10.930753   2016-06-24       2025-09-28
# 1    2025-09-23T04:37:08.866086   2020-07-02       2025-09-28
# 2    2025-09-21T01:40:52.801087   2016-06-24       2025-09-28
# 3    2025-09-20T18:36:32.225991   2016-06-24       2025-09-28
# 4    2025-09-17T14:31:20.642693   2016-06-24       2025-09-28
# ..                          ...          ...              ...
# 995  2025-09-22T05:24:22.040516   2016-06-24       2025-09-28
# 996  2025-09-23T15:19:16.907966   2016-06-24       2025-09-28
# 997  2025-09-20T20:47:47.350804   2016-06-24       2025-09-28
# 998  2025-09-19T17:44:11.433154   2016-06-24       2025-09-28
# 999  2025-09-18T05:49:44.521357   2016-06-24       2025-09-28
#
#                  load_datetime
# 0   2025-09-28 20:45:34.141382
# 1   2025-09-28 20:45:34.141382
# 2   2025-09-28 20:45:34.141382
# 3   2025-09-28 20:45:34.141382
# 4   2025-09-28 20:45:34.141382
# ..                         ...
# 995 2025-09-28 20:45:34.141382
# 996 2025-09-28 20:45:34.141382
# 997 2025-09-28 20:45:34.141382
# 998 2025-09-28 20:45:34.141382
# 999 2025-09-28 20:45:34.141382
#
# [1000 rows x 52 columns]
