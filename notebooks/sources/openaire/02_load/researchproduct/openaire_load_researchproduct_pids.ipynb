# %%
from datetime import date
import pandas as pd

pd.set_option('display.max_columns', None)
pd.set_option('display.max_rows', 5)

df = catalog.load('raw/openaire/researchproduct_dev#parquet')
# Out:
#                     INFO     Loading data from raw/openaire/researchproduct_dev#parquet         ]8;id=464884;file:///home/pablo/dev/conicet/kedro-conicet/.venv/lib/python3.10/site-packages/kedro/io/data_catalog.py\data_catalog.py]8;;\:]8;id=77182;file:///home/pablo/dev/conicet/kedro-conicet/.venv/lib/python3.10/site-packages/kedro/io/data_catalog.py#389\389]8;;\
#                              (ParquetDataset)...

# %%
def _pick_load_dt(df: pd.DataFrame):
    # Si hay una sola fecha en el batch, usala; si hay varias, quedate con la más reciente;
    # si no hay, hoy.
    if 'load_datetime' not in df.columns or df['load_datetime'].isna().all():
        return date.today()
    vals = df['load_datetime'].dropna()
    if vals.nunique() == 1:
        return vals.iloc[0]
    return pd.to_datetime(vals).max().date()

# %%
df
# Out:
# <pre style="white-space:pre;overflow-x:auto;line-height:normal;font-family:Menlo,'DejaVu Sans Mono',consolas,'Courier New',monospace"></pre>
#                                                authors openAccessColor  \
# 0    [{'fullName': 'Susevich, María Laura', 'name':...            gold
# 1    [{'fullName': 'Steffen, Kevin Denis', 'name': ...            gold
# ..                                                 ...             ...
# 298  [{'fullName': 'Seré, Pablo Ricardo', 'name': '...            None
# 299  [{'fullName': 'TomÃ¡s, Facundo', 'name': 'Facu...            gold
#
#     publiclyFunded         type  \
# 0            False  publication
# 1            False  publication
# ..             ...          ...
# 298          False  publication
# 299          False  publication
#
#                                            language  \
# 0    {'code': 'spa', 'label': 'Spanish; Castilian'}
# 1    {'code': 'spa', 'label': 'Spanish; Castilian'}
# ..                                              ...
# 298         {'code': 'esl/spa', 'label': 'Spanish'}
# 299             {'code': 'eng', 'label': 'English'}
#
#                                              countries  \
# 0                                                 None
# 1                                                 None
# ..                                                 ...
# 298  [{'code': 'AR', 'label': 'Argentina', 'provena...
# 299  [{'code': 'AR', 'label': 'Argentina', 'provena...
#
#                                               subjects  \
# 0    [{'provenance': None, 'subject': {'scheme': 'k...
# 1    [{'provenance': None, 'subject': {'scheme': 'k...
# ..                                                 ...
# 298  [{'provenance': None, 'subject': {'scheme': 'k...
# 299  [{'provenance': None, 'subject': {'scheme': 'k...
#
#                                              mainTitle subTitle  \
# 0    Dicistrovirus from the pollinator community fo...     None
# 1    Variability in the growth rates of Saanen kids...     None
# ..                                                 ...      ...
# 298  Efecto de la concentración del silano MTMO sob...     None
# 299  Guerra Civil española y carteles de propaganda...     None
#
#                                           descriptions publicationDate  \
# 0    [Los Dicistrovirus son una familia de virus qu...      2022-08-31
# 1    [This study was carried out to determine the v...      2023-12-18
# ..                                                 ...             ...
# 298  [Los pretratamientos superficiales a base de s...      2017-01-01
# 299  [El cartelismo durante la Guerra Civil español...      2006-01-01
#
#                                              publisher embargoEndDate  \
# 0    Universidad Nacional Mayor de San Marcos, Facu...           None
# 1    Universidad Nacional Mayor de San Marcos, Facu...           None
# ..                                                 ...            ...
# 298                                               None           None
# 299                   Universidad Nacional de La Plata           None
#
#                                                sources  \
# 0    [Revista de Investigaciones Veterinarias del P...
# 1    [Revista de Investigaciones Veterinarias del P...
# ..                                                 ...
# 298  [reponame:SEDICI (UNLP), instname:Universidad ...
# 299  [Olivar: Revista de Literatura y Cultura Españ...
#
#                                  formats contributors coverages  \
# 0                      [application/pdf]         None      None
# 1                      [application/pdf]         None      None
# ..                                   ...          ...       ...
# 298                    [application/pdf]         None      None
# 299  [application/pdf, 63-85, text/html]         None      None
#
#                                        bestAccessRight  \
# 0    {'code': 'c_abf2', 'label': 'OPEN', 'scheme': ...
# 1    {'code': 'c_abf2', 'label': 'OPEN', 'scheme': ...
# ..                                                 ...
# 298  {'code': 'c_abf2', 'label': 'OPEN', 'scheme': ...
# 299  {'code': 'c_abf2', 'label': 'OPEN', 'scheme': ...
#
#                                              container documentationUrls  \
# 0    {'conferenceDate': None, 'conferencePlace': No...              None
# 1    {'conferenceDate': None, 'conferencePlace': No...              None
# ..                                                 ...               ...
# 298                                               None              None
# 299  {'conferenceDate': None, 'conferencePlace': No...              None
#
#     codeRepositoryUrl programmingLanguage contactPeople contactGroups tools  \
# 0                None                None          None          None  None
# 1                None                None          None          None  None
# ..                ...                 ...           ...           ...   ...
# 298              None                None          None          None  None
# 299              None                None          None          None  None
#
#      size version geoLocations  \
# 0    None    None         None
# 1    None    None         None
# ..    ...     ...          ...
# 298  None    None         None
# 299  None    None         None
#
#                                                  id  \
# 0    4dc99724cf04::319dc88111c9b2d6021228590e79130a
# 1    4dc99724cf04::95ea5df70a451a0487e051faa6c0a646
# ..                                              ...
# 298  dedup_wf_002::00cece367574590aa05deb123340c6e6
# 299  dedup_wf_002::00cf1fe88397a2c3ce9d41fe616b29cf
#
#                                            originalIds  pids dateOfCollection  \
# 0    [50|4dc99724cf04::319dc88111c9b2d6021228590e79...  None             None
# 1    [oai:ojs.csi.unmsm:article/25240, 50|4dc99724c...  None             None
# ..                                                 ...   ...              ...
# 298  [oai:sedici.unlp.edu.ar:10915/94520, 50|od____...  None             None
# 299  [oai:doaj.org/article:aef7dde8694742949f050de1...  None             None
#
#     lastUpdateTimeStamp                                         indicators  \
# 0                  None  {'citationImpact': {'citationClass': 'C5', 'ci...
# 1                  None  {'citationImpact': {'citationClass': 'C5', 'ci...
# ..                  ...                                                ...
# 298                None  {'citationImpact': {'citationClass': 'C5', 'ci...
# 299                None  {'citationImpact': {'citationClass': 'C5', 'ci...
#
#     projects                                      organizations  \
# 0       None  [{'acronym': 'UNLPAM', 'id': 'openorgs____::db...
# 1       None  [{'acronym': 'Universidad Nacional de La Pampa...
# ..       ...                                                ...
# 298     None  [{'acronym': 'UNLP', 'id': 'openorgs____::40b9...
# 299     None  [{'acronym': 'UNLP', 'id': 'openorgs____::40b9...
#
#                                            communities  \
# 0    [{'code': 'knowmad', 'label': 'Knowmad Institu...
# 1                                                 None
# ..                                                 ...
# 298                                               None
# 299  [{'code': 'dh-ch', 'label': 'Digital Humanitie...
#
#                                          collectedFrom  \
# 0    [{'key': 'openaire____::0b74b6a356bbf23c245f9a...
# 1    [{'key': 'openaire____::0b74b6a356bbf23c245f9a...
# ..                                                 ...
# 298  [{'key': 'opendoar____::dc6e224a8d74ce03bf3011...
# 299  [{'key': 'openaire____::df45502607927471ecf8a6...
#
#                                              instances isGreen  \
# 0    [{'accessRight': {'code': 'c_abf2', 'label': '...   False
# 1    [{'accessRight': {'code': 'c_abf2', 'label': '...   False
# ..                                                 ...     ...
# 298  [{'accessRight': None, 'alternateIdentifiers':...    True
# 299  [{'accessRight': {'code': 'c_abf2', 'label': '...    True
#
#     isInDiamondJournal                               relOrganizationId  \
# 0                False  openorgs____::40b9f835648a3e0d057d6917dd7e54d5
# 1                False  openorgs____::40b9f835648a3e0d057d6917dd7e54d5
# ..                 ...                                             ...
# 298              False  openorgs____::40b9f835648a3e0d057d6917dd7e54d5
# 299              False  openorgs____::40b9f835648a3e0d057d6917dd7e54d5
#
#     load_datetime
# 0      2025-09-04
# 1      2025-09-04
# ..            ...
# 298    2025-09-04
# 299    2025-09-04
#
# [300 rows x 43 columns]

# %%
load_dt = _pick_load_dt(df)

# %%
load_dt = _pick_load_dt(df)

# %%
df_research_pid = df.loc[:,['id','pids']]
df_research_pid.dropna(inplace=True)

# %%
df_research_pid
# Out:
# <pre style="white-space:pre;overflow-x:auto;line-height:normal;font-family:Menlo,'DejaVu Sans Mono',consolas,'Courier New',monospace"></pre>
#                                                  id  \
# 3    RECOLECTA___::24cb4438d1afe299e63cfdea4a31911f
# 116  dedup_wf_002::0005b301e367f0fc799b29dc387d3bd1
# ..                                              ...
# 295  dedup_wf_002::00c9e0caebc2510ca2bf89679a107477
# 296  dedup_wf_002::00ca0acaf13ec262a1697b86aa3ecb85
#
#                                                 pids
# 3     [{'scheme': 'handle', 'value': '10261/97737'}]
# 116  [{'scheme': 'handle', 'value': '11336/112574'}]
# ..                                               ...
# 295  [{'scheme': 'handle', 'value': '11336/151361'}]
# 296   [{'scheme': 'handle', 'value': '11336/34154'}]
#
# [24 rows x 2 columns]

# %%
df_research_pid = df_research_pid.explode('pids').reset_index(drop=True)

# %%
df_research_pid
# Out:
# <pre style="white-space:pre;overflow-x:auto;line-height:normal;font-family:Menlo,'DejaVu Sans Mono',consolas,'Courier New',monospace"></pre>
#                                                 id  \
# 0   RECOLECTA___::24cb4438d1afe299e63cfdea4a31911f
# 1   dedup_wf_002::0005b301e367f0fc799b29dc387d3bd1
# ..                                             ...
# 40  dedup_wf_002::00c9e0caebc2510ca2bf89679a107477
# 41  dedup_wf_002::00ca0acaf13ec262a1697b86aa3ecb85
#
#                                              pids
# 0    {'scheme': 'handle', 'value': '10261/97737'}
# 1   {'scheme': 'handle', 'value': '11336/112574'}
# ..                                            ...
# 40  {'scheme': 'handle', 'value': '11336/151361'}
# 41   {'scheme': 'handle', 'value': '11336/34154'}
#
# [42 rows x 2 columns]

# %%
df_pid = pd.json_normalize(df_research_pid['pids'])

# %%
df_pid
# Out:
# <pre style="white-space:pre;overflow-x:auto;line-height:normal;font-family:Menlo,'DejaVu Sans Mono',consolas,'Courier New',monospace"></pre>
#     scheme         value
# 0   handle   10261/97737
# 1   handle  11336/112574
# ..     ...           ...
# 40  handle  11336/151361
# 41  handle   11336/34154
#
# [42 rows x 2 columns]

# %%
df_research_pid = pd.concat([df_research_pid['id'], df_pid], axis=1)
df_research_pid['load_datetime'] = load_dt

# %%
df_research_pid
# Out:
# <pre style="white-space:pre;overflow-x:auto;line-height:normal;font-family:Menlo,'DejaVu Sans Mono',consolas,'Courier New',monospace"></pre>
#                                                 id  scheme         value  \
# 0   RECOLECTA___::24cb4438d1afe299e63cfdea4a31911f  handle   10261/97737
# 1   dedup_wf_002::0005b301e367f0fc799b29dc387d3bd1  handle  11336/112574
# ..                                             ...     ...           ...
# 40  dedup_wf_002::00c9e0caebc2510ca2bf89679a107477  handle  11336/151361
# 41  dedup_wf_002::00ca0acaf13ec262a1697b86aa3ecb85  handle   11336/34154
#
#    load_datetime
# 0     2025-09-04
# 1     2025-09-04
# ..           ...
# 40    2025-09-04
# 41    2025-09-04
#
# [42 rows x 4 columns]

# %% [markdown]
# ## Node
# + info en https://graph.openaire.eu/docs/data-model/entities/research-product

# %%
def openaire_land_researchproduct_pids(df: pd.DataFrame)-> pd.DataFrame:

    load_dt = _pick_load_dt(df)
    
    df_research_pid = df.loc[:,['id','pids']]
    df_research_pid.dropna(inplace=True)
    
    df_research_pid = df_research_pid.explode('pids').reset_index(drop=True)

    df_pid = pd.json_normalize(df_research_pid['pids'])
    
    df_research_pid = pd.concat([df_research_pid['id'], df_pid], axis=1)
    df_research_pid['load_datetime'] = load_dt

    return df_research_pid

# %%
df_research_pid = openaire_land_researchproduct_pids(df)

# %%
df_research_pid
# Out:
# <pre style="white-space:pre;overflow-x:auto;line-height:normal;font-family:Menlo,'DejaVu Sans Mono',consolas,'Courier New',monospace"></pre>
#                                                 id  scheme         value  \
# 0   RECOLECTA___::24cb4438d1afe299e63cfdea4a31911f  handle   10261/97737
# 1   dedup_wf_002::0005b301e367f0fc799b29dc387d3bd1  handle  11336/112574
# ..                                             ...     ...           ...
# 40  dedup_wf_002::00c9e0caebc2510ca2bf89679a107477  handle  11336/151361
# 41  dedup_wf_002::00ca0acaf13ec262a1697b86aa3ecb85  handle   11336/34154
#
#    load_datetime
# 0     2025-09-04
# 1     2025-09-04
# ..           ...
# 40    2025-09-04
# 41    2025-09-04
#
# [42 rows x 4 columns]
