# %%
from datetime import date
import pandas as pd

pd.set_option('display.max_columns', None)
pd.set_option('display.max_rows', 5)

df = catalog.load('raw/openaire/researchproduct_dev#parquet')
# Out:
#                     INFO     Loading data from raw/openaire/researchproduct_dev#parquet         ]8;id=973368;file:///root/kedro-unlp/.venv/lib/python3.10/site-packages/kedro/io/data_catalog.py\data_catalog.py]8;;\:]8;id=965456;file:///root/kedro-unlp/.venv/lib/python3.10/site-packages/kedro/io/data_catalog.py#389\389]8;;\
#                              (ParquetDataset)...

# %%
def _pick_load_dt(df: pd.DataFrame):
    # Si hay una sola fecha en el batch, usala; si hay varias, quedate con la más reciente;
    # si no hay, hoy.
    if 'load_datetime' not in df.columns or df['load_datetime'].isna().all():
        return date.today()
    vals = df['load_datetime'].dropna()
    if vals.nunique() == 1:
        return vals.iloc[0]
    return pd.to_datetime(vals).max().date()

# %%
df_research_instances = df[['id','instances']].explode('instances').reset_index(drop=True)

# %%
df_research_instances
# Out:
# <pre style="white-space:pre;overflow-x:auto;line-height:normal;font-family:Menlo,'DejaVu Sans Mono',consolas,'Courier New',monospace"></pre>
#                                                   id  \
# 0     4dc99724cf04::319dc88111c9b2d6021228590e79130a
# 1     4dc99724cf04::95ea5df70a451a0487e051faa6c0a646
# ...                                              ...
# 2940  dedup_wf_002::037c9fce98a79decd202e1afba75b99e
# 2941  dedup_wf_002::037c9fce98a79decd202e1afba75b99e
#
#                                               instances
# 0     {'accessRight': {'code': 'c_abf2', 'label': 'O...
# 1     {'accessRight': {'code': 'c_abf2', 'label': 'O...
# ...                                                 ...
# 2940  {'accessRight': None, 'alternateIdentifiers': ...
# 2941  {'accessRight': {'code': 'c_abf2', 'label': 'O...
#
# [2942 rows x 2 columns]

# %%
df_research_instances
# Out:
# <pre style="white-space:pre;overflow-x:auto;line-height:normal;font-family:Menlo,'DejaVu Sans Mono',consolas,'Courier New',monospace"></pre>
#                                                   id  \
# 0     4dc99724cf04::319dc88111c9b2d6021228590e79130a
# 1     4dc99724cf04::95ea5df70a451a0487e051faa6c0a646
# ...                                              ...
# 2940  dedup_wf_002::037c9fce98a79decd202e1afba75b99e
# 2941  dedup_wf_002::037c9fce98a79decd202e1afba75b99e
#
#                                               instances
# 0     {'accessRight': {'code': 'c_abf2', 'label': 'O...
# 1     {'accessRight': {'code': 'c_abf2', 'label': 'O...
# ...                                                 ...
# 2940  {'accessRight': None, 'alternateIdentifiers': ...
# 2941  {'accessRight': {'code': 'c_abf2', 'label': 'O...
#
# [2942 rows x 2 columns]

# %%
df_instances = pd.json_normalize(df_research_instances['instances'])
df_research_instances = pd.concat([df_research_instances['id'], df_instances], axis=1)

# %%
df_research_instances
# Out:
# <pre style="white-space:pre;overflow-x:auto;line-height:normal;font-family:Menlo,'DejaVu Sans Mono',consolas,'Courier New',monospace"></pre>
#                                                   id  \
# 0     4dc99724cf04::319dc88111c9b2d6021228590e79130a
# 1     4dc99724cf04::95ea5df70a451a0487e051faa6c0a646
# ...                                              ...
# 2940  dedup_wf_002::037c9fce98a79decd202e1afba75b99e
# 2941  dedup_wf_002::037c9fce98a79decd202e1afba75b99e
#
#                                    alternateIdentifiers      license  pids  \
# 0     [{'scheme': 'doi', 'value': '10.15381/rivep.v3...        CC BY  None
# 1     [{'scheme': 'doi', 'value': '10.15381/rivep.v3...        CC BY  None
# ...                                                 ...          ...   ...
# 2940                                               None         None  None
# 2941                                               None  CC BY NC SA  None
#
#      publicationDate         refereed     type  \
# 0         2022-08-31  nonPeerReviewed  Article
# 1         2023-12-18  nonPeerReviewed  Article
# ...              ...              ...      ...
# 2940      2007-01-01  nonPeerReviewed  Article
# 2941      2007-01-01  nonPeerReviewed  Article
#
#                                                    urls accessRight.code  \
# 0     [https://revistasinvestigacion.unmsm.edu.pe/in...           c_abf2
# 1     [https://revistasinvestigacion.unmsm.edu.pe/in...           c_abf2
# ...                                                 ...              ...
# 2940      [http://sedici.unlp.edu.ar/handle/10915/9942]              NaN
# 2941      [http://sedici.unlp.edu.ar/handle/10915/9942]           c_abf2
#
#      accessRight.label accessRight.openAccessRoute  \
# 0                 OPEN                        gold
# 1                 OPEN                        gold
# ...                ...                         ...
# 2940               NaN                         NaN
# 2941              OPEN                        None
#
#                                      accessRight.scheme  \
# 0     http://vocabularies.coar-repositories.org/docu...
# 1     http://vocabularies.coar-repositories.org/docu...
# ...                                                 ...
# 2940                                                NaN
# 2941  http://vocabularies.coar-repositories.org/docu...
#
#                                    collectedFrom.key  \
# 0     openaire____::0b74b6a356bbf23c245f9ae9a748745c
# 1     openaire____::0b74b6a356bbf23c245f9ae9a748745c
# ...                                              ...
# 2940  opendoar____::01e9565cecc4e989123f9620c1d09c09
# 2941  opendoar____::dc6e224a8d74ce03bf301152d6e33e97
#
#                                     collectedFrom.value  \
# 0     Revistas de investigación Universidad Nacional...
# 1     Revistas de investigación Universidad Nacional...
# ...                                                 ...
# 2940    Servicio de Difusión de la Creación Intelectual
# 2941  LAReferencia - Red Federada de Repositorios In...
#
#                                         hostedBy.key  \
# 0     doajarticles::7ddb9c3989849c068ee96705dba3766f
# 1     doajarticles::7ddb9c3989849c068ee96705dba3766f
# ...                                              ...
# 2940  opendoar____::01e9565cecc4e989123f9620c1d09c09
# 2941  opendoar____::dc6e224a8d74ce03bf301152d6e33e97
#
#                                          hostedBy.value  accessRight
# 0      Revista de Investigaciones Veterinarias del Perú          NaN
# 1      Revista de Investigaciones Veterinarias del Perú          NaN
# ...                                                 ...          ...
# 2940    Servicio de Difusión de la Creación Intelectual          NaN
# 2941  LAReferencia - Red Federada de Repositorios In...          NaN
#
# [2942 rows x 17 columns]

# %%
df_research_instances = df_research_instances.explode('pids').reset_index(drop=True)

# %%
df_research_instances
# Out:
# <pre style="white-space:pre;overflow-x:auto;line-height:normal;font-family:Menlo,'DejaVu Sans Mono',consolas,'Courier New',monospace"></pre>
#                                                   id  \
# 0     4dc99724cf04::319dc88111c9b2d6021228590e79130a
# 1     4dc99724cf04::95ea5df70a451a0487e051faa6c0a646
# ...                                              ...
# 2949  dedup_wf_002::037c9fce98a79decd202e1afba75b99e
# 2950  dedup_wf_002::037c9fce98a79decd202e1afba75b99e
#
#                                    alternateIdentifiers      license  pids  \
# 0     [{'scheme': 'doi', 'value': '10.15381/rivep.v3...        CC BY  None
# 1     [{'scheme': 'doi', 'value': '10.15381/rivep.v3...        CC BY  None
# ...                                                 ...          ...   ...
# 2949                                               None         None  None
# 2950                                               None  CC BY NC SA  None
#
#      publicationDate         refereed     type  \
# 0         2022-08-31  nonPeerReviewed  Article
# 1         2023-12-18  nonPeerReviewed  Article
# ...              ...              ...      ...
# 2949      2007-01-01  nonPeerReviewed  Article
# 2950      2007-01-01  nonPeerReviewed  Article
#
#                                                    urls accessRight.code  \
# 0     [https://revistasinvestigacion.unmsm.edu.pe/in...           c_abf2
# 1     [https://revistasinvestigacion.unmsm.edu.pe/in...           c_abf2
# ...                                                 ...              ...
# 2949      [http://sedici.unlp.edu.ar/handle/10915/9942]              NaN
# 2950      [http://sedici.unlp.edu.ar/handle/10915/9942]           c_abf2
#
#      accessRight.label accessRight.openAccessRoute  \
# 0                 OPEN                        gold
# 1                 OPEN                        gold
# ...                ...                         ...
# 2949               NaN                         NaN
# 2950              OPEN                        None
#
#                                      accessRight.scheme  \
# 0     http://vocabularies.coar-repositories.org/docu...
# 1     http://vocabularies.coar-repositories.org/docu...
# ...                                                 ...
# 2949                                                NaN
# 2950  http://vocabularies.coar-repositories.org/docu...
#
#                                    collectedFrom.key  \
# 0     openaire____::0b74b6a356bbf23c245f9ae9a748745c
# 1     openaire____::0b74b6a356bbf23c245f9ae9a748745c
# ...                                              ...
# 2949  opendoar____::01e9565cecc4e989123f9620c1d09c09
# 2950  opendoar____::dc6e224a8d74ce03bf301152d6e33e97
#
#                                     collectedFrom.value  \
# 0     Revistas de investigación Universidad Nacional...
# 1     Revistas de investigación Universidad Nacional...
# ...                                                 ...
# 2949    Servicio de Difusión de la Creación Intelectual
# 2950  LAReferencia - Red Federada de Repositorios In...
#
#                                         hostedBy.key  \
# 0     doajarticles::7ddb9c3989849c068ee96705dba3766f
# 1     doajarticles::7ddb9c3989849c068ee96705dba3766f
# ...                                              ...
# 2949  opendoar____::01e9565cecc4e989123f9620c1d09c09
# 2950  opendoar____::dc6e224a8d74ce03bf301152d6e33e97
#
#                                          hostedBy.value  accessRight
# 0      Revista de Investigaciones Veterinarias del Perú          NaN
# 1      Revista de Investigaciones Veterinarias del Perú          NaN
# ...                                                 ...          ...
# 2949    Servicio de Difusión de la Creación Intelectual          NaN
# 2950  LAReferencia - Red Federada de Repositorios In...          NaN
#
# [2951 rows x 17 columns]

# %%
df_research_instances = df_research_instances.explode('urls').reset_index(drop=True)

# %%
df_research_instances
# Out:
# <pre style="white-space:pre;overflow-x:auto;line-height:normal;font-family:Menlo,'DejaVu Sans Mono',consolas,'Courier New',monospace"></pre>
#                                                   id  \
# 0     4dc99724cf04::319dc88111c9b2d6021228590e79130a
# 1     4dc99724cf04::95ea5df70a451a0487e051faa6c0a646
# ...                                              ...
# 3094  dedup_wf_002::037c9fce98a79decd202e1afba75b99e
# 3095  dedup_wf_002::037c9fce98a79decd202e1afba75b99e
#
#                                    alternateIdentifiers      license  pids  \
# 0     [{'scheme': 'doi', 'value': '10.15381/rivep.v3...        CC BY  None
# 1     [{'scheme': 'doi', 'value': '10.15381/rivep.v3...        CC BY  None
# ...                                                 ...          ...   ...
# 3094                                               None         None  None
# 3095                                               None  CC BY NC SA  None
#
#      publicationDate         refereed     type  \
# 0         2022-08-31  nonPeerReviewed  Article
# 1         2023-12-18  nonPeerReviewed  Article
# ...              ...              ...      ...
# 3094      2007-01-01  nonPeerReviewed  Article
# 3095      2007-01-01  nonPeerReviewed  Article
#
#                                                    urls accessRight.code  \
# 0     https://revistasinvestigacion.unmsm.edu.pe/ind...           c_abf2
# 1     https://revistasinvestigacion.unmsm.edu.pe/ind...           c_abf2
# ...                                                 ...              ...
# 3094        http://sedici.unlp.edu.ar/handle/10915/9942              NaN
# 3095        http://sedici.unlp.edu.ar/handle/10915/9942           c_abf2
#
#      accessRight.label accessRight.openAccessRoute  \
# 0                 OPEN                        gold
# 1                 OPEN                        gold
# ...                ...                         ...
# 3094               NaN                         NaN
# 3095              OPEN                        None
#
#                                      accessRight.scheme  \
# 0     http://vocabularies.coar-repositories.org/docu...
# 1     http://vocabularies.coar-repositories.org/docu...
# ...                                                 ...
# 3094                                                NaN
# 3095  http://vocabularies.coar-repositories.org/docu...
#
#                                    collectedFrom.key  \
# 0     openaire____::0b74b6a356bbf23c245f9ae9a748745c
# 1     openaire____::0b74b6a356bbf23c245f9ae9a748745c
# ...                                              ...
# 3094  opendoar____::01e9565cecc4e989123f9620c1d09c09
# 3095  opendoar____::dc6e224a8d74ce03bf301152d6e33e97
#
#                                     collectedFrom.value  \
# 0     Revistas de investigación Universidad Nacional...
# 1     Revistas de investigación Universidad Nacional...
# ...                                                 ...
# 3094    Servicio de Difusión de la Creación Intelectual
# 3095  LAReferencia - Red Federada de Repositorios In...
#
#                                         hostedBy.key  \
# 0     doajarticles::7ddb9c3989849c068ee96705dba3766f
# 1     doajarticles::7ddb9c3989849c068ee96705dba3766f
# ...                                              ...
# 3094  opendoar____::01e9565cecc4e989123f9620c1d09c09
# 3095  opendoar____::dc6e224a8d74ce03bf301152d6e33e97
#
#                                          hostedBy.value  accessRight
# 0      Revista de Investigaciones Veterinarias del Perú          NaN
# 1      Revista de Investigaciones Veterinarias del Perú          NaN
# ...                                                 ...          ...
# 3094    Servicio de Difusión de la Creación Intelectual          NaN
# 3095  LAReferencia - Red Federada de Repositorios In...          NaN
#
# [3096 rows x 17 columns]

# %%
df_pids = pd.json_normalize(df_research_instances['pids'])
df_research_instances = df_research_instances.drop(columns=['pids'])
df_research_instances = pd.concat([df_research_instances, df_pids], axis=1)

# %%
df_research_instances
# Out:
# <pre style="white-space:pre;overflow-x:auto;line-height:normal;font-family:Menlo,'DejaVu Sans Mono',consolas,'Courier New',monospace"></pre>
#                                                   id  \
# 0     4dc99724cf04::319dc88111c9b2d6021228590e79130a
# 1     4dc99724cf04::95ea5df70a451a0487e051faa6c0a646
# ...                                              ...
# 3094  dedup_wf_002::037c9fce98a79decd202e1afba75b99e
# 3095  dedup_wf_002::037c9fce98a79decd202e1afba75b99e
#
#                                    alternateIdentifiers      license  \
# 0     [{'scheme': 'doi', 'value': '10.15381/rivep.v3...        CC BY
# 1     [{'scheme': 'doi', 'value': '10.15381/rivep.v3...        CC BY
# ...                                                 ...          ...
# 3094                                               None         None
# 3095                                               None  CC BY NC SA
#
#      publicationDate         refereed     type  \
# 0         2022-08-31  nonPeerReviewed  Article
# 1         2023-12-18  nonPeerReviewed  Article
# ...              ...              ...      ...
# 3094      2007-01-01  nonPeerReviewed  Article
# 3095      2007-01-01  nonPeerReviewed  Article
#
#                                                    urls accessRight.code  \
# 0     https://revistasinvestigacion.unmsm.edu.pe/ind...           c_abf2
# 1     https://revistasinvestigacion.unmsm.edu.pe/ind...           c_abf2
# ...                                                 ...              ...
# 3094        http://sedici.unlp.edu.ar/handle/10915/9942              NaN
# 3095        http://sedici.unlp.edu.ar/handle/10915/9942           c_abf2
#
#      accessRight.label accessRight.openAccessRoute  \
# 0                 OPEN                        gold
# 1                 OPEN                        gold
# ...                ...                         ...
# 3094               NaN                         NaN
# 3095              OPEN                        None
#
#                                      accessRight.scheme  \
# 0     http://vocabularies.coar-repositories.org/docu...
# 1     http://vocabularies.coar-repositories.org/docu...
# ...                                                 ...
# 3094                                                NaN
# 3095  http://vocabularies.coar-repositories.org/docu...
#
#                                    collectedFrom.key  \
# 0     openaire____::0b74b6a356bbf23c245f9ae9a748745c
# 1     openaire____::0b74b6a356bbf23c245f9ae9a748745c
# ...                                              ...
# 3094  opendoar____::01e9565cecc4e989123f9620c1d09c09
# 3095  opendoar____::dc6e224a8d74ce03bf301152d6e33e97
#
#                                     collectedFrom.value  \
# 0     Revistas de investigación Universidad Nacional...
# 1     Revistas de investigación Universidad Nacional...
# ...                                                 ...
# 3094    Servicio de Difusión de la Creación Intelectual
# 3095  LAReferencia - Red Federada de Repositorios In...
#
#                                         hostedBy.key  \
# 0     doajarticles::7ddb9c3989849c068ee96705dba3766f
# 1     doajarticles::7ddb9c3989849c068ee96705dba3766f
# ...                                              ...
# 3094  opendoar____::01e9565cecc4e989123f9620c1d09c09
# 3095  opendoar____::dc6e224a8d74ce03bf301152d6e33e97
#
#                                          hostedBy.value  accessRight scheme  \
# 0      Revista de Investigaciones Veterinarias del Perú          NaN    NaN
# 1      Revista de Investigaciones Veterinarias del Perú          NaN    NaN
# ...                                                 ...          ...    ...
# 3094    Servicio de Difusión de la Creación Intelectual          NaN    NaN
# 3095  LAReferencia - Red Federada de Repositorios In...          NaN    NaN
#
#      value
# 0      NaN
# 1      NaN
# ...    ...
# 3094   NaN
# 3095   NaN
#
# [3096 rows x 18 columns]

# %%
df_research_alternateidentifiers = df_research_instances[['id','alternateIdentifiers']].dropna().explode('alternateIdentifiers').reset_index(drop=True)
df_alternateidentifiers = pd.json_normalize(df_research_alternateidentifiers['alternateIdentifiers'])
df_research_alternateidentifiers = pd.concat([df_research_alternateidentifiers['id'], df_alternateidentifiers], axis=1)

# %%
df_research_alternateidentifiers
# Out:
# <pre style="white-space:pre;overflow-x:auto;line-height:normal;font-family:Menlo,'DejaVu Sans Mono',consolas,'Courier New',monospace"></pre>
#                                                  id scheme  \
# 0    4dc99724cf04::319dc88111c9b2d6021228590e79130a    doi
# 1    4dc99724cf04::95ea5df70a451a0487e051faa6c0a646    doi
# ..                                              ...    ...
# 208  dedup_wf_002::0304102ae00eec44a7108bfa0c70d71a  arXiv
# 209  dedup_wf_002::0304102ae00eec44a7108bfa0c70d71a  arXiv
#
#                           value
# 0    10.15381/rivep.v33i4.21901
# 1    10.15381/rivep.v34i6.25240
# ..                          ...
# 208                   1412.0237
# 209                   1412.0237
#
# [210 rows x 3 columns]

# %%
df_research_instances.drop(columns=['alternateIdentifiers'], inplace=True)

# %%
df_research_instances
# Out:
# <pre style="white-space:pre;overflow-x:auto;line-height:normal;font-family:Menlo,'DejaVu Sans Mono',consolas,'Courier New',monospace"></pre>
#                                                   id      license  \
# 0     4dc99724cf04::319dc88111c9b2d6021228590e79130a        CC BY
# 1     4dc99724cf04::95ea5df70a451a0487e051faa6c0a646        CC BY
# ...                                              ...          ...
# 3094  dedup_wf_002::037c9fce98a79decd202e1afba75b99e         None
# 3095  dedup_wf_002::037c9fce98a79decd202e1afba75b99e  CC BY NC SA
#
#      publicationDate         refereed     type  \
# 0         2022-08-31  nonPeerReviewed  Article
# 1         2023-12-18  nonPeerReviewed  Article
# ...              ...              ...      ...
# 3094      2007-01-01  nonPeerReviewed  Article
# 3095      2007-01-01  nonPeerReviewed  Article
#
#                                                    urls accessRight.code  \
# 0     https://revistasinvestigacion.unmsm.edu.pe/ind...           c_abf2
# 1     https://revistasinvestigacion.unmsm.edu.pe/ind...           c_abf2
# ...                                                 ...              ...
# 3094        http://sedici.unlp.edu.ar/handle/10915/9942              NaN
# 3095        http://sedici.unlp.edu.ar/handle/10915/9942           c_abf2
#
#      accessRight.label accessRight.openAccessRoute  \
# 0                 OPEN                        gold
# 1                 OPEN                        gold
# ...                ...                         ...
# 3094               NaN                         NaN
# 3095              OPEN                        None
#
#                                      accessRight.scheme  \
# 0     http://vocabularies.coar-repositories.org/docu...
# 1     http://vocabularies.coar-repositories.org/docu...
# ...                                                 ...
# 3094                                                NaN
# 3095  http://vocabularies.coar-repositories.org/docu...
#
#                                    collectedFrom.key  \
# 0     openaire____::0b74b6a356bbf23c245f9ae9a748745c
# 1     openaire____::0b74b6a356bbf23c245f9ae9a748745c
# ...                                              ...
# 3094  opendoar____::01e9565cecc4e989123f9620c1d09c09
# 3095  opendoar____::dc6e224a8d74ce03bf301152d6e33e97
#
#                                     collectedFrom.value  \
# 0     Revistas de investigación Universidad Nacional...
# 1     Revistas de investigación Universidad Nacional...
# ...                                                 ...
# 3094    Servicio de Difusión de la Creación Intelectual
# 3095  LAReferencia - Red Federada de Repositorios In...
#
#                                         hostedBy.key  \
# 0     doajarticles::7ddb9c3989849c068ee96705dba3766f
# 1     doajarticles::7ddb9c3989849c068ee96705dba3766f
# ...                                              ...
# 3094  opendoar____::01e9565cecc4e989123f9620c1d09c09
# 3095  opendoar____::dc6e224a8d74ce03bf301152d6e33e97
#
#                                          hostedBy.value  accessRight scheme  \
# 0      Revista de Investigaciones Veterinarias del Perú          NaN    NaN
# 1      Revista de Investigaciones Veterinarias del Perú          NaN    NaN
# ...                                                 ...          ...    ...
# 3094    Servicio de Difusión de la Creación Intelectual          NaN    NaN
# 3095  LAReferencia - Red Federada de Repositorios In...          NaN    NaN
#
#      value
# 0      NaN
# 1      NaN
# ...    ...
# 3094   NaN
# 3095   NaN
#
# [3096 rows x 17 columns]

# %% [markdown]
# ## Paso 1: Convierto tipos y selecciono columnas con cardinalidad 1 con respecto a cada research product
# + info en https://graph.openaire.eu/docs/data-model/entities/research-product

# %%
def openaire_land_researchproduct_instances(df: pd.DataFrame)-> pd.DataFrame:

    load_dt = _pick_load_dt(df)

    df_research_instances = df[['id','instances']].explode('instances').reset_index(drop=True)

    df_instances = pd.json_normalize(df_research_instances['instances'])
    df_research_instances = pd.concat([df_research_instances['id'], df_instances], axis=1)

    df_research_instances = df_research_instances.explode('pids').reset_index(drop=True)

    df_research_instances = df_research_instances.explode('urls').reset_index(drop=True)

    df_pids = pd.json_normalize(df_research_instances['pids'])
    df_research_instances = df_research_instances.drop(columns=['pids'])

    df_research_instances = pd.concat([df_research_instances, df_pids], axis=1)

    df_research_alternateidentifiers = df_research_instances[['id','alternateIdentifiers']].dropna().explode('alternateIdentifiers').reset_index(drop=True)
    df_alternateidentifiers = pd.json_normalize(df_research_alternateidentifiers['alternateIdentifiers'])
    df_research_alternateidentifiers = pd.concat([df_research_alternateidentifiers['id'], df_alternateidentifiers], axis=1)

    df_research_instances.drop(columns=['alternateIdentifiers'], inplace=True)

    df_research_instances['load_datetime'] = load_dt
    df_research_alternateidentifiers['load_datetime'] = load_dt

    return df_research_instances, df_research_alternateidentifiers

# %%
df_research_instances, df_research_alternateidentifiers = openaire_land_researchproduct_instances(df)

# %%
df_research_instances
# Out:
# <pre style="white-space:pre;overflow-x:auto;line-height:normal;font-family:Menlo,'DejaVu Sans Mono',consolas,'Courier New',monospace"></pre>
#                                                   id      license  \
# 0     4dc99724cf04::319dc88111c9b2d6021228590e79130a        CC BY
# 1     4dc99724cf04::95ea5df70a451a0487e051faa6c0a646        CC BY
# ...                                              ...          ...
# 3094  dedup_wf_002::037c9fce98a79decd202e1afba75b99e         None
# 3095  dedup_wf_002::037c9fce98a79decd202e1afba75b99e  CC BY NC SA
#
#      publicationDate         refereed     type  \
# 0         2022-08-31  nonPeerReviewed  Article
# 1         2023-12-18  nonPeerReviewed  Article
# ...              ...              ...      ...
# 3094      2007-01-01  nonPeerReviewed  Article
# 3095      2007-01-01  nonPeerReviewed  Article
#
#                                                    urls accessRight.code  \
# 0     https://revistasinvestigacion.unmsm.edu.pe/ind...           c_abf2
# 1     https://revistasinvestigacion.unmsm.edu.pe/ind...           c_abf2
# ...                                                 ...              ...
# 3094        http://sedici.unlp.edu.ar/handle/10915/9942              NaN
# 3095        http://sedici.unlp.edu.ar/handle/10915/9942           c_abf2
#
#      accessRight.label accessRight.openAccessRoute  \
# 0                 OPEN                        gold
# 1                 OPEN                        gold
# ...                ...                         ...
# 3094               NaN                         NaN
# 3095              OPEN                        None
#
#                                      accessRight.scheme  \
# 0     http://vocabularies.coar-repositories.org/docu...
# 1     http://vocabularies.coar-repositories.org/docu...
# ...                                                 ...
# 3094                                                NaN
# 3095  http://vocabularies.coar-repositories.org/docu...
#
#                                    collectedFrom.key  \
# 0     openaire____::0b74b6a356bbf23c245f9ae9a748745c
# 1     openaire____::0b74b6a356bbf23c245f9ae9a748745c
# ...                                              ...
# 3094  opendoar____::01e9565cecc4e989123f9620c1d09c09
# 3095  opendoar____::dc6e224a8d74ce03bf301152d6e33e97
#
#                                     collectedFrom.value  \
# 0     Revistas de investigación Universidad Nacional...
# 1     Revistas de investigación Universidad Nacional...
# ...                                                 ...
# 3094    Servicio de Difusión de la Creación Intelectual
# 3095  LAReferencia - Red Federada de Repositorios In...
#
#                                         hostedBy.key  \
# 0     doajarticles::7ddb9c3989849c068ee96705dba3766f
# 1     doajarticles::7ddb9c3989849c068ee96705dba3766f
# ...                                              ...
# 3094  opendoar____::01e9565cecc4e989123f9620c1d09c09
# 3095  opendoar____::dc6e224a8d74ce03bf301152d6e33e97
#
#                                          hostedBy.value  accessRight scheme  \
# 0      Revista de Investigaciones Veterinarias del Perú          NaN    NaN
# 1      Revista de Investigaciones Veterinarias del Perú          NaN    NaN
# ...                                                 ...          ...    ...
# 3094    Servicio de Difusión de la Creación Intelectual          NaN    NaN
# 3095  LAReferencia - Red Federada de Repositorios In...          NaN    NaN
#
#      value load_datetime
# 0      NaN    2025-09-05
# 1      NaN    2025-09-05
# ...    ...           ...
# 3094   NaN    2025-09-05
# 3095   NaN    2025-09-05
#
# [3096 rows x 18 columns]

# %%
df_research_alternateidentifiers
# Out:
# <pre style="white-space:pre;overflow-x:auto;line-height:normal;font-family:Menlo,'DejaVu Sans Mono',consolas,'Courier New',monospace"></pre>
#                                                  id scheme  \
# 0    4dc99724cf04::319dc88111c9b2d6021228590e79130a    doi
# 1    4dc99724cf04::95ea5df70a451a0487e051faa6c0a646    doi
# ..                                              ...    ...
# 208  dedup_wf_002::0304102ae00eec44a7108bfa0c70d71a  arXiv
# 209  dedup_wf_002::0304102ae00eec44a7108bfa0c70d71a  arXiv
#
#                           value load_datetime
# 0    10.15381/rivep.v33i4.21901    2025-09-05
# 1    10.15381/rivep.v34i6.25240    2025-09-05
# ..                          ...           ...
# 208                   1412.0237    2025-09-05
# 209                   1412.0237    2025-09-05
#
# [210 rows x 4 columns]
