# %%
from datetime import date
import pandas as pd

pd.set_option('display.max_columns', None)
pd.set_option('display.max_rows', 5)

df = catalog.load('raw/openaire/researchproduct_dev#parquet')
# Out:
#                     INFO     Loading data from raw/openaire/researchproduct_dev#parquet         ]8;id=980289;file:///root/kedro-unlp/.venv/lib/python3.10/site-packages/kedro/io/data_catalog.py\data_catalog.py]8;;\:]8;id=673276;file:///root/kedro-unlp/.venv/lib/python3.10/site-packages/kedro/io/data_catalog.py#389\389]8;;\
#                              (ParquetDataset)...

# %%
def _pick_load_dt(df: pd.DataFrame):
    # Si hay una sola fecha en el batch, usala; si hay varias, quedate con la más reciente;
    # si no hay, hoy.
    if 'load_datetime' not in df.columns or df['load_datetime'].isna().all():
        return date.today()
    vals = df['load_datetime'].dropna()
    if vals.nunique() == 1:
        return vals.iloc[0]
    return pd.to_datetime(vals).max().date()

# %%
df_research_subjects = df.loc[:,['id','subjects']]
df_research_subjects.dropna(inplace=True)
# Out:
#                     WARNING  /tmp/ipykernel_3430655/583825167.py:2: SettingWithCopyWarning:         ]8;id=618419;file:///root/.pyenv/versions/3.10.12/lib/python3.10/warnings.py\warnings.py]8;;\:]8;id=732149;file:///root/.pyenv/versions/3.10.12/lib/python3.10/warnings.py#109\109]8;;\
#                              A value is trying to be set on a copy of a slice from a DataFrame
#
#                              See the caveats in the documentation:
#                              https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#
#                              returning-a-view-versus-a-copy
#                                df_research_subjects.dropna(inplace=True)

# %%
df_research_subjects
# Out:
# <pre style="white-space:pre;overflow-x:auto;line-height:normal;font-family:Menlo,'DejaVu Sans Mono',consolas,'Courier New',monospace"></pre>
#                                                  id  \
# 0    4dc99724cf04::319dc88111c9b2d6021228590e79130a
# 1    4dc99724cf04::95ea5df70a451a0487e051faa6c0a646
# 2    4dc99724cf04::fd4ac9e4a4b67e70441e5d033c144e1e
# 3    RECOLECTA___::24cb4438d1afe299e63cfdea4a31911f
# 4    RECOLECTA___::c5f9bd7b9739f4c5f064595b286d2e01
# ..                                              ...
# 995  dedup_wf_002::037a11b75e1662b0beb84c3b97f47ce1
# 996  dedup_wf_002::037a8383ee10ffcebea2e3102e3fa6ce
# 997  dedup_wf_002::037ba1ff4a8a10f7948e078bb3d6efb6
# 998  dedup_wf_002::037c3a3ae3212005fc63e98d8378595c
# 999  dedup_wf_002::037c9fce98a79decd202e1afba75b99e
#
#                                               subjects
# 0    [{'provenance': None, 'subject': {'scheme': 'k...
# 1    [{'provenance': None, 'subject': {'scheme': 'k...
# 2    [{'provenance': None, 'subject': {'scheme': 'k...
# 3    [{'provenance': None, 'subject': {'scheme': 'k...
# 4    [{'provenance': None, 'subject': {'scheme': 'k...
# ..                                                 ...
# 995  [{'provenance': None, 'subject': {'scheme': 'k...
# 996  [{'provenance': None, 'subject': {'scheme': 'k...
# 997  [{'provenance': None, 'subject': {'scheme': 'k...
# 998  [{'provenance': None, 'subject': {'scheme': 'k...
# 999  [{'provenance': None, 'subject': {'scheme': 'k...
#
# [1000 rows x 2 columns]

# %%
df_research_subjects = df_research_subjects.explode('subjects').reset_index(drop=True)

# %%
df_research_subjects
# Out:
# <pre style="white-space:pre;overflow-x:auto;line-height:normal;font-family:Menlo,'DejaVu Sans Mono',consolas,'Courier New',monospace"></pre>
#                                                   id  \
# 0     4dc99724cf04::319dc88111c9b2d6021228590e79130a
# 1     4dc99724cf04::319dc88111c9b2d6021228590e79130a
# 2     4dc99724cf04::319dc88111c9b2d6021228590e79130a
# 3     4dc99724cf04::319dc88111c9b2d6021228590e79130a
# 4     4dc99724cf04::319dc88111c9b2d6021228590e79130a
# ...                                              ...
# 7522  dedup_wf_002::037c9fce98a79decd202e1afba75b99e
# 7523  dedup_wf_002::037c9fce98a79decd202e1afba75b99e
# 7524  dedup_wf_002::037c9fce98a79decd202e1afba75b99e
# 7525  dedup_wf_002::037c9fce98a79decd202e1afba75b99e
# 7526  dedup_wf_002::037c9fce98a79decd202e1afba75b99e
#
#                                                subjects
# 0     {'provenance': None, 'subject': {'scheme': 'ke...
# 1     {'provenance': None, 'subject': {'scheme': 'ke...
# 2     {'provenance': None, 'subject': {'scheme': 'ke...
# 3     {'provenance': None, 'subject': {'scheme': 'ke...
# 4     {'provenance': None, 'subject': {'scheme': 'ke...
# ...                                                 ...
# 7522  {'provenance': None, 'subject': {'scheme': 'ke...
# 7523  {'provenance': None, 'subject': {'scheme': 'ke...
# 7524  {'provenance': None, 'subject': {'scheme': 'ke...
# 7525  {'provenance': None, 'subject': {'scheme': 'ke...
# 7526  {'provenance': None, 'subject': {'scheme': 'ke...
#
# [7527 rows x 2 columns]

# %%
df_subjects = pd.json_normalize(df_research_subjects['subjects'])
df_research_subjects = pd.concat([df_research_subjects['id'], df_subjects],axis=1)

# %%
df_research_subjects
# Out:
# <pre style="white-space:pre;overflow-x:auto;line-height:normal;font-family:Menlo,'DejaVu Sans Mono',consolas,'Courier New',monospace"></pre>
#                                                   id provenance  \
# 0     4dc99724cf04::319dc88111c9b2d6021228590e79130a       None
# 1     4dc99724cf04::319dc88111c9b2d6021228590e79130a       None
# 2     4dc99724cf04::319dc88111c9b2d6021228590e79130a       None
# 3     4dc99724cf04::319dc88111c9b2d6021228590e79130a       None
# 4     4dc99724cf04::319dc88111c9b2d6021228590e79130a       None
# ...                                              ...        ...
# 7522  dedup_wf_002::037c9fce98a79decd202e1afba75b99e       None
# 7523  dedup_wf_002::037c9fce98a79decd202e1afba75b99e       None
# 7524  dedup_wf_002::037c9fce98a79decd202e1afba75b99e       None
# 7525  dedup_wf_002::037c9fce98a79decd202e1afba75b99e       None
# 7526  dedup_wf_002::037c9fce98a79decd202e1afba75b99e       None
#
#      subject.scheme               subject.value
# 0           keyword                     pigeons
# 1           keyword               polinizadores
# 2           keyword               dicistrovirus
# 3           keyword                 pollinators
# 4           keyword                     palomas
# ...             ...                         ...
# 7522        keyword     International relations
# 7523        keyword           Political science
# 7524        keyword  Relaciones Internacionales
# 7525        keyword                    JZ2-6530
# 7526        keyword                           J
#
# [7527 rows x 4 columns]

# %% [markdown]
# ## Paso 1: Convierto tipos y selecciono columnas con cardinalidad 1 con respecto a cada research product
# + info en https://graph.openaire.eu/docs/data-model/entities/research-product

# %%
def openaire_land_researchproduct_subjects(df: pd.DataFrame)-> pd.DataFrame:

    load_dt = _pick_load_dt(df)

    df_research_subjects = df.loc[:,['id','subjects']]
    df_research_subjects.dropna(inplace=True)

    df_research_subjects = df_research_subjects.explode('subjects').reset_index(drop=True)

    df_subjects = pd.json_normalize(df_research_subjects['subjects'])
    df_research_subjects = pd.concat([df_research_subjects['id'], df_subjects],axis=1)

    df_research_subjects['load_datetime'] = load_dt

    return df_research_subjects

# %%
df_research_subjects = openaire_land_researchproduct_subjects(df)
# Out:
# [09/08/25 11:07:52] WARNING  /tmp/ipykernel_3430655/2516393576.py:7: SettingWithCopyWarning:        ]8;id=227498;file:///root/.pyenv/versions/3.10.12/lib/python3.10/warnings.py\warnings.py]8;;\:]8;id=464299;file:///root/.pyenv/versions/3.10.12/lib/python3.10/warnings.py#109\109]8;;\
#                              A value is trying to be set on a copy of a slice from a DataFrame
#
#                              See the caveats in the documentation:
#                              https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#
#                              returning-a-view-versus-a-copy
#                                df_research_subjects.dropna(inplace=True)

# %%
df_research_subjects
# Out:
# <pre style="white-space:pre;overflow-x:auto;line-height:normal;font-family:Menlo,'DejaVu Sans Mono',consolas,'Courier New',monospace"></pre>
#                                                   id provenance  \
# 0     4dc99724cf04::319dc88111c9b2d6021228590e79130a       None
# 1     4dc99724cf04::319dc88111c9b2d6021228590e79130a       None
# 2     4dc99724cf04::319dc88111c9b2d6021228590e79130a       None
# 3     4dc99724cf04::319dc88111c9b2d6021228590e79130a       None
# 4     4dc99724cf04::319dc88111c9b2d6021228590e79130a       None
# ...                                              ...        ...
# 7522  dedup_wf_002::037c9fce98a79decd202e1afba75b99e       None
# 7523  dedup_wf_002::037c9fce98a79decd202e1afba75b99e       None
# 7524  dedup_wf_002::037c9fce98a79decd202e1afba75b99e       None
# 7525  dedup_wf_002::037c9fce98a79decd202e1afba75b99e       None
# 7526  dedup_wf_002::037c9fce98a79decd202e1afba75b99e       None
#
#      subject.scheme               subject.value load_datetime
# 0           keyword                     pigeons    2025-09-05
# 1           keyword               polinizadores    2025-09-05
# 2           keyword               dicistrovirus    2025-09-05
# 3           keyword                 pollinators    2025-09-05
# 4           keyword                     palomas    2025-09-05
# ...             ...                         ...           ...
# 7522        keyword     International relations    2025-09-05
# 7523        keyword           Political science    2025-09-05
# 7524        keyword  Relaciones Internacionales    2025-09-05
# 7525        keyword                    JZ2-6530    2025-09-05
# 7526        keyword                           J    2025-09-05
#
# [7527 rows x 5 columns]
