# %%
from datetime import date
import pandas as pd

pd.set_option('display.max_columns', None)

filter_param = catalog.load('params:openaire_fetch_options.filter_param')
filter_value = catalog.load('params:openaire_fetch_options.filter_value')
df = catalog.load('raw/openaire/researchproduct#parquet')
df_ldg = catalog.load('ldg/openaire/researchproduct')
# Out:
#                     INFO     Loading data from params:openaire_fetch_options.filter_param       ]8;id=377346;file:///root/kedro-unlp/.venv/lib/python3.10/site-packages/kedro/io/data_catalog.py\data_catalog.py]8;;\:]8;id=750510;file:///root/kedro-unlp/.venv/lib/python3.10/site-packages/kedro/io/data_catalog.py#389\389]8;;\
#                              (MemoryDataset)...
#                     INFO     Loading data from params:openaire_fetch_options.filter_value       ]8;id=786250;file:///root/kedro-unlp/.venv/lib/python3.10/site-packages/kedro/io/data_catalog.py\data_catalog.py]8;;\:]8;id=925040;file:///root/kedro-unlp/.venv/lib/python3.10/site-packages/kedro/io/data_catalog.py#389\389]8;;\
#                              (MemoryDataset)...
#                     INFO     Loading data from raw/openaire/researchproduct#parquet             ]8;id=218470;file:///root/kedro-unlp/.venv/lib/python3.10/site-packages/kedro/io/data_catalog.py\data_catalog.py]8;;\:]8;id=688250;file:///root/kedro-unlp/.venv/lib/python3.10/site-packages/kedro/io/data_catalog.py#389\389]8;;\
#                              (ParquetDataset)...
# [06/26/25 11:55:15] INFO     Loading data from ldg/openaire/researchproduct                     ]8;id=367173;file:///root/kedro-unlp/.venv/lib/python3.10/site-packages/kedro/io/data_catalog.py\data_catalog.py]8;;\:]8;id=120896;file:///root/kedro-unlp/.venv/lib/python3.10/site-packages/kedro/io/data_catalog.py#389\389]8;;\
#                              (SQLTableDataset)...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 192664 entries, 0 to 192663
# Data columns (total 45 columns):
#  #   Column               Non-Null Count   Dtype
# ---  ------               --------------   -----
#  0   authors              192462 non-null  object
#  1   openAccessColor      47527 non-null   object
#  2   publiclyFunded       127812 non-null  object
#  3   type                 192664 non-null  object
#  4   language             192664 non-null  object
#  5   countries            173312 non-null  object
#  6   subjects             188762 non-null  object
#  7   mainTitle            192663 non-null  object
#  8   subTitle             0 non-null       object
#  9   descriptions         189707 non-null  object
#  10  publicationDate      192644 non-null  object
#  11  publisher            83383 non-null   object
#  12  embargoEndDate       4027 non-null    object
#  13  sources              107146 non-null  object
#  14  formats              171174 non-null  object
#  15  contributors         21744 non-null   object
#  16  coverages            0 non-null       object
#  17  bestAccessRight      125443 non-null  object
#  18  container            56971 non-null   object
#  19  documentationUrls    0 non-null       object
#  20  codeRepositoryUrl    0 non-null       object
#  21  programmingLanguage  0 non-null       object
#  22  contactPeople        5 non-null       object
#  23  contactGroups        0 non-null       object
#  24  tools                0 non-null       object
#  25  size                 8 non-null       object
#  26  version              11 non-null      object
#  27  geoLocations         0 non-null       object
#  28  id                   192664 non-null  object
#  29  originalIds          192664 non-null  object
#  30  pids                 66532 non-null   object
#  31  dateOfCollection     0 non-null       object
#  32  lastUpdateTimeStamp  0 non-null       object
#  33  indicators           192185 non-null  object
#  34  instances            192664 non-null  object
#  35  isGreen              127812 non-null  object
#  36  isInDiamondJournal   127812 non-null  object
#  37  relOrganizationId    192664 non-null  object
#  38  country              0 non-null       object
#  39  description          0 non-null       object
#  40  format               0 non-null       object
#  41  source               0 non-null       object
#  42  contributor          0 non-null       object
#  43  contactPerson        0 non-null       object
#  44  coverage             0 non-null       object
# dtypes: object(45)
# memory usage: 66.1+ MB

# %%
df_ldg.columns
# Out:
# <pre style="white-space:pre;overflow-x:auto;line-height:normal;font-family:Menlo,'DejaVu Sans Mono',consolas,'Courier New',monospace"></pre>
# Index(['id', 'openAccessColor', 'publiclyFunded', 'type', 'mainTitle',
#        'publicationDate', 'isGreen', 'isInDiamondJournal', 'publisher',
#        'embargoEndDate', 'language_code', 'language_label',
#        'bestAccessRight_label', 'bestAccessRight_scheme', 'usageCounts',
#        'citationImpact.citationClass', 'citationImpact.citationCount',
#        'citationImpact.impulse', 'citationImpact.impulseClass',
#        'citationImpact.influence', 'citationImpact.influenceClass',
#        'citationImpact.popularity', 'citationImpact.popularityClass',
#        'usageCounts.downloads', 'usageCounts.views', 'load_datetime',
#        'relCollectedFromDatasourceId'],
#       dtype='object')

# %%
df.columns
# Out:
# <pre style="white-space:pre;overflow-x:auto;line-height:normal;font-family:Menlo,'DejaVu Sans Mono',consolas,'Courier New',monospace"></pre>
# Index(['authors', 'openAccessColor', 'publiclyFunded', 'type', 'language',
#        'countries', 'subjects', 'mainTitle', 'subTitle', 'descriptions',
#        'publicationDate', 'publisher', 'embargoEndDate', 'sources', 'formats',
#        'contributors', 'coverages', 'bestAccessRight', 'container',
#        'documentationUrls', 'codeRepositoryUrl', 'programmingLanguage',
#        'contactPeople', 'contactGroups', 'tools', 'size', 'version',
#        'geoLocations', 'id', 'originalIds', 'pids', 'dateOfCollection',
#        'lastUpdateTimeStamp', 'indicators', 'instances', 'isGreen',
#        'isInDiamondJournal', 'relOrganizationId'],
#       dtype='object')

# %%
df.head(4)
# Out:
# <pre style="white-space:pre;overflow-x:auto;line-height:normal;font-family:Menlo,'DejaVu Sans Mono',consolas,'Courier New',monospace"></pre>
#                                              authors openAccessColor  \
# 0  [{'fullName': 'Susevich, María Laura', 'name':...            gold
# 1  [{'fullName': 'Steffen, Kevin Denis', 'name': ...            gold
# 2  [{'fullName': 'Paredes A., Manuel', 'name': 'M...            gold
# 3  [{'fullName': 'Evangelista, Carolina', 'name':...            None
#
#   publiclyFunded         type                                        language  \
# 0          False  publication  {'code': 'spa', 'label': 'Spanish; Castilian'}
# 1          False  publication  {'code': 'spa', 'label': 'Spanish; Castilian'}
# 2          False  publication  {'code': 'spa', 'label': 'Spanish; Castilian'}
# 3          False  publication         {'code': 'esl/spa', 'label': 'Spanish'}
#
#   countries                                           subjects  \
# 0      None  [{'provenance': None, 'subject': {'scheme': 'k...
# 1      None  [{'provenance': None, 'subject': {'scheme': 'k...
# 2      None  [{'provenance': None, 'subject': {'scheme': 'k...
# 3      None  [{'provenance': None, 'subject': {'scheme': 'k...
#
#                                            mainTitle subTitle  \
# 0  Dicistrovirus from the pollinator community fo...     None
# 1  Variability in the growth rates of Saanen kids...     None
# 2  Effects of dietary inclusion of alfalfa meal o...     None
# 3  Estudio de la viabilidad del algoritmo super-t...     None
#
#                                         descriptions publicationDate  \
# 0  [Los Dicistrovirus son una familia de virus qu...      2022-08-31
# 1  [This study was carried out to determine the v...      2023-12-18
# 2  [Se utilizaron 240 pollos de engorde hembras H...      2020-06-20
# 3  [En este trabajo se presenta el diseño de un c...      2013-01-01
#
#                                            publisher embargoEndDate  \
# 0  Universidad Nacional Mayor de San Marcos, Facu...           None
# 1  Universidad Nacional Mayor de San Marcos, Facu...           None
# 2  Universidad Nacional Mayor de San Marcos, Facu...           None
# 3                                               None           None
#
#                                              sources            formats  \
# 0  [Revista de Investigaciones Veterinarias del P...  [application/pdf]
# 1  [Revista de Investigaciones Veterinarias del P...  [application/pdf]
# 2  [Revista de Investigaciones Veterinarias del P...  [application/pdf]
# 3  [reponame:Digital.CSIC. Repositorio Institucio...               None
#
#                                         contributors coverages  \
# 0                                               None      None
# 1                                               None      None
# 2                                               None      None
# 3  [European Commission, Ministerio de Economía y...      None
#
#                                      bestAccessRight  \
# 0  {'code': 'c_abf2', 'label': 'OPEN', 'scheme': ...
# 1  {'code': 'c_abf2', 'label': 'OPEN', 'scheme': ...
# 2  {'code': 'c_abf2', 'label': 'OPEN', 'scheme': ...
# 3  {'code': 'c_abf2', 'label': 'OPEN', 'scheme': ...
#
#                                            container documentationUrls  \
# 0  {'conferenceDate': None, 'conferencePlace': No...              None
# 1  {'conferenceDate': None, 'conferencePlace': No...              None
# 2  {'conferenceDate': None, 'conferencePlace': No...              None
# 3                                               None              None
#
#   codeRepositoryUrl programmingLanguage contactPeople contactGroups tools  \
# 0              None                None          None          None  None
# 1              None                None          None          None  None
# 2              None                None          None          None  None
# 3              None                None          None          None  None
#
#    size version geoLocations                                              id  \
# 0  None    None         None  4dc99724cf04::319dc88111c9b2d6021228590e79130a
# 1  None    None         None  4dc99724cf04::95ea5df70a451a0487e051faa6c0a646
# 2  None    None         None  4dc99724cf04::fd4ac9e4a4b67e70441e5d033c144e1e
# 3  None    None         None  RECOLECTA___::24cb4438d1afe299e63cfdea4a31911f
#
#                                          originalIds  \
# 0  [50|4dc99724cf04::319dc88111c9b2d6021228590e79...
# 1  [oai:ojs.csi.unmsm:article/25240, 50|4dc99724c...
# 2  [50|4dc99724cf04::fd4ac9e4a4b67e70441e5d033c14...
# 3  [50|RECOLECTA___::24cb4438d1afe299e63cfdea4a31...
#
#                                              pids dateOfCollection  \
# 0                                            None             None
# 1                                            None             None
# 2                                            None             None
# 3  [{'scheme': 'handle', 'value': '10261/97737'}]             None
#
#   lastUpdateTimeStamp                                         indicators  \
# 0                None  {'citationImpact': {'citationClass': 'C5', 'ci...
# 1                None  {'citationImpact': {'citationClass': 'C5', 'ci...
# 2                None  {'citationImpact': {'citationClass': 'C5', 'ci...
# 3                None  {'citationImpact': {'citationClass': 'C5', 'ci...
#
#                                            instances isGreen  \
# 0  [{'alternateIdentifiers': [{'scheme': 'doi', '...   False
# 1  [{'alternateIdentifiers': [{'scheme': 'doi', '...   False
# 2  [{'alternateIdentifiers': [{'scheme': 'doi', '...   False
# 3  [{'alternateIdentifiers': None, 'articleProces...    True
#
#   isInDiamondJournal                               relOrganizationId
# 0              False  openorgs____::40b9f835648a3e0d057d6917dd7e54d5
# 1              False  openorgs____::40b9f835648a3e0d057d6917dd7e54d5
# 2              False  openorgs____::40b9f835648a3e0d057d6917dd7e54d5
# 3              False  openorgs____::40b9f835648a3e0d057d6917dd7e54d5

# %% [markdown]
# Se muestran las columnas que no estan en ldg pero si en el df con los researchproducts de la última descarga. Muchos de los nuevos atributos tienen una relacion con research product de 1 a N. Estas relaciones se tratan en otros nodos, por ejemplo "authors"

# %%
columnas_nuevas = set(df.columns) - set(df_ldg.columns)
columnas_nuevas
# Out:
# <pre style="white-space:pre;overflow-x:auto;line-height:normal;font-family:Menlo,'DejaVu Sans Mono',consolas,'Courier New',monospace"></pre>
# {
#     'contactPeople',
#     'version',
#     'documentationUrls',
#     'subTitle',
#     'pids',
#     'subjects',
#     'size',
#     'language',
#     'originalIds',
#     'bestAccessRight',
#     'lastUpdateTimeStamp',
#     'descriptions',
#     'geoLocations',
#     'sources',
#     'authors',
#     'codeRepositoryUrl',
#     'programmingLanguage',
#     'indicators',
#     'contributors',
#     'formats',
#     'contactGroups',
#     'dateOfCollection',
#     'countries',
#     'tools',
#     'instances',
#     'coverages',
#     'container',
#     'relOrganizationId'
# }

# %% [markdown]
# ## Paso 1: Convierto tipos y selecciono columnas con cardinalidad 1 con respecto a cada research product
# + info en https://graph.openaire.eu/docs/data-model/entities/research-product

# %%
def land_openaire_researchproduct(filter_param, filter_value, df: pd.DataFrame)-> pd.DataFrame:

    expected_columns = [
        'id',
        'openAccessColor',
        'publiclyFunded',
        'type',
        'language',
        'country',
        'mainTitle',
        'description',
        'publicationDate',
        'format',
        'bestAccessRight',
        'indicators',
        'isGreen',
        'isInDiamondJournal',
        'publisher',
        'source',
        'container',
        'contributor',
        'contactPerson',
        'coverage',
        'contactPerson',
        'embargoEndDate',
        'dateOfCollection',        
    ]

    # Agregar columnas faltantes con NaN
    for col in expected_columns:
        if col not in df.columns:
            df[col] = pd.NA

    df = df.convert_dtypes()

    df_researchproduct = df[expected_columns].copy()
    df_researchproduct.reset_index(drop=True, inplace=True)

    # language
    df_researchproduct['language'] = df_researchproduct['language'].apply(
        lambda x: x if isinstance(x, dict) else {}
    )
    df_researchproduct['language_code'] = df_researchproduct['language'].apply(lambda x: x['code'])
    df_researchproduct['language_label'] = df_researchproduct['language'].apply(lambda x: x['label'])

    
    ## bestAccessRight
    df_researchproduct['bestAccessRight_label'] = df['bestAccessRight'].apply(lambda x: x['label'] if x else None)
    df_researchproduct['bestAccessRight_scheme'] = df['bestAccessRight'].apply(lambda x: x['scheme'] if x else None)

    ## indicators
    df_indicators = pd.json_normalize(df['indicators']).reset_index(drop=True)
    
    indicators_expected_columns = [
        "citationImpact.citationClass",
        "citationImpact.citationCount",
        "citationImpact.impulse",
        "citationImpact.impulseClass",
        "citationImpact.influence",
        "citationImpact.influenceClass",
        "citationImpact.popularity",
        "citationImpact.popularityClass",
        "usageCounts.downloads",
        "usageCounts.views",
    ]

    # Agregar columnas para indicators y faltantes con NaN
    for col in indicators_expected_columns:
        if col not in df_indicators.columns:
            df_indicators[col] = pd.NA

    df_researchproduct = pd.concat([df_researchproduct.drop(columns=['indicators']).reset_index(drop=True), df_indicators], axis=1)

    # TODO country
    # TODO description
    # TODO format
    # TODO instance
    # TODO container
    # TODO contributor
    # TODO contactPerson
    # TODO coverage

    ## drop de columnas procesadas en otros df
    df_researchproduct.drop(columns=[
        'country', 'bestAccessRight', 
        'language', 'format',  
        'container', 'source', 'description',
        'contributor', 'contactPerson', 'coverage'
        ], inplace=True)

    df_researchproduct['load_datetime'] = date.today()

    df_researchproduct[filter_param] = filter_value

    return df_researchproduct

# %%
df_researchproduct = land_openaire_researchproduct(filter_param, filter_value, df)

# %%
df_researchproduct
# Out:
# <pre style="white-space:pre;overflow-x:auto;line-height:normal;font-family:Menlo,'DejaVu Sans Mono',consolas,'Courier New',monospace"></pre>
#                                                     id openAccessColor  \
# 0       4dc99724cf04::319dc88111c9b2d6021228590e79130a            gold
# 1       4dc99724cf04::95ea5df70a451a0487e051faa6c0a646            gold
# 2       4dc99724cf04::fd4ac9e4a4b67e70441e5d033c144e1e            gold
# 3       RECOLECTA___::24cb4438d1afe299e63cfdea4a31911f            <NA>
# 4       a9ac50f576aa::00c814cefd73d31b4691640dc4c7238b            <NA>
# ...                                                ...             ...
# 192659  revistasumft::106b3b4f6115356de22e7aaf07960b34            gold
# 192660  sarcservicod::ef3df246e21f4f481210a503f22cf9a6            gold
# 192661  sharePrprorg::b68010ac09fbe1824d423110978b672f            <NA>
# 192662  sygma_______::2c3527ec5206f82ddcaad7886eff9ae1            <NA>
# 192663  sygma_______::3079abb21c5b12128a985a530b670d27            <NA>
#
#         publiclyFunded         type  \
# 0                False  publication
# 1                False  publication
# 2                False  publication
# 3                False  publication
# 4                False  publication
# ...                ...          ...
# 192659           False  publication
# 192660           False  publication
# 192661           False  publication
# 192662            <NA>        other
# 192663            <NA>        other
#
#                                                 mainTitle publicationDate  \
# 0       Dicistrovirus from the pollinator community fo...      2022-08-31
# 1       Variability in the growth rates of Saanen kids...      2023-12-18
# 2       Effects of dietary inclusion of alfalfa meal o...      2020-06-20
# 3       Estudio de la viabilidad del algoritmo super-t...      2013-01-01
# 4       Craniofacial growth trajectories and dental de...      2006-01-01
# ...                                                   ...             ...
# 192659  Deconstructing the classic categories of an et...      2023-12-31
# 192660               Argentine wind genealogy (1990-2020)      2021-08-05
# 192661  Nutraceutic Potential of two Allium Species an...      2019-03-25
# 192662                                    Tax Competition      2018-05-28
# 192663  PlateUNLP: An Open-Source Solution for Automat...      2024-01-01
#
#         isGreen  isInDiamondJournal  \
# 0         False               False
# 1         False               False
# 2         False               False
# 3          True               False
# 4         False               False
# ...         ...                 ...
# 192659    False               False
# 192660    False               False
# 192661     True               False
# 192662     <NA>                <NA>
# 192663     <NA>                <NA>
#
#                                                 publisher embargoEndDate  \
# 0       Universidad Nacional Mayor de San Marcos, Facu...           <NA>
# 1       Universidad Nacional Mayor de San Marcos, Facu...           <NA>
# 2       Universidad Nacional Mayor de San Marcos, Facu...           <NA>
# 3                                                    <NA>           <NA>
# 4                                                    <NA>           <NA>
# ...                                                   ...            ...
# 192659                                         PPGAS/UFMT           <NA>
# 192660                      Centro de Estudos Geográficos           <NA>
# 192661                                          Preprints           <NA>
# 192662                                             Zenodo           <NA>
# 192663                       The Eurographics Association           <NA>
#
#        dateOfCollection language_code      language_label  \
# 0                  None           spa  Spanish; Castilian
# 1                  None           spa  Spanish; Castilian
# 2                  None           spa  Spanish; Castilian
# 3                  None       esl/spa             Spanish
# 4                  None           eng             English
# ...                 ...           ...                 ...
# 192659             None           por          Portuguese
# 192660             None           spa  Spanish; Castilian
# 192661             None           eng             English
# 192662             None           eng             English
# 192663             None          null                null
#
#        bestAccessRight_label  \
# 0                       OPEN
# 1                       OPEN
# 2                       OPEN
# 3                       OPEN
# 4                     CLOSED
# ...                      ...
# 192659                  OPEN
# 192660                  OPEN
# 192661                  OPEN
# 192662                  OPEN
# 192663                  OPEN
#
#                                    bestAccessRight_scheme  usageCounts  \
# 0       http://vocabularies.coar-repositories.org/docu...          NaN
# 1       http://vocabularies.coar-repositories.org/docu...          NaN
# 2       http://vocabularies.coar-repositories.org/docu...          NaN
# 3       http://vocabularies.coar-repositories.org/docu...          NaN
# 4       http://vocabularies.coar-repositories.org/docu...          NaN
# ...                                                   ...          ...
# 192659  http://vocabularies.coar-repositories.org/docu...          NaN
# 192660  http://vocabularies.coar-repositories.org/docu...          NaN
# 192661  http://vocabularies.coar-repositories.org/docu...          NaN
# 192662  http://vocabularies.coar-repositories.org/docu...          NaN
# 192663  http://vocabularies.coar-repositories.org/docu...          NaN
#
#        citationImpact.citationClass  citationImpact.citationCount  \
# 0                                C5                           0.0
# 1                                C5                           0.0
# 2                                C5                           0.0
# 3                                C5                           0.0
# 4                                C5                           0.0
# ...                             ...                           ...
# 192659                           C5                           0.0
# 192660                           C5                           0.0
# 192661                           C5                           0.0
# 192662                           C5                           0.0
# 192663                           C5                           0.0
#
#         citationImpact.impulse citationImpact.impulseClass  \
# 0                          0.0                          C5
# 1                          0.0                          C5
# 2                          0.0                          C5
# 3                          0.0                          C5
# 4                          0.0                          C5
# ...                        ...                         ...
# 192659                     0.0                          C5
# 192660                     0.0                          C5
# 192661                     0.0                          C5
# 192662                     0.0                          C5
# 192663                     0.0                          C5
#
#         citationImpact.influence citationImpact.influenceClass  \
# 0                   2.739285e-09                            C5
# 1                   2.739285e-09                            C5
# 2                   2.739285e-09                            C5
# 3                   2.739285e-09                            C5
# 4                   2.739285e-09                            C5
# ...                          ...                           ...
# 192659              2.739285e-09                            C5
# 192660              2.739285e-09                            C5
# 192661              2.739285e-09                            C5
# 192662              2.739285e-09                            C5
# 192663              2.739285e-09                            C5
#
#         citationImpact.popularity citationImpact.popularityClass  \
# 0                    2.296654e-09                             C5
# 1                    2.657229e-09                             C5
# 2                    1.727562e-09                             C5
# 3                    7.109064e-10                             C5
# 4                    3.791923e-10                             C5
# ...                           ...                            ...
# 192659               2.657229e-09                             C5
# 192660               1.989393e-09                             C5
# 192661               1.504444e-09                             C5
# 192662               1.314316e-09                             C5
# 192663               3.080367e-09                             C5
#
#         usageCounts.downloads  usageCounts.views load_datetime  \
# 0                         NaN                NaN    2025-06-26
# 1                         NaN                NaN    2025-06-26
# 2                         NaN                NaN    2025-06-26
# 3                        31.0               11.0    2025-06-26
# 4                         NaN                NaN    2025-06-26
# ...                       ...                ...           ...
# 192659                    NaN                NaN    2025-06-26
# 192660                    NaN                NaN    2025-06-26
# 192661                    NaN                NaN    2025-06-26
# 192662                    NaN                NaN    2025-06-26
# 192663                    NaN                NaN    2025-06-26
#
#                                      relOrganizationId
# 0       openorgs____::40b9f835648a3e0d057d6917dd7e54d5
# 1       openorgs____::40b9f835648a3e0d057d6917dd7e54d5
# 2       openorgs____::40b9f835648a3e0d057d6917dd7e54d5
# 3       openorgs____::40b9f835648a3e0d057d6917dd7e54d5
# 4       openorgs____::40b9f835648a3e0d057d6917dd7e54d5
# ...                                                ...
# 192659  openorgs____::40b9f835648a3e0d057d6917dd7e54d5
# 192660  openorgs____::40b9f835648a3e0d057d6917dd7e54d5
# 192661  openorgs____::40b9f835648a3e0d057d6917dd7e54d5
# 192662  openorgs____::40b9f835648a3e0d057d6917dd7e54d5
# 192663  openorgs____::40b9f835648a3e0d057d6917dd7e54d5
#
# [192664 rows x 28 columns]
