# %%
from datetime import date
import pandas as pd

pd.set_option('display.max_columns', None)
pd.set_option('display.max_rows', 5)

df = catalog.load('raw/openaire/researchproduct_dev#parquet')
# Out:
#                     INFO     Loading data from raw/openaire/researchproduct_dev#parquet         ]8;id=713340;file:///root/kedro-unlp/.venv/lib/python3.10/site-packages/kedro/io/data_catalog.py\data_catalog.py]8;;\:]8;id=455636;file:///root/kedro-unlp/.venv/lib/python3.10/site-packages/kedro/io/data_catalog.py#389\389]8;;\
#                              (ParquetDataset)...

# %%
def _pick_load_dt(df: pd.DataFrame):
    # Si hay una sola fecha en el batch, usala; si hay varias, quedate con la más reciente;
    # si no hay, hoy.
    if 'load_datetime' not in df.columns or df['load_datetime'].isna().all():
        return date.today()
    vals = df['load_datetime'].dropna()
    if vals.nunique() == 1:
        return vals.iloc[0]
    return pd.to_datetime(vals).max().date()

# %%
df
# Out:
# <pre style="white-space:pre;overflow-x:auto;line-height:normal;font-family:Menlo,'DejaVu Sans Mono',consolas,'Courier New',monospace"></pre>
#                                                authors openAccessColor  \
# 0    [{'fullName': 'Susevich, María Laura', 'name':...            gold
# 1    [{'fullName': 'Steffen, Kevin Denis', 'name': ...            gold
# ..                                                 ...             ...
# 998  [{'fullName': 'Giorgi, Edgard Ervar Salvador',...            None
# 999  [{'fullName': 'Jong-youn, Choo', 'name': 'Choo...            gold
#
#     publiclyFunded         type  \
# 0            False  publication
# 1            False  publication
# ..             ...          ...
# 998          False  publication
# 999          False  publication
#
#                                            language  \
# 0    {'code': 'spa', 'label': 'Spanish; Castilian'}
# 1    {'code': 'spa', 'label': 'Spanish; Castilian'}
# ..                                              ...
# 998             {'code': 'eng', 'label': 'English'}
# 999         {'code': 'esl/spa', 'label': 'Spanish'}
#
#                                              countries  \
# 0                                                 None
# 1                                                 None
# ..                                                 ...
# 998  [{'code': 'AR', 'label': 'Argentina', 'provena...
# 999  [{'code': 'AR', 'label': 'Argentina', 'provena...
#
#                                               subjects  \
# 0    [{'provenance': None, 'subject': {'scheme': 'k...
# 1    [{'provenance': None, 'subject': {'scheme': 'k...
# ..                                                 ...
# 998  [{'provenance': None, 'subject': {'scheme': 'k...
# 999  [{'provenance': None, 'subject': {'scheme': 'k...
#
#                                              mainTitle subTitle  \
# 0    Dicistrovirus from the pollinator community fo...     None
# 1    Variability in the growth rates of Saanen kids...     None
# ..                                                 ...      ...
# 998  A case study of oversight and neglect in the h...     None
# 999    Un nuevo enfoque de la relación Corea-Argentina     None
#
#                                           descriptions publicationDate  \
# 0    [Los Dicistrovirus son una familia de virus qu...      2022-08-31
# 1    [This study was carried out to determine the v...      2023-12-18
# ..                                                 ...             ...
# 998  [Presentamos y discutimos datos obtenidos de l...      2024-01-01
# 999  [El autor señala que Argentina y Corea, despué...      2007-01-01
#
#                                              publisher embargoEndDate  \
# 0    Universidad Nacional Mayor de San Marcos, Facu...           None
# 1    Universidad Nacional Mayor de San Marcos, Facu...           None
# ..                                                 ...            ...
# 998                                               None           None
# 999                   Universidad Nacional de La Plata           None
#
#                                                sources  \
# 0    [Revista de Investigaciones Veterinarias del P...
# 1    [Revista de Investigaciones Veterinarias del P...
# ..                                                 ...
# 998                                               None
# 999  [Relaciones Internacionales, Vol 16, Iss 33 (2...
#
#                         formats contributors coverages  \
# 0             [application/pdf]         None      None
# 1             [application/pdf]         None      None
# ..                          ...          ...       ...
# 998  [application/pdf, 114-117]         None      None
# 999           [application/pdf]         None      None
#
#                                        bestAccessRight  \
# 0    {'code': 'c_abf2', 'label': 'OPEN', 'scheme': ...
# 1    {'code': 'c_abf2', 'label': 'OPEN', 'scheme': ...
# ..                                                 ...
# 998  {'code': 'c_abf2', 'label': 'OPEN', 'scheme': ...
# 999  {'code': 'c_abf2', 'label': 'OPEN', 'scheme': ...
#
#                                              container documentationUrls  \
# 0    {'conferenceDate': None, 'conferencePlace': No...              None
# 1    {'conferenceDate': None, 'conferencePlace': No...              None
# ..                                                 ...               ...
# 998                                               None              None
# 999  {'conferenceDate': None, 'conferencePlace': No...              None
#
#     codeRepositoryUrl programmingLanguage contactPeople contactGroups tools  \
# 0                None                None          None          None  None
# 1                None                None          None          None  None
# ..                ...                 ...           ...           ...   ...
# 998              None                None          None          None  None
# 999              None                None          None          None  None
#
#      size version geoLocations  \
# 0    None    None         None
# 1    None    None         None
# ..    ...     ...          ...
# 998  None    None         None
# 999  None    None         None
#
#                                                  id  \
# 0    4dc99724cf04::319dc88111c9b2d6021228590e79130a
# 1    4dc99724cf04::95ea5df70a451a0487e051faa6c0a646
# ..                                              ...
# 998  dedup_wf_002::037c3a3ae3212005fc63e98d8378595c
# 999  dedup_wf_002::037c9fce98a79decd202e1afba75b99e
#
#                                            originalIds  pids dateOfCollection  \
# 0    [50|4dc99724cf04::319dc88111c9b2d6021228590e79...  None             None
# 1    [oai:ojs.csi.unmsm:article/25240, 50|4dc99724c...  None             None
# ..                                                 ...   ...              ...
# 998  [oai:sedici.unlp.edu.ar:10915/170737, 50|od___...  None             None
# 999  [oai:doaj.org/article:e0290ebaabbc460eadb6638c...  None             None
#
#     lastUpdateTimeStamp                                         indicators  \
# 0                  None  {'citationImpact': {'citationClass': 'C5', 'ci...
# 1                  None  {'citationImpact': {'citationClass': 'C5', 'ci...
# ..                  ...                                                ...
# 998                None  {'citationImpact': {'citationClass': 'C5', 'ci...
# 999                None  {'citationImpact': {'citationClass': 'C5', 'ci...
#
#     projects                                      organizations  \
# 0       None  [{'acronym': 'UNLPAM', 'id': 'openorgs____::db...
# 1       None  [{'acronym': 'Universidad Nacional de La Pampa...
# ..       ...                                                ...
# 998     None  [{'acronym': 'UNLP', 'id': 'openorgs____::40b9...
# 999     None  [{'acronym': 'UNLP', 'id': 'openorgs____::40b9...
#
#                                            communities  \
# 0    [{'code': 'knowmad', 'label': 'Knowmad Institu...
# 1                                                 None
# ..                                                 ...
# 998                                               None
# 999                                               None
#
#                                          collectedFrom  \
# 0    [{'key': 'openaire____::0b74b6a356bbf23c245f9a...
# 1    [{'key': 'openaire____::0b74b6a356bbf23c245f9a...
# ..                                                 ...
# 998  [{'key': 'openaire____::df45502607927471ecf8a6...
# 999  [{'key': 'opendoar____::dc6e224a8d74ce03bf3011...
#
#                                              instances isGreen  \
# 0    [{'accessRight': {'code': 'c_abf2', 'label': '...   False
# 1    [{'accessRight': {'code': 'c_abf2', 'label': '...   False
# ..                                                 ...     ...
# 998  [{'accessRight': None, 'alternateIdentifiers':...    True
# 999  [{'accessRight': {'code': 'c_abf2', 'label': '...    True
#
#     isInDiamondJournal                               relOrganizationId  \
# 0                False  openorgs____::40b9f835648a3e0d057d6917dd7e54d5
# 1                False  openorgs____::40b9f835648a3e0d057d6917dd7e54d5
# ..                 ...                                             ...
# 998              False  openorgs____::40b9f835648a3e0d057d6917dd7e54d5
# 999              False  openorgs____::40b9f835648a3e0d057d6917dd7e54d5
#
#     load_datetime
# 0      2025-09-05
# 1      2025-09-05
# ..            ...
# 998    2025-09-05
# 999    2025-09-05
#
# [1000 rows x 43 columns]

# %%
load_dt = _pick_load_dt(df)

# %%
df_research_pid = df.loc[:,['id','pids']]
df_research_pid.dropna(inplace=True)

# %%
df_research_pid
# Out:
# <pre style="white-space:pre;overflow-x:auto;line-height:normal;font-family:Menlo,'DejaVu Sans Mono',consolas,'Courier New',monospace"></pre>
#                                                  id  \
# 3    RECOLECTA___::24cb4438d1afe299e63cfdea4a31911f
# 116  dedup_wf_002::0005b301e367f0fc799b29dc387d3bd1
# ..                                              ...
# 987  dedup_wf_002::0371facbe40925273620155e4639ff06
# 989  dedup_wf_002::03758bd23c38a7125705d74fc4f38575
#
#                                                   pids
# 3       [{'scheme': 'handle', 'value': '10261/97737'}]
# 116    [{'scheme': 'handle', 'value': '11336/112574'}]
# ..                                                 ...
# 987  [{'scheme': 'handle', 'value': '20.500.12110/a...
# 989     [{'scheme': 'handle', 'value': '11336/33252'}]
#
# [107 rows x 2 columns]

# %%
df_research_pid = df_research_pid.explode('pids').reset_index(drop=True)

# %%
df_research_pid
# Out:
# <pre style="white-space:pre;overflow-x:auto;line-height:normal;font-family:Menlo,'DejaVu Sans Mono',consolas,'Courier New',monospace"></pre>
#                                                  id  \
# 0    RECOLECTA___::24cb4438d1afe299e63cfdea4a31911f
# 1    dedup_wf_002::0005b301e367f0fc799b29dc387d3bd1
# ..                                              ...
# 146  dedup_wf_002::0371facbe40925273620155e4639ff06
# 147  dedup_wf_002::03758bd23c38a7125705d74fc4f38575
#
#                                                   pids
# 0         {'scheme': 'handle', 'value': '10261/97737'}
# 1        {'scheme': 'handle', 'value': '11336/112574'}
# ..                                                 ...
# 146  {'scheme': 'handle', 'value': '20.500.12110/af...
# 147       {'scheme': 'handle', 'value': '11336/33252'}
#
# [148 rows x 2 columns]

# %%
df_pid = pd.json_normalize(df_research_pid['pids'])

# %%
df_pid
# Out:
# <pre style="white-space:pre;overflow-x:auto;line-height:normal;font-family:Menlo,'DejaVu Sans Mono',consolas,'Courier New',monospace"></pre>
#      scheme                          value
# 0    handle                    10261/97737
# 1    handle                   11336/112574
# ..      ...                            ...
# 146  handle  20.500.12110/afa_v12_n01_p159
# 147  handle                    11336/33252
#
# [148 rows x 2 columns]

# %%
df_research_pid = pd.concat([df_research_pid['id'], df_pid], axis=1)
df_research_pid['load_datetime'] = load_dt

# %%
df_research_pid
# Out:
# <pre style="white-space:pre;overflow-x:auto;line-height:normal;font-family:Menlo,'DejaVu Sans Mono',consolas,'Courier New',monospace"></pre>
#                                                  id  scheme  \
# 0    RECOLECTA___::24cb4438d1afe299e63cfdea4a31911f  handle
# 1    dedup_wf_002::0005b301e367f0fc799b29dc387d3bd1  handle
# ..                                              ...     ...
# 146  dedup_wf_002::0371facbe40925273620155e4639ff06  handle
# 147  dedup_wf_002::03758bd23c38a7125705d74fc4f38575  handle
#
#                              value load_datetime
# 0                      10261/97737    2025-09-05
# 1                     11336/112574    2025-09-05
# ..                             ...           ...
# 146  20.500.12110/afa_v12_n01_p159    2025-09-05
# 147                    11336/33252    2025-09-05
#
# [148 rows x 4 columns]

# %% [markdown]
# ## Node
# + info en https://graph.openaire.eu/docs/data-model/entities/research-product

# %%
def openaire_land_researchproduct_pids(df: pd.DataFrame)-> pd.DataFrame:

    df_research_pid = df.loc[:,['id','pids']]
    df_research_pid.dropna(inplace=True)
    
    df_research_pid = df_research_pid.explode('pids').reset_index(drop=True)

    df_pid = pd.json_normalize(df_research_pid['pids'])
    
    df_research_pid = pd.concat([df_research_pid['id'], df_pid], axis=1)
    df_research_pid['load_datetime'] = load_dt

    return df_research_pid

# %%
df_research_pid = openaire_land_researchproduct_pids(df)

# %%
df_research_pid
# Out:
# <pre style="white-space:pre;overflow-x:auto;line-height:normal;font-family:Menlo,'DejaVu Sans Mono',consolas,'Courier New',monospace"></pre>
#                                                  id  scheme  \
# 0    RECOLECTA___::24cb4438d1afe299e63cfdea4a31911f  handle
# 1    dedup_wf_002::0005b301e367f0fc799b29dc387d3bd1  handle
# ..                                              ...     ...
# 146  dedup_wf_002::0371facbe40925273620155e4639ff06  handle
# 147  dedup_wf_002::03758bd23c38a7125705d74fc4f38575  handle
#
#                              value load_datetime
# 0                      10261/97737    2025-09-05
# 1                     11336/112574    2025-09-05
# ..                             ...           ...
# 146  20.500.12110/afa_v12_n01_p159    2025-09-05
# 147                    11336/33252    2025-09-05
#
# [148 rows x 4 columns]
