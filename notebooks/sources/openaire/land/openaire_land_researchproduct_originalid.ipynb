# %%
from datetime import date
import pandas as pd

pd.set_option('display.max_columns', None)
pd.set_option('display.max_rows', 5)

df = catalog.load('raw/openaire/researchproduct_dev#parquet')
# Out:
#                     INFO     Loading data from raw/openaire/researchproduct_dev#parquet         ]8;id=230270;file:///root/kedro-unlp/.venv/lib/python3.10/site-packages/kedro/io/data_catalog.py\data_catalog.py]8;;\:]8;id=593714;file:///root/kedro-unlp/.venv/lib/python3.10/site-packages/kedro/io/data_catalog.py#389\389]8;;\
#                              (ParquetDataset)...

# %%
def _pick_load_dt(df: pd.DataFrame):

    # si no hay, hoy.
    if 'load_datetime' not in df.columns or df['load_datetime'].isna().all():
        return date.today()
    vals = df['load_datetime'].dropna()
    if vals.nunique() == 1:
        return vals.iloc[0]
    return pd.to_datetime(vals).max().date()

# %%
df
# Out:
# <pre style="white-space:pre;overflow-x:auto;line-height:normal;font-family:Menlo,'DejaVu Sans Mono',consolas,'Courier New',monospace"></pre>
#                                                authors openAccessColor  \
# 0    [{'fullName': 'Susevich, María Laura', 'name':...            gold
# 1    [{'fullName': 'Steffen, Kevin Denis', 'name': ...            gold
# 2    [{'fullName': 'Paredes A., Manuel', 'name': 'M...            gold
# 3    [{'fullName': 'Evangelista, Carolina', 'name':...            None
# 4    [{'fullName': 'Ferral, Anabella', 'name': 'Ana...            None
# ..                                                 ...             ...
# 995  [{'fullName': 'Diaz, Alicia', 'name': 'Alicia'...            None
# 996  [{'fullName': 'Pates, Giuliana', 'name': 'Giul...            None
# 997  [{'fullName': 'Rogovsky, Diana Matilde', 'name...            None
# 998  [{'fullName': 'Giorgi, Edgard Ervar Salvador',...            None
# 999  [{'fullName': 'Jong-youn, Choo', 'name': 'Choo...            gold
#
#     publiclyFunded         type  \
# 0            False  publication
# 1            False  publication
# 2            False  publication
# 3            False  publication
# 4            False  publication
# ..             ...          ...
# 995          False  publication
# 996          False  publication
# 997          False  publication
# 998          False  publication
# 999          False  publication
#
#                                            language  \
# 0    {'code': 'spa', 'label': 'Spanish; Castilian'}
# 1    {'code': 'spa', 'label': 'Spanish; Castilian'}
# 2    {'code': 'spa', 'label': 'Spanish; Castilian'}
# 3           {'code': 'esl/spa', 'label': 'Spanish'}
# 4               {'code': 'eng', 'label': 'English'}
# ..                                              ...
# 995             {'code': 'eng', 'label': 'English'}
# 996         {'code': 'esl/spa', 'label': 'Spanish'}
# 997         {'code': 'esl/spa', 'label': 'Spanish'}
# 998             {'code': 'eng', 'label': 'English'}
# 999         {'code': 'esl/spa', 'label': 'Spanish'}
#
#                                              countries  \
# 0                                                 None
# 1                                                 None
# 2                                                 None
# 3                                                 None
# 4                                                 None
# ..                                                 ...
# 995  [{'code': 'FR', 'label': 'France', 'provenance...
# 996  [{'code': 'AR', 'label': 'Argentina', 'provena...
# 997  [{'code': 'AR', 'label': 'Argentina', 'provena...
# 998  [{'code': 'AR', 'label': 'Argentina', 'provena...
# 999  [{'code': 'AR', 'label': 'Argentina', 'provena...
#
#                                               subjects  \
# 0    [{'provenance': None, 'subject': {'scheme': 'k...
# 1    [{'provenance': None, 'subject': {'scheme': 'k...
# 2    [{'provenance': None, 'subject': {'scheme': 'k...
# 3    [{'provenance': None, 'subject': {'scheme': 'k...
# 4    [{'provenance': None, 'subject': {'scheme': 'k...
# ..                                                 ...
# 995  [{'provenance': None, 'subject': {'scheme': 'k...
# 996  [{'provenance': None, 'subject': {'scheme': 'k...
# 997  [{'provenance': None, 'subject': {'scheme': 'k...
# 998  [{'provenance': None, 'subject': {'scheme': 'k...
# 999  [{'provenance': None, 'subject': {'scheme': 'k...
#
#                                              mainTitle subTitle  \
# 0    Dicistrovirus from the pollinator community fo...     None
# 1    Variability in the growth rates of Saanen kids...     None
# 2    Effects of dietary inclusion of alfalfa meal o...     None
# 3    Estudio de la viabilidad del algoritmo super-t...     None
# 4     Bringing satellite and nanotechnologies together     None
# ..                                                 ...      ...
# 995  Supporting Knowledge Sharing in a Community wi...     None
# 996  Reflexiones en torno a la configuración de heg...     None
# 997                         La posibilidad de un ocaso     None
# 998  A case study of oversight and neglect in the h...     None
# 999    Un nuevo enfoque de la relación Corea-Argentina     None
#
#                                           descriptions publicationDate  \
# 0    [Los Dicistrovirus son una familia de virus qu...      2022-08-31
# 1    [This study was carried out to determine the v...      2023-12-18
# 2    [Se utilizaron 240 pollos de engorde hembras H...      2020-06-20
# 3    [En este trabajo se presenta el diseño de un c...      2013-01-01
# 4    [Nowadays, we witness remarkable technological...            None
# ..                                                 ...             ...
# 995  [In this paper, we propose a technological app...      2004-01-01
# 996  [Se plantearán, en este ensayo, algunas de las...      2015-01-01
# 997  [En la danza se dice que el instrumento, medio...      2022-01-01
# 998  [Presentamos y discutimos datos obtenidos de l...      2024-01-01
# 999  [El autor señala que Argentina y Corea, despué...      2007-01-01
#
#                                              publisher embargoEndDate  \
# 0    Universidad Nacional Mayor de San Marcos, Facu...           None
# 1    Universidad Nacional Mayor de San Marcos, Facu...           None
# 2    Universidad Nacional Mayor de San Marcos, Facu...           None
# 3                                                 None           None
# 4                                                 None           None
# ..                                                 ...            ...
# 995                                              Array           None
# 996                                               None           None
# 997                                               None           None
# 998                                               None           None
# 999                   Universidad Nacional de La Plata           None
#
#                                                sources  \
# 0    [Revista de Investigaciones Veterinarias del P...
# 1    [Revista de Investigaciones Veterinarias del P...
# 2    [Revista de Investigaciones Veterinarias del P...
# 3    [reponame:Digital.CSIC. Repositorio Institucio...
# 4    [reponame:Dipòsit Digital de Documents de la U...
# ..                                                 ...
# 995                                               None
# 996  [reponame:SEDICI (UNLP), instname:Universidad ...
# 997  [reponame:SEDICI (UNLP), instname:Universidad ...
# 998                                               None
# 999  [Relaciones Internacionales, Vol 16, Iss 33 (2...
#
#                         formats  \
# 0             [application/pdf]
# 1             [application/pdf]
# 2             [application/pdf]
# 3                          None
# 4             [application/pdf]
# ..                          ...
# 995                        None
# 996           [application/pdf]
# 997    [application/pdf, 79-82]
# 998  [application/pdf, 114-117]
# 999           [application/pdf]
#
#                                           contributors coverages  \
# 0                                                 None      None
# 1                                                 None      None
# 2                                                 None      None
# 3    [European Commission, Ministerio de Economía y...      None
# 4                                                 None      None
# ..                                                 ...       ...
# 995                              [Loria, Publications]      None
# 996                                               None      None
# 997                                               None      None
# 998                                               None      None
# 999                                               None      None
#
#                                        bestAccessRight  \
# 0    {'code': 'c_abf2', 'label': 'OPEN', 'scheme': ...
# 1    {'code': 'c_abf2', 'label': 'OPEN', 'scheme': ...
# 2    {'code': 'c_abf2', 'label': 'OPEN', 'scheme': ...
# 3    {'code': 'c_abf2', 'label': 'OPEN', 'scheme': ...
# 4    {'code': 'c_abf2', 'label': 'OPEN', 'scheme': ...
# ..                                                 ...
# 995  {'code': 'c_14cb', 'label': 'CLOSED', 'scheme'...
# 996  {'code': 'c_abf2', 'label': 'OPEN', 'scheme': ...
# 997  {'code': 'c_abf2', 'label': 'OPEN', 'scheme': ...
# 998  {'code': 'c_abf2', 'label': 'OPEN', 'scheme': ...
# 999  {'code': 'c_abf2', 'label': 'OPEN', 'scheme': ...
#
#                                              container documentationUrls  \
# 0    {'conferenceDate': None, 'conferencePlace': No...              None
# 1    {'conferenceDate': None, 'conferencePlace': No...              None
# 2    {'conferenceDate': None, 'conferencePlace': No...              None
# 3                                                 None              None
# 4                                                 None              None
# ..                                                 ...               ...
# 995                                               None              None
# 996                                               None              None
# 997                                               None              None
# 998                                               None              None
# 999  {'conferenceDate': None, 'conferencePlace': No...              None
#
#     codeRepositoryUrl programmingLanguage contactPeople contactGroups tools  \
# 0                None                None          None          None  None
# 1                None                None          None          None  None
# 2                None                None          None          None  None
# 3                None                None          None          None  None
# 4                None                None          None          None  None
# ..                ...                 ...           ...           ...   ...
# 995              None                None          None          None  None
# 996              None                None          None          None  None
# 997              None                None          None          None  None
# 998              None                None          None          None  None
# 999              None                None          None          None  None
#
#      size version geoLocations  \
# 0    None    None         None
# 1    None    None         None
# 2    None    None         None
# 3    None    None         None
# 4    None    None         None
# ..    ...     ...          ...
# 995  None    None         None
# 996  None    None         None
# 997  None    None         None
# 998  None    None         None
# 999  None    None         None
#
#                                                  id  \
# 0    4dc99724cf04::319dc88111c9b2d6021228590e79130a
# 1    4dc99724cf04::95ea5df70a451a0487e051faa6c0a646
# 2    4dc99724cf04::fd4ac9e4a4b67e70441e5d033c144e1e
# 3    RECOLECTA___::24cb4438d1afe299e63cfdea4a31911f
# 4    RECOLECTA___::c5f9bd7b9739f4c5f064595b286d2e01
# ..                                              ...
# 995  dedup_wf_002::037a11b75e1662b0beb84c3b97f47ce1
# 996  dedup_wf_002::037a8383ee10ffcebea2e3102e3fa6ce
# 997  dedup_wf_002::037ba1ff4a8a10f7948e078bb3d6efb6
# 998  dedup_wf_002::037c3a3ae3212005fc63e98d8378595c
# 999  dedup_wf_002::037c9fce98a79decd202e1afba75b99e
#
#                                            originalIds  \
# 0    [50|4dc99724cf04::319dc88111c9b2d6021228590e79...
# 1    [oai:ojs.csi.unmsm:article/25240, 50|4dc99724c...
# 2    [50|4dc99724cf04::fd4ac9e4a4b67e70441e5d033c14...
# 3    [50|RECOLECTA___::24cb4438d1afe299e63cfdea4a31...
# 4    [oai:dnet:uabarcelona_::74fd71e608cc0b77e1c3f0...
# ..                                                 ...
# 995  [50|inria2______::a1ba3bd8feaf025babd7acf8bec2...
# 996  [oai:sedici.unlp.edu.ar:10915/54246, 50|od____...
# 997  [50|od______1329::db88fe08a664022e318f0b1777d8...
# 998  [oai:sedici.unlp.edu.ar:10915/170737, 50|od___...
# 999  [oai:doaj.org/article:e0290ebaabbc460eadb6638c...
#
#                                                pids dateOfCollection  \
# 0                                              None             None
# 1                                              None             None
# 2                                              None             None
# 3    [{'scheme': 'handle', 'value': '10261/97737'}]             None
# 4                                              None             None
# ..                                              ...              ...
# 995                                            None             None
# 996                                            None             None
# 997                                            None             None
# 998                                            None             None
# 999                                            None             None
#
#     lastUpdateTimeStamp                                         indicators  \
# 0                  None  {'citationImpact': {'citationClass': 'C5', 'ci...
# 1                  None  {'citationImpact': {'citationClass': 'C5', 'ci...
# 2                  None  {'citationImpact': {'citationClass': 'C5', 'ci...
# 3                  None  {'citationImpact': {'citationClass': 'C5', 'ci...
# 4                  None                                               None
# ..                  ...                                                ...
# 995                None  {'citationImpact': {'citationClass': 'C5', 'ci...
# 996                None  {'citationImpact': {'citationClass': 'C5', 'ci...
# 997                None  {'citationImpact': {'citationClass': 'C5', 'ci...
# 998                None  {'citationImpact': {'citationClass': 'C5', 'ci...
# 999                None  {'citationImpact': {'citationClass': 'C5', 'ci...
#
#                                               projects  \
# 0                                                 None
# 1                                                 None
# 2                                                 None
# 3    [{'acronym': 'ACRES', 'code': '911767', 'funde...
# 4                                                 None
# ..                                                 ...
# 995                                               None
# 996                                               None
# 997                                               None
# 998                                               None
# 999                                               None
#
#                                          organizations  \
# 0    [{'acronym': 'UNLPAM', 'id': 'openorgs____::db...
# 1    [{'acronym': 'Universidad Nacional de La Pampa...
# 2    [{'acronym': 'Universidad Nacional de La Pampa...
# 3    [{'acronym': 'CSIC', 'id': 'openorgs____::7b08...
# 4    [{'acronym': 'UNLP', 'id': 'openorgs____::40b9...
# ..                                                 ...
# 995  [{'acronym': 'CNRS', 'id': 'openorgs____::7fbd...
# 996  [{'acronym': 'UNLP', 'id': 'openorgs____::40b9...
# 997  [{'acronym': 'UNLP', 'id': 'openorgs____::40b9...
# 998  [{'acronym': 'UNLP', 'id': 'openorgs____::40b9...
# 999  [{'acronym': 'UNLP', 'id': 'openorgs____::40b9...
#
#                                            communities  \
# 0    [{'code': 'knowmad', 'label': 'Knowmad Institu...
# 1                                                 None
# 2                                                 None
# 3                                                 None
# 4                                                 None
# ..                                                 ...
# 995  [{'code': 'inria', 'label': 'INRIA', 'provenan...
# 996                                               None
# 997                                               None
# 998                                               None
# 999                                               None
#
#                                          collectedFrom  \
# 0    [{'key': 'openaire____::0b74b6a356bbf23c245f9a...
# 1    [{'key': 'openaire____::0b74b6a356bbf23c245f9a...
# 2    [{'key': 'openaire____::0b74b6a356bbf23c245f9a...
# 3    [{'key': 'openaire____::4cb2a3eb94033446c37331...
# 4    [{'key': 'openaire____::4cb2a3eb94033446c37331...
# ..                                                 ...
# 995  [{'key': 'openaire____::eac72c1f2fb54aea5ecdbc...
# 996  [{'key': 'openaire____::df45502607927471ecf8a6...
# 997  [{'key': 'openaire____::df45502607927471ecf8a6...
# 998  [{'key': 'openaire____::df45502607927471ecf8a6...
# 999  [{'key': 'opendoar____::dc6e224a8d74ce03bf3011...
#
#                                              instances isGreen  \
# 0    [{'accessRight': {'code': 'c_abf2', 'label': '...   False
# 1    [{'accessRight': {'code': 'c_abf2', 'label': '...   False
# 2    [{'accessRight': {'code': 'c_abf2', 'label': '...   False
# 3    [{'accessRight': {'code': 'c_abf2', 'label': '...    True
# 4    [{'accessRight': {'code': 'c_abf2', 'label': '...    True
# ..                                                 ...     ...
# 995  [{'accessRight': {'code': 'c_14cb', 'label': '...   False
# 996  [{'accessRight': None, 'alternateIdentifiers':...    True
# 997  [{'accessRight': None, 'alternateIdentifiers':...    True
# 998  [{'accessRight': None, 'alternateIdentifiers':...    True
# 999  [{'accessRight': {'code': 'c_abf2', 'label': '...    True
#
#     isInDiamondJournal                               relOrganizationId  \
# 0                False  openorgs____::40b9f835648a3e0d057d6917dd7e54d5
# 1                False  openorgs____::40b9f835648a3e0d057d6917dd7e54d5
# 2                False  openorgs____::40b9f835648a3e0d057d6917dd7e54d5
# 3                False  openorgs____::40b9f835648a3e0d057d6917dd7e54d5
# 4                False  openorgs____::40b9f835648a3e0d057d6917dd7e54d5
# ..                 ...                                             ...
# 995              False  openorgs____::40b9f835648a3e0d057d6917dd7e54d5
# 996              False  openorgs____::40b9f835648a3e0d057d6917dd7e54d5
# 997              False  openorgs____::40b9f835648a3e0d057d6917dd7e54d5
# 998              False  openorgs____::40b9f835648a3e0d057d6917dd7e54d5
# 999              False  openorgs____::40b9f835648a3e0d057d6917dd7e54d5
#
#     load_datetime
# 0      2025-09-05
# 1      2025-09-05
# 2      2025-09-05
# 3      2025-09-05
# 4      2025-09-05
# ..            ...
# 995    2025-09-05
# 996    2025-09-05
# 997    2025-09-05
# 998    2025-09-05
# 999    2025-09-05
#
# [1000 rows x 43 columns]

# %%
df_research_originalids = df[['id','originalIds']]

# %%
df_research_originalids
# Out:
# <pre style="white-space:pre;overflow-x:auto;line-height:normal;font-family:Menlo,'DejaVu Sans Mono',consolas,'Courier New',monospace"></pre>
#                                                  id  \
# 0    4dc99724cf04::319dc88111c9b2d6021228590e79130a
# 1    4dc99724cf04::95ea5df70a451a0487e051faa6c0a646
# 2    4dc99724cf04::fd4ac9e4a4b67e70441e5d033c144e1e
# 3    RECOLECTA___::24cb4438d1afe299e63cfdea4a31911f
# 4    RECOLECTA___::c5f9bd7b9739f4c5f064595b286d2e01
# ..                                              ...
# 995  dedup_wf_002::037a11b75e1662b0beb84c3b97f47ce1
# 996  dedup_wf_002::037a8383ee10ffcebea2e3102e3fa6ce
# 997  dedup_wf_002::037ba1ff4a8a10f7948e078bb3d6efb6
# 998  dedup_wf_002::037c3a3ae3212005fc63e98d8378595c
# 999  dedup_wf_002::037c9fce98a79decd202e1afba75b99e
#
#                                            originalIds
# 0    [50|4dc99724cf04::319dc88111c9b2d6021228590e79...
# 1    [oai:ojs.csi.unmsm:article/25240, 50|4dc99724c...
# 2    [50|4dc99724cf04::fd4ac9e4a4b67e70441e5d033c14...
# 3    [50|RECOLECTA___::24cb4438d1afe299e63cfdea4a31...
# 4    [oai:dnet:uabarcelona_::74fd71e608cc0b77e1c3f0...
# ..                                                 ...
# 995  [50|inria2______::a1ba3bd8feaf025babd7acf8bec2...
# 996  [oai:sedici.unlp.edu.ar:10915/54246, 50|od____...
# 997  [50|od______1329::db88fe08a664022e318f0b1777d8...
# 998  [oai:sedici.unlp.edu.ar:10915/170737, 50|od___...
# 999  [oai:doaj.org/article:e0290ebaabbc460eadb6638c...
#
# [1000 rows x 2 columns]

# %%
df_research_originalids = df_research_originalids.explode('originalIds').reset_index(drop=True)

# %%
df_research_originalids
# Out:
# <pre style="white-space:pre;overflow-x:auto;line-height:normal;font-family:Menlo,'DejaVu Sans Mono',consolas,'Courier New',monospace"></pre>
#                                                   id  \
# 0     4dc99724cf04::319dc88111c9b2d6021228590e79130a
# 1     4dc99724cf04::319dc88111c9b2d6021228590e79130a
# 2     4dc99724cf04::95ea5df70a451a0487e051faa6c0a646
# 3     4dc99724cf04::95ea5df70a451a0487e051faa6c0a646
# 4     4dc99724cf04::fd4ac9e4a4b67e70441e5d033c144e1e
# ...                                              ...
# 5515  dedup_wf_002::037c9fce98a79decd202e1afba75b99e
# 5516  dedup_wf_002::037c9fce98a79decd202e1afba75b99e
# 5517  dedup_wf_002::037c9fce98a79decd202e1afba75b99e
# 5518  dedup_wf_002::037c9fce98a79decd202e1afba75b99e
# 5519  dedup_wf_002::037c9fce98a79decd202e1afba75b99e
#
#                                             originalIds
# 0     50|4dc99724cf04::319dc88111c9b2d6021228590e79130a
# 1                       oai:ojs.csi.unmsm:article/21901
# 2                       oai:ojs.csi.unmsm:article/25240
# 3     50|4dc99724cf04::95ea5df70a451a0487e051faa6c0a646
# 4     50|4dc99724cf04::fd4ac9e4a4b67e70441e5d033c144e1e
# ...                                                 ...
# 5515  oai:doaj.org/article:e0290ebaabbc460eadb6638c7...
# 5516  50|doajarticles::e2d75f1446d91978c44cf6313b8c4684
# 5517  50|od______1329::059069d02946685668868f0429c1cf91
# 5518                  oai:sedici.unlp.edu.ar:10915/9942
# 5519  50|od______3056::059069d02946685668868f0429c1cf91
#
# [5520 rows x 2 columns]

# %% [markdown]
# ## Node
# + info en https://graph.openaire.eu/docs/data-model/entities/research-product

# %%
def openaire_land_researchproduct_originalid(df: pd.DataFrame)-> pd.DataFrame:

    load_dt = _pick_load_dt(df)

    df_research_originalids = df[['id','originalIds']]

    df_research_originalids = df_research_originalids.explode('originalIds').reset_index(drop=True)

    df_research_originalids['load_datetime'] = load_dt

    return df_research_originalids

# %%
df_research_originalids = openaire_land_researchproduct_originalid(df)

# %%
df_research_originalids
# Out:
# <pre style="white-space:pre;overflow-x:auto;line-height:normal;font-family:Menlo,'DejaVu Sans Mono',consolas,'Courier New',monospace"></pre>
#                                                   id  \
# 0     4dc99724cf04::319dc88111c9b2d6021228590e79130a
# 1     4dc99724cf04::319dc88111c9b2d6021228590e79130a
# 2     4dc99724cf04::95ea5df70a451a0487e051faa6c0a646
# 3     4dc99724cf04::95ea5df70a451a0487e051faa6c0a646
# 4     4dc99724cf04::fd4ac9e4a4b67e70441e5d033c144e1e
# ...                                              ...
# 5515  dedup_wf_002::037c9fce98a79decd202e1afba75b99e
# 5516  dedup_wf_002::037c9fce98a79decd202e1afba75b99e
# 5517  dedup_wf_002::037c9fce98a79decd202e1afba75b99e
# 5518  dedup_wf_002::037c9fce98a79decd202e1afba75b99e
# 5519  dedup_wf_002::037c9fce98a79decd202e1afba75b99e
#
#                                             originalIds load_datetime
# 0     50|4dc99724cf04::319dc88111c9b2d6021228590e79130a    2025-09-05
# 1                       oai:ojs.csi.unmsm:article/21901    2025-09-05
# 2                       oai:ojs.csi.unmsm:article/25240    2025-09-05
# 3     50|4dc99724cf04::95ea5df70a451a0487e051faa6c0a646    2025-09-05
# 4     50|4dc99724cf04::fd4ac9e4a4b67e70441e5d033c144e1e    2025-09-05
# ...                                                 ...           ...
# 5515  oai:doaj.org/article:e0290ebaabbc460eadb6638c7...    2025-09-05
# 5516  50|doajarticles::e2d75f1446d91978c44cf6313b8c4684    2025-09-05
# 5517  50|od______1329::059069d02946685668868f0429c1cf91    2025-09-05
# 5518                  oai:sedici.unlp.edu.ar:10915/9942    2025-09-05
# 5519  50|od______3056::059069d02946685668868f0429c1cf91    2025-09-05
#
# [5520 rows x 3 columns]
