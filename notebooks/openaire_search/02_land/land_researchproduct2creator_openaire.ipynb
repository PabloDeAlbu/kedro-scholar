# %%
from datetime import date
import ast
import pandas as pd

pd.set_option('display.max_columns', None)
df = catalog.load('raw/openaire/researchproduct')
# Out:
#                     INFO     Loading data from raw/openaire/researchproduct (CSVDataset)...     ]8;id=725345;file:///root/kedro-cic/.venv/lib/python3.10/site-packages/kedro/io/data_catalog.py\data_catalog.py]8;;\:]8;id=590734;file:///root/kedro-cic/.venv/lib/python3.10/site-packages/kedro/io/data_catalog.py#389\389]8;;\

# %% [markdown]
# ## Paso 0: Seleccionar columnas con identificador y 'creator'

# %%
df_researchproduct = df.loc[:, ['dri:objIdentifier', 'creator']]
df_researchproduct = df_researchproduct.convert_dtypes()

# %%
df_researchproduct.head(5)
# Out:
# <pre style="white-space:pre;overflow-x:auto;line-height:normal;font-family:Menlo,'DejaVu Sans Mono',consolas,'Courier New',monospace"></pre>
#                                 dri:objIdentifier  \
# 0  doi_dedup___::2577d684a839dc78be3e1307914cdfd5
# 1  doi_________::01bdfeebe25730711be433245a4426e7
# 2  doi_dedup___::fccba469c4dbc14c5cec34e69ab21625
# 3  doi_dedup___::000d1effb7dd214508cfa2db791e3814
# 4  doi_dedup___::387324dfb1abac93013eccfd545780c1
#
#                                              creator
# 0  [{'@rank': '1', '@name': 'Diana', '@surname': ...
# 1  [{'@rank': '1', '@name': 'María S.', '@surname...
# 2  [{'@rank': '1', '#text': 'Nancy Esther Quarant...
# 3  [{'@rank': '1', '@name': 'Federico', '@surname...
# 4             {'@rank': '1', '#text': 'Clara Tapia'}

# %% [markdown]
# ## Paso 1: Asegurarse de que 'creator' sea un diccionario o lista

# %%
df_researchproduct['creator'] = df_researchproduct['creator'].apply(lambda x: ast.literal_eval(x) if isinstance(x, str) else x)
df_researchproduct['creator'] = df_researchproduct['creator'].apply(lambda x: [x] if not isinstance(x, list) else x)

# %%
df_researchproduct
# Out:
# <pre style="white-space:pre;overflow-x:auto;line-height:normal;font-family:Menlo,'DejaVu Sans Mono',consolas,'Courier New',monospace"></pre>
#                                    dri:objIdentifier  \
# 0     doi_dedup___::2577d684a839dc78be3e1307914cdfd5
# 1     doi_________::01bdfeebe25730711be433245a4426e7
# 2     doi_dedup___::fccba469c4dbc14c5cec34e69ab21625
# 3     doi_dedup___::000d1effb7dd214508cfa2db791e3814
# 4     doi_dedup___::387324dfb1abac93013eccfd545780c1
# ...                                              ...
# 3870  doi_dedup___::a901f8fcb7a8e4fd764da3fdbf42c064
# 3871  doi_dedup___::7d4824281cdafde3676552da1141877a
# 3872  doi_dedup___::acf6451bd9b42e6b944f84d81fe47232
# 3873  doi_dedup___::42f7f1f2a1e586ca7bb4942987b54b71
# 3874  doi_dedup___::10fb361856b54e85f1dd2a296b90d1ad
#
#                                                 creator
# 0     [{'@rank': '1', '@name': 'Diana', '@surname': ...
# 1     [{'@rank': '1', '@name': 'María S.', '@surname...
# 2     [{'@rank': '1', '#text': 'Nancy Esther Quarant...
# 3     [{'@rank': '1', '@name': 'Federico', '@surname...
# 4              [{'@rank': '1', '#text': 'Clara Tapia'}]
# ...                                                 ...
# 3870  [{'@rank': '1', '@name': 'María Esther Ferná...
# 3871  [{'@rank': '1', '@name': 'Rosa María', '@surn...
# 3872  [{'@rank': '1', '@name': 'Jason', '@surname': ...
# 3873  [{'@rank': '1', '#text': 'Guillermo Daniel Man...
# 3874  [{'@rank': '1', '@surname': 'Ana María Vargas ...
#
# [3875 rows x 2 columns]

# %% [markdown]
# ## Paso 2: Explode la columna 'creator' y reinicia el índice

# %%
df_researchproduct = df_researchproduct.explode('creator').reset_index(drop=True)

# %%
df_researchproduct
# Out:
# <pre style="white-space:pre;overflow-x:auto;line-height:normal;font-family:Menlo,'DejaVu Sans Mono',consolas,'Courier New',monospace"></pre>
#                                     dri:objIdentifier  \
# 0      doi_dedup___::2577d684a839dc78be3e1307914cdfd5
# 1      doi_dedup___::2577d684a839dc78be3e1307914cdfd5
# 2      doi_dedup___::2577d684a839dc78be3e1307914cdfd5
# 3      doi_________::01bdfeebe25730711be433245a4426e7
# 4      doi_________::01bdfeebe25730711be433245a4426e7
# ...                                               ...
# 18572  doi_dedup___::42f7f1f2a1e586ca7bb4942987b54b71
# 18573  doi_dedup___::10fb361856b54e85f1dd2a296b90d1ad
# 18574  doi_dedup___::10fb361856b54e85f1dd2a296b90d1ad
# 18575  doi_dedup___::10fb361856b54e85f1dd2a296b90d1ad
# 18576  doi_dedup___::10fb361856b54e85f1dd2a296b90d1ad
#
#                                                  creator
# 0      {'@rank': '1', '@name': 'Diana', '@surname': '...
# 1      {'@rank': '2', '@name': 'Angelo', '@surname': ...
# 2      {'@rank': '3', '@name': 'Angel Ricardo', '@sur...
# 3      {'@rank': '1', '@name': 'María S.', '@surname'...
# 4      {'@rank': '2', '@name': 'Juan J.', '@surname':...
# ...                                                  ...
# 18572  {'@rank': '5', '@orcid': '0000-0002-6677-2471'...
# 18573  {'@rank': '1', '@surname': 'Ana María Vargas D...
# 18574  {'@rank': '2', '@surname': 'Stella Maris Martí...
# 18575  {'@rank': '3', '@surname': 'Roxana Mariani', '...
# 18576  {'@rank': '4', '@surname': 'Graciela Varela', ...
#
# [18577 rows x 2 columns]

# %% [markdown]
# ## Paso 3: Normalizar la columna 'creator' en nuevas columnas

# %%
creator_expanded = pd.json_normalize(df_researchproduct["creator"])

# %%
creator_expanded
# Out:
# <pre style="white-space:pre;overflow-x:auto;line-height:normal;font-family:Menlo,'DejaVu Sans Mono',consolas,'Courier New',monospace"></pre>
#       @rank          @name               @surname  \
# 0         1          Diana             Monteoliva
# 1         2         Angelo               Plastino
# 2         3  Angel Ricardo               Plastino
# 3         1       María S.    Leguizamón‐Aparicio
# 4         2        Juan J.                  Musci
# ...     ...            ...                    ...
# 18572     5            NaN                    NaN
# 18573     1            NaN  Ana María Vargas Díaz
# 18574     2            NaN    Stella Maris Martín
# 18575     3            NaN         Roxana Mariani
# 18576     4            NaN        Graciela Varela
#
#                               #text               @orcid       @orcid_pending
# 0                  Diana Monteoliva                  NaN                  NaN
# 1                   Angelo Plastino  0000-0001-5934-2783                  NaN
# 2            Angel Ricardo Plastino                  NaN                  NaN
# 3      María S. Leguizamón‐Aparicio                  NaN                  NaN
# 4                     Juan J. Musci                  NaN                  NaN
# ...                             ...                  ...                  ...
# 18572       Diego Bautista Genovese  0000-0002-6677-2471                  NaN
# 18573         Ana María Vargas Díaz                  NaN                  NaN
# 18574           Stella Maris Martín                  NaN                  NaN
# 18575                Roxana Mariani                  NaN  0000-0002-0066-6692
# 18576               Graciela Varela                  NaN                  NaN
#
# [18577 rows x 6 columns]

# %% [markdown]
# ## Paso 4: Concatenar df_researchproduct con df_creator asegurando que los índices están alineados

# %%
df_researchproduct2creator = pd.concat([df_researchproduct, creator_expanded], axis=1)
df_researchproduct2creator.drop(columns='creator', inplace=True)

# %%
df_researchproduct2creator
# Out:
# <pre style="white-space:pre;overflow-x:auto;line-height:normal;font-family:Menlo,'DejaVu Sans Mono',consolas,'Courier New',monospace"></pre>
#                                     dri:objIdentifier @rank          @name  \
# 0      doi_dedup___::2577d684a839dc78be3e1307914cdfd5     1          Diana
# 1      doi_dedup___::2577d684a839dc78be3e1307914cdfd5     2         Angelo
# 2      doi_dedup___::2577d684a839dc78be3e1307914cdfd5     3  Angel Ricardo
# 3      doi_________::01bdfeebe25730711be433245a4426e7     1       María S.
# 4      doi_________::01bdfeebe25730711be433245a4426e7     2        Juan J.
# ...                                               ...   ...            ...
# 18572  doi_dedup___::42f7f1f2a1e586ca7bb4942987b54b71     5            NaN
# 18573  doi_dedup___::10fb361856b54e85f1dd2a296b90d1ad     1            NaN
# 18574  doi_dedup___::10fb361856b54e85f1dd2a296b90d1ad     2            NaN
# 18575  doi_dedup___::10fb361856b54e85f1dd2a296b90d1ad     3            NaN
# 18576  doi_dedup___::10fb361856b54e85f1dd2a296b90d1ad     4            NaN
#
#                     @surname                         #text  \
# 0                 Monteoliva              Diana Monteoliva
# 1                   Plastino               Angelo Plastino
# 2                   Plastino        Angel Ricardo Plastino
# 3        Leguizamón‐Aparicio  María S. Leguizamón‐Aparicio
# 4                      Musci                 Juan J. Musci
# ...                      ...                           ...
# 18572                    NaN       Diego Bautista Genovese
# 18573  Ana María Vargas Díaz         Ana María Vargas Díaz
# 18574    Stella Maris Martín           Stella Maris Martín
# 18575         Roxana Mariani                Roxana Mariani
# 18576        Graciela Varela               Graciela Varela
#
#                     @orcid       @orcid_pending
# 0                      NaN                  NaN
# 1      0000-0001-5934-2783                  NaN
# 2                      NaN                  NaN
# 3                      NaN                  NaN
# 4                      NaN                  NaN
# ...                    ...                  ...
# 18572  0000-0002-6677-2471                  NaN
# 18573                  NaN                  NaN
# 18574                  NaN                  NaN
# 18575                  NaN  0000-0002-0066-6692
# 18576                  NaN                  NaN
#
# [18577 rows x 7 columns]

# %% [markdown]
# ## Paso 5: Agrego load_datetime

# %%
df_researchproduct2creator['load_datetime'] = date.today()

# %%
df_researchproduct2creator
# Out:
# <pre style="white-space:pre;overflow-x:auto;line-height:normal;font-family:Menlo,'DejaVu Sans Mono',consolas,'Courier New',monospace"></pre>
#                                     dri:objIdentifier @rank          @name  \
# 0      doi_dedup___::2577d684a839dc78be3e1307914cdfd5     1          Diana
# 1      doi_dedup___::2577d684a839dc78be3e1307914cdfd5     2         Angelo
# 2      doi_dedup___::2577d684a839dc78be3e1307914cdfd5     3  Angel Ricardo
# 3      doi_________::01bdfeebe25730711be433245a4426e7     1       María S.
# 4      doi_________::01bdfeebe25730711be433245a4426e7     2        Juan J.
# ...                                               ...   ...            ...
# 18572  doi_dedup___::42f7f1f2a1e586ca7bb4942987b54b71     5            NaN
# 18573  doi_dedup___::10fb361856b54e85f1dd2a296b90d1ad     1            NaN
# 18574  doi_dedup___::10fb361856b54e85f1dd2a296b90d1ad     2            NaN
# 18575  doi_dedup___::10fb361856b54e85f1dd2a296b90d1ad     3            NaN
# 18576  doi_dedup___::10fb361856b54e85f1dd2a296b90d1ad     4            NaN
#
#                     @surname                         #text  \
# 0                 Monteoliva              Diana Monteoliva
# 1                   Plastino               Angelo Plastino
# 2                   Plastino        Angel Ricardo Plastino
# 3        Leguizamón‐Aparicio  María S. Leguizamón‐Aparicio
# 4                      Musci                 Juan J. Musci
# ...                      ...                           ...
# 18572                    NaN       Diego Bautista Genovese
# 18573  Ana María Vargas Díaz         Ana María Vargas Díaz
# 18574    Stella Maris Martín           Stella Maris Martín
# 18575         Roxana Mariani                Roxana Mariani
# 18576        Graciela Varela               Graciela Varela
#
#                     @orcid       @orcid_pending load_datetime
# 0                      NaN                  NaN    2024-11-28
# 1      0000-0001-5934-2783                  NaN    2024-11-28
# 2                      NaN                  NaN    2024-11-28
# 3                      NaN                  NaN    2024-11-28
# 4                      NaN                  NaN    2024-11-28
# ...                    ...                  ...           ...
# 18572  0000-0002-6677-2471                  NaN    2024-11-28
# 18573                  NaN                  NaN    2024-11-28
# 18574                  NaN                  NaN    2024-11-28
# 18575                  NaN  0000-0002-0066-6692    2024-11-28
# 18576                  NaN                  NaN    2024-11-28
#
# [18577 rows x 8 columns]
