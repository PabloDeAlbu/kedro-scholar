# %%
import requests
import pandas as pd
import xmltodict
import math

# %%
dim_doi = catalog.load('stg/dim_doi')
r_token = catalog.load('params:openaire_fetch_options.access_token')
env = 'dev'
pd.set_option("display.max_columns", None)
# Out:
# [01/28/25 14:47:45] INFO     Loading data from stg/dim_doi (SQLTableDataset)...                 ]8;id=482722;file:///home/pablo/dev/CIC/dw-cic/kedro/kedro-cic/.venv/lib/python3.10/site-packages/kedro/io/data_catalog.py\data_catalog.py]8;;\:]8;id=533212;file:///home/pablo/dev/CIC/dw-cic/kedro/kedro-cic/.venv/lib/python3.10/site-packages/kedro/io/data_catalog.py#389\389]8;;\
# ╭─────────────────────────────── Traceback (most recent call last) ────────────────────────────────╮
# │ /home/pablo/dev/CIC/dw-cic/kedro/kedro-cic/.venv/lib/python3.10/site-packages/kedro/io/core.py:2 │
# │ 44 in load                                                                                       │
# │                                                                                                  │
# │   241 │   │   │   self._logger.debug("Loading %s", str(self))                                    │
# │   242 │   │   │                                                                                  │
# │   243 │   │   │   try:                                                                           │
# │ ❱ 244 │   │   │   │   return load_func(self)                                                     │
# │   245 │   │   │   except DatasetError:                                                           │
# │   246 │   │   │   │   raise                                                                      │
# │   247 │   │   │   except Exception as exc:                                                       │
# │                                                                                                  │
# │ /home/pablo/dev/CIC/dw-cic/kedro/kedro-cic/.venv/lib/python3.10/site-packages/kedro_datasets/pan │
# │ das/sql_dataset.py:266 in load                                                                   │
# │                                                                                                  │
# │   263 │   │   }                                                                                  │
# │   264 │                                                                                          │
# │   265 │   def load(self) -> pd.DataFrame:                                                        │
# │ ❱ 266 │   │   return pd.read_sql_table(con=self.engine, **self._load_args)                       │
# │   267 │                                                                                          │
# │   268 │   def save(self, data: pd.DataFrame) -> None:                                            │
# │   269 │   │   data.to_sql(con=self.engine, **self._save_args)                                    │
# │                                                                                                  │
# │ /home/pablo/dev/CIC/dw-cic/kedro/kedro-cic/.venv/lib/python3.10/site-packages/pandas/io/sql.py:3 │
# │ 86 in read_sql_table                                                                             │
# │                                                                                                  │
# │    383 │                                                                                         │
# │    384 │   with pandasSQL_builder(con, schema=schema, need_transaction=True) as pandas_sql:      │
# │    385 │   │   if not pandas_sql.has_table(table_name):                                          │
# │ ❱  386 │   │   │   raise ValueError(f"Table {table_name} not found")                             │
# │    387 │   │                                                                                     │
# │    388 │   │   table = pandas_sql.read_table(                                                    │
# │    389 │   │   │   table_name,                                                                   │
# ╰──────────────────────────────────────────────────────────────────────────────────────────────────╯
# ValueError: Table dim_doi not found
#
# The above exception was the direct cause of the following exception:
#
# ╭─────────────────────────────── Traceback (most recent call last) ────────────────────────────────╮
# │ in <module>:1                                                                                    │
# │                                                                                                  │
# │ ❱ 1 dim_doi = catalog.load('stg/dim_doi')                                                        │
# │   2 r_token = catalog.load('params:openaire_fetch_options.access_token')                        │
# │   3 env = 'dev'                                                                                  │
# │   4 pd.set_option("display.max_columns", None)                                                   │
# │                                                                                                  │
# │ /home/pablo/dev/CIC/dw-cic/kedro/kedro-cic/.venv/lib/python3.10/site-packages/kedro/io/data_cata │
# │ log.py:396 in load                                                                               │
# │                                                                                                  │
# │   393 │   │   │   extra={"markup": True},                                                        │
# │   394 │   │   )                                                                                  │
# │   395 │   │                                                                                      │
# │ ❱ 396 │   │   result = dataset.load()                                                            │
# │   397 │   │                                                                                      │
# │   398 │   │   return result                                                                      │
# │   399                                                                                            │
# │                                                                                                  │
# │ /home/pablo/dev/CIC/dw-cic/kedro/kedro-cic/.venv/lib/python3.10/site-packages/kedro/io/core.py:2 │
# │ 51 in load                                                                                       │
# │                                                                                                  │
# │   248 │   │   │   │   # This exception handling is by design as the composed datasets            │
# │   249 │   │   │   │   # can throw any type of exception.                                         │
# │   250 │   │   │   │   message = f"Failed while loading data from dataset {self!s}.\n{exc!s}"     │
# │ ❱ 251 │   │   │   │   raise DatasetError(message) from exc                                       │
# │   252 │   │                                                                                      │
# │   253 │   │   load.__annotations__["return"] = load_func.__annotations__.get("return")           │
# │   254 │   │   load.__loadwrapped__ = True  # type: ignore[attr-defined]                          │
# ╰──────────────────────────────────────────────────────────────────────────────────────────────────╯
# DatasetError: Failed while loading data from dataset SQLTableDataset(load_args={'schema': stg}, save_args={'index':
# False}, table_name=dim_doi).
# Table dim_doi not found

# %%
dim_doi
# Out:
# <pre style="white-space:pre;overflow-x:auto;line-height:normal;font-family:Menlo,'DejaVu Sans Mono',consolas,'Courier New',monospace"></pre>
# 'REPLACE_ME'

# %% [markdown]
# ### Recupero datos de OpenAire Graph
#
# Hago una pequeña manipulación de datos, que debería evitarse. Para eso en vez de el hub doi, hay que usar una dim_doi con el valor del pid ya manipulado en mart.

# %%
def fetch_researchproduct_openaire(dim_doi: pd.DataFrame, r_token, env)-> pd.DataFrame:
    base_url = "https://api.openaire.eu/search/researchProducts"
    df_list = []

    doi_limit = 9999
    if (env == 'dev'): doi_limit = 9
    
    skipped_list = []

    not_in_openaire = dim_doi['in_openaire'] == False
    dim_doi = dim_doi[not_in_openaire]

    doi_list = dim_doi.iloc[0:doi_limit]['doi'].to_list()
    doi_comma_separated = ','.join(doi_list)

    # se define cantidad de batches a partir de la cantidad de resultados por batch y cantidad de doi
    batch_size = 10
    num_batches = math.ceil(len(doi_list) / batch_size)

    for batch_index in range(num_batches):

        batch = doi_list[batch_index * batch_size : (batch_index + 1) * batch_size]
        doi_comma_separated = ','.join(batch)

        graph_url = f"{base_url}?doi={doi_comma_separated}"
        headers = { 'Authorization': f'Bearer {r_token}' }

        api_response = requests.get(graph_url, headers=headers)
        print(f'GET "{graph_url}" {api_response.status_code}')

        if api_response.status_code == 200:
            data_dict = xmltodict.parse(api_response.content)
            results = data_dict.get('response', {}).get('results', {}).get('result', [])

            for result in results:

                publication_header = result.get('header', {})
                publication_metadata = result.get('metadata', {}).get('oaf:entity', {}).get('oaf:result', {})

                publication = publication_header | publication_metadata 
                if publication:
                    df_normalized = pd.json_normalize(publication, max_level=0)
                    df_list.append(df_normalized)
                else:
                    print("No publication data found in result")
        else:
            print(f'Error: Received status code {api_response.status_code}')
            skipped_list.extend(batch)
            break

    print(f'{len(df_list)} batches processed')
    print(f'{len(skipped_list)} DOIs skipped')

    if df_list:
        df = pd.concat(df_list, ignore_index=True)
    else:
        df = pd.DataFrame()   

    return df, skipped_list

# %%
df, skiped_list = fetch_researchproduct_openaire(dim_doi, r_token, env)
# Out:
# GET "https://api.openaire.eu/search/researchProducts?doi=10.24267/22564004.544,10.5151/despro-sigradi2016-510,10.1051/0004-6361/201732349,10.1016/j.revpalbo.2021.104401,10.4322/polimeros.2013.033,10.3390/quantum4010009,10.1111/j.1472-765x.2005.01785.x,10.1016/j.foodqual.2007.06.004,10.1016/j.asr.2020.07.008" 200
# 9 batches processed
# 0 DOIs skipped

# %%
df
# Out:
# <pre style="white-space:pre;overflow-x:auto;line-height:normal;font-family:Menlo,'DejaVu Sans Mono',consolas,'Courier New',monospace"></pre>
#                                   @xmlns:xsi  \
# 0  http://www.w3.org/2001/XMLSchema-instance
# 1  http://www.w3.org/2001/XMLSchema-instance
# 2  http://www.w3.org/2001/XMLSchema-instance
# 3  http://www.w3.org/2001/XMLSchema-instance
# 4  http://www.w3.org/2001/XMLSchema-instance
# 5  http://www.w3.org/2001/XMLSchema-instance
# 6  http://www.w3.org/2001/XMLSchema-instance
# 7  http://www.w3.org/2001/XMLSchema-instance
# 8  http://www.w3.org/2001/XMLSchema-instance
#
#                                 dri:objIdentifier     dri:dateOfCollection  \
# 0  doi_dedup___::2577d684a839dc78be3e1307914cdfd5  2024-10-11T14:10:24.466
# 1  doi_dedup___::fccba469c4dbc14c5cec34e69ab21625  2024-10-11T14:20:20.957
# 2  doi_dedup___::000d1effb7dd214508cfa2db791e3814  2024-10-11T14:28:54.171
# 3  doi_dedup___::387324dfb1abac93013eccfd545780c1  2024-10-11T14:13:38.393
# 4  doi_dedup___::f691ad831dbde25ac81f54df69d9c4c3  2024-10-11T14:19:48.391
# 5  doi_dedup___::003ad75f1f31e07802bd516776c071a5  2024-10-11T14:20:19.329
# 6  doi_dedup___::e5dc4572d11550244ba129c0f2980ca0  2024-10-11T14:04:09.651
# 7  doi_dedup___::8016b09f3458d8268c0d12f1886cb7e0  2024-10-11T14:16:23.494
# 8  doi_dedup___::88c803ab22c0e31bda1479dad4e1788f  2024-10-11T14:19:21.159
#
#   dri:dateOfTransformation                                      collectedfrom  \
# 0                     None  [{'@name': 'LAReferencia - Red Federada de Rep...
# 1                     None  [{'@name': 'Crossref', '@id': 'openaire____::0...
# 2                     None  [{'@name': 'LAReferencia - Red Federada de Rep...
# 3                     None  [{'@name': 'UnpayWall', '@id': 'openaire____::...
# 4                     None  [{'@name': 'Crossref', '@id': 'openaire____::0...
# 5                     None  [{'@name': 'UnpayWall', '@id': 'openaire____::...
# 6                     None  [{'@name': 'LAReferencia - Red Federada de Rep...
# 7                     None  [{'@name': 'Recolector de Ciencia Abierta, REC...
# 8                     None  [{'@name': 'UnpayWall', '@id': 'openaire____::...
#
#                                           originalId  \
# 0  [quantum4010009, 10.3390/quantum4010009, 50|do...
# 1  [S0273117720304853, 10.1016/j.asr.2020.07.008,...
# 2  [10.24267/22564004.544, 50|doiboost____|000d1e...
# 3  [10.5151/despro-sigradi2016-510, 50|doiboost__...
# 4  [S0034666721000257, 10.1016/j.revpalbo.2021.10...
# 5  [aa32349-17, 10.1051/0004-6361/201732349, 50|d...
# 6  [10.4322/polimeros.2013.033, 50|doiboost____|e...
# 7  [S0950329307000754, 10.1016/j.foodqual.2007.06...
# 8  [10.1111/j.1472-765X.2005.01785.x, 10.1111/j.1...
#
#                                                  pid  \
# 0  {'@classid': 'doi', '@classname': 'Digital Obj...
# 1  [{'@classid': 'doi', '@classname': 'Digital Ob...
# 2  [{'@classid': 'doi', '@classname': 'Digital Ob...
# 3  [{'@classid': 'doi', '@classname': 'Digital Ob...
# 4  [{'@classid': 'doi', '@classname': 'Digital Ob...
# 5  [{'@classid': 'doi', '@classname': 'Digital Ob...
# 6  [{'@classid': 'doi', '@classname': 'Digital Ob...
# 7  [{'@classid': 'doi', '@classname': 'Digital Ob...
# 8  [{'@classid': 'doi', '@classname': 'Digital Ob...
#
#                                              measure  \
# 0  [{'@id': 'influence', '@score': '3.29944E-9', ...
# 1  [{'@id': 'influence', '@score': '2.95062E-9', ...
# 2  [{'@id': 'influence', '@score': '2.8970693E-9'...
# 3  [{'@id': 'influence', '@score': '3.1040028E-9'...
# 4  [{'@id': 'influence', '@score': '2.9581497E-9'...
# 5  [{'@id': 'influence', '@score': '3.6903365E-9'...
# 6  [{'@id': 'influence', '@score': '2.9315002E-9'...
# 7  [{'@id': 'influence', '@score': '5.8182086E-9'...
# 8  [{'@id': 'influence', '@score': '4.953451E-9',...
#
#                                   fulltext  \
# 0  http://www.mdpi.com/2624-960X/4/1/9/pdf
# 1                                      NaN
# 2                                      NaN
# 3                                      NaN
# 4                                      NaN
# 5                                      NaN
# 6                                      NaN
# 7                                      NaN
# 8                                      NaN
#
#                                                title  \
# 0  [{'@classid': 'main title', '@classname': 'mai...
# 1  [{'@classid': 'main title', '@classname': 'mai...
# 2  [{'@classid': 'main title', '@classname': 'mai...
# 3  [{'@classid': 'main title', '@classname': 'mai...
# 4  [{'@classid': 'main title', '@classname': 'mai...
# 5  [{'@classid': 'main title', '@classname': 'mai...
# 6  [{'@classid': 'main title', '@classname': 'mai...
# 7  [{'@classid': 'main title', '@classname': 'mai...
# 8  [{'@classid': 'main title', '@classname': 'mai...
#
#                                      bestaccessright  \
# 0  {'@classid': 'OPEN', '@classname': 'Open Acces...
# 1  {'@classid': 'CLOSED', '@classname': 'Closed A...
# 2  {'@classid': 'OPEN', '@classname': 'Open Acces...
# 3  {'@classid': 'OPEN', '@classname': 'Open Acces...
# 4  {'@classid': 'CLOSED', '@classname': 'Closed A...
# 5  {'@classid': 'OPEN', '@classname': 'Open Acces...
# 6  {'@classid': 'OPEN', '@classname': 'Open Acces...
# 7  {'@classid': 'CLOSED', '@classname': 'Closed A...
# 8  {'@classid': 'OPEN', '@classname': 'Open Acces...
#
#                                              creator  \
# 0  [{'@rank': '1', '@name': 'Diana', '@surname': ...
# 1  [{'@rank': '1', '#text': 'Nancy Esther Quarant...
# 2  [{'@rank': '1', '@name': 'Federico', '@surname...
# 3             {'@rank': '1', '#text': 'Clara Tapia'}
# 4  [{'@rank': '1', '#text': 'Micaela Paolicchi'},...
# 5  [{'@rank': '1', '@orcid': '0000-0002-9032-5815...
# 6  [{'@rank': '1', '@name': 'Sebastián', '@surna...
# 7  [{'@rank': '1', '@name': 'M. M.', '@surname': ...
# 8  [{'@rank': '1', '#text': 'Lilia Reneé Cavaglie...
#
#                                              country dateofacceptance  \
# 0  {'@classid': 'AR', '@classname': 'Argentina', ...       2022-02-22
# 1                                                NaN       2020-10-01
# 2  {'@classid': 'AR', '@classname': 'Argentina', ...       2021-07-09
# 3                                                NaN       2016-12-01
# 4                                                NaN       2021-05-01
# 5                                                NaN       2018-07-01
# 6  {'@classid': 'AR', '@classname': 'Argentina', ...       2013-01-01
# 7  {'@classid': 'ES', '@classname': 'Spain', '@sc...       2008-01-01
# 8                                                NaN       2005-11-01
#
#                                          description  \
# 0  <jats:p>We deal here with an exactly solvable ...
# 1  Abstract   In a first paper, we presented an i...
# 2  <jats:p>El objetivo de este artículo es analiz...
# 3  Palabras clave:   IMPRESION 3D; TEXTILES; INDU...
# 4  Abstract   Phytoliths represent an important f...
# 5  <jats:p><jats:italic>Aims</jats:italic>. The b...
# 6  En este trabajo se estudiaron mezclas epoxy/po...
# 7  [Authors López-Osornio and Hough: Agencia Naci...
# 8  Enterobacter cloacae, Microbacterium oleovoran...
#
#                                              subject  \
# 0  [{'@classid': 'keyword', '@classname': 'keywor...
# 1  [{'@classid': 'FOS', '@classname': 'Fields of ...
# 2  [{'@classid': 'keyword', '@classname': 'keywor...
# 3  [{'@classid': 'FOS', '@classname': 'Fields of ...
# 4  [{'@classid': 'FOS', '@classname': 'Fields of ...
# 5  [{'@classid': 'FOS', '@classname': 'Fields of ...
# 6  [{'@classid': 'keyword', '@classname': 'keywor...
# 7  [{'@classid': 'SDG', '@classname': 'Sustainabl...
# 8  [{'@classid': 'FOS', '@classname': 'Fields of ...
#
#                                             language  \
# 0  {'@classid': 'und', '@classname': 'Undetermine...
# 1  {'@classid': 'und', '@classname': 'Undetermine...
# 2  {'@classid': 'und', '@classname': 'Undetermine...
# 3  {'@classid': 'und', '@classname': 'Undetermine...
# 4  {'@classid': 'und', '@classname': 'Undetermine...
# 5  {'@classid': 'und', '@classname': 'Undetermine...
# 6  {'@classid': 'und', '@classname': 'Undetermine...
# 7  {'@classid': 'und', '@classname': 'Undetermine...
# 8  {'@classid': 'und', '@classname': 'Undetermine...
#
#                                         relevantdate  \
# 0  [{'@classid': 'created', '@classname': 'create...
# 1  [{'@classid': 'created', '@classname': 'create...
# 2  [{'@classid': 'created', '@classname': 'create...
# 3  [{'@classid': 'created', '@classname': 'create...
# 4  [{'@classid': 'created', '@classname': 'create...
# 5  [{'@classid': 'created', '@classname': 'create...
# 6  [{'@classid': 'created', '@classname': 'create...
# 7  [{'@classid': 'created', '@classname': 'create...
# 8  [{'@classid': 'created', '@classname': 'create...
#
#                        publisher  \
# 0                        MDPI AG
# 1                    Elsevier BV
# 2          Universidad de Boyacá
# 3                Editora Blucher
# 4                    Elsevier BV
# 5                   EDP Sciences
# 6            FapUNIFESP (SciELO)
# 7                    Elsevier BV
# 8  Oxford University Press (OUP)
#
#                                               source  \
# 0  [Crossref, Quantum Reports; Volume 4; Issue 1;...
# 1                                           Crossref
# 2  [Crossref, reponame:SEDICI (UNLP), instname:Un...
# 3                                           Crossref
# 4                                           Crossref
# 5                                           Crossref
# 6  [reponame:CONICET Digital (CONICET), instacron...
# 7  [Crossref, reponame:Digital.CSIC. Repositorio ...
# 8                                           Crossref
#
#                          format  \
# 0    [application/pdf, 127-134]
# 1                           NaN
# 2      [application/pdf, 27-47]
# 3                           NaN
# 4                           NaN
# 5                           NaN
# 6  [application/pdf, text/html]
# 7                           NaN
# 8                           NaN
#
#                                           resulttype  \
# 0  {'@classid': 'publication', '@classname': 'pub...
# 1  {'@classid': 'publication', '@classname': 'pub...
# 2  {'@classid': 'publication', '@classname': 'pub...
# 3  {'@classid': 'publication', '@classname': 'pub...
# 4  {'@classid': 'publication', '@classname': 'pub...
# 5  {'@classid': 'publication', '@classname': 'pub...
# 6  {'@classid': 'publication', '@classname': 'pub...
# 7  {'@classid': 'publication', '@classname': 'pub...
# 8  {'@classid': 'publication', '@classname': 'pub...
#
#                                         resourcetype isgreen openaccesscolor  \
# 0  {'@classid': 'publication', '@classname': 'pub...    true            gold
# 1  {'@classid': 'publication', '@classname': 'pub...   false          bronze
# 2  {'@classid': 'publication', '@classname': 'pub...    true            gold
# 3  {'@classid': 'publication', '@classname': 'pub...   false          bronze
# 4  {'@classid': 'publication', '@classname': 'pub...   false          bronze
# 5  {'@classid': 'publication', '@classname': 'pub...   false          bronze
# 6  {'@classid': 'publication', '@classname': 'pub...    true            gold
# 7  {'@classid': 'publication', '@classname': 'pub...   false          bronze
# 8  {'@classid': 'publication', '@classname': 'pub...   false          bronze
#
#   isindiamondjournal publiclyfunded  \
# 0              false          false
# 1              false          false
# 2              false          false
# 3              false          false
# 4              false          false
# 5              false          false
# 6              false          false
# 7              false          false
# 8              false          false
#
#                                              journal  \
# 0  {'@eissn': '2624-960X', '@ep': '134', '@sp': '...
# 1  {'@issn': '0273-1177', '@ep': '2000', '@sp': '...
# 2  {'@issn': '2256-4004', '@eissn': '2539-147X', ...
# 3                         Blucher Design Proceedings
# 4  {'@issn': '0034-6667', '@sp': '104401', '@vol'...
# 5  {'@issn': '0004-6361', '@eissn': '1432-0746', ...
# 6  {'@eissn': '1678-5169', '@ep': '365', '@sp': '...
# 7  {'@issn': '0950-3293', '@ep': '20', '@sp': '12...
# 8  {'@issn': '0266-8254', '@eissn': '1365-2673', ...
#
#                                             datainfo  \
# 0  {'inferred': 'true', 'deletedbyinference': 'fa...
# 1  {'inferred': 'true', 'deletedbyinference': 'fa...
# 2  {'inferred': 'true', 'deletedbyinference': 'fa...
# 3  {'inferred': 'true', 'deletedbyinference': 'fa...
# 4  {'inferred': 'true', 'deletedbyinference': 'fa...
# 5  {'inferred': 'true', 'deletedbyinference': 'fa...
# 6  {'inferred': 'true', 'deletedbyinference': 'fa...
# 7  {'inferred': 'true', 'deletedbyinference': 'fa...
# 8  {'inferred': 'true', 'deletedbyinference': 'fa...
#
#                                                 rels  \
# 0  {'rel': [{'@inferred': 'true', '@trust': '0.65...
# 1  {'rel': [{'@inferred': 'false', '@trust': '0.9...
# 2  {'rel': {'@inferred': 'false', '@trust': '0.9'...
# 3                                               None
# 4  {'rel': [{'@inferred': 'false', '@trust': '0.9...
# 5  {'rel': [{'@inferred': 'true', '@trust': '0.89...
# 6  {'rel': [{'@inferred': 'true', '@trust': '0.85...
# 7  {'rel': [{'@inferred': 'false', '@trust': '0.9...
# 8  {'rel': [{'@inferred': 'false', '@trust': '0.9...
#
#                                             children  \
# 0  {'result': [{'@objidentifier': 'doajarticles::...
# 1  {'result': {'@objidentifier': 'doi_________::f...
# 2  {'result': [{'@objidentifier': 'doi_________::...
# 3  {'result': {'@objidentifier': 'doi_________::3...
# 4  {'result': {'@objidentifier': 'doi_________::f...
# 5  {'result': {'@objidentifier': 'doi_________::0...
# 6  {'result': [{'@objidentifier': 'od______3498::...
# 7  {'result': [{'@objidentifier': 'RECOLECTA___::...
# 8  {'result': [{'@objidentifier': 'doi_________::...
#
#                                              context  \
# 0                                                NaN
# 1  {'@id': 'energy-planning', '@label': 'Energy P...
# 2  {'@id': 'energy-planning', '@label': 'Energy P...
# 3                                                NaN
# 4                                                NaN
# 5  {'@id': 'neanias-space', '@label': 'NEANIAS Sp...
# 6                                                NaN
# 7  {'@id': 'knowmad', '@label': 'Knowmad Institut...
# 8                                                NaN
#
#                                          contributor
# 0                                                NaN
# 1                                                NaN
# 2                                                NaN
# 3                                                NaN
# 4                                                NaN
# 5                                                NaN
# 6                                                NaN
# 7  [Agencia Nacional de Promoción Científica y Te...
# 8                                                NaN
