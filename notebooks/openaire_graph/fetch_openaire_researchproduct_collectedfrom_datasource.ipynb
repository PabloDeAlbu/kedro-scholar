# %%
import time
import requests
import pandas as pd

# %%
relCollectedFromDatasourceId = catalog.load('params:openaire_researchproduct_collectedfrom_datasource_fetch_options.relCollectedFromDatasourceId')
env = 'dev'
access_token = catalog.load('params:openaire_researchproduct_collectedfrom_datasource_fetch_options.access_token')
refresh_token = catalog.load('params:openaire_researchproduct_collectedfrom_datasource_fetch_options.refresh_token')
# Out:
# [01/30/25 13:44:19] INFO     Loading data from                                                  ]8;id=550681;file:///home/pablo/dev/CIC/dw-cic/kedro/kedro-cic/.venv/lib/python3.10/site-packages/kedro/io/data_catalog.py\data_catalog.py]8;;\:]8;id=537160;file:///home/pablo/dev/CIC/dw-cic/kedro/kedro-cic/.venv/lib/python3.10/site-packages/kedro/io/data_catalog.py#389\389]8;;\
#                              params:openaire_researchproduct_collectedfrom_datasource_fetch_opt
#                              ions.relCollectedFromDatasourceId (MemoryDataset)...
#                     INFO     Loading data from                                                  ]8;id=560708;file:///home/pablo/dev/CIC/dw-cic/kedro/kedro-cic/.venv/lib/python3.10/site-packages/kedro/io/data_catalog.py\data_catalog.py]8;;\:]8;id=345783;file:///home/pablo/dev/CIC/dw-cic/kedro/kedro-cic/.venv/lib/python3.10/site-packages/kedro/io/data_catalog.py#389\389]8;;\
#                              params:openaire_researchproduct_collectedfrom_datasource_fetch_opt
#                              ions.access_token (MemoryDataset)...
#                     INFO     Loading data from                                                  ]8;id=704828;file:///home/pablo/dev/CIC/dw-cic/kedro/kedro-cic/.venv/lib/python3.10/site-packages/kedro/io/data_catalog.py\data_catalog.py]8;;\:]8;id=168585;file:///home/pablo/dev/CIC/dw-cic/kedro/kedro-cic/.venv/lib/python3.10/site-packages/kedro/io/data_catalog.py#389\389]8;;\
#                              params:openaire_researchproduct_collectedfrom_datasource_fetch_opt
#                              ions.refresh_token (MemoryDataset)...

# %%
def refresh_access_token(refresh_token):
    """Obtiene un nuevo access_token usando el refresh_token."""
    refresh_url = f"https://services.openaire.eu/uoa-user-management/api/users/getAccessToken?refreshToken={refresh_token}"
    response = requests.get(refresh_url)
    if response.status_code == 200:
        return response.json().get("access_token")
    else:
        raise Exception(f"Failed to refresh token: {response.status_code}")

def fetch_openaire_researchproduct_collectedfrom_datasource(relCollectedFromDatasourceId, access_token, refresh_token, env):
    cursor = '*'
    base_url = 'https://api.openaire.eu/graph/researchProducts'
    iteration_limit = 5
    iteration_count = 0
    page_size = 50  # Ajustar este valor según sea necesario
    max_retries = 5  # Máximo número de reintentos en caso de error 429
    retry_wait = 5   # Tiempo inicial de espera entre reintentos en segundos
    
    def get_headers():
        return {
            "accept": "application/json",
            'Authorization': f'Bearer {access_token}'
        }
    
    params = {
        "relCollectedFromDatasourceId": relCollectedFromDatasourceId,  # Búsqueda por institución
        "pageSize": page_size,
        "cursor": cursor
    }
    
    while True:
        response = requests.get(base_url, headers=get_headers(), params=params)
        
        # Si el token es inválido o expiró, intentar renovarlo
        if response.status_code == 403:
            print("Access token expired or invalid. Refreshing token...")
            access_token = refresh_access_token(refresh_token)
            continue  # Reintentar la solicitud con el nuevo token
        
        if response.status_code != 200:
            raise Exception(f"Failed to retrieve data: {response.status_code}")
        
        api_response = response.json()
        print(f'Iteration count: {iteration_count}')
        print(f'GET {response.url}')
        
        # Crear DataFrame con las columnas del primer resultado
        df = pd.DataFrame.from_dict(api_response['results'])
        
        # Actualizar cursor
        cursor = api_response['header'].get('nextCursor', None)
        params["cursor"] = cursor
        
        # Bucle para iterar con el cursor
        while cursor:
            if env == 'dev' and iteration_count >= iteration_limit:
                break
            
            iteration_count += 1
            print(f'Iteration count: {iteration_count}')
            print(f'GET {response.url}')
            
            time.sleep(2)
            
            # Reintentos en caso de error 429
            retries = 0
            while retries < max_retries:
                response = requests.get(base_url, headers=get_headers(), params=params)
                
                if response.status_code == 403:
                    print("Access token expired during execution. Refreshing token...")
                    access_token = refresh_access_token(refresh_token)
                    continue  # Reintentar con el nuevo token
                
                if response.status_code == 429:
                    retries += 1
                    print(f"Rate limit hit. Retry {retries}/{max_retries}. Waiting {retry_wait} seconds...")
                    time.sleep(retry_wait)
                    retry_wait *= 2  # Incrementar el tiempo de espera exponencialmente
                else:
                    break
            
            if response.status_code != 200:
                print(f"Failed to retrieve data at iteration {iteration_count}: {response.status_code}")
                break
            
            api_response = response.json()
            
            if not api_response.get('results'):
                print("No more results. Stopping iteration.")
                break
            
            df_tmp = pd.DataFrame.from_dict(api_response['results'])
            df = pd.concat([df, df_tmp])
            
            cursor = api_response['header'].get('nextCursor', None)
            params["cursor"] = cursor
        
        return df, df.head(1000)

# %%
df, df_dev = fetch_openaire_researchproduct_collectedfrom_datasource(relCollectedFromDatasourceId, access_token, refresh_token, env)
# Out:
# Access token expired or invalid. Refreshing token...
# Iteration count: 0
# GET https://api.openaire.eu/graph/researchProducts?relCollectedFromDatasourceId=opendoar____%3A%3A2222f99fe4ee52bacba5f5406ff033aa&pageSize=50&cursor=%2A
# Iteration count: 1
# GET https://api.openaire.eu/graph/researchProducts?relCollectedFromDatasourceId=opendoar____%3A%3A2222f99fe4ee52bacba5f5406ff033aa&pageSize=50&cursor=%2A
# Iteration count: 2
# GET https://api.openaire.eu/graph/researchProducts?relCollectedFromDatasourceId=opendoar____%3A%3A2222f99fe4ee52bacba5f5406ff033aa&pageSize=50&cursor=AoI%2FD2RlZHVwX3dmXzAwMjo6MGFkYzJlMjhiMTU1YTQ2NjQzYTIxMDQ5M2IxMmFkODgIP4AAAA%3D%3D
# Iteration count: 3
# GET https://api.openaire.eu/graph/researchProducts?relCollectedFromDatasourceId=opendoar____%3A%3A2222f99fe4ee52bacba5f5406ff033aa&pageSize=50&cursor=AoI%2FD2RlZHVwX3dmXzAwMjo6MTM2MmE5MjFhY2FjODEzZGE0NjVhYzhiZmFlMzQ5NTkIP4AAAA%3D%3D
# Iteration count: 4
# GET https://api.openaire.eu/graph/researchProducts?relCollectedFromDatasourceId=opendoar____%3A%3A2222f99fe4ee52bacba5f5406ff033aa&pageSize=50&cursor=AoI%2FD2RlZHVwX3dmXzAwMjo6MWY2YjZlYjBmZTllZTgzYjc0YTU1MmQ2MDkzMDgxOTEIP4AAAA%3D%3D
# Iteration count: 5
# GET https://api.openaire.eu/graph/researchProducts?relCollectedFromDatasourceId=opendoar____%3A%3A2222f99fe4ee52bacba5f5406ff033aa&pageSize=50&cursor=AoI%2FD2RlZHVwX3dmXzAwMjo6MjgyNDI1ZmQyMDFjNzI2NWM5MGY2YjJmMWEzNjQ3M2UIP4AAAA%3D%3D

# %%
df
# Out:
# <pre style="white-space:pre;overflow-x:auto;line-height:normal;font-family:Menlo,'DejaVu Sans Mono',consolas,'Courier New',monospace"></pre>
#                                                author openAccessColor  \
# 0   [{'fullName': 'Miniussi, Claudio L.', 'name': ...            None
# 1   [{'fullName': 'De Giusti, Marisa Raquel', 'nam...            None
# 2   [{'fullName': 'Pesado, Patricia Mabel', 'name'...            None
# 3   [{'fullName': 'Almirón, Adriana E.', 'name': '...            None
# 4   [{'fullName': 'Rascio, Vicente J. D.', 'name':...            None
# ..                                                ...             ...
# 45  [{'fullName': 'Comisión de Investigaciones Cie...            None
# 46  [{'fullName': 'Caprari, Juan J.', 'name': 'Jua...            None
# 47  [{'fullName': 'Voisin, Axel Iván', 'name': 'Ax...            None
# 48  [{'fullName': 'Betancur, T.', 'name': 'T.', 's...            None
# 49  [{'fullName': 'Gómez de Saravia, Sandra Gabrie...            None
#
#    publiclyFunded   type                                  language  \
# 0            None  other   {'code': 'Español', 'label': 'Español'}
# 1            None  other  {'code': 'und', 'label': 'Undetermined'}
# 2            None  other  {'code': 'und', 'label': 'Undetermined'}
# 3            None  other  {'code': 'und', 'label': 'Undetermined'}
# 4            None  other  {'code': 'und', 'label': 'Undetermined'}
# ..            ...    ...                                       ...
# 45           None  other   {'code': 'Español', 'label': 'Español'}
# 46           None  other  {'code': 'und', 'label': 'Undetermined'}
# 47           None  other  {'code': 'und', 'label': 'Undetermined'}
# 48           None  other  {'code': 'und', 'label': 'Undetermined'}
# 49           None  other     {'code': 'Inglés', 'label': 'Inglés'}
#
#                                              subjects  \
# 0   [{'subject': {'scheme': 'keyword', 'value': 'a...
# 1   [{'subject': {'scheme': 'keyword', 'value': 'C...
# 2   [{'subject': {'scheme': 'keyword', 'value': 'I...
# 3   [{'subject': {'scheme': 'keyword', 'value': 'P...
# 4   [{'subject': {'scheme': 'keyword', 'value': 'r...
# ..                                                ...
# 45  [{'subject': {'scheme': 'keyword', 'value': 'A...
# 46  [{'subject': {'scheme': 'keyword', 'value': 'I...
# 47  [{'subject': {'scheme': 'keyword', 'value': 'A...
# 48  [{'subject': {'scheme': 'keyword', 'value': 'h...
# 49  [{'subject': {'scheme': 'keyword', 'value': 'B...
#
#                                             mainTitle  \
# 0   Aplicacion de la fluorescencia de Rayos X al a...
# 1   2º Taller para la generación de perfiles de in...
# 2    Calidad en el desarrollo de Sistemas de Software
# 3   First record of Rineloricaria reisi, R. stella...
# 4   Contribución al estudio del comportamiento de ...
# ..                                                ...
# 45                                       Acta n° 1515
# 46  Efecto del ensayo de inmersión alternada sobre...
# 47  Extracción y balance de nutrientes para trigo ...
# 48  Métodos para evaluar interacciones entre cuerp...
# 49  Phototrophic Biofilms on Exterior Brick Substrate
#
#                                           description publicationDate  \
# 0   [La fluorescencia de Rayos X puede ser aplicad...      1969-01-01
# 1   [Objetivos del taller:  - Entender la necesida...      2018-10-01
# 2   [El proyecto de investigación y desarrollo “Si...      2006-06-01
# 3   [Rineloricaria reisi, R. stellata, and R. zain...      2014-01-01
# 4   [Formulaciones antiincrustantes fueron estudia...      1971-01-01
# ..                                                ...             ...
# 45  [Incluye los siguientes anexos: - Anexo 2.1. B...      2020-11-19
# 46  [El presente trabajo es el tercero de una seri...      1980-01-01
# 47  [El desplazamiento de los sistemas de producci...      2016-09-01
# 48  [La comprensión de la dinámica de ecosistemas ...      2012-01-01
# 49  [La Plata Cathedral is considered a historical...      2016-01-01
#
#                                             publisher  \
# 0   Laboratorio de Entrenamiento Multidisciplinari...
# 1                                                 NaN
# 2                                                 NaN
# 3                                                 NaN
# 4   Laboratorio de Entrenamiento Multidisciplinari...
# ..                                                ...
# 45                                                NaN
# 46                                                NaN
# 47                                                NaN
# 48                                                NaN
# 49                                 Trade Science Inc.
#
#                              format  \
# 0          [application/pdf, 11 p.]
# 1       [application/pdf, 55 diap.]
# 2           [application/pdf, 4 p.]
# 3   [application/pdf, p. 1528-1530]
# 4      [application/pdf, p. 77-147]
# ..                              ...
# 45                [application/pdf]
# 46    [application/pdf, p. 119-151]
# 47          [application/pdf, 1 p.]
# 48          [application/pdf, 5 p.]
# 49         [application/pdf, 10 p.]
#
#                                       bestAccessRight  \
# 0   {'code': 'c_abf2', 'label': 'OPEN', 'scheme': ...
# 1   {'code': 'c_abf2', 'label': 'OPEN', 'scheme': ...
# 2   {'code': 'c_abf2', 'label': 'OPEN', 'scheme': ...
# 3   {'code': 'c_abf2', 'label': 'OPEN', 'scheme': ...
# 4   {'code': 'c_abf2', 'label': 'OPEN', 'scheme': ...
# ..                                                ...
# 45  {'code': 'c_abf2', 'label': 'OPEN', 'scheme': ...
# 46  {'code': 'c_abf2', 'label': 'OPEN', 'scheme': ...
# 47  {'code': 'c_abf2', 'label': 'OPEN', 'scheme': ...
# 48  {'code': 'c_abf2', 'label': 'OPEN', 'scheme': ...
# 49  {'code': 'c_abf2', 'label': 'OPEN', 'scheme': ...
#
#                                                 id  \
# 0   dedup_wf_002::0084e248427bc09d1ea962ee8254febc
# 1   dedup_wf_002::00df9d3169981ad636b245c4eb46fd2e
# 2   dedup_wf_002::02486530ee27ea6d8fa443ce0bf3156e
# 3   dedup_wf_002::030e478a4a6206520f0c95a165c4582b
# 4   dedup_wf_002::04d710c7907d0fc982ef0df1528ac550
# ..                                             ...
# 45  od______9441::02f1a7708a0ad499a99819b6db55f1f3
# 46  od______9441::02fd0e72152b88e7ac2f1bed7fba04bb
# 47  od______9441::03110795eb060ab071c876557ba7b7b1
# 48  od______9441::031137adcb518537962c55dbba14058e
# 49  od______9441::0316335c0e914aea497516998e8d8ad1
#
#                                            originalId  \
# 0   [oai:digital.cic.gba.gob.ar:11746/755, 50|od__...
# 1   [50|od______9441::40276da60c9d26730d7d2c5d53f9...
# 2   [50|od______9441::d0e0daf7569603798aa06f76cdc1...
# 3   [50|od______9441::25284dcd824f3211323f138deb3d...
# 4   [oai:digital.cic.gba.gob.ar:11746/591, 50|od__...
# ..                                                ...
# 45  [oai:digital.cic.gba.gob.ar:11746/10735, 50|od...
# 46  [50|od______9441::02fd0e72152b88e7ac2f1bed7fba...
# 47  [50|od______9441::03110795eb060ab071c876557ba7...
# 48  [oai:digital.cic.gba.gob.ar:11746/4028, 50|od_...
# 49  [oai:digital.cic.gba.gob.ar:11746/7258, 50|od_...
#
#                                            indicators  \
# 0   {'citationImpact': {'citationCount': 0.0, 'inf...
# 1   {'citationImpact': {'citationCount': 0.0, 'inf...
# 2   {'citationImpact': {'citationCount': 0.0, 'inf...
# 3   {'citationImpact': {'citationCount': 0.0, 'inf...
# 4   {'citationImpact': {'citationCount': 0.0, 'inf...
# ..                                                ...
# 45  {'citationImpact': {'citationCount': 0.0, 'inf...
# 46  {'citationImpact': {'citationCount': 0.0, 'inf...
# 47  {'citationImpact': {'citationCount': 0.0, 'inf...
# 48  {'citationImpact': {'citationCount': 0.0, 'inf...
# 49  {'citationImpact': {'citationCount': 0.0, 'inf...
#
#                                              instance isGreen  \
# 0   [{'type': 'Other ORP type', 'url': ['https://d...    None
# 1   [{'type': 'Unknown', 'url': ['http://digital.c...    None
# 2   [{'type': 'Unknown', 'url': ['http://digital.c...    None
# 3   [{'type': 'Unknown', 'url': ['http://digital.c...    None
# 4   [{'license': 'CC BY', 'type': 'Unknown', 'url'...    None
# ..                                                ...     ...
# 45  [{'type': 'Other ORP type', 'url': ['https://d...    None
# 46  [{'type': 'Unknown', 'url': ['http://digital.c...    None
# 47  [{'type': 'Unknown', 'url': ['http://digital.c...    None
# 48  [{'type': 'Unknown', 'url': ['http://digital.c...    None
# 49  [{'type': 'Other ORP type', 'url': ['https://d...    None
#
#    isInDiamondJournal contributor country
# 0                None         NaN     NaN
# 1                None         NaN     NaN
# 2                None         NaN     NaN
# 3                None         NaN     NaN
# 4                None         NaN     NaN
# ..                ...         ...     ...
# 45               None         NaN     NaN
# 46               None         NaN     NaN
# 47               None         NaN     NaN
# 48               None         NaN     NaN
# 49               None         NaN     NaN
#
# [300 rows x 20 columns]
