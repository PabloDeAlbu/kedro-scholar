# %%
import time
import requests
import pandas as pd

# %%
filter = catalog.load('params:openaire_researchproduct_collectedfrom_datasource_fetch_options.filter')
filter_value = catalog.load('params:openaire_researchproduct_collectedfrom_datasource_fetch_options.filter_value')
env = 'dev'
access_token = catalog.load('params:openaire_researchproduct_collectedfrom_datasource_fetch_options.access_token')
refresh_token = catalog.load('params:openaire_researchproduct_collectedfrom_datasource_fetch_options.refresh_token')
# Out:
# [02/10/25 07:41:27] INFO     Loading data from                                                  ]8;id=998898;file:///home/pablo/dev/CIC/dw-cic/kedro/kedro-cic/.venv/lib/python3.10/site-packages/kedro/io/data_catalog.py\data_catalog.py]8;;\:]8;id=546822;file:///home/pablo/dev/CIC/dw-cic/kedro/kedro-cic/.venv/lib/python3.10/site-packages/kedro/io/data_catalog.py#389\389]8;;\
#                              params:openaire_researchproduct_collectedfrom_datasource_fetch_opt
#                              ions.filter (MemoryDataset)...
#                     INFO     Loading data from                                                  ]8;id=691687;file:///home/pablo/dev/CIC/dw-cic/kedro/kedro-cic/.venv/lib/python3.10/site-packages/kedro/io/data_catalog.py\data_catalog.py]8;;\:]8;id=460862;file:///home/pablo/dev/CIC/dw-cic/kedro/kedro-cic/.venv/lib/python3.10/site-packages/kedro/io/data_catalog.py#389\389]8;;\
#                              params:openaire_researchproduct_collectedfrom_datasource_fetch_opt
#                              ions.organization_id (MemoryDataset)...
#                     INFO     Loading data from                                                  ]8;id=636804;file:///home/pablo/dev/CIC/dw-cic/kedro/kedro-cic/.venv/lib/python3.10/site-packages/kedro/io/data_catalog.py\data_catalog.py]8;;\:]8;id=617076;file:///home/pablo/dev/CIC/dw-cic/kedro/kedro-cic/.venv/lib/python3.10/site-packages/kedro/io/data_catalog.py#389\389]8;;\
#                              params:openaire_researchproduct_collectedfrom_datasource_fetch_opt
#                              ions.access_token (MemoryDataset)...
#                     INFO     Loading data from                                                  ]8;id=551835;file:///home/pablo/dev/CIC/dw-cic/kedro/kedro-cic/.venv/lib/python3.10/site-packages/kedro/io/data_catalog.py\data_catalog.py]8;;\:]8;id=902625;file:///home/pablo/dev/CIC/dw-cic/kedro/kedro-cic/.venv/lib/python3.10/site-packages/kedro/io/data_catalog.py#389\389]8;;\
#                              params:openaire_researchproduct_collectedfrom_datasource_fetch_opt
#                              ions.refresh_token (MemoryDataset)...

# %%
def refresh_access_token(refresh_token):
    """Obtiene un nuevo access_token usando el refresh_token."""
    refresh_url = f"https://services.openaire.eu/uoa-user-management/api/users/getAccessToken?refreshToken={refresh_token}"
    response = requests.get(refresh_url)
    if response.status_code == 200:
        return response.json().get("access_token")
    else:
        raise Exception(f"Failed to refresh token: {response.status_code}")

def fetch_openaire_graph_researchproduct(filter, filter_value, access_token, refresh_token, env):
    cursor = '*'
    base_url = 'https://api.openaire.eu/graph/researchProducts'
    iteration_limit = 5
    iteration_count = 0
    page_size = 50  # Ajustar este valor según sea necesario
    max_retries = 5  # Máximo número de reintentos en caso de error 429
    retry_wait = 5   # Tiempo inicial de espera entre reintentos en segundos
    
    def get_headers():
        return {
            "accept": "application/json",
            'Authorization': f'Bearer {access_token}'
        }
    
    params = {
        filter: filter_value,  # Búsqueda por institución
        "pageSize": page_size,
        "cursor": cursor
    }
    
    while True:
        response = requests.get(base_url, headers=get_headers(), params=params)
        
        # Si el token es inválido o expiró, intentar renovarlo
        if response.status_code == 403:
            print("Access token expired or invalid. Refreshing token...")
            access_token = refresh_access_token(refresh_token)
            continue  # Reintentar la solicitud con el nuevo token
        
        if response.status_code != 200:
            raise Exception(f"Failed to retrieve data: {response.status_code}")
        
        api_response = response.json()
        print(f'Iteration count: {iteration_count}')
        print(f'GET {response.url}')
        
        # Crear DataFrame con las columnas del primer resultado
        df = pd.DataFrame.from_dict(api_response['results'])
        
        # Actualizar cursor
        cursor = api_response['header'].get('nextCursor', None)
        params["cursor"] = cursor
        
        # Bucle para iterar con el cursor
        while cursor:
            if env == 'dev' and iteration_count >= iteration_limit:
                break
            
            iteration_count += 1
            print(f'Iteration count: {iteration_count}')
            print(f'GET {response.url}')
            
            time.sleep(2)
            
            # Reintentos en caso de error 429
            retries = 0
            while retries < max_retries:
                response = requests.get(base_url, headers=get_headers(), params=params)
                
                if response.status_code == 403:
                    print("Access token expired during execution. Refreshing token...")
                    access_token = refresh_access_token(refresh_token)
                    continue  # Reintentar con el nuevo token
                
                if response.status_code == 429:
                    retries += 1
                    print(f"Rate limit hit. Retry {retries}/{max_retries}. Waiting {retry_wait} seconds...")
                    time.sleep(retry_wait)
                    retry_wait *= 2  # Incrementar el tiempo de espera exponencialmente
                else:
                    break
            
            if response.status_code != 200:
                print(f"Failed to retrieve data at iteration {iteration_count}: {response.status_code}")
                break
            
            api_response = response.json()
            
            if not api_response.get('results'):
                print("No more results. Stopping iteration.")
                break
            
            df_tmp = pd.DataFrame.from_dict(api_response['results'])
            df = pd.concat([df, df_tmp])
            
            cursor = api_response['header'].get('nextCursor', None)
            params["cursor"] = cursor
        
        return df, df.head(1000)

# %%
df, df_dev = fetch_openaire_graph_researchproduct(filter, filter_value, access_token, refresh_token, env)
# Out:
# Access token expired or invalid. Refreshing token...
# Iteration count: 0
# GET https://api.openaire.eu/graph/researchProducts?relOrganizationId=openorgs____%3A%3A40b9f835648a3e0d057d6917dd7e54d5&pageSize=50&cursor=%2A
# Iteration count: 1
# GET https://api.openaire.eu/graph/researchProducts?relOrganizationId=openorgs____%3A%3A40b9f835648a3e0d057d6917dd7e54d5&pageSize=50&cursor=%2A
# Iteration count: 2
# GET https://api.openaire.eu/graph/researchProducts?relOrganizationId=openorgs____%3A%3A40b9f835648a3e0d057d6917dd7e54d5&pageSize=50&cursor=AoI%2FD2RlZHVwX3dmXzAwMjo6MDAzOTVjZDIxYTA1ZDI0YTBhMjc3ZGRlNzBlM2MyZjQIP4AAAA%3D%3D
# Iteration count: 3
# GET https://api.openaire.eu/graph/researchProducts?relOrganizationId=openorgs____%3A%3A40b9f835648a3e0d057d6917dd7e54d5&pageSize=50&cursor=AoI%2FD2RlZHVwX3dmXzAwMjo6MDA3MTZmMjkxNGE0NGMyMzA2YWI4MDMzMjgwZWQ1ODAIP4AAAA%3D%3D
# Iteration count: 4
# GET https://api.openaire.eu/graph/researchProducts?relOrganizationId=openorgs____%3A%3A40b9f835648a3e0d057d6917dd7e54d5&pageSize=50&cursor=AoI%2FD2RlZHVwX3dmXzAwMjo6MDBhYzhmNmIyZjkwOTg4NjUzOTA4ZTdhNmU4MGZiNWEIP4AAAA%3D%3D
# Iteration count: 5
# GET https://api.openaire.eu/graph/researchProducts?relOrganizationId=openorgs____%3A%3A40b9f835648a3e0d057d6917dd7e54d5&pageSize=50&cursor=AoI%2FD2RlZHVwX3dmXzAwMjo6MDBmMDIwMTZkYWNjNmZiMjhlN2ExNTRkOWZiODNlMmQIP4AAAA%3D%3D

# %%
df
# Out:
# <pre style="white-space:pre;overflow-x:auto;line-height:normal;font-family:Menlo,'DejaVu Sans Mono',consolas,'Courier New',monospace"></pre>
#                                                author openAccessColor  \
# 0   [{'fullName': 'Steffen, Kevin Denis', 'name': ...            gold
# 1   [{'fullName': 'Evangelista, Carolina', 'name':...            None
# 2   [{'fullName': 'Mostoghiu, Robert', 'name': 'Ro...            None
# 3   [{'fullName': 'Rubio, Damián', 'name': 'Damiá...            None
# 4   [{'fullName': 'Ojeda Hidalgo, José F.', 'name'...            gold
# ..                                                ...             ...
# 45  [{'fullName': 'Lasta, Jorge Augusto', 'name': ...            None
# 46  [{'fullName': 'Revista Institucional de la Fac...            None
# 47  [{'fullName': 'Cei, José Miguel Alfredo María'...            None
# 48  [{'fullName': 'Cilento, Laura', 'name': 'Laura...            gold
# 49  [{'fullName': 'Secretaría de Género de la Facu...            None
#
#    publiclyFunded         type  \
# 0           False  publication
# 1           False  publication
# 2           False  publication
# 3           False  publication
# 4           False  publication
# ..            ...          ...
# 45          False  publication
# 46          False  publication
# 47          False  publication
# 48          False  publication
# 49          False  publication
#
#                                           language  \
# 0   {'code': 'spa', 'label': 'Spanish; Castilian'}
# 1          {'code': 'Español', 'label': 'Español'}
# 2              {'code': 'eng', 'label': 'English'}
# 3          {'code': 'esl/spa', 'label': 'Spanish'}
# 4              {'code': 'eng', 'label': 'English'}
# ..                                             ...
# 45         {'code': 'esl/spa', 'label': 'Spanish'}
# 46         {'code': 'esl/spa', 'label': 'Spanish'}
# 47             {'code': 'eng', 'label': 'English'}
# 48         {'code': 'esl/spa', 'label': 'Spanish'}
# 49         {'code': 'esl/spa', 'label': 'Spanish'}
#
#                                              subjects  \
# 0   [{'subject': {'scheme': 'keyword', 'value': 'g...
# 1   [{'subject': {'scheme': 'keyword', 'value': 'C...
# 2   [{'subject': {'scheme': 'keyword', 'value': 'S...
# 3   [{'subject': {'scheme': 'keyword', 'value': 'G...
# 4   [{'subject': {'scheme': 'keyword', 'value': 'A...
# ..                                                ...
# 45  [{'subject': {'scheme': 'keyword', 'value': 'C...
# 46  [{'subject': {'scheme': 'keyword', 'value': 'C...
# 47  [{'subject': {'scheme': 'keyword', 'value': 'A...
# 48  [{'subject': {'scheme': 'keyword', 'value': 'e...
# 49  [{'subject': {'scheme': 'keyword', 'value': 'M...
#
#                                             mainTitle  \
# 0   Variability in the growth rates of Saanen kids...
# 1   Estudio de la viabilidad del algoritmo super-t...
# 2   The Three Hundred project: The gas disruption ...
# 3   Evolución del sistema de gestión de incidentes...
# 4   Responsabilidad Social Corporativa en Empresas...
# ..                                                ...
# 45  Respuesta inmunológica de bovinos vacunados si...
# 46  Workshop: "Fluctuaciones macroeconómicas y cri...
# 47  Primeros apuntes ecológicos y herpetológicos s...
# 48  “Serie del Encuentro”, primera colección del C...
# 49  (Re)Hacer los medios : Comunicación en clave f...
#
#                                           description publicationDate  \
# 0   [This study was carried out to determine the v...      2023-12-18
# 1   [En este trabajo se presenta el diseño de un c...      2013-01-01
# 2   [We analyse the gas content evolution of infal...      2021-03-01
# 3   [Esta tesina detalla el desarrollo de un siste...      2023-06-23
# 4   [El presente artículo presenta un conjunto de ...      2013-12-01
# ..                                                ...             ...
# 45  [Se estudia la respuesta inmunológica de bovin...      1978-01-01
# 46  [Perry G. Mehrling es doctor en Economía de la...      2014-12-01
# 47  [Geological and ecological aspects of an extra...      1970-01-01
# 48  [La reflexión sobre la práctica editorial y lo...      2013-01-01
# 49  [(Re)Hacer los medios. Comunicación en clave f...      2022-01-01
#
#                                             publisher  ...  \
# 0   Universidad Nacional Mayor de San Marcos, Facu...  ...
# 1                                                 NaN  ...
# 2                       Oxford University Press (OUP)  ...
# 3                                                 NaN  ...
# 4                    Universidad Nacional de La Plata  ...
# ..                                                ...  ...
# 45                                                NaN  ...
# 46                                                NaN  ...
# 47                                                NaN  ...
# 48                   Universidad Nacional de La Plata  ...
# 49  Editorial de la Universidad Nacional de La Pla...  ...
#
#                                                 id  \
# 0   4dc99724cf04::95ea5df70a451a0487e051faa6c0a646
# 1   RECOLECTA___::24cb4438d1afe299e63cfdea4a31911f
# 2   core_ac_uk__::a391293fe8bd6c9c6c203ee15e8c2e8f
# 3   dedup_wf_002::00004d08998bcb6f35ce5d53811f12e9
# 4   dedup_wf_002::0000eb33b6be05d67799615dd117e5b2
# ..                                             ...
# 45  dedup_wf_002::01504e314a4f352cc244d64c6cb72a79
# 46  dedup_wf_002::0150d22e4775af3c7965c14921f4176f
# 47  dedup_wf_002::0152767df678ac928375ebd4d6079725
# 48  dedup_wf_002::0152976d6d89c7781aa7447192d99498
# 49  dedup_wf_002::0154bda3fd593f174234f990829b4b34
#
#                                            originalId  \
# 0   [oai:ojs.csi.unmsm:article/25240, 50|4dc99724c...
# 1   [50|RECOLECTA___::24cb4438d1afe299e63cfdea4a31...
# 2   [oai:nottingham-repository.worktribe.com:53501...
# 3   [oai:sedici.unlp.edu.ar:10915/154923, 50|od___...
# 4   [oai:doaj.org/article:a86e0a7dd7ad4000ae40ad07...
# ..                                                ...
# 45  [50|od______1329::3d938f84a5fcb447e48259a71e15...
# 46  [50|od______1329::bd16c62b0c656e595ffdbc725b03...
# 47  [50|od______1329::ef5d80f7bdd894c3807786e0c048...
# 48  [oai:doaj.org/article:637f323d009e4f64be0e3ae6...
# 49  [50|od______1329::84519200c2fc44bc086749a0ad31...
#
#                                            indicators  \
# 0   {'citationImpact': {'citationCount': 0.0, 'inf...
# 1   {'citationImpact': {'citationCount': 0.0, 'inf...
# 2   {'citationImpact': {'citationCount': 0.0, 'inf...
# 3   {'citationImpact': {'citationCount': 0.0, 'inf...
# 4   {'citationImpact': {'citationCount': 0.0, 'inf...
# ..                                                ...
# 45  {'citationImpact': {'citationCount': 0.0, 'inf...
# 46  {'citationImpact': {'citationCount': 0.0, 'inf...
# 47  {'citationImpact': {'citationCount': 0.0, 'inf...
# 48  {'citationImpact': {'citationCount': 0.0, 'inf...
# 49  {'citationImpact': {'citationCount': 0.0, 'inf...
#
#                                              instance isGreen  \
# 0   [{'alternateIdentifier': [{'scheme': 'doi', 'v...   False
# 1   [{'pid': [{'scheme': 'handle', 'value': '10261...    True
# 2   [{'type': 'Article', 'url': ['https://nottingh...    True
# 3   [{'type': 'Doctoral thesis', 'url': ['http://s...    True
# 4   [{'type': 'Article', 'url': ['https://doaj.org...   False
# ..                                                ...     ...
# 45  [{'type': 'Doctoral thesis', 'url': ['http://s...    True
# 46  [{'type': 'Article', 'url': ['http://sedici.un...    True
# 47  [{'type': 'Article', 'url': ['http://sedici.un...   False
# 48  [{'type': 'Article', 'url': ['https://doaj.org...    True
# 49  [{'type': 'Book', 'url': ['http://sedici.unlp....    True
#
#    isInDiamondJournal                                        contributor  \
# 0               False                                                NaN
# 1               False  [European Commission, Ministerio de Economía y...
# 2               False                                                NaN
# 3               False           [Lanfranco, Einar Felipe, Venosa, Paula]
# 4               False                                                NaN
# ..                ...                                                ...
# 45              False                              [Gimeno, Emilio Juan]
# 46              False                                                NaN
# 47              False                                                NaN
# 48              False                                                NaN
# 49              False                                                NaN
#
#                                                pid  \
# 0                                              NaN
# 1   [{'scheme': 'handle', 'value': '10261/97737'}]
# 2                                              NaN
# 3                                              NaN
# 4                                              NaN
# ..                                             ...
# 45                                             NaN
# 46                                             NaN
# 47                                             NaN
# 48                                             NaN
# 49                                             NaN
#
#                                               country contactPerson
# 0                                                 NaN           NaN
# 1                                                 NaN           NaN
# 2                                                 NaN           NaN
# 3   [{'code': 'AR', 'label': 'Argentina', 'provena...           NaN
# 4   [{'code': 'AR', 'label': 'Argentina', 'provena...           NaN
# ..                                                ...           ...
# 45  [{'code': 'AR', 'label': 'Argentina', 'provena...           NaN
# 46  [{'code': 'AR', 'label': 'Argentina', 'provena...           NaN
# 47  [{'code': 'AR', 'label': 'Argentina', 'provena...           NaN
# 48  [{'code': 'AR', 'label': 'Argentina', 'provena...           NaN
# 49  [{'code': 'AR', 'label': 'Argentina', 'provena...           NaN
#
# [300 rows x 24 columns]
