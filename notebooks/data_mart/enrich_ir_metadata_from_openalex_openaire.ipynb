# %%
import pandas as pd

pd.set_option('display.max_columns', None)
pd.set_option('display.max_rows', 5)

# %%
dim_url_openaire = catalog.load('stg_openaire/dim_url_openaire')
dim_doi_openaire = catalog.load('stg_openaire/dim_doi_openaire')
dim_author_openalex = catalog.load('stg_openalex/dim_author_openalex')
dim_institution_openalex = catalog.load('stg_openalex/dim_institution_openalex')

bridge_publication_oaiidentifier_openaire = catalog.load('stg_openaire/bridge_publication_oaiidentifier_openaire')
bridge_publication_doi_openaire = catalog.load('stg_openaire/bridge_publication_doi_openaire')

bridge_author_institution_openalex = catalog.load('stg_openalex/bridge_author_institution_openalex')
bridge_publication_author_openalex = catalog.load('stg_openalex/bridge_publication_author_openalex')
bridge_publication_oai_id_openaire = catalog.load('stg_openaire/bridge_publication_oaiidentifier_openaire')

fact_publication_openalex = catalog.load('stg_openalex/fact_publication_openalex')
fact_publication_openaire = catalog.load('stg_openaire/fact_publication_openaire')
fact_publication_dspace = catalog.load('stg_dspace5/fact_publication_dspace5')
# Out:
#                     INFO     Loading data from stg_openaire/dim_url_openaire                    ]8;id=831742;file:///root/kedro-cic/.venv/lib/python3.10/site-packages/kedro/io/data_catalog.py\data_catalog.py]8;;\:]8;id=274551;file:///root/kedro-cic/.venv/lib/python3.10/site-packages/kedro/io/data_catalog.py#389\389]8;;\
#                              (SQLTableDataset)...
# [04/15/25 11:55:49] INFO     Loading data from stg_openaire/dim_doi_openaire                    ]8;id=638139;file:///root/kedro-cic/.venv/lib/python3.10/site-packages/kedro/io/data_catalog.py\data_catalog.py]8;;\:]8;id=448503;file:///root/kedro-cic/.venv/lib/python3.10/site-packages/kedro/io/data_catalog.py#389\389]8;;\
#                              (SQLTableDataset)...
#                     INFO     Loading data from stg_openalex/dim_author_openalex                 ]8;id=186805;file:///root/kedro-cic/.venv/lib/python3.10/site-packages/kedro/io/data_catalog.py\data_catalog.py]8;;\:]8;id=479318;file:///root/kedro-cic/.venv/lib/python3.10/site-packages/kedro/io/data_catalog.py#389\389]8;;\
#                              (SQLTableDataset)...
#                     INFO     Loading data from stg_openalex/dim_institution_openalex            ]8;id=623577;file:///root/kedro-cic/.venv/lib/python3.10/site-packages/kedro/io/data_catalog.py\data_catalog.py]8;;\:]8;id=102294;file:///root/kedro-cic/.venv/lib/python3.10/site-packages/kedro/io/data_catalog.py#389\389]8;;\
#                              (SQLTableDataset)...
#                     INFO     Loading data from                                                  ]8;id=822705;file:///root/kedro-cic/.venv/lib/python3.10/site-packages/kedro/io/data_catalog.py\data_catalog.py]8;;\:]8;id=215924;file:///root/kedro-cic/.venv/lib/python3.10/site-packages/kedro/io/data_catalog.py#389\389]8;;\
#                              stg_openaire/bridge_publication_oaiidentifier_openaire
#                              (SQLTableDataset)...
# [04/15/25 11:55:55] INFO     Loading data from stg_openaire/bridge_publication_doi_openaire     ]8;id=238916;file:///root/kedro-cic/.venv/lib/python3.10/site-packages/kedro/io/data_catalog.py\data_catalog.py]8;;\:]8;id=430537;file:///root/kedro-cic/.venv/lib/python3.10/site-packages/kedro/io/data_catalog.py#389\389]8;;\
#                              (SQLTableDataset)...
#                     INFO     Loading data from stg_openalex/bridge_author_institution_openalex  ]8;id=504730;file:///root/kedro-cic/.venv/lib/python3.10/site-packages/kedro/io/data_catalog.py\data_catalog.py]8;;\:]8;id=828134;file:///root/kedro-cic/.venv/lib/python3.10/site-packages/kedro/io/data_catalog.py#389\389]8;;\
#                              (SQLTableDataset)...
# [04/15/25 11:55:58] INFO     Loading data from stg_openalex/bridge_publication_author_openalex  ]8;id=85633;file:///root/kedro-cic/.venv/lib/python3.10/site-packages/kedro/io/data_catalog.py\data_catalog.py]8;;\:]8;id=664539;file:///root/kedro-cic/.venv/lib/python3.10/site-packages/kedro/io/data_catalog.py#389\389]8;;\
#                              (SQLTableDataset)...
# [04/15/25 11:56:04] INFO     Loading data from                                                  ]8;id=387339;file:///root/kedro-cic/.venv/lib/python3.10/site-packages/kedro/io/data_catalog.py\data_catalog.py]8;;\:]8;id=880731;file:///root/kedro-cic/.venv/lib/python3.10/site-packages/kedro/io/data_catalog.py#389\389]8;;\
#                              stg_openaire/bridge_publication_oaiidentifier_openaire
#                              (SQLTableDataset)...
# [04/15/25 11:56:09] INFO     Loading data from stg_openalex/fact_publication_openalex           ]8;id=47668;file:///root/kedro-cic/.venv/lib/python3.10/site-packages/kedro/io/data_catalog.py\data_catalog.py]8;;\:]8;id=988040;file:///root/kedro-cic/.venv/lib/python3.10/site-packages/kedro/io/data_catalog.py#389\389]8;;\
#                              (SQLTableDataset)...
# [04/15/25 11:56:10] INFO     Loading data from stg_openaire/fact_publication_openaire           ]8;id=780924;file:///root/kedro-cic/.venv/lib/python3.10/site-packages/kedro/io/data_catalog.py\data_catalog.py]8;;\:]8;id=85074;file:///root/kedro-cic/.venv/lib/python3.10/site-packages/kedro/io/data_catalog.py#389\389]8;;\
#                              (SQLTableDataset)...
# [04/15/25 11:56:17] INFO     Loading data from stg_dspace5/fact_publication_dspace5             ]8;id=338995;file:///root/kedro-cic/.venv/lib/python3.10/site-packages/kedro/io/data_catalog.py\data_catalog.py]8;;\:]8;id=139276;file:///root/kedro-cic/.venv/lib/python3.10/site-packages/kedro/io/data_catalog.py#389\389]8;;\
#                              (SQLTableDataset)...

# %% [markdown]
# # 1. Estado actual del repositorio institucional (IR)

# %%
fact_publication_dspace[['handle','title','type','dateavailable','dateissued']]
# Out:
# <pre style="white-space:pre;overflow-x:auto;line-height:normal;font-family:Menlo,'DejaVu Sans Mono',consolas,'Courier New',monospace"></pre>
#               handle                                              title  \
# 0         10915/6381  Descripción y comparación del condrocráneo en ...
# 1       10915/171711  Disputas y consensos en el proceso de profesio...
# ...              ...                                                ...
# 166348   10915/87118  Defeitos superficiais do arco de aço 0.019” x ...
# 166349   10915/39984  Papel de la investigación cualitativa en los e...
#
#                          type       dateavailable          dateissued
# 0                    Articulo 2008-08-14 00:00:00 2002-12-31 21:00:00
# 1                       Tesis 2024-10-21 09:53:41 2019-12-31 21:00:00
# ...                       ...                 ...                 ...
# 166348  Objeto de conferencia 2019-12-10 11:00:19 2018-12-31 21:00:00
# 166349  Objeto de conferencia 2014-09-16 13:40:47 2009-12-31 21:00:00
#
# [166350 rows x 5 columns]

# %% [markdown]
# # 2. Superposición con OpenAIRE
#
# En esta sección se identifican los ítems del repositorio que también están presentes en OpenAIRE, lo que permite recuperar métricas de uso como vistas y descargas.
#
# Es posible filtrar las publicaciones recupero del IR **original_id**. En este caso se filtraran aquellos que contengan **oai:sedici.unlp.edu.ar:10915**, que es el prefijo de los identificador OAI que OpenAIRE recupera.

# %%
sedici_filter = bridge_publication_oai_id_openaire["original_id"].str.contains("oai:sedici.unlp.edu.ar:10915", na=False)

dim_oai_id_openaire = bridge_publication_oai_id_openaire[sedici_filter].copy()

dim_oai_id_openaire["handle"] = dim_oai_id_openaire["original_id"].str.extract(r"(10915/\d+)")

dim_oai_id_openaire[['researchproduct_id','original_id','handle']]
# Out:
# <pre style="white-space:pre;overflow-x:auto;line-height:normal;font-family:Menlo,'DejaVu Sans Mono',consolas,'Courier New',monospace"></pre>
#                                     researchproduct_id  \
# 3       od______1329::9f9a58be8f3130fe0a691d0183d9d811
# 4       od______1329::157ea3482a5d9bc9de0884b206d971b1
# ...                                                ...
# 256482  doi_dedup___::1158fbf05a79157287e3d12aaf655611
# 256483  doi_dedup___::e2b415fdef79ecb1de24a57968677aa5
#
#                                 original_id        handle
# 3       oai:sedici.unlp.edu.ar:10915/136271  10915/136271
# 4       oai:sedici.unlp.edu.ar:10915/158786  10915/158786
# ...                                     ...           ...
# 256482   oai:sedici.unlp.edu.ar:10915/95196   10915/95196
# 256483   oai:sedici.unlp.edu.ar:10915/83920   10915/83920
#
# [164763 rows x 3 columns]

# %% [markdown]
# Del código anterior podemos obtener el **researchproduct_id** de las publicaciones en OpenAIRE recuperadas del IR. También es posible deducir el **handle** de cada recurso en el IR a partir del **original_id**. Esto se hace porque OpenAIRE no modela el **handle**.
#
# _There is an exception though: Handle(s) are minted by several repositories; as listing them all would not be a viable option, to avoid losing them as PIDs, Handles bypass the PID authority filtering rule. In all other cases, PIDs are included in the graph as alternate Identifiers._
#
# Más info en https://graph.openaire.eu/docs/data-model/pids-and-identifiers/

# %% [markdown]
# # Publicaciones en OpenAIRE de IR con handle y DOI

# %%
publication_ir_openaire = pd.merge(
    dim_oai_id_openaire,
    fact_publication_dspace,
    on='handle'
)

publication_ir_openaire[['researchproduct_id','handle','title','type','dateavailable','dateissued']]
# Out:
# <pre style="white-space:pre;overflow-x:auto;line-height:normal;font-family:Menlo,'DejaVu Sans Mono',consolas,'Courier New',monospace"></pre>
#                                     researchproduct_id        handle  \
# 0       od______1329::9f9a58be8f3130fe0a691d0183d9d811  10915/136271
# 1       od______1329::157ea3482a5d9bc9de0884b206d971b1  10915/158786
# ...                                                ...           ...
# 162556  doi_dedup___::1158fbf05a79157287e3d12aaf655611   10915/95196
# 162557  doi_dedup___::e2b415fdef79ecb1de24a57968677aa5   10915/83920
#
#                                                     title  \
# 0       Binarias X en cúmulos densos en el Universo te...
# 1       Integrated requirements engineering framework ...
# ...                                                   ...
# 162556  Procesos de recarga/descarga en acuíferos some...
# 162557  Analysing derived metallicities and ionization...
#
#                          type       dateavailable          dateissued
# 0                       Tesis 2022-05-13 09:51:34 2021-12-31 21:00:00
# 1       Objeto de conferencia 2023-10-11 14:44:41 2022-12-31 21:00:00
# ...                       ...                 ...                 ...
# 162556               Articulo 2020-05-07 08:41:32 2018-12-31 21:00:00
# 162557               Articulo 2019-10-23 15:08:32 2010-12-31 21:00:00
#
# [162558 rows x 6 columns]

# %% [markdown]
# # Merge con OpenAIRE
# a partir del _researchproduct_id_

# %%
fact_publication_ir_openaire = pd.merge(
    fact_publication_openaire,
    publication_ir_openaire,
    on='researchproduct_id'
)

fact_publication_ir_openaire
# Out:
# <pre style="white-space:pre;overflow-x:auto;line-height:normal;font-family:Menlo,'DejaVu Sans Mono',consolas,'Courier New',monospace"></pre>
#                                     researchproduct_id publicly_funded  \
# 0       dedup_wf_002::deab70435016b7340e8a20d22fe865b3           false
# 1       dedup_wf_002::ec363c52727664369f5c51bbfb6b5c91           false
# ...                                                ...             ...
# 159730  doi_dedup___::df7ee1e9fdfc474df6fd2c944629a50c           false
# 159731  od______1329::bd9f62798d789cc7d38a00a1fda37a15         NO DATA
#
#                                                main_title    publication_date  \
# 0       Estudio del efecto de hormonas vegetales en la... 2021-06-13 21:00:00
# 1       Aspectos discursivos en lo educativo. Producci... 2017-02-28 21:00:00
# ...                                                   ...                 ...
# 159730                  Energy of a perturbed rigid rotor 1994-12-31 21:00:00
# 159731              Tensiones en la historia de un nombre 2022-10-31 21:00:00
#
#         is_green  is_in_diamond_journal language_code language_label  \
# 0           True                  False       esl/spa        Spanish
# 1           True                  False       esl/spa        Spanish
# ...          ...                    ...           ...            ...
# 159730      True                  False           und   Undetermined
# 159731     False                  False       esl/spa        Spanish
#
#        best_access_right                              best_access_right_uri  \
# 0                   OPEN  http://vocabularies.coar-repositories.org/docu...
# 1                   OPEN  http://vocabularies.coar-repositories.org/docu...
# ...                  ...                                                ...
# 159730              OPEN  http://vocabularies.coar-repositories.org/docu...
# 159731           NO DATA                                            NO DATA
#
#        citation_class  citation_count  impulse impulse_class     influence  \
# 0                  C5               0      0.0            C5  2.753393e-09
# 1                  C5               0      0.0            C5  2.753393e-09
# ...               ...             ...      ...           ...           ...
# 159730             C5               3      0.0            C5  2.971293e-09
# 159731             C5               0      0.0            C5  2.753393e-09
#
#        influence_class    popularity popularity_class  downloads  views  \
# 0                   C5  2.006179e-09               C5          0      0
# 1                   C5  1.161560e-09               C5          0      0
# ...                ...           ...              ...        ...    ...
# 159730              C5  1.275839e-09               C5          4      2
# 159731              C5  2.316203e-09               C5          0      0
#
#                                       publisher embargo_end_date  \
# 0                                       NO DATA              NaT
# 1              Universidad Nacional de La Plata              NaT
# ...                                         ...              ...
# 159730  Springer Science and Business Media LLC              NaT
# 159731                                  NO DATA              NaT
#
#                                      researchproduct_hk_x  \
# 0       b'\x00\x06\x7f\xa9\xceA\xd2\xcc\x1bq\xd1`\xf9r...
# 1                b'\x00\x07+}\x1c-nyJ\xdb\x1c\x8d\x9e4+<'
# ...                                                   ...
# 159730  b'\xff\xf9\x1e\xd7\x1bs\xe3\x07`\xedE7\x12\xec...
# 159731  b'\xff\xfef\x82\xfe[k\xa5.\x11\x11"\x81\xc4\xe...
#
#                                      researchproduct_hk_y  \
# 0       b'\x00\x06\x7f\xa9\xceA\xd2\xcc\x1bq\xd1`\xf9r...
# 1                b'\x00\x07+}\x1c-nyJ\xdb\x1c\x8d\x9e4+<'
# ...                                                   ...
# 159730  b'\xff\xf9\x1e\xd7\x1bs\xe3\x07`\xedE7\x12\xec...
# 159731  b'\xff\xfef\x82\xfe[k\xa5.\x11\x11"\x81\xc4\xe...
#
#                                               original_hk  \
# 0             b'\x88\x0c,\x11zf\x12[\xb0Bv\x02^\xf0\xbcq'
# 1          b'M\x96\xc2!M.\x7f<\xde\xb8\xb8\x1dg\xcf"\x15'
# ...                                                   ...
# 159730           b'C\xb0\x05$"\xcf\xa9 sM\xde\xdd&P\x12:'
# 159731  b'b\x7fSE\x9a\x9eS\xe7\xd5\xe89\x98\x88\x16b\xe2'
#
#                                 original_id        handle  \
# 0       oai:sedici.unlp.edu.ar:10915/120335  10915/120335
# 1        oai:sedici.unlp.edu.ar:10915/59786   10915/59786
# ...                                     ...           ...
# 159730  oai:sedici.unlp.edu.ar:10915/134857  10915/134857
# 159731  oai:sedici.unlp.edu.ar:10915/158586  10915/158586
#
#                                                   item_hk item_id  \
# 0       b'\x82(1\xc8:\xcbI%\x94\xb9\xd9\xf8k\xbb\x8c\xa2'  132040
# 1          b'\xb8\xad(\xdb\xcbWD\x98M(\x8f\x0f\xe9\x0708'   62673
# ...                                                   ...     ...
# 159730     b'\x1ex/\xdf\xd6\xaejq\xda\xf6JN\x16D\xb0\xa9'  145075
# 159731  b'\xf3\xe9u\xec9\x1f\xce\x1c\xc2\xb2y\xb9\xf8L...  176598
#
#                                                     title  \
# 0       Estudio del efecto de hormonas vegetales en la...
# 1       Aspectos discursivos en lo educativo: producci...
# ...                                                   ...
# 159730                  Energy of a perturbed rigid rotor
# 159731              Tensiones en la historia de un nombre
#
#                          type       dateavailable          dateissued  \
# 0                       Tesis 2021-06-16 09:39:44 2020-12-31 21:00:00
# 1                    Articulo 2017-04-24 12:15:47 2017-02-28 21:00:00
# ...                       ...                 ...                 ...
# 159730               Articulo 2022-04-22 11:59:02 1994-12-31 21:00:00
# 159731  Objeto de conferencia 2023-10-06 15:49:30 2022-12-31 21:00:00
#
#                                                 handle_hk
# 0       b'\xe5o\xb6\xf2\x80\x13p\xbb`\x88\xa1\x90\xe5\...
# 1                   b"|5\xb1'J\x00J\x10RUVi\xf4\xc4r\xaa"
# ...                                                   ...
# 159730  b'\x9b\x0bU\xfa\x03\x8ft\x0e]1\xc8\x08}\xd4\xf...
# 159731  b'b\xf0\xbe\x84\xdb\xb1P\xf3\x0fm\xae<]\t\xa3\...
#
# [159732 rows x 34 columns]

# %% [markdown]
# # 3. Publicaciones en OpenAlex candidatas a ser depositadas

# %%
publication_ir_openaire = pd.merge(
    publication_ir_openaire,
    bridge_publication_doi_openaire,
)

publication_ir_openaire = pd.merge(
    publication_ir_openaire,
    dim_doi_openaire
)

# %%
publication_ir_openaire
# Out:
# <pre style="white-space:pre;overflow-x:auto;line-height:normal;font-family:Menlo,'DejaVu Sans Mono',consolas,'Courier New',monospace"></pre>
#                                    researchproduct_id  \
# 0      doi_dedup___::ecca40bb574fe0eb6e581ed45e49437f
# 1      doi_dedup___::e8a676234981ab04d1cfb0f1cd338267
# ...                                               ...
# 38051  doi_dedup___::e2b415fdef79ecb1de24a57968677aa5
# 38052  doi_dedup___::e2b415fdef79ecb1de24a57968677aa5
#
#                                       researchproduct_hk  \
# 0      b'pTs\xfd_\x8d\x19\x8b\xb9\xa9\xc8\xa2\xfbA\xefT'
# 1      b'\x97@\xc2\x9c\xa7\x84\xebRZ\xb9\x99;\xba\xa6...
# ...                                                  ...
# 38051  b'\x02T\x01\x0b=F\xe5\x1a\x9d;\x9b\xe8\xde\xe4...
# 38052  b'\x02T\x01\x0b=F\xe5\x1a\x9d;\x9b\xe8\xde\xe4...
#
#                                              original_hk  \
# 0      b'fP\xa8B\x00\x9c\xe0\xad\x95.\x8c\xe8\t2\x15\...
# 1            b'\x07"\x83_D3\xe6<r\xcb\x98\x16y\x87h\x03'
# ...                                                  ...
# 38051    b'\xc7K4\r\x91m\xf5\xa3\x07\x8e{+\x06\x1a\xdcz'
# 38052    b'\xc7K4\r\x91m\xf5\xa3\x07\x8e{+\x06\x1a\xdcz'
#
#                                original_id        handle  \
# 0      oai:sedici.unlp.edu.ar:10915/117188  10915/117188
# 1      oai:sedici.unlp.edu.ar:10915/134320  10915/134320
# ...                                    ...           ...
# 38051   oai:sedici.unlp.edu.ar:10915/83920   10915/83920
# 38052   oai:sedici.unlp.edu.ar:10915/83920   10915/83920
#
#                                                  item_hk item_id  \
# 0      b'0\x8f\xc3\xd5\x8c?\x1f\xf3C\xcc\x13\xcaBu\x9aA'  128713
# 1      b'\xa2vou\x14\x05\x1f\xf1\xa5]M\xa2\x10\x06\x0e5'  144150
# ...                                                  ...     ...
# 38051  b'\x0b\x88\x14z\xc7/\x93\xce\xf5\x05\x8a5H\x97...   90686
# 38052  b'\x0b\x88\x14z\xc7/\x93\xce\xf5\x05\x8a5H\x97...   90686
#
#                                                    title      type  \
# 0      O desenho paisagista na megacidade latino-amer...  Articulo
# 1      Nonlocality effects in the phase diagram of ne...  Articulo
# ...                                                  ...       ...
# 38051  Analysing derived metallicities and ionization...  Articulo
# 38052  Analysing derived metallicities and ionization...  Articulo
#
#             dateavailable          dateissued  \
# 0     2021-04-15 15:43:12 2009-12-31 21:00:00
# 1     2022-04-11 18:20:51 2008-11-22 22:00:00
# ...                   ...                 ...
# 38051 2019-10-23 15:08:32 2010-12-31 21:00:00
# 38052 2019-10-23 15:08:32 2010-12-31 21:00:00
#
#                                                handle_hk  \
# 0      b'\x90|\x00\xf0NZ\x80\x81\x87\xe3\xe1MI\xff\x1ar'
# 1            b'\x92@\x9aXh*}H\x0b\xd8\x155\x91\x81\xf0l'
# ...                                                  ...
# 38051  b'i\xa2\x9d\xc0w\xd7\x9a\x99\xd6\xa0\xa2\x02\x...
# 38052  b'i\xa2\x9d\xc0w\xd7\x9a\x99\xd6\xa0\xa2\x02\x...
#
#                                                   doi_hk  \
# 0           b'JK\xa7\\\xfe_N\xeb[#~\xe5\xc1\x9e\x95\xa4'
# 1         b'~\x19Dj\x8dY\xc7\xa8:\x95\xf9L\xef\x93m\xb9'
# ...                                                  ...
# 38051  b'\x15\xcem\x04\xf3\x08Ik\xe7\xd0+\xc9\xb6fw\xe1'
# 38052  b']R$\x03\xee\xc1\xb3\xd1\xafS~\x98\xc8\x0b\xf...
#
#                                     doi
# 0               10.14295/rbho.v16i1.503
# 1             10.1134/s1063779608070101
# ...                                 ...
# 38051          10.48550/arxiv.1104.5460
# 38052  10.1111/j.1365-2966.2011.18978.x
#
# [38053 rows x 14 columns]

# %%
fact_publication = pd.merge(
    publication_ir_openaire,
    fact_publication_openalex,
    on='doi',
    how='outer'
)

# %%
fact_publication
# Out:
# <pre style="white-space:pre;overflow-x:auto;line-height:normal;font-family:Menlo,'DejaVu Sans Mono',consolas,'Courier New',monospace"></pre>
#                                    researchproduct_id  \
# 0                                                 NaN
# 1      dedup_wf_002::f1012b3f859ba0b0313c413fde7889f2
# ...                                               ...
# 62781  doi_dedup___::a3d256bad3c334a5e87e0b101e1df836
# 62782                                             NaN
#
#                                       researchproduct_hk  \
# 0                                                    NaN
# 1      b'\x0c\xca\x14^\x87\xd8!\xfeK\xcc\xee`\x15\x19...
# ...                                                  ...
# 62781  b'\x9d|\x81\xa9\xc5\x1e\x0c-J\x05\xb5\xc1\xcf\...
# 62782                                                NaN
#
#                                              original_hk  \
# 0                                                    NaN
# 1           b'\xf3\xd5vit\xccP\xb9\x81\rz\x8c\xdcwE\xb8'
# ...                                                  ...
# 62781  b'\x9dBK\xc2R\x80\xbeT\x18O\xb2\xcfp\xc9\x87\xfb'
# 62782                                                NaN
#
#                                original_id        handle  \
# 0                                      NaN           NaN
# 1       oai:sedici.unlp.edu.ar:10915/89307   10915/89307
# ...                                    ...           ...
# 62781  oai:sedici.unlp.edu.ar:10915/135294  10915/135294
# 62782                                  NaN           NaN
#
#                                                  item_hk item_id  \
# 0                                                    NaN     NaN
# 1        b'\xdc]\x86\xe53\xa4\xad\x90i\t\x13FD\x97p\x0f'   96639
# ...                                                  ...     ...
# 62781  b'\x0c\xf0h\xb8 \xae"U\xe2z\xe6Y\xac\x04\xb0\x94'  144272
# 62782                                                NaN     NaN
#
#                                                  title_x    type_x  \
# 0                                                    NaN       NaN
# 1      Ejes para una historia de los docentes en Amér...  Articulo
# ...                                                  ...       ...
# 62781  Espacio y tiempo en las representaciones infan...  Articulo
# 62782                                                NaN       NaN
#
#             dateavailable          dateissued  \
# 0                     NaT                 NaT
# 1     2020-02-19 09:45:31 2014-12-31 21:00:00
# ...                   ...                 ...
# 62781 2022-04-29 09:27:55 2015-12-31 21:00:00
# 62782                 NaT                 NaT
#
#                                                handle_hk  \
# 0                                                    NaN
# 1      b'\xed\xb3\xcb\xa7\xa3[\x1f\xd4\x9a\x17\x83e[\...
# ...                                                  ...
# 62781  b'{=\xc4L\xdal\xb4\xea\xe7E\xc9\x8f\x03F\xaf\x99'
# 62782                                                NaN
#
#                                                   doi_hk  \
# 0                                                    NaN
# 1               b'\xde.\x97R@5|!^\xa7\xf4\x01yT\xfa\x02'
# ...                                                  ...
# 62781  b'8\x90:ho\xaa\xec\xc6j\xee\xfc\xbf\x98\x7f\x9...
# 62782                                                NaN
#
#                                        doi  \
# 0                 10.0000/rtpe.v17i1.27716
# 1                 10.0000/rtpe.v18i1.28994
# ...                                    ...
# 62781  10.9789/2525-3050.2016.v1i2.461-480
# 62782     10.9789/2525-3050.2018.v3i5.5-11
#
#                                                  work_hk  \
# 0        b'j\xca\x83\xfd&\xfc\xe8\x92\x90\xb9@u\xf3\n~A'
# 1      b'\xdc\xc9e\xca\xd4\xe9\x8e\xd2EI>\x8a\xfe7\xc...
# ...                                                  ...
# 62781  b'\xd42\xe6\x0f\xc0E\xcb\xf0\xb2_\x14\x9d\xe6\...
# 62782  b'U\xc5\rf\xd2\xa6\x05\x121\xb0\xb0\xcc4\x05\x...
#
#                                 work_id         mag    pmcid     pmid  \
# 0      https://openalex.org/W2259437383  2259437383  NO DATA  NO DATA
# 1      https://openalex.org/W1952395981  1952395981  NO DATA  NO DATA
# ...                                 ...         ...      ...      ...
# 62781  https://openalex.org/W2966130144  2966130144  NO DATA  NO DATA
# 62782  https://openalex.org/W4243805373     NO DATA  NO DATA  NO DATA
#
#                                                  title_y   type_y  \
# 0      Desafíos y respuestas del feminismo en América...  article
# 1      Ejes para una historia de los docentes en Amér...  article
# ...                                                  ...      ...
# 62781  Espacio y tiempo en las representaciones infan...  article
# 62782                                       Presentación  article
#
#        publication_year    publication_date  countries_distinct_count  \
# 0                2014.0 2013-12-31 21:00:00                       1.0
# 1                2015.0 2014-12-31 21:00:00                       1.0
# ...                 ...                 ...                       ...
# 62781            2019.0 2019-02-24 21:00:00                       1.0
# 62782            2019.0 2019-02-24 21:00:00                       1.0
#
#        institutions_distinct_count  fwci has_fulltext fulltext_origin  \
# 0                              2.0   0.0        False         NO DATA
# 1                              3.0   0.0        False         NO DATA
# ...                            ...   ...          ...             ...
# 62781                          1.0   0.0         True             pdf
# 62782                          3.0   0.0         True             pdf
#
#        cited_by_count is_retracted is_paratext  locations_count  \
# 0                 0.0        False       False              1.0
# 1                 0.0        False       False              1.0
# ...               ...          ...         ...              ...
# 62781             0.0        False       False              3.0
# 62782             0.0        False       False              1.0
#
#        referenced_works_count any_repository_has_fulltext  is_oa oa_status  \
# 0                         0.0                       False  False    closed
# 1                         0.0                       False  False    closed
# ...                       ...                         ...    ...       ...
# 62781                    30.0                        True   True    hybrid
# 62782                     4.0                       False   True    hybrid
#
#                                                   oa_url  \
# 0                                                NO DATA
# 1                                                NO DATA
# ...                                                  ...
# 62781  http://seer.unirio.br/index.php/revistam/artic...
# 62782  http://seer.unirio.br/index.php/revistam/artic...
#
#        cited_by_percentile_year_max  cited_by_percentile_year_min  \
# 0                              66.0                           0.0
# 1                              66.0                           0.0
# ...                             ...                           ...
# 62781                          61.0                           0.0
# 62782                          61.0                           0.0
#
#       citation_normalized_percentile_is_in_top_10_percent  \
# 0                                                  False
# 1                                                  False
# ...                                                  ...
# 62781                                              False
# 62782                                              False
#
#       citation_normalized_percentile_is_in_top_1_percent  \
# 0                                                  False
# 1                                                  False
# ...                                                  ...
# 62781                                              False
# 62782                                              False
#
#        citation_normalized_percentile_value apc_list_currency  \
# 0                                       0.0           NO DATA
# 1                                       0.0           NO DATA
# ...                                     ...               ...
# 62781                                   0.0           NO DATA
# 62782                                   0.0           NO DATA
#
#       apc_list_provenance  apc_list_value  apc_list_value_usd  \
# 0                 NO DATA             0.0                 0.0
# 1                 NO DATA             0.0                 0.0
# ...                   ...             ...                 ...
# 62781             NO DATA             0.0                 0.0
# 62782             NO DATA             0.0                 0.0
#
#       apc_paid_currency apc_paid_provenance  apc_paid_value  \
# 0               NO DATA             NO DATA             0.0
# 1               NO DATA             NO DATA             0.0
# ...                 ...                 ...             ...
# 62781           NO DATA             NO DATA             0.0
# 62782           NO DATA             NO DATA             0.0
#
#        apc_paid_value_usd
# 0                     0.0
# 1                     0.0
# ...                   ...
# 62781                 0.0
# 62782                 0.0
#
# [62783 rows x 50 columns]

# %%
not_in_ir = fact_publication['researchproduct_id'].isna()
publication_to_import = fact_publication[not_in_ir]
publication_to_import.drop(columns=['researchproduct_id','researchproduct_hk','handle','doi_hk','doi'], inplace=True)
# Out:
# [04/15/25 11:58:26] WARNING  /tmp/ipykernel_3461409/2534656676.py:3: SettingWithCopyWarning:        ]8;id=546294;file:///root/.pyenv/versions/3.10.12/lib/python3.10/warnings.py\warnings.py]8;;\:]8;id=275877;file:///root/.pyenv/versions/3.10.12/lib/python3.10/warnings.py#109\109]8;;\
#                              A value is trying to be set on a copy of a slice from a DataFrame
#
#                              See the caveats in the documentation:
#                              https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#
#                              returning-a-view-versus-a-copy
#                                publication_to_import.drop(columns=['researchproduct_id','researchpr
#                              oduct_hk','handle','doi_hk','doi'], inplace=True)

# %%
publication_to_import
# Out:
# <pre style="white-space:pre;overflow-x:auto;line-height:normal;font-family:Menlo,'DejaVu Sans Mono',consolas,'Courier New',monospace"></pre>
#       original_hk original_id item_hk item_id title_x type_x dateavailable  \
# 0             NaN         NaN     NaN     NaN     NaN    NaN           NaT
# 3             NaN         NaN     NaN     NaN     NaN    NaN           NaT
# ...           ...         ...     ...     ...     ...    ...           ...
# 62778         NaN         NaN     NaN     NaN     NaN    NaN           NaT
# 62782         NaN         NaN     NaN     NaN     NaN    NaN           NaT
#
#       dateissued handle_hk                                            work_hk  \
# 0            NaT       NaN    b'j\xca\x83\xfd&\xfc\xe8\x92\x90\xb9@u\xf3\n~A'
# 3            NaT       NaN  b'\xe8W\x85\xdc\x1d\xb22a\xef\xb5\x85\x0f\xf6\...
# ...          ...       ...                                                ...
# 62778        NaT       NaN     b"\xff'\x95M\x18G\x16:\x9f`\xb19\xeeH\x8d\xd9"
# 62782        NaT       NaN  b'U\xc5\rf\xd2\xa6\x05\x121\xb0\xb0\xcc4\x05\x...
#
#                                 work_id         mag    pmcid  \
# 0      https://openalex.org/W2259437383  2259437383  NO DATA
# 3      https://openalex.org/W1975426358  1975426358  NO DATA
# ...                                 ...         ...      ...
# 62778  https://openalex.org/W3097904788  3097904788  NO DATA
# 62782  https://openalex.org/W4243805373     NO DATA  NO DATA
#
#                                           pmid  \
# 0                                      NO DATA
# 3      https://pubmed.ncbi.nlm.nih.gov/8893084
# ...                                        ...
# 62778                                  NO DATA
# 62782                                  NO DATA
#
#                                                  title_y   type_y  \
# 0      Desafíos y respuestas del feminismo en América...  article
# 3      Orthocephalization in the postweaning squirrel...  article
# ...                                                  ...      ...
# 62778  Towards an ontological reason law in economics...  article
# 62782                                       Presentación  article
#
#        publication_year    publication_date  countries_distinct_count  \
# 0                2014.0 2013-12-31 21:00:00                       1.0
# 3                1996.0 1996-09-30 21:00:00                       1.0
# ...                 ...                 ...                       ...
# 62778            2020.0 2020-11-01 21:00:00                       1.0
# 62782            2019.0 2019-02-24 21:00:00                       1.0
#
#        institutions_distinct_count  fwci has_fulltext fulltext_origin  \
# 0                              2.0   0.0        False         NO DATA
# 3                              1.0   0.0         True          ngrams
# ...                            ...   ...          ...             ...
# 62778                          3.0   1.0         True             pdf
# 62782                          3.0   0.0         True             pdf
#
#        cited_by_count is_retracted is_paratext  locations_count  \
# 0                 0.0        False       False              1.0
# 3                 6.0        False       False              2.0
# ...               ...          ...         ...              ...
# 62778             7.0        False       False              5.0
# 62782             0.0        False       False              1.0
#
#        referenced_works_count any_repository_has_fulltext  is_oa oa_status  \
# 0                         0.0                       False  False    closed
# 3                        20.0                       False  False    closed
# ...                       ...                         ...    ...       ...
# 62778                     9.0                        True   True      gold
# 62782                     4.0                       False   True    hybrid
#
#                                                   oa_url  \
# 0                                                NO DATA
# 3                                                NO DATA
# ...                                                  ...
# 62778        https://jssidoi.org/ird/article/download/53
# 62782  http://seer.unirio.br/index.php/revistam/artic...
#
#        cited_by_percentile_year_max  cited_by_percentile_year_min  \
# 0                              66.0                           0.0
# 3                              74.0                          73.0
# ...                             ...                           ...
# 62778                          84.0                          82.0
# 62782                          61.0                           0.0
#
#       citation_normalized_percentile_is_in_top_10_percent  \
# 0                                                  False
# 3                                                  False
# ...                                                  ...
# 62778                                              False
# 62782                                              False
#
#       citation_normalized_percentile_is_in_top_1_percent  \
# 0                                                  False
# 3                                                  False
# ...                                                  ...
# 62778                                              False
# 62782                                              False
#
#        citation_normalized_percentile_value apc_list_currency  \
# 0                                       0.0           NO DATA
# 3                                       0.0               USD
# ...                                     ...               ...
# 62778                                   1.0               EUR
# 62782                                   0.0           NO DATA
#
#       apc_list_provenance  apc_list_value  apc_list_value_usd  \
# 0                 NO DATA             0.0                 0.0
# 3                    doaj          4840.0              4840.0
# ...                   ...             ...                 ...
# 62778                doaj           350.0               377.0
# 62782             NO DATA             0.0                 0.0
#
#       apc_paid_currency apc_paid_provenance  apc_paid_value  \
# 0               NO DATA             NO DATA             0.0
# 3               NO DATA             NO DATA             0.0
# ...                 ...                 ...             ...
# 62778               EUR                doaj           350.0
# 62782           NO DATA             NO DATA             0.0
#
#        apc_paid_value_usd
# 0                     0.0
# 3                     0.0
# ...                   ...
# 62778               377.0
# 62782                 0.0
#
# [24723 rows x 45 columns]

# %% [markdown]
# # Autores de las publicaciones a importar

# %%
ror_filter = dim_institution_openalex['ror'] == 'https://ror.org/01tjs6929'
dim_institution_openalex[ror_filter]
# Out:
# <pre style="white-space:pre;overflow-x:auto;line-height:normal;font-family:Menlo,'DejaVu Sans Mono',consolas,'Courier New',monospace"></pre>
#                                          institution_hk  \
# 2187  b'Yg\x0f\xef\xa2{\xdd\x1a\xa2\x1e\xf5\x06\x1du...
#
#                        institution_id                        ror country_code  \
# 2187  https://openalex.org/I874386039  https://ror.org/01tjs6929           AR
#
#                           display_name
# 2187  Universidad Nacional de La Plata

# %%
institution_author_openalex = pd.merge(
    bridge_author_institution_openalex,
    dim_institution_openalex[ror_filter]
)

# %%
institution_author_openalex[['author_institution_hk','author_hk']]
# Out:
# <pre style="white-space:pre;overflow-x:auto;line-height:normal;font-family:Menlo,'DejaVu Sans Mono',consolas,'Courier New',monospace"></pre>
#                                    author_institution_hk  \
# 0      b'\x00\x01o`\xa9\x1cD\xfc\xab\xca\xa3^Cd\x1d\xf6'
# 1      b'\x00\t\xff\x7f\x9b<G[\xe7\xfa\x9c\xd6-\xa9_\...
# ...                                                  ...
# 19909  b'\xff\xfa\xbe\x7f\x04I\xa4\xe9\xbbm\xca\x99o\...
# 19910  b'\xff\xff\x1b{\xcf\xd9H\xf6\x89\xf7\xfb\xa9\x...
#
#                                                author_hk
# 0         b'n`:\xc2\xb1\xde\xcct\x9d\xc8n\xa2C\xea\xf1J'
# 1      b'\xe87\xdc\x16\xdf\x02\xcf\xefYF\xa9\xa50\x1f...
# ...                                                  ...
# 19909  b'\xe3\xc0\x88\xbexx\x85`\xec\xe2\xfe\xdd$\xc0...
# 19910  b'v\xa4\xc5\xb2\xb2\x9b\x93\xa5K\xe3C\xf0\x0b0...
#
# [19911 rows x 2 columns]

# %%
institutional_authors = pd.merge(
    institution_author_openalex,
    dim_author_openalex,
    on='author_hk'
).sort_values(by=['works_count', 'cited_by_count'], ascending=False)

institutional_authors.drop(columns=['author_institution_hk','author_hk','institution_hk'], inplace=True)

# %%
institutional_authors[['author_id','display_name_y','works_count','cited_by_count']]
# Out:
# <pre style="white-space:pre;overflow-x:auto;line-height:normal;font-family:Menlo,'DejaVu Sans Mono',consolas,'Courier New',monospace"></pre>
#                               author_id           display_name_y  works_count  \
# 3308   https://openalex.org/A5046725106        C. Padilla Aranda         2244
# 18776  https://openalex.org/A5101793588                F. Alonso         1543
# ...                                 ...                      ...          ...
# 13259  https://openalex.org/A5116034307     Maria José Cigorraga            0
# 16948  https://openalex.org/A5116015717  Olivia Espindola-Moreno            0
#
#        cited_by_count
# 3308           123934
# 18776           82057
# ...               ...
# 13259               0
# 16948               0
#
# [19043 rows x 4 columns]
