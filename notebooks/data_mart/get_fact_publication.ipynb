# %%
import pandas as pd
pd.set_option('display.max_columns', None)

# %% [markdown]
# Quiero identificar que producen los investigadores de una institución.
#
# Para eso se propone, identificar primero quienes son esos investigadores que declararon como su filiación, la institución que nos interesa en algun de sus publicaciones.

# %% [markdown]
# ## Carga de hubs, links y satélites

# %%
fact_publication_openalex = catalog.load('dm/fact_publication_openalex')
fact_publication_openaire = catalog.load('dm/fact_publication_openaire')
# Out:
#                     INFO     Loading data from dm/fact_publication_openalex                     ]8;id=981526;file:///home/pablo/.local/lib/python3.10/site-packages/kedro/io/data_catalog.py\data_catalog.py]8;;\:]8;id=662374;file:///home/pablo/.local/lib/python3.10/site-packages/kedro/io/data_catalog.py#389\389]8;;\
#                              (SQLTableDataset)...
# [03/28/25 12:28:07] INFO     Loading data from dm/fact_publication_openaire                     ]8;id=945102;file:///home/pablo/.local/lib/python3.10/site-packages/kedro/io/data_catalog.py\data_catalog.py]8;;\:]8;id=534460;file:///home/pablo/.local/lib/python3.10/site-packages/kedro/io/data_catalog.py#389\389]8;;\
#                              (SQLTableDataset)...

# %%
fact_publication_openalex
# Out:
# <pre style="white-space:pre;overflow-x:auto;line-height:normal;font-family:Menlo,'DejaVu Sans Mono',consolas,'Courier New',monospace"></pre>
#                                   work_hk                           work_id  \
# 0      \x0000d87d5d5db7f52b2988b00bd20e01  https://openalex.org/W3017375070
# 1      \x0000de9a0a2aab08f09bb24637198620  https://openalex.org/W3031656744
# 2      \x0002dc5f051da88bc7043b9246881672  https://openalex.org/W2126508961
# 3      \x00044529d1385693f85a68bd1246202d  https://openalex.org/W2932283061
# 4      \x0008a91f2d168889e03af719213e0bfe  https://openalex.org/W1976041922
# ...                                   ...                               ...
# 39565  \xfff2d24fe86494ea907e9be35eb16773  https://openalex.org/W3131021675
# 39566  \xfff3ddbc0e55da2379ea818a5076cc4e  https://openalex.org/W1591599329
# 39567  \xfffca5f5768d680d326abeae84e043e4  https://openalex.org/W1913525733
# 39568  \xfffecc7345b770b7558b99d8bb46560d  https://openalex.org/W3196308089
# 39569  \xffff2c3687de7dbe1a27679b47b8c6b0  https://openalex.org/W2942219882
#
#                               work_ids_hk                              doi_hk  \
# 0      \x9568fc508b69ff9d882131620ff72a69  \xd0bf2f68bfb163bf5d324449dfcc4002
# 1      \x0716c06fe958df90424cf12028e16ad6  \xf91738e54762d2233d559ec0d7338224
# 2      \x70487468801e9c4666fbfd641f4d8ed0  \xcc2eb299c1c66a2d1d54e35cee66e109
# 3      \x2a212094e96f4a85ab2096a934f0902a  \xd01a3bee176a1acd3461bbc25cc2b369
# 4      \x6f1121e24b93244cac7eee3244022aa9  \x209bb7b453b6c37c442106dc9a81c0b1
# ...                                   ...                                 ...
# 39565  \xddbb3a88cfba63e0d266bdaa49829fc3  \x0f5cf43d58acdd220c01fbb88b719e50
# 39566  \xe0a4065ecac791700c18d5407a6cc29a  \x64c3e4903cc478b53d3a63533ae06242
# 39567  \x04bf4769789a4d10aca4804ed8d22ae0  \x0929c327f367182985b1dd3f8113cb2d
# 39568  \x8045504e1deb4e32cbb9456eb1abb5d4  \xce1cc5fee686490bc1502897b05e3ca0
# 39569  \xcb55f34e43c04f72359e45990afa89fd  \x38a00a1f1a380985542f8390dfe7ecfc
#
#                                    mag_hk                             pmid_hk  \
# 0      \xfe0e1c72fca1e77bd5415b5ccfc03111  \xc2cd69fe9ceead6e8e3d26821247f123
# 1      \x0897c1d54506643a8653ac67d69183ed  \xc2cd69fe9ceead6e8e3d26821247f123
# 2      \xe52104d9482822b089c910deb232c4c4  \xc2cd69fe9ceead6e8e3d26821247f123
# 3      \x3ec29e3c9600b68a8d3820ee54c166bc  \xc2cd69fe9ceead6e8e3d26821247f123
# 4      \x05ac58d185ae05f6768096c922107e4e  \xc2cd69fe9ceead6e8e3d26821247f123
# ...                                   ...                                 ...
# 39565  \x625bc130a6c3fd5d7e1f79060296960c  \xc2cd69fe9ceead6e8e3d26821247f123
# 39566  \xddabc3d3853a4fa4764ac1bee34ceaa1  \xc2cd69fe9ceead6e8e3d26821247f123
# 39567  \xa53201a4f8f7ae5d76aa7dc16f521f47  \xc2cd69fe9ceead6e8e3d26821247f123
# 39568  \xa4231b86b9a57f9f11ecb35575f2a171  \xc2cd69fe9ceead6e8e3d26821247f123
# 39569  \xcd7bde2a7dd1ff61cac82846f1609735  \xc2cd69fe9ceead6e8e3d26821247f123
#
#                                  pmcid_hk                               doi  \
# 0      \xc2cd69fe9ceead6e8e3d26821247f123   10.37603/2250.7728.v24.n1.28239
# 1      \xc2cd69fe9ceead6e8e3d26821247f123             10.24215/16696581e278
# 2      \xc2cd69fe9ceead6e8e3d26821247f123     10.1080/00222933.2015.1091097
# 3      \xc2cd69fe9ceead6e8e3d26821247f123              10.25085/rsea.780101
# 4      \xc2cd69fe9ceead6e8e3d26821247f123                 10.1021/ie050740m
# ...                                   ...                               ...
# 39565  \xc2cd69fe9ceead6e8e3d26821247f123             10.24215/2422572xe083
# 39566  \xc2cd69fe9ceead6e8e3d26821247f123               10.35537/10915/4583
# 39567  \xc2cd69fe9ceead6e8e3d26821247f123  10.1046/j.1365-2699.2001.00523.x
# 39568  \xc2cd69fe9ceead6e8e3d26821247f123        10.25260/ea.21.31.3.0.1508
# 39569  \xc2cd69fe9ceead6e8e3d26821247f123         10.5380/jlasss.v9i1.61189
#
#                                             coar_uri           label_es  \
# 0      http://purl.org/coar/resource_type/c_2df8fbb1  ARTÍCULO ORIGINAL
# 1      http://purl.org/coar/resource_type/c_2df8fbb1  ARTÍCULO ORIGINAL
# 2      http://purl.org/coar/resource_type/c_2df8fbb1  ARTÍCULO ORIGINAL
# 3      http://purl.org/coar/resource_type/c_2df8fbb1  ARTÍCULO ORIGINAL
# 4      http://purl.org/coar/resource_type/c_2df8fbb1  ARTÍCULO ORIGINAL
# ...                                              ...                ...
# 39565  http://purl.org/coar/resource_type/c_2df8fbb1  ARTÍCULO ORIGINAL
# 39566      http://purl.org/coar/resource_type/c_46ec              TESIS
# 39567  http://purl.org/coar/resource_type/c_2df8fbb1  ARTÍCULO ORIGINAL
# 39568  http://purl.org/coar/resource_type/c_2df8fbb1  ARTÍCULO ORIGINAL
# 39569  http://purl.org/coar/resource_type/c_2df8fbb1  ARTÍCULO ORIGINAL
#
#                   label   parent_label_1 parent_label_2 parent_label_3  \
# 0      RESEARCH ARTICLE  JOURNAL ARTICLE        JOURNAL           TEXT
# 1      RESEARCH ARTICLE  JOURNAL ARTICLE        JOURNAL           TEXT
# 2      RESEARCH ARTICLE  JOURNAL ARTICLE        JOURNAL           TEXT
# 3      RESEARCH ARTICLE  JOURNAL ARTICLE        JOURNAL           TEXT
# 4      RESEARCH ARTICLE  JOURNAL ARTICLE        JOURNAL           TEXT
# ...                 ...              ...            ...            ...
# 39565  RESEARCH ARTICLE  JOURNAL ARTICLE        JOURNAL           TEXT
# 39566            THESIS             TEXT           None           None
# 39567  RESEARCH ARTICLE  JOURNAL ARTICLE        JOURNAL           TEXT
# 39568  RESEARCH ARTICLE  JOURNAL ARTICLE        JOURNAL           TEXT
# 39569  RESEARCH ARTICLE  JOURNAL ARTICLE        JOURNAL           TEXT
#
#                                                    title  \
# 0      Potrero de Garay y el espacio habitacional pre...
# 1      Impacto de la pandemia por COVID-19 en la salu...
# 2      Aquatic Diptera (Insecta) assemblages in four ...
# 3      Up-regulated pathways in response to Deformed ...
# 4      Behavior of Catalytic Pellets at High Reaction...
# ...                                                  ...
# 39565  Reflexiones sobre la violencia en la adolescencia
# 39566  Análisis paleoambiental y estratigrafía secuen...
# 39567               The voice of historical biogeography
# 39568  Circulación de virus ARN entre diversas especi...
# 39569  Los debates de la educación física y los enfoq...
#
#                                             display_name language  \
# 0      Potrero de Garay y el espacio habitacional pre...       es
# 1      Impacto de la pandemia por COVID-19 en la salu...  NO DATA
# 2      Aquatic Diptera (Insecta) assemblages in four ...       en
# 3      Up-regulated pathways in response to Deformed ...       en
# 4      Behavior of Catalytic Pellets at High Reaction...       en
# ...                                                  ...      ...
# 39565  Reflexiones sobre la violencia en la adolescencia       es
# 39566  Análisis paleoambiental y estratigrafía secuen...       es
# 39567               The voice of historical biogeography       en
# 39568  Circulación de virus ARN entre diversas especi...       en
# 39569  Los debates de la educación física y los enfoq...       es
#
#                type    type_crossref fulltext_origin  \
# 0           article  journal-article             pdf
# 1           article  journal-article             pdf
# 2           article  journal-article             pdf
# 3           article  journal-article             pdf
# 4           article  journal-article             pdf
# ...             ...              ...             ...
# 39565       article  journal-article             pdf
# 39566  dissertation     dissertation             pdf
# 39567       article  journal-article          ngrams
# 39568       article  journal-article             pdf
# 39569       article  journal-article         NO DATA
#
#                                         cited_by_api_url  has_fulltext  \
# 0      https://api.openalex.org/works?filter=cites:W3...          True
# 1      https://api.openalex.org/works?filter=cites:W3...          True
# 2      https://api.openalex.org/works?filter=cites:W2...          True
# 3      https://api.openalex.org/works?filter=cites:W2...          True
# 4      https://api.openalex.org/works?filter=cites:W1...          True
# ...                                                  ...           ...
# 39565  https://api.openalex.org/works?filter=cites:W3...          True
# 39566  https://api.openalex.org/works?filter=cites:W1...          True
# 39567  https://api.openalex.org/works?filter=cites:W1...          True
# 39568  https://api.openalex.org/works?filter=cites:W3...          True
# 39569  https://api.openalex.org/works?filter=cites:W2...         False
#
#        is_retracted  is_paratext  institutions_distinct_count  fwci  \
# 0             False        False                            3     0
# 1             False        False                            4     1
# 2             False        False                            2     0
# 3             False        False                            4     1
# 4             False        False                            2     1
# ...             ...          ...                          ...   ...
# 39565         False        False                            1     0
# 39566         False        False                            1     0
# 39567         False        False                            1     7
# 39568         False        False                            2     0
# 39569         False        False                            1     5
#
#        cited_by_count  locations_count  referenced_works_count  \
# 0                   0                2                       1
# 1                   7                2                       0
# 2                   1                4                      26
# 3                  22                4                      52
# 4                  14                2                      12
# ...               ...              ...                     ...
# 39565               1                2                       1
# 39566              12                3                     160
# 39567             181                1                      58
# 39568               1                1                      51
# 39569               3                1                       0
#
#        countries_distinct_count  publication_year oa_status  \
# 0                             1              2020    closed
# 1                             4              2020   diamond
# 2                             1              2015     green
# 3                             1              2019   diamond
# 4                             1              2005     green
# ...                         ...               ...       ...
# 39565                         1              2021   diamond
# 39566                         1              2003    hybrid
# 39567                         1              2001    bronze
# 39568                         1              2021   diamond
# 39569                         1              2018    closed
#
#                                                   oa_url  \
# 0      https://dialnet.unirioja.es/descarga/articulo/...
# 1      https://perio.unlp.edu.ar/ojs/index.php/questi...
# 2      https://zenodo.org/records/3990102/files/sourc...
# 3                   https://doi.org/10.25085/rsea.780101
# 4      https://ri.conicet.gov.ar/bitstream/11336/5497...
# ...                                                  ...
# 39565  https://revistas.unlp.edu.ar/revpsi/article/do...
# 39566  http://sedici.unlp.edu.ar/bitstream/handle/109...
# 39567  https://onlinelibrary.wiley.com/doi/pdfdirect/...
# 39568  https://ojs.ecologiaaustral.com.ar/index.php/E...
# 39569                                            NO DATA
#
#        any_repository_has_fulltext  is_oa apc_list_currency  \
# 0                             True  False               USD
# 1                            False   True               USD
# 2                             True   True           NO DATA
# 3                             True   True               USD
# 4                             True   True           NO DATA
# ...                            ...    ...               ...
# 39565                         True   True               USD
# 39566                         True   True           NO DATA
# 39567                        False   True               USD
# 39568                        False   True               USD
# 39569                        False  False           NO DATA
#
#       apc_list_provenance  apc_list_value  apc_list_value_usd  \
# 0                 NO DATA               0                   0
# 1                 NO DATA               0                   0
# 2                 NO DATA               0                   0
# 3                 NO DATA               0                   0
# 4                 NO DATA               0                   0
# ...                   ...             ...                 ...
# 39565                doaj               0                   0
# 39566             NO DATA               0                   0
# 39567             NO DATA            4840                4840
# 39568                doaj               0                   0
# 39569             NO DATA               0                   0
#
#       apc_paid_currency apc_paid_provenance  apc_paid_value  \
# 0               NO DATA             NO DATA               0
# 1               NO DATA             NO DATA               0
# 2               NO DATA             NO DATA               0
# 3               NO DATA             NO DATA               0
# 4               NO DATA             NO DATA               0
# ...                 ...                 ...             ...
# 39565           NO DATA             NO DATA               0
# 39566           NO DATA             NO DATA               0
# 39567           NO DATA             NO DATA               0
# 39568           NO DATA             NO DATA               0
# 39569           NO DATA             NO DATA               0
#
#        apc_paid_value_usd  \
# 0                       0
# 1                       0
# 2                       0
# 3                       0
# 4                       0
# ...                   ...
# 39565                   0
# 39566                   0
# 39567                   0
# 39568                   0
# 39569                   0
#
#        citation_normalized_percentile_is_in_top_10_percent  \
# 0                                                  False
# 1                                                  False
# 2                                                  False
# 3                                                  False
# 4                                                  False
# ...                                                  ...
# 39565                                              False
# 39566                                               True
# 39567                                               True
# 39568                                              False
# 39569                                              False
#
#        citation_normalized_percentile_is_in_top_1_percent  \
# 0                                                  False
# 1                                                  False
# 2                                                  False
# 3                                                  False
# 4                                                  False
# ...                                                  ...
# 39565                                              False
# 39566                                              False
# 39567                                              False
# 39568                                              False
# 39569                                              False
#
#        citation_normalized_percentile_value  cited_by_percentile_year_max  \
# 0                                         0                            60
# 1                                         1                            84
# 2                                         0                            73
# 3                                         1                            93
# 4                                         1                            85
# ...                                     ...                           ...
# 39565                                     0                            66
# 39566                                     1                            82
# 39567                                     1                            98
# 39568                                     0                            66
# 39569                                     1                            77
#
#        cited_by_percentile_year_min biblio_first_page biblio_issue  \
# 0                                 0                69            1
# 1                                82              e278         mayo
# 2                                66               905        13-14
# 3                                92                 1            1
# 4                                84                85            1
# ...                             ...               ...          ...
# 39565                            57               083      NO DATA
# 39566                            81           NO DATA      NO DATA
# 39567                            97               157            2
# 39568                            57               413            3
# 39569                            74                45            1
#
#       biblio_last_page biblio_volume
# 0                   74            24
# 1                 e278             1
# 2                  921            50
# 3                   11            78
# 4                   97            45
# ...                ...           ...
# 39565              083       NO DATA
# 39566          NO DATA       NO DATA
# 39567              168            28
# 39568              419            31
# 39569               45             9
#
# [39570 rows x 52 columns]

# %% [markdown]
# ## Trasnformaciones

# %%
def get_fact_publication(
        fact_publication_openalex, 
        fact_publication_openaire, 
    ):

    # Agregar columnas de presencia en cada fuente
    fact_publication_openalex['in_openalex'] = 1
    fact_publication_openaire['in_openaire'] = 1

    fact_publication = pd.merge(
        fact_publication_openalex,
        fact_publication_openaire,
        on='doi_hk',
        how='left',
        suffixes=('','_delete')
    )

    # Rellenar NaN en in_openaire con 0
    fact_publication['in_openaire'] = fact_publication['in_openaire'].fillna(0).astype(int)

    # Eliminar columnas terminadas en '_delete'
    fact_publication = fact_publication.loc[:, ~fact_publication.columns.str.endswith('_delete')]

    return fact_publication

# %%
import pandas as pd

def get_fact_publication_openaire(
        hub_coar_resourcetype,
        hub_openaire_doi,
        hub_openaire_researchproduct,
        link_coar_openaire_resourcetype,
        link_openaire_researchproduct_type,
        link_openaire_researchproduct_doi,
        sat_coar_resourcetype,
        sat_openaire_researchproduct,
    ):

    hub_coar_resourcetype.drop(columns=['load_datetime', 'source'], inplace=True)
    hub_openaire_doi.drop(columns=['load_datetime', 'source'], inplace=True)
    hub_openaire_researchproduct.drop(columns=['load_datetime', 'source'], inplace=True)
    link_coar_openaire_resourcetype.drop(columns=['load_datetime', 'source'], inplace=True)
    link_openaire_researchproduct_type.drop(columns=['load_datetime', 'source'], inplace=True)
    link_openaire_researchproduct_doi.drop(columns=['load_datetime', 'source'], inplace=True)
    sat_coar_resourcetype.drop(columns=['load_datetime', 'source', 'hashdiff'], inplace=True)
    sat_openaire_researchproduct.drop(columns=['load_datetime', 'source', 'hashdiff'], inplace=True)

    fact_publication_openaire = pd.merge(
        hub_openaire_researchproduct,
        link_openaire_researchproduct_type
    )

    fact_publication_openaire = pd.merge(
        fact_publication_openaire,
        link_openaire_researchproduct_doi
    )

    fact_publication_openaire = pd.merge(
        fact_publication_openaire,
        hub_openaire_doi
    )

    fact_publication_openaire = pd.merge(
        fact_publication_openaire,
        link_coar_openaire_resourcetype
    ).drop(columns=['type_hk', 'researchproduct_type_hk', 'link_coar_openaire_hk'])

    fact_publication_openaire = pd.merge(
        fact_publication_openaire,
        hub_coar_resourcetype
    )

    fact_publication_openaire = pd.merge(
        fact_publication_openaire,
        sat_coar_resourcetype
    ).drop(columns=['coar_hk'])

    fact_publication_openaire = pd.merge(
        fact_publication_openaire,
        sat_openaire_researchproduct
    )

    return fact_publication_openaire

def get_fact_publication_openalex(
        hub_coar_resourcetype,
        hub_openalex_work,
        hub_openalex_work_type,
        hub_openalex_doi,
        link_coar_openalex_resourcetype,
        link_openalex_work_type,
        sal_openalex_work,
        sat_coar_resourcetype,
        sat_openalex_work,
    ):

    # hubs
    hub_coar_resourcetype.drop(columns=['load_datetime','source'], inplace=True)
    hub_openalex_work.drop(columns=['load_datetime','source'], inplace=True)
    hub_openalex_work_type.drop(columns=['load_datetime','source'], inplace=True)
    hub_openalex_doi.drop(columns=['load_datetime','source'], inplace=True)
    
    #links
    link_coar_openalex_resourcetype.drop(columns=['load_datetime','source'], inplace=True)
    link_openalex_work_type.drop(columns=['load_datetime','source'], inplace=True)
    sal_openalex_work.drop(columns=['load_datetime','source'], inplace=True)

    # satellites
    sat_coar_resourcetype.drop(columns=['load_datetime','source','hashdiff'], inplace=True)
    sat_openalex_work.drop(columns=['load_datetime','source','hashdiff'], inplace=True)

    fact_publication_openalex = pd.merge(
        hub_openalex_work,
        link_openalex_work_type
    )

    fact_publication_openalex = pd.merge(
        fact_publication_openalex,
        sal_openalex_work
    )

    fact_publication_openalex = pd.merge(
        fact_publication_openalex,
        hub_openalex_doi
    )

    fact_publication_openalex = pd.merge(
        fact_publication_openalex,
        link_coar_openalex_resourcetype
    ).drop(columns=['type_hk', 'work_type_hk', 'link_coar_openalex_hk'])

    fact_publication_openalex = pd.merge(
        fact_publication_openalex,
        hub_coar_resourcetype
    )

    fact_publication_openalex = pd.merge(
        fact_publication_openalex,
        sat_coar_resourcetype
    ).drop(columns=['coar_hk'])

    fact_publication_openalex = pd.merge(
        fact_publication_openalex,
        sat_openalex_work
    )

    return fact_publication_openalex

def get_fact_publication(
        fact_publication_openaire,
        fact_publication_openalex,
    ):

    # Agregar columnas de presencia en cada fuente
    fact_publication_openaire['in_openaire'] = 'OpenAIRE'
    fact_publication_openalex['in_openalex'] = 'OpenAlex'

    fact_publication = pd.merge(
        fact_publication_openaire,
        fact_publication_openalex,
        on='doi_hk',
        how='outer',
        suffixes=('_delete','')
    )

    # Rellenar NaN en in_openaire con 0
    fact_publication['in_openaire'] = fact_publication['in_openaire'].fillna('No').astype(int)
    fact_publication['cited_by_count'] = fact_publication['cited_by_count'].fillna('No').astype(int)

    # Completar label_es con label_es_delete si es nulo
    if 'label_es' in fact_publication.columns and 'label_es_delete' in fact_publication.columns:
        fact_publication['label_es'] = fact_publication['label_es'].fillna(fact_publication['label_es_delete'])

    # Completar coar_uri con coar_uri_delete si es nulo
    if 'coar_uri' in fact_publication.columns and 'coar_uri_delete' in fact_publication.columns:
        fact_publication['coar_uri'] = fact_publication['coar_uri'].fillna(fact_publication['coar_uri_delete'])

    # Eliminar columnas terminadas en '_delete'
    fact_publication = fact_publication.loc[:, ~fact_publication.columns.str.endswith('_delete')]
    fact_publication = fact_publication.loc[:, ~fact_publication.columns.str.endswith('_hk')]

    # Ordenar por cited_by_count en orden descendente
    fact_publication = fact_publication.sort_values(by='cited_by_count', ascending=False)

    return fact_publication

# %%
fact_publication = get_fact_publication(fact_publication_openaire, fact_publication_openalex)

# %%
fact_publication
# Out:
# <pre style="white-space:pre;overflow-x:auto;line-height:normal;font-family:Menlo,'DejaVu Sans Mono',consolas,'Courier New',monospace"></pre>
#                                    researchproduct_id publicly_funded  \
# 53617                                             NaN             NaN
# 5860   doi_dedup___::15cc0690e6a9e57c7e902d19b135b38e           false
# 3081   doi_dedup___::b42cfbf63632bbbe576cc30690c8a459           false
# 54232  doi_dedup___::02bc80ea1648191aabdc5cbf4e828c4a            true
# 68076  doi_dedup___::2d411cd6f6f44c0c1bb40fba811703cc           false
# ...                                               ...             ...
# 9011   doi_dedup___::afc0abe37b43ec5f27cb29acd3adea92           false
# 9009   doi_dedup___::1ba5f41db97597230c15f44ba7c9fc1d           false
# 35839  doi_dedup___::8426d119c5539d91bfb01e43b37115b0           false
# 35861  doi_dedup___::dafa6de5b8f8770c678d26a4a7ce739e           false
# 35842  doi_dedup___::3abe738b406300f1e771ba1f750a98e9           false
#
#                                               main_title    publication_date  \
# 53617                                                NaN                 NaT
# 5860   The Leiden/Argentine/Bonn (LAB) Survey of Gala... 2005-08-31 21:00:00
# 3081   The clustering of galaxies in the completed SD... 2017-03-27 21:00:00
# 54232  Genome sequence and analysis of the tuber crop... 2011-06-30 21:00:00
# 68076  The Simons Genome Diversity Project: 300 genom... 2016-09-20 21:00:00
# ...                                                  ...                 ...
# 9011   ON THE MULTIPLICITY OF THE ZERO-AGE MAIN-SEQUE... 2010-01-19 21:00:00
# 9009   Organización campesina y dominios políticos en... 2018-06-28 21:00:00
# 35839  Diabetes mellitus: efectos de la glicosilación... 2019-08-19 21:00:00
# 35861  Early evolution of the angiosperm clade Astera... 2015-08-09 21:00:00
# 35842  Interpretación de las curvas del respirador en... 2012-04-30 21:00:00
#
#       is_green is_in_diamond_journal language_code language_label  \
# 53617      NaN                   NaN           NaN            NaN
# 5860      True                 False           und   Undetermined
# 3081      True                 False           und   Undetermined
# 54232     True                 False           und   Undetermined
# 68076     True                 False           und   Undetermined
# ...        ...                   ...           ...            ...
# 9011      True                 False           und   Undetermined
# 9009     False                 False           und   Undetermined
# 35839     True                 False           und   Undetermined
# 35861     True                 False           und   Undetermined
# 35842     True                 False           und   Undetermined
#
#       best_access_right                              best_access_right_uri  \
# 53617               NaN                                                NaN
# 5860               OPEN  http://vocabularies.coar-repositories.org/docu...
# 3081               OPEN  http://vocabularies.coar-repositories.org/docu...
# 54232              OPEN  http://vocabularies.coar-repositories.org/docu...
# 68076              OPEN  http://vocabularies.coar-repositories.org/docu...
# ...                 ...                                                ...
# 9011               OPEN  http://vocabularies.coar-repositories.org/docu...
# 9009               OPEN  http://vocabularies.coar-repositories.org/docu...
# 35839              OPEN  http://vocabularies.coar-repositories.org/docu...
# 35861              OPEN  http://vocabularies.coar-repositories.org/docu...
# 35842              OPEN  http://vocabularies.coar-repositories.org/docu...
#
#       citation_class  citation_count  impulse impulse_class     influence  \
# 53617            NaN             NaN      NaN           NaN           NaN
# 5860              C1          3183.0    141.0            C2  1.377713e-07
# 3081              C1          2255.0    877.0            C1  7.124477e-08
# 54232             C1          1847.0    418.0            C1  8.223324e-08
# 68076             C2          1177.0    423.0            C1  4.797223e-08
# ...              ...             ...      ...           ...           ...
# 9011              C4            21.0      6.0            C4  3.797048e-09
# 9009              C5             4.0      3.0            C5  3.246820e-09
# 35839             C5             0.0      0.0            C5  2.841867e-09
# 35861             C3           127.0     37.0            C3  7.922124e-09
# 35842             C4            28.0     12.0            C4  5.793675e-09
#
#       influence_class    popularity popularity_class  downloads  views  \
# 53617             NaN           NaN              NaN        NaN    NaN
# 5860               C2  5.560557e-07               C2       87.0   15.0
# 3081               C2  1.456016e-06               C1       47.0   12.0
# 54232              C2  6.549857e-07               C1      736.0  628.0
# 68076              C3  6.680841e-07               C1       45.0   18.0
# ...               ...           ...              ...        ...    ...
# 9011               C5  3.327847e-09               C5       58.0   14.0
# 9009               C5  4.430594e-09               C5       67.0   24.0
# 35839              C5  1.626197e-09               C5        0.0  100.0
# 35861              C4  6.012131e-08               C3       30.0    9.0
# 35842              C4  7.410928e-09               C4        0.0    0.0
#
#                                              publisher    embargo_end_date  \
# 53617                                              NaN                 NaT
# 5860                                      EDP Sciences 2004-12-31 21:00:00
# 3081                     Oxford University Press (OUP) 2015-12-31 21:00:00
# 54232          Springer Science and Business Media LLC                 NaT
# 68076          Springer Science and Business Media LLC 2015-12-31 21:00:00
# ...                                                ...                 ...
# 9011                     American Astronomical Society 2009-12-31 21:00:00
# 9009                  Universidad Nacional de La Plata                 NaT
# 35839                 Universidad Nacional de La Plata                 NaT
# 35861  Proceedings of the National Academy of Sciences                 NaT
# 35842                                      Elsevier BV                 NaT
#
#        in_openaire                           work_id  \
# 53617            0  https://openalex.org/W4211046286
# 5860             1  https://openalex.org/W4292403095
# 3081             1  https://openalex.org/W2501864044
# 54232            1  https://openalex.org/W2012331775
# 68076            1  https://openalex.org/W2522993044
# ...            ...                               ...
# 9011             1                               NaN
# 9009             1                               NaN
# 35839            1                               NaN
# 35861            1                               NaN
# 35842            1                               NaN
#
#                                  doi  \
# 53617  10.1088/1748-0221/3/08/s08003
# 5860      10.1051/0004-6361:20041864
# 3081            10.1093/mnras/stx721
# 54232            10.1038/nature10158
# 68076            10.1038/nature18964
# ...                              ...
# 9011                             NaN
# 9009                             NaN
# 35839                            NaN
# 35861                            NaN
# 35842                            NaN
#
#                                             coar_uri           label_es  \
# 53617  http://purl.org/coar/resource_type/c_2df8fbb1  ARTÍCULO ORIGINAL
# 5860   http://purl.org/coar/resource_type/c_2df8fbb1  ARTÍCULO ORIGINAL
# 3081   http://purl.org/coar/resource_type/c_2df8fbb1  ARTÍCULO ORIGINAL
# 54232  http://purl.org/coar/resource_type/c_2df8fbb1  ARTÍCULO ORIGINAL
# 68076  http://purl.org/coar/resource_type/c_2df8fbb1  ARTÍCULO ORIGINAL
# ...                                              ...                ...
# 9011       http://purl.org/coar/resource_type/c_18cf              TEXTO
# 9009       http://purl.org/coar/resource_type/c_18cf              TEXTO
# 35839      http://purl.org/coar/resource_type/c_18cf              TEXTO
# 35861      http://purl.org/coar/resource_type/c_18cf              TEXTO
# 35842      http://purl.org/coar/resource_type/c_18cf              TEXTO
#
#                   label   parent_label_1 parent_label_2 parent_label_3  \
# 53617  RESEARCH ARTICLE  JOURNAL ARTICLE        JOURNAL           TEXT
# 5860   RESEARCH ARTICLE  JOURNAL ARTICLE        JOURNAL           TEXT
# 3081   RESEARCH ARTICLE  JOURNAL ARTICLE        JOURNAL           TEXT
# 54232  RESEARCH ARTICLE  JOURNAL ARTICLE        JOURNAL           TEXT
# 68076  RESEARCH ARTICLE  JOURNAL ARTICLE        JOURNAL           TEXT
# ...                 ...              ...            ...            ...
# 9011                NaN              NaN            NaN            NaN
# 9009                NaN              NaN            NaN            NaN
# 35839               NaN              NaN            NaN            NaN
# 35861               NaN              NaN            NaN            NaN
# 35842               NaN              NaN            NaN            NaN
#
#                                                    title  \
# 53617  The ATLAS Experiment at the CERN Large Hadron ...
# 5860   The Leiden/Argentine/Bonn (LAB) Survey of Gala...
# 3081   The clustering of galaxies in the completed SD...
# 54232  Genome sequence and analysis of the tuber crop...
# 68076  The Simons Genome Diversity Project: 300 genom...
# ...                                                  ...
# 9011                                                 NaN
# 9009                                                 NaN
# 35839                                                NaN
# 35861                                                NaN
# 35842                                                NaN
#
#                                             display_name language     type  \
# 53617  The ATLAS Experiment at the CERN Large Hadron ...       en  article
# 5860   The Leiden/Argentine/Bonn (LAB) Survey of Gala...       en  article
# 3081   The clustering of galaxies in the completed SD...       en  article
# 54232  Genome sequence and analysis of the tuber crop...       en  article
# 68076  The Simons Genome Diversity Project: 300 genom...       en  article
# ...                                                  ...      ...      ...
# 9011                                                 NaN      NaN      NaN
# 9009                                                 NaN      NaN      NaN
# 35839                                                NaN      NaN      NaN
# 35861                                                NaN      NaN      NaN
# 35842                                                NaN      NaN      NaN
#
#          type_crossref fulltext_origin  \
# 53617  journal-article             pdf
# 5860   journal-article             pdf
# 3081   journal-article             pdf
# 54232  journal-article          ngrams
# 68076  journal-article             pdf
# ...                ...             ...
# 9011               NaN             NaN
# 9009               NaN             NaN
# 35839              NaN             NaN
# 35861              NaN             NaN
# 35842              NaN             NaN
#
#                                         cited_by_api_url has_fulltext  \
# 53617  https://api.openalex.org/works?filter=cites:W4...         True
# 5860   https://api.openalex.org/works?filter=cites:W4...         True
# 3081   https://api.openalex.org/works?filter=cites:W2...         True
# 54232  https://api.openalex.org/works?filter=cites:W2...         True
# 68076  https://api.openalex.org/works?filter=cites:W2...         True
# ...                                                  ...          ...
# 9011                                                 NaN          NaN
# 9009                                                 NaN          NaN
# 35839                                                NaN          NaN
# 35861                                                NaN          NaN
# 35842                                                NaN          NaN
#
#       is_retracted is_paratext  institutions_distinct_count   fwci  \
# 53617        False       False                        188.0   54.0
# 5860         False       False                          4.0   21.0
# 3081         False       False                         57.0  118.0
# 54232        False       False                         19.0  149.0
# 68076        False       False                         48.0   92.0
# ...            ...         ...                          ...    ...
# 9011           NaN         NaN                          NaN    NaN
# 9009           NaN         NaN                          NaN    NaN
# 35839          NaN         NaN                          NaN    NaN
# 35861          NaN         NaN                          NaN    NaN
# 35842          NaN         NaN                          NaN    NaN
#
#        cited_by_count  locations_count  referenced_works_count  \
# 53617            3806              9.0                   154.0
# 5860             3199              8.0                     7.0
# 3081             2582             21.0                   234.0
# 54232            1979              5.0                    55.0
# 68076            1474              3.0                    47.0
# ...               ...              ...                     ...
# 9011                0              NaN                     NaN
# 9009                0              NaN                     NaN
# 35839               0              NaN                     NaN
# 35861               0              NaN                     NaN
# 35842               0              NaN                     NaN
#
#        countries_distinct_count  publication_year oa_status  \
# 53617                      36.0            2008.0     green
# 5860                        2.0            2005.0    bronze
# 3081                       12.0            2017.0    bronze
# 54232                      12.0            2011.0    hybrid
# 68076                      20.0            2016.0     green
# ...                         ...               ...       ...
# 9011                        NaN               NaN       NaN
# 9009                        NaN               NaN       NaN
# 35839                       NaN               NaN       NaN
# 35861                       NaN               NaN       NaN
# 35842                       NaN               NaN       NaN
#
#                                                   oa_url  \
# 53617      https://doi.org/10.1088/1748-0221/3/08/s08003
# 5860   https://www.aanda.org/articles/aa/pdf/2005/35/...
# 3081   https://academic.oup.com/mnras/article-pdf/470...
# 54232    https://www.nature.com/articles/nature10158.pdf
# 68076  https://www.ncbi.nlm.nih.gov/pmc/articles/PMC5...
# ...                                                  ...
# 9011                                                 NaN
# 9009                                                 NaN
# 35839                                                NaN
# 35861                                                NaN
# 35842                                                NaN
#
#       any_repository_has_fulltext is_oa apc_list_currency apc_list_provenance  \
# 53617                        True  True           NO DATA             NO DATA
# 5860                         True  True           NO DATA             NO DATA
# 3081                         True  True               GBP             NO DATA
# 54232                        True  True               EUR             NO DATA
# 68076                        True  True               EUR             NO DATA
# ...                           ...   ...               ...                 ...
# 9011                          NaN   NaN               NaN                 NaN
# 9009                          NaN   NaN               NaN                 NaN
# 35839                         NaN   NaN               NaN                 NaN
# 35861                         NaN   NaN               NaN                 NaN
# 35842                         NaN   NaN               NaN                 NaN
#
#        apc_list_value  apc_list_value_usd apc_paid_currency  \
# 53617             0.0                 0.0           NO DATA
# 5860              0.0                 0.0           NO DATA
# 3081           2310.0              2833.0           NO DATA
# 54232          9750.0             11690.0               EUR
# 68076          9750.0             11690.0           NO DATA
# ...               ...                 ...               ...
# 9011              NaN                 NaN               NaN
# 9009              NaN                 NaN               NaN
# 35839             NaN                 NaN               NaN
# 35861             NaN                 NaN               NaN
# 35842             NaN                 NaN               NaN
#
#       apc_paid_provenance  apc_paid_value  apc_paid_value_usd  \
# 53617             NO DATA             0.0                 0.0
# 5860              NO DATA             0.0                 0.0
# 3081              NO DATA             0.0                 0.0
# 54232             NO DATA          9750.0             11690.0
# 68076             NO DATA             0.0                 0.0
# ...                   ...             ...                 ...
# 9011                  NaN             NaN                 NaN
# 9009                  NaN             NaN                 NaN
# 35839                 NaN             NaN                 NaN
# 35861                 NaN             NaN                 NaN
# 35842                 NaN             NaN                 NaN
#
#       citation_normalized_percentile_is_in_top_10_percent  \
# 53617                                               True
# 5860                                                True
# 3081                                                True
# 54232                                               True
# 68076                                               True
# ...                                                  ...
# 9011                                                 NaN
# 9009                                                 NaN
# 35839                                                NaN
# 35861                                                NaN
# 35842                                                NaN
#
#       citation_normalized_percentile_is_in_top_1_percent  \
# 53617                                               True
# 5860                                                True
# 3081                                                True
# 54232                                              False
# 68076                                               True
# ...                                                  ...
# 9011                                                 NaN
# 9009                                                 NaN
# 35839                                                NaN
# 35861                                                NaN
# 35842                                                NaN
#
#        citation_normalized_percentile_value  cited_by_percentile_year_max  \
# 53617                                   1.0                         100.0
# 5860                                    1.0                         100.0
# 3081                                    1.0                         100.0
# 54232                                   1.0                         100.0
# 68076                                   1.0                         100.0
# ...                                     ...                           ...
# 9011                                    NaN                           NaN
# 9009                                    NaN                           NaN
# 35839                                   NaN                           NaN
# 35861                                   NaN                           NaN
# 35842                                   NaN                           NaN
#
#        cited_by_percentile_year_min biblio_first_page biblio_issue  \
# 53617                          99.0            S08003           08
# 5860                           99.0               775            2
# 3081                           99.0              2617            3
# 54232                          99.0               189         7355
# 68076                          99.0               201         7624
# ...                             ...               ...          ...
# 9011                            NaN               NaN          NaN
# 9009                            NaN               NaN          NaN
# 35839                           NaN               NaN          NaN
# 35861                           NaN               NaN          NaN
# 35842                           NaN               NaN          NaN
#
#       biblio_last_page biblio_volume  in_openalex
# 53617           S08003             3          1.0
# 5860               782           440          1.0
# 3081              2652           470          1.0
# 54232              195           475          1.0
# 68076              206           538          1.0
# ...                ...           ...          ...
# 9011               NaN           NaN          NaN
# 9009               NaN           NaN          NaN
# 35839              NaN           NaN          NaN
# 35861              NaN           NaN          NaN
# 35842              NaN           NaN          NaN
#
# [69620 rows x 70 columns]
