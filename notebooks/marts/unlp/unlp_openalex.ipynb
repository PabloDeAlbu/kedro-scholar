# %%
import pandas as pd
pd.set_option('display.max_columns', None)

# %%
fct_openalex_work = catalog.load('dm_openalex/fct_openalex_work')
dim_openalex_author = catalog.load('dm_openalex/dim_openalex_author')
dim_openalex_institution = catalog.load('dm_openalex/dim_openalex_institution')
brg_openalex_author_institution= catalog.load('dm_openalex/brg_openalex_author_institution')
brg_openalex_publication_author= catalog.load('dm_openalex/brg_openalex_publication_author')
# Out:
# [08/13/25 10:46:51] INFO     Loading data from dm_openalex/fct_openalex_work                    ]8;id=576117;file:///home/pablo/.local/lib/python3.10/site-packages/kedro/io/data_catalog.py\data_catalog.py]8;;\:]8;id=928776;file:///home/pablo/.local/lib/python3.10/site-packages/kedro/io/data_catalog.py#389\389]8;;\
#                              (SQLTableDataset)...

# %%
fct_openalex_work
# Out:
# <pre style="white-space:pre;overflow-x:auto;line-height:normal;font-family:Menlo,'DejaVu Sans Mono',consolas,'Courier New',monospace"></pre>
#                                 work_id                               doi  \
# 0      https://openalex.org/W3017375070   10.37603/2250.7728.v24.n1.28239
# 1      https://openalex.org/W1636265793                              None
# 2      https://openalex.org/W2932283061              10.25085/rsea.780101
# 3      https://openalex.org/W3162889405                 10.1111/age.13077
# 4      https://openalex.org/W2954695399             10.24215/18524478e045
# ...                                 ...                               ...
# 50087  https://openalex.org/W1591599329               10.35537/10915/4583
# 50088  https://openalex.org/W4388277714                              None
# 50089  https://openalex.org/W2738541392                              None
# 50090  https://openalex.org/W1913525733  10.1046/j.1365-2699.2001.00523.x
# 50091  https://openalex.org/W2942219882         10.5380/jlasss.v9i1.61189
#
#               mag pmcid                                      pmid  \
# 0      3017375070  None                                      None
# 1      1636265793  None                                      None
# 2      2932283061  None                                      None
# 3      3162889405  None  https://pubmed.ncbi.nlm.nih.gov/34013628
# 4      2954695399  None                                      None
# ...           ...   ...                                       ...
# 50087  1591599329  None                                      None
# 50088        None  None                                      None
# 50089  2738541392  None                                      None
# 50090  1913525733  None                                      None
# 50091  2942219882  None                                      None
#
#                                                    title          type  \
# 0      Potrero de Garay y el espacio habitacional pre...       article
# 1      La ciudad y el acontecimiento. Juventud, clase...       article
# 2      Up-regulated pathways in response to Deformed ...       article
# 3      Screening and detection of chromosomal copy nu...       article
# 4      La lengua en disputa: los debates en la prensa...       article
# ...                                                  ...           ...
# 50087  Análisis paleoambiental y estratigrafía secuen...  dissertation
# 50088  Focus on open access in Latin America. Remedio...       article
# 50089  Historia de la música en América Latina. Ese v...       article
# 50090               The voice of historical biogeography       article
# 50091  Los debates de la educación física y los enfoq...       article
#
#        publication_year    publication_date  countries_distinct_count  \
# 0                  2020 2020-04-17 21:00:00                         1
# 1                  2012 2012-08-31 21:00:00                         2
# 2                  2019 2019-03-27 21:00:00                         1
# 3                  2021 2021-05-18 21:00:00                         4
# 4                  2019 2019-06-26 21:00:00                         2
# ...                 ...                 ...                       ...
# 50087              2003 2002-12-31 21:00:00                         1
# 50088              2014 2014-03-31 21:00:00                         1
# 50089              2016 2016-08-31 21:00:00                         1
# 50090              2001 2001-01-31 21:00:00                         1
# 50091              2018 2018-09-02 21:00:00                         1
#
#        institutions_distinct_count  fwci  has_fulltext fulltext_origin  \
# 0                                3   0.0          True             pdf
# 1                                2   0.0         False            None
# 2                                4   1.0          True             pdf
# 3                                7   1.0          True             pdf
# 4                                4   1.0          True             pdf
# ...                            ...   ...           ...             ...
# 50087                            1   NaN          True             pdf
# 50088                            1   0.0         False            None
# 50089                            1   0.0         False            None
# 50090                            1   7.0          True          ngrams
# 50091                            1   5.0         False            None
#
#        cited_by_count  is_retracted  is_paratext  locations_count  \
# 0                   0         False        False                2
# 1                   0         False        False                1
# 2                  22         False        False                4
# 3                   9         False        False                2
# 4                   2         False        False                4
# ...               ...           ...          ...              ...
# 50087              12         False        False                3
# 50088               0         False        False                1
# 50089               0         False        False                1
# 50090             181         False        False                1
# 50091               3         False        False                1
#
#        referenced_works_count  any_repository_has_fulltext  is_oa oa_status  \
# 0                           1                         True  False    closed
# 1                          11                        False  False    closed
# 2                          52                         True   True   diamond
# 3                          51                         True   True     green
# 4                          25                         True   True   diamond
# ...                       ...                          ...    ...       ...
# 50087                     160                         True   True    hybrid
# 50088                       0                        False  False    closed
# 50089                       0                        False  False    closed
# 50090                      58                        False   True    bronze
# 50091                       0                        False  False    closed
#
#                                                   oa_url  \
# 0      https://dialnet.unirioja.es/descarga/articulo/...
# 1                                                   None
# 2                   https://doi.org/10.25085/rsea.780101
# 3      http://helvia.uco.es/xmlui/bitstream/10396/277...
# 4      https://www.olivar.fahce.unlp.edu.ar/article/d...
# ...                                                  ...
# 50087  http://sedici.unlp.edu.ar/bitstream/handle/109...
# 50088                                               None
# 50089                                               None
# 50090  https://onlinelibrary.wiley.com/doi/pdfdirect/...
# 50091                                               None
#
#        cited_by_percentile_year_max  cited_by_percentile_year_min  \
# 0                                60                             0
# 1                                64                             0
# 2                                93                            92
# 3                                87                            85
# 4                                74                            69
# ...                             ...                           ...
# 50087                            82                            81
# 50088                            66                             0
# 50089                            66                             0
# 50090                            98                            97
# 50091                            77                            74
#
#       citation_normalized_percentile_is_in_top_10_percent  \
# 0                                                  False
# 1                                                  False
# 2                                                  False
# 3                                                  False
# 4                                                  False
# ...                                                  ...
# 50087                                               True
# 50088                                              False
# 50089                                              False
# 50090                                               True
# 50091                                              False
#
#       citation_normalized_percentile_is_in_top_1_percent  \
# 0                                                  False
# 1                                                  False
# 2                                                  False
# 3                                                  False
# 4                                                  False
# ...                                                  ...
# 50087                                              False
# 50088                                              False
# 50089                                              False
# 50090                                              False
# 50091                                              False
#
#        citation_normalized_percentile_value apc_list_currency  apc_list_value  \
# 0                                       0.0               USD             0.0
# 1                                       0.0              None             NaN
# 2                                       1.0               USD             0.0
# 3                                       1.0               USD          3400.0
# 4                                       1.0               USD             0.0
# ...                                     ...               ...             ...
# 50087                                   1.0              None             NaN
# 50088                                   0.0              None             NaN
# 50089                                   0.0              None             NaN
# 50090                                   1.0               USD          4840.0
# 50091                                   1.0              None             NaN
#
#        apc_list_value_usd apc_paid_currency  apc_paid_value  \
# 0                     0.0              None             NaN
# 1                     NaN              None             NaN
# 2                     0.0              None             NaN
# 3                  3400.0              None             NaN
# 4                     0.0              None             NaN
# ...                   ...               ...             ...
# 50087                 NaN              None             NaN
# 50088                 NaN              None             NaN
# 50089                 NaN              None             NaN
# 50090              4840.0              None             NaN
# 50091                 NaN              None             NaN
#
#        apc_paid_value_usd                                            work_hk  \
# 0                     NaN  b'\x00\x00\xd8}]]\xb7\xf5+)\x88\xb0\x0b\xd2\x0...
# 1                     NaN  b'\x00\x00\xf0\xe4\xaexLj6j\x94\xd4\xe7\x19\xd0k'
# 2                     NaN           b'\x00\x04E)\xd18V\x93\xf8Zh\xbd\x12F -'
# 3                     NaN       b'\x00\t\xf6K\x86liv%\xd7\x1bT3\xf5\x08\x9c'
# 4                     NaN  b'\x00\x0e\xf8\x01T{\x8e\xf9N\xf9\xaf\x8c#\xaf...
# ...                   ...                                                ...
# 50087                 NaN  b'\xff\xf3\xdd\xbc\x0eU\xda#y\xea\x81\x8aPv\xccN'
# 50088                 NaN  b'\xff\xf9V\x9d\xea\xdb\xc7\xea\x01\x07\x98\xe...
# 50089                 NaN  b'\xff\xfa5B\x95\xf0\x7fz0\xb3\xcd\xf9\xaa^\x9...
# 50090                 NaN  b'\xff\xfc\xa5\xf5v\x8dh\r2j\xbe\xae\x84\xe0C\...
# 50091                 NaN  b"\xff\xff,6\x87\xde}\xbe\x1a'g\x9bG\xb8\xc6\xb0"
#
#                                                   doi_hk  \
# 0      b'\x08\xbf\x18\x9e\xe6\x91\x1d\xacU\x14\x1a\x9...
# 1                                                   None
# 2        b'\xf9\x8au\xdbN8\x11\xe4\x18%\t\xca\xd1AM\xd7'
# 3      b'\xac\x8b\x16\xde\xf9v\xc6n\xbc\x98\x1f\xf7g\...
# 4          b'\n\x0c\x05\xd7#\xa8\x14\x7f~S\xa9Cf.\r\x1b'
# ...                                                  ...
# 50087           b'\xc8f|cI\xeb\x83`\xf4\xfa\x047B\xce#_'
# 50088                                               None
# 50089                                               None
# 50090       b'F\x1c6!\xb4\x1f\xd2M\xf60:\r\x18v\xfb\xf3'
# 50091  b'`\x93\x87\xc7\x1a\xc1}\x11R\xad;\xa62\r\xee\...
#
#                                                   mag_hk pmcid_hk  \
# 0      b'\xfe\x0e\x1cr\xfc\xa1\xe7{\xd5A[\\\xcf\xc01\...     None
# 1      b'\x15\xf0?\xc2aP4a\xeb6\xc3\x15\xc3\x04\xed\xfa'     None
# 2      b'>\xc2\x9e<\x96\x00\xb6\x8a\x8d8 \xeeT\xc1f\xbc'     None
# 3            b'8S\x0f\xed\x1dr?\x02*G\x08\xe7\xb1 \x8c['     None
# 4         b'.6\xe7Xk~\xf6\xd6(\x15\xed.\xd0\xe2\xb7\x18'     None
# ...                                                  ...      ...
# 50087  b'\xdd\xab\xc3\xd3\x85:O\xa4vJ\xc1\xbe\xe3L\xe...     None
# 50088                                               None     None
# 50089    b'=\xf3\\g\x99\x05\xf1\xc1\x90\xde\x1b\x1a(8lo'     None
# 50090     b'\xa52\x01\xa4\xf8\xf7\xae]v\xaa}\xc1oR\x1fG'     None
# 50091        b'\xcd{\xde*}\xd1\xffa\xca\xc8(F\xf1`\x975'     None
#
#                                               pmid_hk          coar_type
# 0                                                None  ARTÍCULO ORIGINAL
# 1                                                None  ARTÍCULO ORIGINAL
# 2                                                None  ARTÍCULO ORIGINAL
# 3      b'psOef\xb7\xeam\xe8\x19\xf7\xf0\xe1\x83(\x0e'  ARTÍCULO ORIGINAL
# 4                                                None  ARTÍCULO ORIGINAL
# ...                                               ...                ...
# 50087                                            None              TESIS
# 50088                                            None  ARTÍCULO ORIGINAL
# 50089                                            None  ARTÍCULO ORIGINAL
# 50090                                            None  ARTÍCULO ORIGINAL
# 50091                                            None  ARTÍCULO ORIGINAL
#
# [50092 rows x 40 columns]

# %%
dim_openalex_author

# %%
dim_openalex_institution

# %%
brg_openalex_author_institution

# %%
brg_openalex_publication_author
