# %%
import pandas as pd

# %%
fct_record_publication = catalog.load('dm_oai/fct_oai_record_publication')
# Out:
# [12/09/25 13:53:56] INFO     Loading data from dm_oai/fct_oai_record_publication               ]8;id=265671;file:///root/kedro-conicet/.venv/lib/python3.10/site-packages/kedro/io/data_catalog.py\data_catalog.py]8;;\:]8;id=500580;file:///root/kedro-conicet/.venv/lib/python3.10/site-packages/kedro/io/data_catalog.py#1048\1048]8;;\
#                              (SQLTableDataset)...

# %%
fct_record_publication
# Out:
# <pre style="white-space:pre;overflow-x:auto;line-height:normal;font-family:Menlo,'DejaVu Sans Mono',consolas,'Courier New',monospace"></pre>
#                                  record_id  \
# 0         oai:ri.conicet.gov.ar:11336/1000
# 1        oai:ri.conicet.gov.ar:11336/10000
# 2       oai:ri.conicet.gov.ar:11336/100000
# 3       oai:ri.conicet.gov.ar:11336/100001
# 4       oai:ri.conicet.gov.ar:11336/100002
# ...                                    ...
# 252458   oai:ri.conicet.gov.ar:11336/99995
# 252459   oai:ri.conicet.gov.ar:11336/99996
# 252460   oai:ri.conicet.gov.ar:11336/99997
# 252461   oai:ri.conicet.gov.ar:11336/99998
# 252462   oai:ri.conicet.gov.ar:11336/99999
#
#                                                     title date_issued  \
# 0       Inferencias paleoecológicas a partir del análi...  2013-06-01
# 1       ¿Escasez de agua en el siglo XXI?: Formas de a...  2013-12-01
# 2       Suelos securitarios: Hacia una antropología ur...  2018-06-01
# ...
