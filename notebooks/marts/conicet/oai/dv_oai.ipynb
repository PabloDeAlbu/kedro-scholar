# %%
import pandas as pd

# %%
ldg_record = catalog.load('dv_oai/ldg_oai_records')
hub_record = catalog.load('dv_oai/hub_oai_record')
# Out:
# [12/08/25 16:20:31] INFO     Loading data from dv_oai/ldg_oai_records (SQLTableDataset)...     ]8;id=456757;file:///home/pablo/dev/scholar/kedro-scholar/.venv/lib/python3.10/site-packages/kedro/io/data_catalog.py\data_catalog.py]8;;\:]8;id=336151;file:///home/pablo/dev/scholar/kedro-scholar/.venv/lib/python3.10/site-packages/kedro/io/data_catalog.py#1048\1048]8;;\
# [12/08/25 16:20:33] INFO     Loading data from dv_oai/hub_oai_record (SQLTableDataset)...      ]8;id=346022;file:///home/pablo/dev/scholar/kedro-scholar/.venv/lib/python3.10/site-packages/kedro/io/data_catalog.py\data_catalog.py]8;;\:]8;id=656015;file:///home/pablo/dev/scholar/kedro-scholar/.venv/lib/python3.10/site-packages/kedro/io/data_catalog.py#1048\1048]8;;\

# %%
ldg_record
# Out:
# <pre style="white-space:pre;overflow-x:auto;line-height:normal;font-family:Menlo,'DejaVu Sans Mono',consolas,'Courier New',monospace"></pre>
#                               record_id         col_id  \
# 0    oai:ri.conicet.gov.ar:11336/179477   com_11336_35
# 1    oai:ri.conicet.gov.ar:11336/116972  com_11336_219
# 2     oai:ri.conicet.gov.ar:11336/23263  com_11336_106
# 3    oai:ri.conicet.gov.ar:11336/215533  com_11336_184
# 4    oai:ri.conicet.gov.ar:11336/109802  com_11336_153
# ..                                  ...            ...
# 995    oai:ri.conicet.gov.ar:11336/8317  com_11336_204
# 996   oai:ri.conicet.gov.ar:11336/42800   com_11336_21
# 997  oai:ri.conicet.gov.ar:11336/140607   com_11336_35
# 998  oai:ri.conicet.gov.ar:11336/248879  com_11336_333
# 999  oai:ri.conicet.gov.ar:11336/124798  com_11336_123
#
#                                                  title date_issued  \
# 0    Paisajes mesetarios en Patagonia: Tecnología d...  2016-12-01
# 1    Distancias entre la ecología y la praxis ambie...  2011-01-01
# 2    Plant community resilience in the face of fire...  2016-02-01
# 3    La puesta en acto de las políticas de formació...  2022-11-01
# 4         Introducción a la Genética Forense No-Humana  2015-01-01
# ..                                                 ...         ...
# 995  A molecular recombination map of Antirrhinum m...  2010-12-01
# 996  NnSR1, a class III non-S-RNase specifically in...  2015-07-01
# 997  Abordaje de la enfermedad de Chagas en el prim...  2020-11-01
# 998                 Magnetic materials in oil industry  2022-01-01
# 999  Ternary copper(II) complex of 5-hydroxytryptop...  2019-12-01
#
#     extract_datetime load_datetime
# 0         2025-12-05    2025-12-07
# 1         2025-12-05    2025-12-07
# 2         2025-12-05    2025-12-07
# 3         2025-12-05    2025-12-07
# 4         2025-12-05    2025-12-07
# ..               ...           ...
# 995       2025-12-05    2025-12-07
# 996       2025-12-05    2025-12-07
# 997       2025-12-05    2025-12-07
# 998       2025-12-05    2025-12-07
# 999       2025-12-05    2025-12-07
#
# [1000 rows x 6 columns]

# %%
hub_record
# Out:
# <pre style="white-space:pre;overflow-x:auto;line-height:normal;font-family:Menlo,'DejaVu Sans Mono',consolas,'Courier New',monospace"></pre>
#                                              record_hk  \
# 0                   b"\x00^//'\xd9\xb1\xbbP-uz\x90qk9"
# 1      b'\x00f\xc1(\xdb\x8bg.\x13\xd7\xf9\xed\n\xa7..'
# 2    b'\x00\xb5\xf1\x8c5\x8c\x05XC\x8a\xd1]\x8d=M\xe6'
# 3    b'\x00\xf7\x12B\xfd\x08\xa3\xde\xc1\x8d\x13F^\...
# 4    b'\x01\x0e\xec\xbf0\xe5\x07+\xe6]\xb3\x00\xc0\...
# ..                                                 ...
# 995     b'\xfdt\xd8\x89O\xd3p\xc8\x07\x1a3D?t\x98\x80'
# 996  b'\xfe\x8byA\xbd\xad\xa5\x90K\xb8\xbd\xab\xdfq>@'
# 997  b'\xfe\x9c\x9d9\xa1\x10\x03K\xc7\r\xd2\x9c\xa6...
# 998  b'\xff\x0b\xfb\xee\xed]s\x0c/\x98\x10\xeeB\xb7...
# 999  b'\xff\xa6\xfa\xbd\xdc\x06\xc9!3rl\x8e0\x08\xe...
#
#                               record_id load_datetime source
# 0    oai:ri.conicet.gov.ar:11336/183864    2025-12-07    OAI
# 1    oai:ri.conicet.gov.ar:11336/250085    2025-12-07    OAI
# 2     oai:ri.conicet.gov.ar:11336/67668    2025-12-07    OAI
# 3    oai:ri.conicet.gov.ar:11336/128785    2025-12-07    OAI
# 4     oai:ri.conicet.gov.ar:11336/29620    2025-12-07    OAI
# ..                                  ...           ...    ...
# 995  oai:ri.conicet.gov.ar:11336/236706    2025-12-07    OAI
# 996   oai:ri.conicet.gov.ar:11336/21294    2025-12-07    OAI
# 997  oai:ri.conicet.gov.ar:11336/214082    2025-12-07    OAI
# 998  oai:ri.conicet.gov.ar:11336/190845    2025-12-07    OAI
# 999   oai:ri.conicet.gov.ar:11336/38492    2025-12-07    OAI
#
# [1000 rows x 4 columns]

# %%
df = catalog.load('dm_oai/fct_oai_record_publication')
df.drop(columns=["record_hk"], inplace=True)
# Out:
# [12/08/25 16:20:34] INFO     Loading data from dm_oai/fct_oai_record_publication               ]8;id=730378;file:///home/pablo/dev/scholar/kedro-scholar/.venv/lib/python3.10/site-packages/kedro/io/data_catalog.py\data_catalog.py]8;;\:]8;id=854983;file:///home/pablo/dev/scholar/kedro-scholar/.venv/lib/python3.10/site-packages/kedro/io/data_catalog.py#1048\1048]8;;\
#                              (SQLTableDataset)...

# %%
df
# Out:
# <pre style="white-space:pre;overflow-x:auto;line-height:normal;font-family:Menlo,'DejaVu Sans Mono',consolas,'Courier New',monospace"></pre>
#                               record_id  \
# 0    oai:ri.conicet.gov.ar:11336/100082
# 1    oai:ri.conicet.gov.ar:11336/100410
# 2    oai:ri.conicet.gov.ar:11336/100455
# 3    oai:ri.conicet.gov.ar:11336/100520
# 4    oai:ri.conicet.gov.ar:11336/100757
# ..                                  ...
# 995   oai:ri.conicet.gov.ar:11336/99041
# 996   oai:ri.conicet.gov.ar:11336/99134
# 997    oai:ri.conicet.gov.ar:11336/9948
# 998   oai:ri.conicet.gov.ar:11336/99756
# 999   oai:ri.conicet.gov.ar:11336/99826
#
#                                                  title date_issued
# 0    The elk, the ass, the tapir, their hooves, and...  2018-03-01
# 1    One-loop effective LFV Zlklm vertex from heavy...  2018-10-01
# 2    East-West cranial differentiation in pre-Colum...  2008-12-01
# 3    AmpuBase: A transcriptome database for eight s...  2018-03-01
# 4    Butyltin and PAH contamination of Mar del Plat...  2015-10-01
# ..                                                 ...         ...
# 995  Co-option of neurotransmitter signaling for in...  2019-07-18
# 996  Dilemmas of labor in Latin America: reorganizi...  2018-03-15
# 997  Los jubilados al mercado. Una genealogía teóri...  2014-10-01
# 998  On the roles of Mg in the activation of G prot...  2010-12-01
# 999  Laboratorio de materiales cerámicos estructura...  2006-04-01
#
# [1000 rows x 3 columns]
