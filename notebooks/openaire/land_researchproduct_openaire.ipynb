# %%
import ast
import pandas as pd

pd.set_option('display.max_columns', None)
df = catalog.load('raw/openaire/researchproduct')
# Out:
#                     INFO     Loading data from raw/openaire/researchproduct (CSVDataset)...     ]8;id=36276;file:///root/kedro-cic/.venv/lib/python3.10/site-packages/kedro/io/data_catalog.py\data_catalog.py]8;;\:]8;id=558433;file:///root/kedro-cic/.venv/lib/python3.10/site-packages/kedro/io/data_catalog.py#389\389]8;;\

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 3875 entries, 0 to 3874
# Data columns (total 39 columns):
#  #   Column                    Non-Null Count  Dtype
# ---  ------                    --------------  -----
#  0   @xmlns:xsi                3875 non-null   object
#  1   dri:objIdentifier         3875 non-null   object
#  2   dri:dateOfCollection      3875 non-null   object
#  3   dri:dateOfTransformation  2 non-null      object
#  4   collectedfrom             3875 non-null   object
#  5   originalId                3875 non-null   object
#  6   pid                       3875 non-null   object
#  7   measure                   3875 non-null   object
#  8   fulltext                  416 non-null    object
#  9   title                     3875 non-null   object
#  10  bestaccessright           3875 non-null   object
#  11  creator                   3842 non-null   object
#  12  country                   1774 non-null   object
#  13  dateofacceptance          3875 non-null   object
#  14  description               3570 non-null   object
#  15  subject                   3480 non-null   object
#  16  language                  3875 non-null   object
#  17  relevantdate              3868 non-null   object
#  18  publisher                 3875 non-null   object
#  19  source                    3862 non-null   object
#  20  format                    2123 non-null   object
#  21  resulttype                3875 non-null   object
#  22  resourcetype              3875 non-null   object
#  23  isgreen                   3832 non-null   object
#  24  openaccesscolor           3377 non-null   object
#  25  isindiamondjournal        3832 non-null   object
#  26  publiclyfunded            3832 non-null   object
#  27  journal                   3642 non-null   object
#  28  datainfo                  3875 non-null   object
#  29  rels                      3223 non-null   object
#  30  children                  3875 non-null   object
#  31  context                   891 non-null    object
#  32  contributor               141 non-null    object
#  33  embargoenddate            90 non-null     object
#  34  processingchargeamount    3 non-null      float64
#  35  processingchargecurrency  3 non-null      object
#  36  lastmetadataupdate        4 non-null      object
#  37  storagedate               5 non-null      object
#  38  version                   2 non-null      object
# dtypes: float64(1), object(38)
# memory usage: 1.2+ MB

# %%
df.shape
# Out:
# <pre style="white-space:pre;overflow-x:auto;line-height:normal;font-family:Menlo,'DejaVu Sans Mono',consolas,'Courier New',monospace"></pre>
# (3875, 39)

# %%
df.head(5)
# Out:
# <pre style="white-space:pre;overflow-x:auto;line-height:normal;font-family:Menlo,'DejaVu Sans Mono',consolas,'Courier New',monospace"></pre>
#                                   @xmlns:xsi  \
# 0  http://www.w3.org/2001/XMLSchema-instance
# 1  http://www.w3.org/2001/XMLSchema-instance
# 2  http://www.w3.org/2001/XMLSchema-instance
# 3  http://www.w3.org/2001/XMLSchema-instance
# 4  http://www.w3.org/2001/XMLSchema-instance
#
#                                 dri:objIdentifier     dri:dateOfCollection  \
# 0  doi_dedup___::2577d684a839dc78be3e1307914cdfd5  2024-10-11T14:10:24.466
# 1  doi_________::01bdfeebe25730711be433245a4426e7  2024-10-11T14:17:56.498
# 2  doi_dedup___::fccba469c4dbc14c5cec34e69ab21625  2024-10-11T14:20:20.957
# 3  doi_dedup___::000d1effb7dd214508cfa2db791e3814  2024-10-11T14:28:54.171
# 4  doi_dedup___::387324dfb1abac93013eccfd545780c1  2024-10-11T14:13:38.393
#
#   dri:dateOfTransformation                                      collectedfrom  \
# 0                      NaN  [{'@name': 'LAReferencia - Red Federada de Rep...
# 1                      NaN  {'@name': 'Crossref', '@id': 'openaire____::08...
# 2                      NaN  [{'@name': 'Crossref', '@id': 'openaire____::0...
# 3                      NaN  [{'@name': 'LAReferencia - Red Federada de Rep...
# 4                      NaN  [{'@name': 'UnpayWall', '@id': 'openaire____::...
#
#                                           originalId  \
# 0  ['quantum4010009', '10.3390/quantum4010009', '...
# 1  ['10.1002/cctc.202301719', '50|doiboost____|01...
# 2  ['S0273117720304853', '10.1016/j.asr.2020.07.0...
# 3  ['10.24267/22564004.544', '50|doiboost____|000...
# 4  ['10.5151/despro-sigradi2016-510', '50|doiboos...
#
#                                                  pid  \
# 0  {'@classid': 'doi', '@classname': 'Digital Obj...
# 1  {'@classid': 'doi', '@classname': 'Digital Obj...
# 2  [{'@classid': 'doi', '@classname': 'Digital Ob...
# 3  [{'@classid': 'doi', '@classname': 'Digital Ob...
# 4  [{'@classid': 'doi', '@classname': 'Digital Ob...
#
#                                              measure  \
# 0  [{'@id': 'influence', '@score': '3.29944E-9', ...
# 1  [{'@id': 'influence', '@score': '2.8970693E-9'...
# 2  [{'@id': 'influence', '@score': '2.95062E-9', ...
# 3  [{'@id': 'influence', '@score': '2.8970693E-9'...
# 4  [{'@id': 'influence', '@score': '3.1040028E-9'...
#
#                                   fulltext  \
# 0  http://www.mdpi.com/2624-960X/4/1/9/pdf
# 1                                      NaN
# 2                                      NaN
# 3                                      NaN
# 4                                      NaN
#
#                                                title  \
# 0  [{'@classid': 'main title', '@classname': 'mai...
# 1  {'@classid': 'main title', '@classname': 'main...
# 2  [{'@classid': 'main title', '@classname': 'mai...
# 3  [{'@classid': 'main title', '@classname': 'mai...
# 4  [{'@classid': 'main title', '@classname': 'mai...
#
#                                      bestaccessright  \
# 0  {'@classid': 'OPEN', '@classname': 'Open Acces...
# 1  {'@classid': 'CLOSED', '@classname': 'Closed A...
# 2  {'@classid': 'CLOSED', '@classname': 'Closed A...
# 3  {'@classid': 'OPEN', '@classname': 'Open Acces...
# 4  {'@classid': 'OPEN', '@classname': 'Open Acces...
#
#                                              creator  \
# 0  [{'@rank': '1', '@name': 'Diana', '@surname': ...
# 1  [{'@rank': '1', '@name': 'María S.', '@surname...
# 2  [{'@rank': '1', '#text': 'Nancy Esther Quarant...
# 3  [{'@rank': '1', '@name': 'Federico', '@surname...
# 4             {'@rank': '1', '#text': 'Clara Tapia'}
#
#                                              country dateofacceptance  \
# 0  {'@classid': 'AR', '@classname': 'Argentina', ...       2022-02-22
# 1                                                NaN       2024-02-16
# 2                                                NaN       2020-10-01
# 3  {'@classid': 'AR', '@classname': 'Argentina', ...       2021-07-09
# 4                                                NaN       2016-12-01
#
#                                          description  \
# 0  <jats:p>We deal here with an exactly solvable ...
# 1  <jats:title>Abstract</jats:title><jats:p>γ‐Val...
# 2  Abstract   In a first paper, we presented an i...
# 3  <jats:p>El objetivo de este artículo es analiz...
# 4  Palabras clave:   IMPRESION 3D; TEXTILES; INDU...
#
#                                              subject  \
# 0  [{'@classid': 'keyword', '@classname': 'keywor...
# 1                                                NaN
# 2  [{'@classid': 'FOS', '@classname': 'Fields of ...
# 3  [{'@classid': 'keyword', '@classname': 'keywor...
# 4  [{'@classid': 'FOS', '@classname': 'Fields of ...
#
#                                             language  \
# 0  {'@classid': 'und', '@classname': 'Undetermine...
# 1  {'@classid': 'und', '@classname': 'Undetermine...
# 2  {'@classid': 'und', '@classname': 'Undetermine...
# 3  {'@classid': 'und', '@classname': 'Undetermine...
# 4  {'@classid': 'und', '@classname': 'Undetermine...
#
#                                         relevantdate              publisher  \
# 0  [{'@classid': 'created', '@classname': 'create...                MDPI AG
# 1  [{'@classid': 'created', '@classname': 'create...                  Wiley
# 2  [{'@classid': 'created', '@classname': 'create...            Elsevier BV
# 3  [{'@classid': 'created', '@classname': 'create...  Universidad de Boyacá
# 4  [{'@classid': 'created', '@classname': 'create...        Editora Blucher
#
#                                               source  \
# 0  ['Crossref', 'Quantum Reports; Volume 4; Issue...
# 1                                           Crossref
# 2                                           Crossref
# 3  ['Crossref', 'reponame:SEDICI (UNLP)', 'instna...
# 4                                           Crossref
#
#                            format  \
# 0  ['application/pdf', '127-134']
# 1                             NaN
# 2                             NaN
# 3    ['application/pdf', '27-47']
# 4                             NaN
#
#                                           resulttype  \
# 0  {'@classid': 'publication', '@classname': 'pub...
# 1  {'@classid': 'publication', '@classname': 'pub...
# 2  {'@classid': 'publication', '@classname': 'pub...
# 3  {'@classid': 'publication', '@classname': 'pub...
# 4  {'@classid': 'publication', '@classname': 'pub...
#
#                                         resourcetype isgreen openaccesscolor  \
# 0  {'@classid': 'publication', '@classname': 'pub...    True            gold
# 1  {'@classid': 'publication', '@classname': 'pub...   False             NaN
# 2  {'@classid': 'publication', '@classname': 'pub...   False          bronze
# 3  {'@classid': 'publication', '@classname': 'pub...    True            gold
# 4  {'@classid': 'publication', '@classname': 'pub...   False          bronze
#
#   isindiamondjournal publiclyfunded  \
# 0              False          False
# 1              False          False
# 2              False          False
# 3              False          False
# 4              False          False
#
#                                              journal  \
# 0  {'@eissn': '2624-960X', '@ep': '134', '@sp': '...
# 1  {'@issn': '1867-3880', '@eissn': '1867-3899', ...
# 2  {'@issn': '0273-1177', '@ep': '2000', '@sp': '...
# 3  {'@issn': '2256-4004', '@eissn': '2539-147X', ...
# 4                         Blucher Design Proceedings
#
#                                             datainfo  \
# 0  {'inferred': 'true', 'deletedbyinference': 'fa...
# 1  {'inferred': 'false', 'deletedbyinference': 'f...
# 2  {'inferred': 'true', 'deletedbyinference': 'fa...
# 3  {'inferred': 'true', 'deletedbyinference': 'fa...
# 4  {'inferred': 'true', 'deletedbyinference': 'fa...
#
#                                                 rels  \
# 0  {'rel': [{'@inferred': 'true', '@trust': '0.65...
# 1  {'rel': [{'@inferred': 'true', '@trust': '0.71...
# 2  {'rel': [{'@inferred': 'false', '@trust': '0.9...
# 3  {'rel': {'@inferred': 'false', '@trust': '0.9'...
# 4                                                NaN
#
#                                             children  \
# 0  {'result': [{'@objidentifier': 'doajarticles::...
# 1  {'instance': {'accessright': {'@classid': 'CLO...
# 2  {'result': {'@objidentifier': 'doi_________::f...
# 3  {'result': [{'@objidentifier': 'doi_________::...
# 4  {'result': {'@objidentifier': 'doi_________::3...
#
#                                              context contributor  \
# 0                                                NaN         NaN
# 1                                                NaN         NaN
# 2  {'@id': 'energy-planning', '@label': 'Energy P...         NaN
# 3  {'@id': 'energy-planning', '@label': 'Energy P...         NaN
# 4                                                NaN         NaN
#
#   embargoenddate  processingchargeamount processingchargecurrency  \
# 0            NaN                     NaN                      NaN
# 1            NaN                     NaN                      NaN
# 2            NaN                     NaN                      NaN
# 3            NaN                     NaN                      NaN
# 4            NaN                     NaN                      NaN
#
#   lastmetadataupdate storagedate version
# 0                NaN         NaN     NaN
# 1                NaN         NaN     NaN
# 2                NaN         NaN     NaN
# 3                NaN         NaN     NaN
# 4                NaN         NaN     NaN

# %% [markdown]
# ## Paso 1: Convierto tipos y selecciono columnas con cardinalidad 1 con respecto a cada research product
# + info en https://graph.openaire.eu/docs/data-model/entities/research-product

# %%
df = df.convert_dtypes()
df_researchproduct = df.loc[:,
[
#       '@xmlns:xsi', 
       'dri:objIdentifier', 
       'dri:dateOfCollection',
       'dri:dateOfTransformation', 
#       'collectedfrom', 
#       'originalId', 
#       'pid',
#       'measure', 
       'fulltext', 
#       'title', 
#       'bestaccessright', 
#       'creator', 
#       'country',
       'dateofacceptance', 
       'description', 
#       'subject', 
#       'language',
#       'relevantdate', 
       'publisher', 
#       'source', 
#       'format', 
#       'resulttype',
#       'resourcetype', 
       'isgreen', 
       'openaccesscolor', 
       'isindiamondjournal',
       'publiclyfunded', 
#       'journal', 
#       'datainfo', 
#       'rels', 
#       'children', 
#       'context',
#       'contributor', 
#       'embargoenddate', 
#       'processingchargeamount',
#       'processingchargecurrency', 
#       'lastmetadataupdate', 
#       'storagedate',
#       'version'
]
]

# %%
df_researchproduct.head(5)
# Out:
# <pre style="white-space:pre;overflow-x:auto;line-height:normal;font-family:Menlo,'DejaVu Sans Mono',consolas,'Courier New',monospace"></pre>
#                                 dri:objIdentifier     dri:dateOfCollection  \
# 0  doi_dedup___::2577d684a839dc78be3e1307914cdfd5  2024-10-11T14:10:24.466
# 1  doi_________::01bdfeebe25730711be433245a4426e7  2024-10-11T14:17:56.498
# 2  doi_dedup___::fccba469c4dbc14c5cec34e69ab21625  2024-10-11T14:20:20.957
# 3  doi_dedup___::000d1effb7dd214508cfa2db791e3814  2024-10-11T14:28:54.171
# 4  doi_dedup___::387324dfb1abac93013eccfd545780c1  2024-10-11T14:13:38.393
#
#   dri:dateOfTransformation                                 fulltext  \
# 0                     <NA>  http://www.mdpi.com/2624-960X/4/1/9/pdf
# 1                     <NA>                                     <NA>
# 2                     <NA>                                     <NA>
# 3                     <NA>                                     <NA>
# 4                     <NA>                                     <NA>
#
#   dateofacceptance                                        description  \
# 0       2022-02-22  <jats:p>We deal here with an exactly solvable ...
# 1       2024-02-16  <jats:title>Abstract</jats:title><jats:p>γ‐Val...
# 2       2020-10-01  Abstract   In a first paper, we presented an i...
# 3       2021-07-09  <jats:p>El objetivo de este artículo es analiz...
# 4       2016-12-01  Palabras clave:   IMPRESION 3D; TEXTILES; INDU...
#
#                publisher  isgreen openaccesscolor  isindiamondjournal  \
# 0                MDPI AG     True            gold               False
# 1                  Wiley    False            <NA>               False
# 2            Elsevier BV    False          bronze               False
# 3  Universidad de Boyacá     True            gold               False
# 4        Editora Blucher    False          bronze               False
#
#    publiclyfunded
# 0           False
# 1           False
# 2           False
# 3           False
# 4           False
