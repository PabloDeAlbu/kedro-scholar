# %%
from datetime import date
import pandas as pd

pd.set_option('display.max_columns', None)

df = catalog.load('raw/openaire/researchproduct#parquet')
# Out:
#                     INFO     Loading data from raw/openaire/researchproduct#parquet             ]8;id=976220;file:///root/kedro-cic/.venv/lib/python3.10/site-packages/kedro/io/data_catalog.py\data_catalog.py]8;;\:]8;id=532267;file:///root/kedro-cic/.venv/lib/python3.10/site-packages/kedro/io/data_catalog.py#389\389]8;;\
#                              (ParquetDataset)...

# %%
df_research_sources = df[['id','sources']]
df_research_sources
# Out:
# <pre style="white-space:pre;overflow-x:auto;line-height:normal;font-family:Menlo,'DejaVu Sans Mono',consolas,'Courier New',monospace"></pre>
#                                                     id  \
# 0       dedup_wf_002::00004d08998bcb6f35ce5d53811f12e9
# 1       dedup_wf_002::0000eb33b6be05d67799615dd117e5b2
# 2       dedup_wf_002::00014d5f38ed4991a97d893df4cf84e7
# 3       dedup_wf_002::0001a843d6ffe65668859ab632a1e531
# 4       dedup_wf_002::00027faeda057626e8abbaba310695fa
# ...                                                ...
# 159802  pmid_dedup__::ed04e7477d247ae376d997093be8fb91
# 159803  pmid_dedup__::f05dc5628f6f331609cc2c34a05bb411
# 159804  pmid_dedup__::f5fc2b12e2042175f489487698896279
# 159805  pmid_dedup__::f79f43c98e4335a8f0270347c58bd12e
# 159806  pmid_dedup__::f8d3cd315536e65b096442ef75eeb8f7
#
#                                                   sources
# 0                                                    None
# 1       [Proyecciones, Iss 8 (2014), reponame:SEDICI (...
# 2                                                    None
# 3       [reponame:SEDICI (UNLP), instname:Universidad ...
# 4       [reponame:SEDICI (UNLP), instname:Universidad ...
# ...                                                   ...
# 159802  [reponame:SEDICI (UNLP), instname:Universidad ...
# 159803  [reponame:SEDICI (UNLP), instname:Universidad ...
# 159804  [reponame:SEDICI (UNLP), instname:Universidad ...
# 159805  [reponame:SEDICI (UNLP), instname:Universidad ...
# 159806  [reponame:SEDICI (UNLP), instname:Universidad ...
#
# [159807 rows x 2 columns]

# %%
df_research_sources = df_research_sources.explode('sources').reset_index(drop=True)
df_research_sources
# Out:
# <pre style="white-space:pre;overflow-x:auto;line-height:normal;font-family:Menlo,'DejaVu Sans Mono',consolas,'Courier New',monospace"></pre>
#                                                     id  \
# 0       dedup_wf_002::00004d08998bcb6f35ce5d53811f12e9
# 1       dedup_wf_002::0000eb33b6be05d67799615dd117e5b2
# 2       dedup_wf_002::0000eb33b6be05d67799615dd117e5b2
# 3       dedup_wf_002::0000eb33b6be05d67799615dd117e5b2
# 4       dedup_wf_002::0000eb33b6be05d67799615dd117e5b2
# ...                                                ...
# 431724  pmid_dedup__::f8d3cd315536e65b096442ef75eeb8f7
# 431725  pmid_dedup__::f8d3cd315536e65b096442ef75eeb8f7
# 431726  pmid_dedup__::f8d3cd315536e65b096442ef75eeb8f7
# 431727  pmid_dedup__::f8d3cd315536e65b096442ef75eeb8f7
# 431728  pmid_dedup__::f8d3cd315536e65b096442ef75eeb8f7
#
#                                                   sources
# 0                                                    None
# 1                              Proyecciones, Iss 8 (2014)
# 2                                  reponame:SEDICI (UNLP)
# 3               instname:Universidad Nacional de La Plata
# 4                                          instacron:UNLP
# ...                                                   ...
# 431724                             reponame:SEDICI (UNLP)
# 431725          instname:Universidad Nacional de La Plata
# 431726                                     instacron:UNLP
# 431727                 reponame:CONICET Digital (CONICET)
# 431728  instname:Consejo Nacional de Investigaciones C...
#
# [431729 rows x 2 columns]

# %%
def land_openaire_rel_researchproduct_sources(df: pd.DataFrame)-> pd.DataFrame:

    df_research_sources = df[['id','sources']]
    df_research_sources = df_research_sources.explode('sources').reset_index(drop=True)

    return df_research_sources

# %%
df_research_sources = land_openaire_rel_researchproduct_sources(df)

# %%
df_research_sources
# Out:
# <pre style="white-space:pre;overflow-x:auto;line-height:normal;font-family:Menlo,'DejaVu Sans Mono',consolas,'Courier New',monospace"></pre>
#                                                     id  \
# 0       dedup_wf_002::00004d08998bcb6f35ce5d53811f12e9
# 1       dedup_wf_002::0000eb33b6be05d67799615dd117e5b2
# 2       dedup_wf_002::0000eb33b6be05d67799615dd117e5b2
# 3       dedup_wf_002::0000eb33b6be05d67799615dd117e5b2
# 4       dedup_wf_002::0000eb33b6be05d67799615dd117e5b2
# ...                                                ...
# 431724  pmid_dedup__::f8d3cd315536e65b096442ef75eeb8f7
# 431725  pmid_dedup__::f8d3cd315536e65b096442ef75eeb8f7
# 431726  pmid_dedup__::f8d3cd315536e65b096442ef75eeb8f7
# 431727  pmid_dedup__::f8d3cd315536e65b096442ef75eeb8f7
# 431728  pmid_dedup__::f8d3cd315536e65b096442ef75eeb8f7
#
#                                                   sources
# 0                                                    None
# 1                              Proyecciones, Iss 8 (2014)
# 2                                  reponame:SEDICI (UNLP)
# 3               instname:Universidad Nacional de La Plata
# 4                                          instacron:UNLP
# ...                                                   ...
# 431724                             reponame:SEDICI (UNLP)
# 431725          instname:Universidad Nacional de La Plata
# 431726                                     instacron:UNLP
# 431727                 reponame:CONICET Digital (CONICET)
# 431728  instname:Consejo Nacional de Investigaciones C...
#
# [431729 rows x 2 columns]
