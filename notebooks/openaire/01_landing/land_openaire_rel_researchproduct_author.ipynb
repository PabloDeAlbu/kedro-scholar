# %%
from datetime import date
import pandas as pd

pd.set_option('display.max_columns', None)

filter_param = catalog.load('params:openaire_fetch_options.filter_param')
filter_value = catalog.load('params:openaire_fetch_options.filter_value')
df = catalog.load('raw/openaire/researchproduct#parquet')
# Out:
#                     INFO     Loading data from params:openaire_fetch_options.filter_param       ]8;id=459527;file:///root/kedro-cic/.venv/lib/python3.10/site-packages/kedro/io/data_catalog.py\data_catalog.py]8;;\:]8;id=811817;file:///root/kedro-cic/.venv/lib/python3.10/site-packages/kedro/io/data_catalog.py#389\389]8;;\
#                              (MemoryDataset)...
#                     INFO     Loading data from params:openaire_fetch_options.filter_value       ]8;id=694382;file:///root/kedro-cic/.venv/lib/python3.10/site-packages/kedro/io/data_catalog.py\data_catalog.py]8;;\:]8;id=680789;file:///root/kedro-cic/.venv/lib/python3.10/site-packages/kedro/io/data_catalog.py#389\389]8;;\
#                              (MemoryDataset)...
#                     INFO     Loading data from raw/openaire/researchproduct#parquet             ]8;id=777790;file:///root/kedro-cic/.venv/lib/python3.10/site-packages/kedro/io/data_catalog.py\data_catalog.py]8;;\:]8;id=71854;file:///root/kedro-cic/.venv/lib/python3.10/site-packages/kedro/io/data_catalog.py#389\389]8;;\
#                              (ParquetDataset)...

# %%
df.columns
# Out:
# <pre style="white-space:pre;overflow-x:auto;line-height:normal;font-family:Menlo,'DejaVu Sans Mono',consolas,'Courier New',monospace"></pre>
# Index(['authors', 'openAccessColor', 'publiclyFunded', 'type', 'language',
#        'countries', 'subjects', 'mainTitle', 'descriptions', 'publicationDate',
#        'formats', 'contributors', 'bestAccessRight', 'id', 'originalIds',
#        'indicators', 'instances', 'isGreen', 'isInDiamondJournal', 'publisher',
#        'sources', 'container', 'pids', 'embargoEndDate',
#        'relCollectedFromDatasourceId'],
#       dtype='object')

# %%
df
# Out:
# <pre style="white-space:pre;overflow-x:auto;line-height:normal;font-family:Menlo,'DejaVu Sans Mono',consolas,'Courier New',monospace"></pre>
#                                                   authors openAccessColor  \
# 0       [{'fullName': 'Rubio, Damián', 'name': 'Damiá...            None
# 1       [{'fullName': 'Ojeda Hidalgo, José F.', 'name'...            gold
# 2       [{'fullName': 'Pons, Claudia', 'name': 'Claudi...            None
# 3       [{'fullName': 'Tarducci, Gabriel', 'name': 'Ga...            None
# 4       [{'fullName': 'Moreno, Manuela', 'name': 'Manu...            None
# ...                                                   ...             ...
# 159802  [{'fullName': 'Scataglini, María Amalia', 'nam...          bronze
# 159803  [{'fullName': 'P. Daniel Ghiringhelli', 'name'...          bronze
# 159804  [{'fullName': 'Massa, L.', 'name': 'L.', 'pid'...          bronze
# 159805  [{'fullName': 'Williams, Sara Inés', 'name': '...            None
# 159806  [{'fullName': 'Jaureguiberry, María', 'name': ...            None
#
#        publiclyFunded         type                                 language  \
# 0               False  publication  {'code': 'esl/spa', 'label': 'Spanish'}
# 1               False  publication      {'code': 'eng', 'label': 'English'}
# 2                None        other  {'code': 'esl/spa', 'label': 'Spanish'}
# 3               False  publication  {'code': 'esl/spa', 'label': 'Spanish'}
# 4               False  publication  {'code': 'esl/spa', 'label': 'Spanish'}
# ...               ...          ...                                      ...
# 159802          False  publication      {'code': 'eng', 'label': 'English'}
# 159803          False  publication      {'code': 'eng', 'label': 'English'}
# 159804          False  publication      {'code': 'eng', 'label': 'English'}
# 159805          False  publication      {'code': 'eng', 'label': 'English'}
# 159806          False  publication      {'code': 'eng', 'label': 'English'}
#
#                                                 countries  \
# 0       [{'code': 'AR', 'label': 'Argentina', 'provena...
# 1       [{'code': 'AR', 'label': 'Argentina', 'provena...
# 2       [{'code': 'AR', 'label': 'Argentina', 'provena...
# 3       [{'code': 'AR', 'label': 'Argentina', 'provena...
# 4       [{'code': 'AR', 'label': 'Argentina', 'provena...
# ...                                                   ...
# 159802  [{'code': 'AR', 'label': 'Argentina', 'provena...
# 159803  [{'code': 'AR', 'label': 'Argentina', 'provena...
# 159804  [{'code': 'AR', 'label': 'Argentina', 'provena...
# 159805  [{'code': 'AR', 'label': 'Argentina', 'provena...
# 159806  [{'code': 'AR', 'label': 'Argentina', 'provena...
#
#                                                  subjects  \
# 0       [{'provenance': None, 'subject': {'scheme': 'k...
# 1       [{'provenance': None, 'subject': {'scheme': 'k...
# 2       [{'provenance': None, 'subject': {'scheme': 'k...
# 3       [{'provenance': None, 'subject': {'scheme': 'k...
# 4       [{'provenance': None, 'subject': {'scheme': 'k...
# ...                                                   ...
# 159802  [{'provenance': None, 'subject': {'scheme': 'k...
# 159803  [{'provenance': None, 'subject': {'scheme': 'k...
# 159804  [{'provenance': None, 'subject': {'scheme': 'k...
# 159805  [{'provenance': None, 'subject': {'scheme': 'k...
# 159806  [{'provenance': None, 'subject': {'scheme': 'k...
#
#                                                 mainTitle  \
# 0       Evolución del sistema de gestión de incidentes...
# 1       Responsabilidad Social Corporativa en Empresas...
# 2       Interfaces naturales como factor de progreso c...
# 3       Composición corporal, gasto energético, desemp...
# 4            Jornadas, exposiciones y encuesta de opinión
# ...                                                   ...
# 159802  Dispersal of the cotton boll weevil (Coleopter...
# 159803  Generation of a recombinant Anticarsia gemmata...
# 159804  Insulin-like growth factor binding proteins fr...
# 159805  Accuracy of pregnancy diagnosis in swine by ul...
# 159806  A simplified scoring system for the diagnosis ...
#
#                                              descriptions publicationDate  \
# 0       [Esta tesina detalla el desarrollo de un siste...      2023-06-23
# 1       [El presente artículo presenta un conjunto de ...      2013-12-01
# 2       [El trastorno de espectro autista (TEA) es una...      2015-04-01
# 3       [La investigación sobre actividad física, gast...      2022-01-01
# 4       [Se describen y comentan las siguientes activi...      2010-01-01
# ...                                                   ...             ...
# 159802  [RAPD technique provides useful information on...      2000-01-01
# 159803  [A recombinant <i>Anticarsia gemmatalis</i> mu...      2001-06-01
# 159804  [This study investigated the effect of glucose...      1997-01-01
# 159805  [Early and accurate diagnosis of nonpregnant s...      2008-01-01
# 159806  [ObjectiveTo compare the capacity of a simplif...      2023-03-01
#
#                            formats                              contributors  \
# 0                [application/pdf]  [Lanfranco, Einar Felipe, Venosa, Paula]
# 1       [application/pdf, 143-162]                                      None
# 2                [application/pdf]                                      None
# 3                [application/pdf]                                      None
# 4         [application/pdf, 52-56]                                      None
# ...                            ...                                       ...
# 159802  [application/pdf, 127-136]                                      None
# 159803  [application/pdf, 363-372]                                      None
# 159804           [application/pdf]                                      None
# 159805  [application/pdf, 269-273]                                      None
# 159806  [application/pdf, 553-557]                                      None
#
#                                           bestAccessRight  \
# 0       {'code': 'c_abf2', 'label': 'OPEN', 'scheme': ...
# 1       {'code': 'c_abf2', 'label': 'OPEN', 'scheme': ...
# 2                                                    None
# 3       {'code': 'c_abf2', 'label': 'OPEN', 'scheme': ...
# 4       {'code': 'c_abf2', 'label': 'OPEN', 'scheme': ...
# ...                                                   ...
# 159802  {'code': 'c_abf2', 'label': 'OPEN', 'scheme': ...
# 159803  {'code': 'c_abf2', 'label': 'OPEN', 'scheme': ...
# 159804  {'code': 'c_abf2', 'label': 'OPEN', 'scheme': ...
# 159805  {'code': 'c_abf2', 'label': 'OPEN', 'scheme': ...
# 159806  {'code': 'c_abf2', 'label': 'OPEN', 'scheme': ...
#
#                                                     id  \
# 0       dedup_wf_002::00004d08998bcb6f35ce5d53811f12e9
# 1       dedup_wf_002::0000eb33b6be05d67799615dd117e5b2
# 2       dedup_wf_002::00014d5f38ed4991a97d893df4cf84e7
# 3       dedup_wf_002::0001a843d6ffe65668859ab632a1e531
# 4       dedup_wf_002::00027faeda057626e8abbaba310695fa
# ...                                                ...
# 159802  pmid_dedup__::ed04e7477d247ae376d997093be8fb91
# 159803  pmid_dedup__::f05dc5628f6f331609cc2c34a05bb411
# 159804  pmid_dedup__::f5fc2b12e2042175f489487698896279
# 159805  pmid_dedup__::f79f43c98e4335a8f0270347c58bd12e
# 159806  pmid_dedup__::f8d3cd315536e65b096442ef75eeb8f7
#
#                                               originalIds  \
# 0       [oai:sedici.unlp.edu.ar:10915/154923, 50|od___...
# 1       [oai:doaj.org/article:a86e0a7dd7ad4000ae40ad07...
# 2       [50|od______1329::d16ffc72c35465a1ffa9dc493a5b...
# 3       [50|od______1329::b653a04092ec3bb583eae28c6e5e...
# 4       [oai:sedici.unlp.edu.ar:10915/52057, 50|od____...
# ...                                                   ...
# 159802  [11138940, 223355806, 50|od______1329::93d8191...
# 159803  [11450955, 124993717, 50|od______1329::c9a70ba...
# 159804  [9416434, 50|od______1329::c8f934c7f0fa8a439df...
# 159805  [od_______267::c1c26def054337d5995921cfb8961ff...
# 159806  [od_______267::9748fb9c1628ec056e60b6f9ae396cc...
#
#                                                indicators  \
# 0       {'citationImpact': {'citationClass': 'C5', 'ci...
# 1       {'citationImpact': {'citationClass': 'C5', 'ci...
# 2       {'citationImpact': {'citationClass': 'C5', 'ci...
# 3       {'citationImpact': {'citationClass': 'C5', 'ci...
# 4       {'citationImpact': {'citationClass': 'C5', 'ci...
# ...                                                   ...
# 159802  {'citationImpact': {'citationClass': 'C4', 'ci...
# 159803  {'citationImpact': {'citationClass': 'C5', 'ci...
# 159804  {'citationImpact': {'citationClass': 'C5', 'ci...
# 159805  {'citationImpact': {'citationClass': 'C5', 'ci...
# 159806  {'citationImpact': {'citationClass': 'C5', 'ci...
#
#                                                 instances isGreen  \
# 0       [{'alternateIdentifiers': None, 'articleProces...    True
# 1       [{'alternateIdentifiers': None, 'articleProces...    True
# 2       [{'alternateIdentifiers': None, 'articleProces...    None
# 3       [{'alternateIdentifiers': None, 'articleProces...    True
# 4       [{'alternateIdentifiers': None, 'articleProces...    True
# ...                                                   ...     ...
# 159802  [{'alternateIdentifiers': [{'scheme': 'doi', '...    True
# 159803  [{'alternateIdentifiers': [{'scheme': 'doi', '...    True
# 159804  [{'alternateIdentifiers': None, 'articleProces...    True
# 159805  [{'alternateIdentifiers': None, 'articleProces...    True
# 159806  [{'alternateIdentifiers': None, 'articleProces...    True
#
#        isInDiamondJournal                         publisher  \
# 0                   False                              None
# 1                   False  Universidad Nacional de La Plata
# 2                    None                              None
# 3                   False                              None
# 4                   False                              None
# ...                   ...                               ...
# 159802              False        Kluwer Academic Publishers
# 159803              False        Kluwer Academic Publishers
# 159804              False                              None
# 159805              False            Canadian Vet Med Assoc
# 159806              False            Canadian Vet Med Assoc
#
#                                                   sources  \
# 0                                                    None
# 1       [Proyecciones, Iss 8 (2014), reponame:SEDICI (...
# 2                                                    None
# 3       [reponame:SEDICI (UNLP), instname:Universidad ...
# 4       [reponame:SEDICI (UNLP), instname:Universidad ...
# ...                                                   ...
# 159802  [reponame:SEDICI (UNLP), instname:Universidad ...
# 159803  [reponame:SEDICI (UNLP), instname:Universidad ...
# 159804  [reponame:SEDICI (UNLP), instname:Universidad ...
# 159805  [reponame:SEDICI (UNLP), instname:Universidad ...
# 159806  [reponame:SEDICI (UNLP), instname:Universidad ...
#
#                                                 container  \
# 0                                                    None
# 1       {'conferenceDate': None, 'conferencePlace': No...
# 2                                                    None
# 3                                                    None
# 4                                                    None
# ...                                                   ...
# 159802  {'conferenceDate': None, 'conferencePlace': No...
# 159803  {'conferenceDate': None, 'conferencePlace': No...
# 159804  {'conferenceDate': None, 'conferencePlace': No...
# 159805  {'conferenceDate': None, 'conferencePlace': No...
# 159806  {'conferenceDate': None, 'conferencePlace': No...
#
#                                                      pids embargoEndDate  \
# 0                                                    None           None
# 1                                                    None           None
# 2                                                    None           None
# 3                                                    None           None
# 4                                                    None           None
# ...                                                   ...            ...
# 159802  [{'scheme': 'pmid', 'value': '11138940'}, {'sc...           None
# 159803  [{'scheme': 'pmid', 'value': '11450955'}, {'sc...           None
# 159804           [{'scheme': 'pmid', 'value': '9416434'}]           None
# 159805  [{'scheme': 'pmid', 'value': '18390099'}, {'sc...           None
# 159806  [{'scheme': 'pmid', 'value': '37265806'}, {'sc...           None
#
#                           relCollectedFromDatasourceId
# 0       opendoar____::01e9565cecc4e989123f9620c1d09c09
# 1       opendoar____::01e9565cecc4e989123f9620c1d09c09
# 2       opendoar____::01e9565cecc4e989123f9620c1d09c09
# 3       opendoar____::01e9565cecc4e989123f9620c1d09c09
# 4       opendoar____::01e9565cecc4e989123f9620c1d09c09
# ...                                                ...
# 159802  opendoar____::01e9565cecc4e989123f9620c1d09c09
# 159803  opendoar____::01e9565cecc4e989123f9620c1d09c09
# 159804  opendoar____::01e9565cecc4e989123f9620c1d09c09
# 159805  opendoar____::01e9565cecc4e989123f9620c1d09c09
# 159806  opendoar____::01e9565cecc4e989123f9620c1d09c09
#
# [159807 rows x 25 columns]

# %%
df_research_author = df[['id','authors']].explode('authors').reset_index(drop=True)
df_research_author
# Out:
# <pre style="white-space:pre;overflow-x:auto;line-height:normal;font-family:Menlo,'DejaVu Sans Mono',consolas,'Courier New',monospace"></pre>
#                                                     id  \
# 0       dedup_wf_002::00004d08998bcb6f35ce5d53811f12e9
# 1       dedup_wf_002::0000eb33b6be05d67799615dd117e5b2
# 2       dedup_wf_002::0000eb33b6be05d67799615dd117e5b2
# 3       dedup_wf_002::0000eb33b6be05d67799615dd117e5b2
# 4       dedup_wf_002::00014d5f38ed4991a97d893df4cf84e7
# ...                                                ...
# 402585  pmid_dedup__::f8d3cd315536e65b096442ef75eeb8f7
# 402586  pmid_dedup__::f8d3cd315536e65b096442ef75eeb8f7
# 402587  pmid_dedup__::f8d3cd315536e65b096442ef75eeb8f7
# 402588  pmid_dedup__::f8d3cd315536e65b096442ef75eeb8f7
# 402589  pmid_dedup__::f8d3cd315536e65b096442ef75eeb8f7
#
#                                                   authors
# 0       {'fullName': 'Rubio, Damián', 'name': 'Damián...
# 1       {'fullName': 'Ojeda Hidalgo, José F.', 'name':...
# 2       {'fullName': 'Conraud Koellner, Eva', 'name': ...
# 3       {'fullName': 'Archundia Fernández, Emigdio', '...
# 4       {'fullName': 'Pons, Claudia', 'name': 'Claudia...
# ...                                                   ...
# 402585  {'fullName': 'Marconi, María José', 'name': 'M...
# 402586  {'fullName': 'Giuliodori, Mauricio Javier', 'n...
# 402587  {'fullName': 'Madoz, Laura Vanina', 'name': 'L...
# 402588  {'fullName': 'Alvarado Pinedo, María Fiorella'...
# 402589  {'fullName': 'Sota, Rodolfo Luzbel de la', 'na...
#
# [402590 rows x 2 columns]

# %%
df_authors = pd.json_normalize(df_research_author['authors'])
df_authors
# Out:
# <pre style="white-space:pre;overflow-x:auto;line-height:normal;font-family:Menlo,'DejaVu Sans Mono',consolas,'Courier New',monospace"></pre>
#                                fullName               name  pid  rank  \
# 0                         Rubio, Damián            Damián  NaN   1.0
# 1                Ojeda Hidalgo, José F.           José F.  NaN   1.0
# 2                 Conraud Koellner, Eva                Eva  NaN   2.0
# 3          Archundia Fernández, Emigdio            Emigdio  NaN   3.0
# 4                         Pons, Claudia            Claudia  NaN   1.0
# ...                                 ...                ...  ...   ...
# 402585              Marconi, María José       María José  NaN   3.0
# 402586      Giuliodori, Mauricio Javier    Mauricio Javier  NaN   4.0
# 402587              Madoz, Laura Vanina       Laura Vanina  NaN   5.0
# 402588  Alvarado Pinedo, María Fiorella    María Fiorella  NaN   6.0
# 402589       Sota, Rodolfo Luzbel de la  Rodolfo Luzbel La  NaN   7.0
#
#                      surname pid.id.scheme pid.id.value  pid.provenance
# 0                      Rubio           NaN          NaN             NaN
# 1              Ojeda Hidalgo           NaN          NaN             NaN
# 2           Conraud Koellner           NaN          NaN             NaN
# 3       Archundia Fernández           NaN          NaN             NaN
# 4                       Pons           NaN          NaN             NaN
# ...                      ...           ...          ...             ...
# 402585               Marconi           NaN          NaN             NaN
# 402586            Giuliodori           NaN          NaN             NaN
# 402587                 Madoz           NaN          NaN             NaN
# 402588       Alvarado Pinedo           NaN          NaN             NaN
# 402589                  Sota           NaN          NaN             NaN
#
# [402590 rows x 8 columns]

# %%
df_research_author = pd.concat([df_research_author['id'], df_authors], axis=1)
df_research_author
# Out:
# <pre style="white-space:pre;overflow-x:auto;line-height:normal;font-family:Menlo,'DejaVu Sans Mono',consolas,'Courier New',monospace"></pre>
#                                                     id  \
# 0       dedup_wf_002::00004d08998bcb6f35ce5d53811f12e9
# 1       dedup_wf_002::0000eb33b6be05d67799615dd117e5b2
# 2       dedup_wf_002::0000eb33b6be05d67799615dd117e5b2
# 3       dedup_wf_002::0000eb33b6be05d67799615dd117e5b2
# 4       dedup_wf_002::00014d5f38ed4991a97d893df4cf84e7
# ...                                                ...
# 402585  pmid_dedup__::f8d3cd315536e65b096442ef75eeb8f7
# 402586  pmid_dedup__::f8d3cd315536e65b096442ef75eeb8f7
# 402587  pmid_dedup__::f8d3cd315536e65b096442ef75eeb8f7
# 402588  pmid_dedup__::f8d3cd315536e65b096442ef75eeb8f7
# 402589  pmid_dedup__::f8d3cd315536e65b096442ef75eeb8f7
#
#                                fullName               name  pid  rank  \
# 0                         Rubio, Damián            Damián  NaN   1.0
# 1                Ojeda Hidalgo, José F.           José F.  NaN   1.0
# 2                 Conraud Koellner, Eva                Eva  NaN   2.0
# 3          Archundia Fernández, Emigdio            Emigdio  NaN   3.0
# 4                         Pons, Claudia            Claudia  NaN   1.0
# ...                                 ...                ...  ...   ...
# 402585              Marconi, María José       María José  NaN   3.0
# 402586      Giuliodori, Mauricio Javier    Mauricio Javier  NaN   4.0
# 402587              Madoz, Laura Vanina       Laura Vanina  NaN   5.0
# 402588  Alvarado Pinedo, María Fiorella    María Fiorella  NaN   6.0
# 402589       Sota, Rodolfo Luzbel de la  Rodolfo Luzbel La  NaN   7.0
#
#                      surname pid.id.scheme pid.id.value  pid.provenance
# 0                      Rubio           NaN          NaN             NaN
# 1              Ojeda Hidalgo           NaN          NaN             NaN
# 2           Conraud Koellner           NaN          NaN             NaN
# 3       Archundia Fernández           NaN          NaN             NaN
# 4                       Pons           NaN          NaN             NaN
# ...                      ...           ...          ...             ...
# 402585               Marconi           NaN          NaN             NaN
# 402586            Giuliodori           NaN          NaN             NaN
# 402587                 Madoz           NaN          NaN             NaN
# 402588       Alvarado Pinedo           NaN          NaN             NaN
# 402589                  Sota           NaN          NaN             NaN
#
# [402590 rows x 9 columns]

# %% [markdown]
# ## Paso 1: Convierto tipos y selecciono columnas con cardinalidad 1 con respecto a cada research product
# + info en https://graph.openaire.eu/docs/data-model/entities/research-product

# %%
def land_openaire_rel_researchproduct_author(df: pd.DataFrame)-> pd.DataFrame:

    df_research_author = df[['id','authors']].explode('authors').reset_index(drop=True)

    df_authors = pd.json_normalize(df_research_author['authors'])

    df_research_author = pd.concat([df_research_author['id'], df_authors], axis=1)
    
    return df_research_author

# %%
df_researchproduct_author = land_openaire_rel_researchproduct_author(df)

# %%
df_researchproduct_author
# Out:
# <pre style="white-space:pre;overflow-x:auto;line-height:normal;font-family:Menlo,'DejaVu Sans Mono',consolas,'Courier New',monospace"></pre>
#                                                     id  \
# 0       dedup_wf_002::00004d08998bcb6f35ce5d53811f12e9
# 1       dedup_wf_002::0000eb33b6be05d67799615dd117e5b2
# 2       dedup_wf_002::0000eb33b6be05d67799615dd117e5b2
# 3       dedup_wf_002::0000eb33b6be05d67799615dd117e5b2
# 4       dedup_wf_002::00014d5f38ed4991a97d893df4cf84e7
# ...                                                ...
# 402585  pmid_dedup__::f8d3cd315536e65b096442ef75eeb8f7
# 402586  pmid_dedup__::f8d3cd315536e65b096442ef75eeb8f7
# 402587  pmid_dedup__::f8d3cd315536e65b096442ef75eeb8f7
# 402588  pmid_dedup__::f8d3cd315536e65b096442ef75eeb8f7
# 402589  pmid_dedup__::f8d3cd315536e65b096442ef75eeb8f7
#
#                                fullName               name  pid  rank  \
# 0                         Rubio, Damián            Damián  NaN   1.0
# 1                Ojeda Hidalgo, José F.           José F.  NaN   1.0
# 2                 Conraud Koellner, Eva                Eva  NaN   2.0
# 3          Archundia Fernández, Emigdio            Emigdio  NaN   3.0
# 4                         Pons, Claudia            Claudia  NaN   1.0
# ...                                 ...                ...  ...   ...
# 402585              Marconi, María José       María José  NaN   3.0
# 402586      Giuliodori, Mauricio Javier    Mauricio Javier  NaN   4.0
# 402587              Madoz, Laura Vanina       Laura Vanina  NaN   5.0
# 402588  Alvarado Pinedo, María Fiorella    María Fiorella  NaN   6.0
# 402589       Sota, Rodolfo Luzbel de la  Rodolfo Luzbel La  NaN   7.0
#
#                      surname pid.id.scheme pid.id.value  pid.provenance
# 0                      Rubio           NaN          NaN             NaN
# 1              Ojeda Hidalgo           NaN          NaN             NaN
# 2           Conraud Koellner           NaN          NaN             NaN
# 3       Archundia Fernández           NaN          NaN             NaN
# 4                       Pons           NaN          NaN             NaN
# ...                      ...           ...          ...             ...
# 402585               Marconi           NaN          NaN             NaN
# 402586            Giuliodori           NaN          NaN             NaN
# 402587                 Madoz           NaN          NaN             NaN
# 402588       Alvarado Pinedo           NaN          NaN             NaN
# 402589                  Sota           NaN          NaN             NaN
#
# [402590 rows x 9 columns]
