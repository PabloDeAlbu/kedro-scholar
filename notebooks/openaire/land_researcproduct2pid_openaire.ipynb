# %%
import ast
import pandas as pd

pd.set_option('display.max_columns', None)
df = catalog.load('raw/openaire/researchproduct')
# Out:
#                     INFO     Loading data from raw/openaire/researchproduct (CSVDataset)...     ]8;id=63534;file:///root/kedro-cic/.venv/lib/python3.10/site-packages/kedro/io/data_catalog.py\data_catalog.py]8;;\:]8;id=786636;file:///root/kedro-cic/.venv/lib/python3.10/site-packages/kedro/io/data_catalog.py#389\389]8;;\

# %%
df = df.convert_dtypes()

# %% [markdown]
# ## Paso 1: Seleccionar columnas con identificador y pid

# %%
df_researchproduct = df.loc[:,['dri:objIdentifier', 'pid']]

# %%
df_researchproduct.head(5)
# Out:
# <pre style="white-space:pre;overflow-x:auto;line-height:normal;font-family:Menlo,'DejaVu Sans Mono',consolas,'Courier New',monospace"></pre>
#                                 dri:objIdentifier  \
# 0  doi_dedup___::2577d684a839dc78be3e1307914cdfd5
# 1  doi_________::01bdfeebe25730711be433245a4426e7
# 2  doi_dedup___::fccba469c4dbc14c5cec34e69ab21625
# 3  doi_dedup___::000d1effb7dd214508cfa2db791e3814
# 4  doi_dedup___::387324dfb1abac93013eccfd545780c1
#
#                                                  pid
# 0  {'@classid': 'doi', '@classname': 'Digital Obj...
# 1  {'@classid': 'doi', '@classname': 'Digital Obj...
# 2  [{'@classid': 'doi', '@classname': 'Digital Ob...
# 3  [{'@classid': 'doi', '@classname': 'Digital Ob...
# 4  [{'@classid': 'doi', '@classname': 'Digital Ob...

# %% [markdown]
# ## Paso 2: Asegurarse de que 'pid' sea un diccionario o lista

# %%
df_researchproduct['pid'] = df_researchproduct['pid'].apply(lambda x: ast.literal_eval(x) if isinstance(x, str) else x)
df_researchproduct['pid'] = df_researchproduct['pid'].apply(lambda x: [x] if not isinstance(x, list) else x)

# %%
df_researchproduct.head(3)
# Out:
# <pre style="white-space:pre;overflow-x:auto;line-height:normal;font-family:Menlo,'DejaVu Sans Mono',consolas,'Courier New',monospace"></pre>
#                                 dri:objIdentifier  \
# 0  doi_dedup___::2577d684a839dc78be3e1307914cdfd5
# 1  doi_________::01bdfeebe25730711be433245a4426e7
# 2  doi_dedup___::fccba469c4dbc14c5cec34e69ab21625
#
#                                                  pid
# 0  [{'@classid': 'doi', '@classname': 'Digital Ob...
# 1  [{'@classid': 'doi', '@classname': 'Digital Ob...
# 2  [{'@classid': 'doi', '@classname': 'Digital Ob...

# %% [markdown]
# ## Paso 3: Explode la columna 'pid' y reinicia el índice

# %%
df_researchproduct = df_researchproduct.explode('pid').reset_index(drop=True)

# %% [markdown]
# ## Paso 4: Normalizar la columna 'pid' en nuevas columnas

# %%
pid_expanded = pd.json_normalize(df_researchproduct["pid"])

# %% [markdown]
# ## Paso 5: Eliminar columnas no deseadas de 'pid'

# %%
pid_expanded.drop(columns=['@classname', '@schemeid', '@schemename', '@inferred', '@provenanceaction', '@trust'], inplace=True)

# %% [markdown]
# ## Paso 5: Concatenar asegurando que los índices están alineados

# %%
df_researchproduct2pid = pd.concat([df_researchproduct, pid_expanded], axis=1)
df_researchproduct2pid.drop(columns='pid', inplace=True)

# %%
df_researchproduct2pid
# Out:
# <pre style="white-space:pre;overflow-x:auto;line-height:normal;font-family:Menlo,'DejaVu Sans Mono',consolas,'Courier New',monospace"></pre>
#                                     dri:objIdentifier @classid  \
# 0      doi_dedup___::2577d684a839dc78be3e1307914cdfd5      doi
# 1      doi_________::01bdfeebe25730711be433245a4426e7      doi
# 2      doi_dedup___::fccba469c4dbc14c5cec34e69ab21625      doi
# 3      doi_dedup___::fccba469c4dbc14c5cec34e69ab21625   mag_id
# 4      doi_dedup___::000d1effb7dd214508cfa2db791e3814      doi
# ...                                               ...      ...
# 10767  doi_dedup___::10fb361856b54e85f1dd2a296b90d1ad      doi
# 10768  doi_dedup___::10fb361856b54e85f1dd2a296b90d1ad      doi
# 10769  doi_dedup___::10fb361856b54e85f1dd2a296b90d1ad      doi
# 10770  doi_dedup___::10fb361856b54e85f1dd2a296b90d1ad   mag_id
# 10771  doi_dedup___::10fb361856b54e85f1dd2a296b90d1ad   handle
#
#                            #text
# 0         10.3390/quantum4010009
# 1         10.1002/cctc.202301719
# 2      10.1016/j.asr.2020.07.008
# 3                     3042553916
# 4          10.24267/22564004.544
# ...                          ...
# 10767         10.15560/13.2.2096
# 10768       10.60692/mqntz-0n998
# 10769       10.60692/4rqe5-dsr28
# 10770                 2607177089
# 10771                11336/57324
#
# [10772 rows x 3 columns]
