# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sn
pd.set_option('display.max_columns', None)

# %%
link_openaire_researchproduct_doi = catalog.load('stg_openaire/link_openaire_researchproduct_doi')
# Out:
# [03/07/25 14:24:46] INFO     Loading data from stg_openaire/link_openaire_researchproduct_doi   ]8;id=819822;file:///home/pablo/.local/lib/python3.10/site-packages/kedro/io/data_catalog.py\data_catalog.py]8;;\:]8;id=205078;file:///home/pablo/.local/lib/python3.10/site-packages/kedro/io/data_catalog.py#389\389]8;;\
#                              (SQLTableDataset)...

# %%
hub_openaire_researchproduct = catalog.load('stg_openaire/hub_openaire_researchproduct')
sat_openaire_researchproduct = catalog.load('stg_openaire/sat_openaire_researchproduct')

fact_publication_openaire = pd.merge(
    hub_openaire_researchproduct,
    sat_openaire_researchproduct
    ).drop(columns=['load_datetime','source', 'hashdiff'])

fact_publication_openaire
# Out:
# ╭─────────────────────────────── Traceback (most recent call last) ────────────────────────────────╮
# │ in <module>:1                                                                                    │
# │                                                                                                  │
# │ ❱ 1 fact_publication_openaire = pd.merge(                                                        │
# │   2 │   hub_openaire_researchproduct,                                                            │
# │   3 │   sat_openaire_researchproduct                                                             │
# │   4 │   ).drop(columns=['load_datetime','source', 'hashdiff'])                                   │
# ╰──────────────────────────────────────────────────────────────────────────────────────────────────╯
# NameError: name 'pd' is not defined
