# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sn
pd.set_option('display.max_columns', None)

# %%
hub_openaire_researchproduct = catalog.load('stg_openaire/hub_openaire_researchproduct')
sat_openaire_researchproduct = catalog.load('stg_openaire/sat_openaire_researchproduct')

fact_publication_openaire = pd.merge(
    hub_openaire_researchproduct,
    sat_openaire_researchproduct
    ).drop(columns=['load_datetime','source', 'hashdiff'])

fact_publication_openaire
# Out:
# [03/10/25 12:19:26] INFO     Loading data from stg_openaire/hub_openaire_researchproduct        ]8;id=964128;file:///home/pablo/.local/lib/python3.10/site-packages/kedro/io/data_catalog.py\data_catalog.py]8;;\:]8;id=969988;file:///home/pablo/.local/lib/python3.10/site-packages/kedro/io/data_catalog.py#389\389]8;;\
#                              (SQLTableDataset)...
# [03/10/25 12:19:27] INFO     Loading data from stg_openaire/sat_openaire_researchproduct        ]8;id=640596;file:///home/pablo/.local/lib/python3.10/site-packages/kedro/io/data_catalog.py\data_catalog.py]8;;\:]8;id=54694;file:///home/pablo/.local/lib/python3.10/site-packages/kedro/io/data_catalog.py#389\389]8;;\
#                              (SQLTableDataset)...
# <pre style="white-space:pre;overflow-x:auto;line-height:normal;font-family:Menlo,'DejaVu Sans Mono',consolas,'Courier New',monospace"></pre>
#                                        researchproduct_hk  \
# 0          b'\x00\x00\x17THQ\x98[3\x04^\xef\xe8\x99$\xab'
# 1          b'\x00\x00)\x04\xcb;p\xe4lJ\x0b\xcaT\xdco\x97'
# 2       b"\x00\x00t\x95\xaf^O\xa2\xd0*\xa0\xf5\x9c\xc9...
# 3       b'\x00\x00{.\x7f\x16/\x19\xa0X\xee\xee\x08\xcf...
# 4       b'\x00\x00\xc1\xb7\x87\xe2\x13\xe7\xe9\xb2\xe2...
# ...                                                   ...
# 185368  b'\xff\xfef\x82\xfe[k\xa5.\x11\x11"\x81\xc4\xe...
# 185369  b"\xff\xfe\x9e\x8c'n\xfa\x16\x0fF\xdeC\xb2\x95...
# 185370  b'\xff\xfe\xbbS&\xdb^\x91\xb2\xd2\xb8/\x0bB>\x08'
# 185371     b'\xff\xfe\xe0\x01c\xbb- J\x7f\x8d\x96K\xcd|@'
# 185372  b'\xff\xff\xb4\xc3H\x9d5J\xda\xd2c\xd8r\x9c|\xa3'
#
#                                     researchproduct_id publicly_funded  \
# 0       od______1329::a2e5908b7fbf15e901137ed03dd9d6cc         NO DATA
# 1       doi_dedup___::8ce8649f770e00b4fb6720599a00a30a           false
# 2       doi_dedup___::c8b6f53213fb70abdc7cbcd358d58446           false
# 3       dedup_wf_002::1177718413493ae04276748002f27f58           false
# 4       od______1329::59afdadcd37e5082c687e292ed29c50a         NO DATA
# ...                                                ...             ...
# 185368  od______1329::bd9f62798d789cc7d38a00a1fda37a15         NO DATA
# 185369  od______1329::5eb75955d2feabc9e52aba649dcb114e         NO DATA
# 185370  dedup_wf_002::69cb08399eda894e62548ec88759f3e3           false
# 185371  dedup_wf_002::026e8a68b98d02dd55b58e4e9e9387c9           false
# 185372  od______1329::29d1c6df8a3408d3dcf4d7f7f82bf0d0         NO DATA
#
#                                                main_title    publication_date  \
# 0       Control super-twisting de orden 3 para la acti... 2022-12-31 21:00:00
# 1       DIVERSITY, TAPHONOMY and PALAEOECOLOGY OF AN A... 2007-02-28 21:00:00
# 2       Efectos del cumplimiento del Ramadán durante e... 2019-09-01 21:00:00
# 3       Los tratados de libre comercio de última gener... 2021-05-31 21:00:00
# 4       Lengua, filología e identidad nacional: sobre ... 2017-05-31 21:00:00
# ...                                                   ...                 ...
# 185368              Tensiones en la historia de un nombre 2022-10-31 21:00:00
# 185369  Prácticas del lenguaje: un espacio para todos ... 2017-08-31 21:00:00
# 185370  Competencia del nuevo Fuero Contencioso Admini... 2007-11-30 21:00:00
# 185371                              Defender los derechos 2016-05-31 21:00:00
# 185372  “Militar” la Reforma Puiggrós: la incidencia d... 2018-11-30 21:00:00
#
#         is_green  is_in_diamond_journal language_code language_label  \
# 0          False                  False       esl/spa        Spanish
# 1           True                  False           und   Undetermined
# 2           True                  False           und   Undetermined
# 3           True                  False       esl/spa        Spanish
# 4          False                  False       esl/spa        Spanish
# ...          ...                    ...           ...            ...
# 185368     False                  False       esl/spa        Spanish
# 185369     False                  False       esl/spa        Spanish
# 185370      True                  False       esl/spa        Spanish
# 185371     False                  False       esl/spa        Spanish
# 185372     False                  False       esl/spa        Spanish
#
#        best_access_right                              best_access_right_uri  \
# 0                NO DATA                                            NO DATA
# 1                   OPEN  http://vocabularies.coar-repositories.org/docu...
# 2                   OPEN  http://vocabularies.coar-repositories.org/docu...
# 3                   OPEN  http://vocabularies.coar-repositories.org/docu...
# 4                NO DATA                                            NO DATA
# ...                  ...                                                ...
# 185368           NO DATA                                            NO DATA
# 185369           NO DATA                                            NO DATA
# 185370              OPEN  http://vocabularies.coar-repositories.org/docu...
# 185371              OPEN  http://vocabularies.coar-repositories.org/docu...
# 185372           NO DATA                                            NO DATA
#
#        citation_class  citation_count  impulse impulse_class     influence  \
# 0                  C5               0      0.0            C5  2.841867e-09
# 1                  C4              49      2.0            C5  4.560159e-09
# 2                  C5               0      0.0            C5  2.841867e-09
# 3                  C5               0      0.0            C5  2.841867e-09
# 4                  C5               0      0.0            C5  2.841867e-09
# ...               ...             ...      ...           ...           ...
# 185368             C5               0      0.0            C5  2.841867e-09
# 185369             C5               0      0.0            C5  2.841867e-09
# 185370             C5               0      0.0            C5  2.841867e-09
# 185371             C5               0      0.0            C5  2.841867e-09
# 185372             C5               0      0.0            C5  2.841867e-09
#
#        influence_class    popularity popularity_class  downloads  views  \
# 0                   C5  2.885067e-09               C5          0      0
# 1                   C4  1.357185e-08               C4         51     11
# 2                   C5  1.626197e-09               C5        214     81
# 3                   C5  2.155773e-09               C5          0      0
# 4                   C5  1.241646e-09               C5         19     45
# ...                ...           ...              ...        ...    ...
# 185368              C5  2.491310e-09               C5          1      1
# 185369              C5  1.241646e-09               C5         79     90
# 185370              C5  4.278328e-10               C5          0      0
# 185371              C5  1.090879e-09               C5          0      0
# 185372              C5  1.418572e-09               C5         18     22
#
#                                                 publisher embargo_end_date
# 0                                                 NO DATA              NaT
# 1                                                   Wiley              NaT
# 2                        Universidad Nacional de La Plata              NaT
# 3                                                 NO DATA              NaT
# 4                                                 NO DATA              NaT
# ...                                                   ...              ...
# 185368                                            NO DATA              NaT
# 185369                                            NO DATA              NaT
# 185370                                            NO DATA              NaT
# 185371  Asociación Civil Red de Carreras de Comunicaci...              NaT
# 185372                                            NO DATA              NaT
#
# [185373 rows x 23 columns]

# %%
hub_openaire_author = catalog.load('stg_openaire/hub_openaire_author')
hub_openaire_author
# Out:
# [03/10/25 13:01:32] INFO     Loading data from stg_openaire/hub_openaire_author                 ]8;id=184407;file:///home/pablo/.local/lib/python3.10/site-packages/kedro/io/data_catalog.py\data_catalog.py]8;;\:]8;id=421211;file:///home/pablo/.local/lib/python3.10/site-packages/kedro/io/data_catalog.py#389\389]8;;\
#                              (SQLTableDataset)...
# ╭─────────────────────────────── Traceback (most recent call last) ────────────────────────────────╮
# │ /home/pablo/.local/lib/python3.10/site-packages/kedro/io/core.py:244 in load                     │
# │                                                                                                  │
# │   241 │   │   │   self._logger.debug("Loading %s", str(self))                                    │
# │   242 │   │   │                                                                                  │
# │   243 │   │   │   try:                                                                           │
# │ ❱ 244 │   │   │   │   return load_func(self)                                                     │
# │   245 │   │   │   except DatasetError:                                                           │
# │   246 │   │   │   │   raise                                                                      │
# │   247 │   │   │   except Exception as exc:                                                       │
# │                                                                                                  │
# │ /home/pablo/.local/lib/python3.10/site-packages/kedro_datasets/pandas/sql_dataset.py:266 in load │
# │                                                                                                  │
# │   263 │   │   }                                                                                  │
# │   264 │                                                                                          │
# │   265 │   def load(self) -> pd.DataFrame:                                                        │
# │ ❱ 266 │   │   return pd.read_sql_table(con=self.engine, **self._load_args)                       │
# │   267 │                                                                                          │
# │   268 │   def save(self, data: pd.DataFrame) -> None:                                            │
# │   269 │   │   data.to_sql(con=self.engine, **self._save_args)                                    │
# │                                                                                                  │
# │ /home/pablo/.local/lib/python3.10/site-packages/pandas/io/sql.py:386 in read_sql_table           │
# │                                                                                                  │
# │    383 │                                                                                         │
# │    384 │   with pandasSQL_builder(con, schema=schema, need_transaction=True) as pandas_sql:      │
# │    385 │   │   if not pandas_sql.has_table(table_name):                                          │
# │ ❱  386 │   │   │   raise ValueError(f"Table {table_name} not found")                             │
# │    387 │   │                                                                                     │
# │    388 │   │   table = pandas_sql.read_table(                                                    │
# │    389 │   │   │   table_name,                                                                   │
# ╰──────────────────────────────────────────────────────────────────────────────────────────────────╯
# ValueError: Table hub_openaire_author not found
#
# The above exception was the direct cause of the following exception:
#
# ╭─────────────────────────────── Traceback (most recent call last) ────────────────────────────────╮
# │ in <module>:1                                                                                    │
# │                                                                                                  │
# │ ❱ 1 hub_openaire_author = catalog.load('stg_openaire/hub_openaire_author')                       │
# │   2 hub_openaire_author                                                                          │
# │   3                                                                                              │
# │                                                                                                  │
# │ /home/pablo/.local/lib/python3.10/site-packages/kedro/io/data_catalog.py:396 in load             │
# │                                                                                                  │
# │   393 │   │   │   extra={"markup": True},                                                        │
# │   394 │   │   )                                                                                  │
# │   395 │   │                                                                                      │
# │ ❱ 396 │   │   result = dataset.load()                                                            │
# │   397 │   │                                                                                      │
# │   398 │   │   return result                                                                      │
# │   399                                                                                            │
# │                                                                                                  │
# │ /home/pablo/.local/lib/python3.10/site-packages/kedro/io/core.py:251 in load                     │
# │                                                                                                  │
# │   248 │   │   │   │   # This exception handling is by design as the composed datasets            │
# │   249 │   │   │   │   # can throw any type of exception.                                         │
# │   250 │   │   │   │   message = f"Failed while loading data from dataset {self!s}.\n{exc!s}"     │
# │ ❱ 251 │   │   │   │   raise DatasetError(message) from exc                                       │
# │   252 │   │                                                                                      │
# │   253 │   │   load.__annotations__["return"] = load_func.__annotations__.get("return")           │
# │   254 │   │   load.__loadwrapped__ = True  # type: ignore[attr-defined]                          │
# ╰──────────────────────────────────────────────────────────────────────────────────────────────────╯
# DatasetError: Failed while loading data from dataset SQLTableDataset(load_args={'schema': stg_openaire},
# save_args={'if_exists': replace, 'index': False, 'schema': stg_openaire}, table_name=hub_openaire_author).
# Table hub_openaire_author not found
