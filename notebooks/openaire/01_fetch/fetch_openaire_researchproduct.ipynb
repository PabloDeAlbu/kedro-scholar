# %%
import requests
import pandas as pd
import xmltodict
import math

# %%
hub_openaire_graph_originalid = catalog.load('stg_openaire_graph/hub_openaire_graph_originalid')
r_token = catalog.load('params:openaire_fetch_options.refresh_token')
env = 'dev'
pd.set_option("display.max_columns", None)
id_column = 'original_id'
id_param = 'originalId'
# Out:
#                     INFO     Loading data from stg_openaire_graph/hub_openaire_graph_originalid ]8;id=342801;file:///home/pablo/dev/CIC/dw-cic/kedro/kedro-cic/.venv/lib/python3.10/site-packages/kedro/io/data_catalog.py\data_catalog.py]8;;\:]8;id=296502;file:///home/pablo/dev/CIC/dw-cic/kedro/kedro-cic/.venv/lib/python3.10/site-packages/kedro/io/data_catalog.py#389\389]8;;\
#                              (SQLTableDataset)...
#                     INFO     Loading data from params:openaire_fetch_options.refresh_token      ]8;id=657233;file:///home/pablo/dev/CIC/dw-cic/kedro/kedro-cic/.venv/lib/python3.10/site-packages/kedro/io/data_catalog.py\data_catalog.py]8;;\:]8;id=55803;file:///home/pablo/dev/CIC/dw-cic/kedro/kedro-cic/.venv/lib/python3.10/site-packages/kedro/io/data_catalog.py#389\389]8;;\
#                              (MemoryDataset)...

# %%
hub_openaire_graph_originalid
# Out:
# <pre style="white-space:pre;overflow-x:auto;line-height:normal;font-family:Menlo,'DejaVu Sans Mono',consolas,'Courier New',monospace"></pre>
#                                              original_hk  \
# 0      b'\x00\x00\xaf@Eu\x82\xdd\xc3\xe0\xa9\xad>>\x1...
# 1      b'\x00\x05\x1d\x05\x05\xfb$[\xb9\x7fmGr\xc7\x8...
# 2           b'\x00\rMJ\xcb\x19k\x80\xa8\x9dO4r\xb2`\xd8'
# 3      b'\x00\x10\xbf\x10K\xe8W\xf6\xe5\xb9\xaf\t\xce...
# 4         b'\x00\x13g.;\x9b\x9eO4\x13\xc7H\x1e=\x00\x03'
# ...                                                  ...
# 19371  b'\xff\xf0\xd9u\xa8\x96sE\xcf\xc5/\xbe\xec\x1aT4'
# 19372  b'\xff\xf3\xf0u\x7f\x1a*t\x87\xb6\xb9\xb0\xc0\...
# 19373  b'\xff\xf4F\xe5\xa6\x1e\xa6B\xaf\x80\x1b;oi\xc...
# 19374  b'\xff\xfa\xf0f\x14\x8d\xf1k\xa4\x164\x08\x19b...
# 19375  b'\xff\xfe4i\xd8\xa4\x08$l\xfa\xd9h\x1c\xe1\x9...
#
#                                              original_id load_datetime  \
# 0      50|od______9441::bf90785b53fcaf6520cdd255553795ac    2025-01-28
# 1      50|od______9441::f343a5445f9f391d9ec6de2f50fc17f9    2025-01-28
# 2                   oai:digital.cic.gba.gob.ar:11746/482    2025-01-28
# 3                  oai:digital.cic.gba.gob.ar:11746/8696    2025-01-28
# 4                  oai:digital.cic.gba.gob.ar:11746/3894    2025-01-28
# ...                                                  ...           ...
# 19371  50|od______9441::004eccb05a755201fbf8803363af5b66    2025-01-28
# 19372               oai:digital.cic.gba.gob.ar:11746/622    2025-01-28
# 19373              oai:digital.cic.gba.gob.ar:11746/8737    2025-01-28
# 19374              oai:digital.cic.gba.gob.ar:11746/6871    2025-01-28
# 19375  50|od______9441::94a521ddc8ca8c9b0574b670906a61f9    2025-01-28
#
#          source
# 0      OPENAIRE
# 1      OPENAIRE
# 2      OPENAIRE
# 3      OPENAIRE
# 4      OPENAIRE
# ...         ...
# 19371  OPENAIRE
# 19372  OPENAIRE
# 19373  OPENAIRE
# 19374  OPENAIRE
# 19375  OPENAIRE
#
# [19376 rows x 4 columns]

# %% [markdown]
# ### Recupero datos de OpenAire Graph
#
# Hago una pequeña manipulación de datos, que debería evitarse. Para eso en vez de el hub doi, hay que usar una dim_doi con el valor del pid ya manipulado en mart.

# %%
def fetch_researchproduct_openaire(df_input: pd.DataFrame, r_token: str, env: str) -> tuple[pd.DataFrame, list]:
    """
    Fetch research product data from OpenAIRE API.

    Args:
        df_input (pd.DataFrame): Input DataFrame containing identifiers.
        r_token (str): Authorization token for OpenAIRE API.
        env (str): Environment ('dev' or 'prod').
        id_column (str): Column name in DataFrame containing identifiers (e.g., 'doi' or 'original_id').
        id_param (str): Query parameter name for the API ('doi' or 'originalId').

    Returns:
        tuple[pd.DataFrame, list]: A tuple containing the resulting DataFrame and a list of skipped IDs.
    """
    base_url = "https://api.openaire.eu/search/researchProducts"
    df_list = []
    id_column = 'original_id'
    id_param = 'originalId'
    id_limit = 9999 if env == 'prod' else 9
    skipped_list = []

    # Filter rows where the ID column is not empty
    id_list = df_input[id_column].dropna().iloc[:id_limit].to_list()

    # Define the number of batches based on batch size and ID count
    batch_size = 10
    num_batches = math.ceil(len(id_list) / batch_size)

    for batch_index in range(num_batches):

        batch = id_list[batch_index * batch_size : (batch_index + 1) * batch_size]
        id_comma_separated = ",".join(batch)

        graph_url = f"{base_url}?{id_param}={id_comma_separated}"
        headers = {'Authorization': f'Bearer {r_token}'}

        api_response = requests.get(graph_url, headers=headers)
        print(f'GET "{graph_url}" {api_response.status_code}')

        if api_response.status_code == 200:
            data_dict = xmltodict.parse(api_response.content)
            results = data_dict.get('response', {}).get('results', {}).get('result', [])

            for result in results:
                publication_header = result.get('header', {})
                publication_metadata = result.get('metadata', {}).get('oaf:entity', {}).get('oaf:result', {})

                publication = publication_header | publication_metadata
                if publication:
                    df_normalized = pd.json_normalize(publication, max_level=0)
                    df_list.append(df_normalized)
                else:
                    print("No publication data found in result")
        else:
            print(f'Error: Received status code {api_response.status_code}')
            skipped_list.extend(batch)
            break

    print(f'{len(df_list)} batches processed')
    print(f'{len(skipped_list)} IDs skipped')

    if df_list:
        df = pd.concat(df_list, ignore_index=True)
    else:
        df = pd.DataFrame()

    return df, skipped_list

# %%
df, skiped_list = fetch_researchproduct_openaire(hub_openaire_graph_originalid, r_token, env, id_column, id_param)
# Out:
# GET "https://api.openaire.eu/search/researchProducts?originalId=50|od______9441::bf90785b53fcaf6520cdd255553795ac,50|od______9441::f343a5445f9f391d9ec6de2f50fc17f9,oai:digital.cic.gba.gob.ar:11746/482,oai:digital.cic.gba.gob.ar:11746/8696,oai:digital.cic.gba.gob.ar:11746/3894,50|od______9441::bf322dde89550792d6386dbb63a24216,50|od______9441::d86511f3c2bd967c73b06c2aa68c8f7b,50|od______9441::a5da66ac9a7e39207c32ecd5c50a2bea,50|od______9441::b2fc67091b462d2f40e3e155c873e4fd" 200
# 9 batches processed
# 0 IDs skipped

# %%
df
# Out:
# <pre style="white-space:pre;overflow-x:auto;line-height:normal;font-family:Menlo,'DejaVu Sans Mono',consolas,'Courier New',monospace"></pre>
#                                   @xmlns:xsi  \
# 0  http://www.w3.org/2001/XMLSchema-instance
# 1  http://www.w3.org/2001/XMLSchema-instance
# 2  http://www.w3.org/2001/XMLSchema-instance
# 3  http://www.w3.org/2001/XMLSchema-instance
# 4  http://www.w3.org/2001/XMLSchema-instance
# 5  http://www.w3.org/2001/XMLSchema-instance
# 6  http://www.w3.org/2001/XMLSchema-instance
# 7  http://www.w3.org/2001/XMLSchema-instance
# 8  http://www.w3.org/2001/XMLSchema-instance
#
#                                 dri:objIdentifier     dri:dateOfCollection  \
# 0  od______9441::f343a5445f9f391d9ec6de2f50fc17f9  2024-12-18T15:57:41.964
# 1  od______9441::bf90785b53fcaf6520cdd255553795ac  2024-12-18T15:57:35.103
# 2  dedup_wf_002::94e76520064587276002f582f761fa34  2024-12-18T15:57:43.601
# 3  od______9441::a5da66ac9a7e39207c32ecd5c50a2bea  2024-12-18T15:57:36.103
# 4  od______9441::76663a48bff44d8a7cd1b2b0eedb303f  2024-12-18T15:57:39.157
# 5  od______9441::b2fc67091b462d2f40e3e155c873e4fd  2024-12-18T15:57:30.722
# 6  dedup_wf_002::9edef6cd1f909c8505a423d72a2ab20c  2024-12-18T15:57:24.075
# 7  dedup_wf_002::db9655c70e201da1b00342f0908c9d2b  2024-12-18T15:57:31.281
# 8  od______9441::62b3d9600838c5d11a616d494016877d  2024-12-18T15:57:19.207
#
#    dri:dateOfTransformation  \
# 0  2024-03-14T12:56:07.024Z
# 1  2024-03-14T12:56:07.281Z
# 2                      None
# 3  2024-03-14T12:56:20.853Z
# 4  2024-03-14T12:56:08.392Z
# 5  2024-03-14T12:56:09.104Z
# 6                      None
# 7                      None
# 8  2024-03-14T12:56:03.886Z
#
#                                        collectedfrom  \
# 0  {'@name': 'CIC-Digital', '@id': 'opendoar____:...
# 1  {'@name': 'CIC-Digital', '@id': 'opendoar____:...
# 2  [{'@name': 'Servicio de Difusión de la Creació...
# 3  {'@name': 'CIC-Digital', '@id': 'opendoar____:...
# 4  {'@name': 'CIC-Digital', '@id': 'opendoar____:...
# 5  {'@name': 'CIC-Digital', '@id': 'opendoar____:...
# 6  [{'@name': 'Servicio de Difusión de la Creació...
# 7  [{'@name': 'Servicio de Difusión de la Creació...
# 8  {'@name': 'CIC-Digital', '@id': 'opendoar____:...
#
#                                           originalId  \
# 0  [50|od______9441::f343a5445f9f391d9ec6de2f50fc...
# 1  [oai:digital.cic.gba.gob.ar:11746/5555, 50|od_...
# 2  [50|od______1329::c7bd52e7a84c83098d0572988a17...
# 3  [50|od______9441::a5da66ac9a7e39207c32ecd5c50a...
# 4  [oai:digital.cic.gba.gob.ar:11746/482, 50|od__...
# 5  [50|od______9441::b2fc67091b462d2f40e3e155c873...
# 6  [oai:sedici.unlp.edu.ar:10915/21955, 50|od____...
# 7  [oai:sedici.unlp.edu.ar:10915/100119, 50|od___...
# 8  [oai:digital.cic.gba.gob.ar:11746/3894, 50|od_...
#
#                                              measure  \
# 0  [{'@id': 'influence', '@score': '2.841867E-9',...
# 1  [{'@id': 'influence', '@score': '2.841867E-9',...
# 2  [{'@id': 'influence', '@score': '2.841867E-9',...
# 3  [{'@id': 'influence', '@score': '2.841867E-9',...
# 4  [{'@id': 'influence', '@score': '2.841867E-9',...
# 5  [{'@id': 'influence', '@score': '2.841867E-9',...
# 6  [{'@id': 'influence', '@score': '2.841867E-9',...
# 7  [{'@id': 'influence', '@score': '2.841867E-9',...
# 8  [{'@id': 'influence', '@score': '2.841867E-9',...
#
#                                                title  \
# 0  {'@classid': 'main title', '@classname': 'main...
# 1  {'@classid': 'main title', '@classname': 'main...
# 2  {'@classid': 'main title', '@classname': 'main...
# 3  {'@classid': 'main title', '@classname': 'main...
# 4  {'@classid': 'main title', '@classname': 'main...
# 5  {'@classid': 'main title', '@classname': 'main...
# 6  {'@classid': 'main title', '@classname': 'main...
# 7  {'@classid': 'main title', '@classname': 'main...
# 8  {'@classid': 'main title', '@classname': 'main...
#
#                                      bestaccessright  \
# 0  {'@classid': 'http://creativecommons.org/licen...
# 1  {'@classid': 'OPEN', '@classname': 'Open Acces...
# 2  {'@classid': 'OPEN', '@classname': 'Open Acces...
# 3  {'@classid': 'http://creativecommons.org/licen...
# 4  {'@classid': 'OPEN', '@classname': 'Open Acces...
# 5  {'@classid': 'OPEN', '@classname': 'Open Acces...
# 6  {'@classid': 'OPEN', '@classname': 'Open Acces...
# 7  {'@classid': 'http://creativecommons.org/licen...
# 8  {'@classid': 'UNKNOWN', '@classname': 'not ava...
#
#                                              creator  \
# 0  {'@rank': '1', '@name': 'Victor Fabricio', '@s...
# 1  {'@rank': '1', '@name': 'César Gustavo', '@su...
# 2  [{'@rank': '1', '@name': 'Natalia', '@surname'...
# 3  [{'@rank': '1', '@name': 'D. H.', '@surname': ...
# 4  [{'@rank': '1', '@name': 'Alfredo', '@surname'...
# 5  {'@rank': '1', '@name': 'Alejandro Arturo', '@...
# 6  [{'@rank': '1', '@name': 'Liliana Inés', '@su...
# 7  {'@rank': '1', '@name': 'Roberto', '@surname':...
# 8  [{'@rank': '1', '@name': 'Miguel Atilio', '@su...
#
#                                  contributor dateofacceptance  \
# 0                       Podestá, Julio César       2014-01-01
# 1  [Balatti, Pedro Alberto, Saparrat, Mario]       2016-01-01
# 2                                        NaN       2019-01-01
# 3                                        NaN       2019-01-01
# 4                                        NaN       1969-01-01
# 5                        Freyre, Lauce Rubén       2003-01-01
# 6                                        NaN       2008-10-01
# 7                                        NaN       2018-01-01
# 8                                        NaN       2007-01-01
#
#                                          description  \
# 0  Durante el período de la beca, 01/04/2013 a la...
# 1  Cladosporium fulvum es un hongo biotrófico no ...
# 2  [Red de Universidades con Carreras en Informát...
# 3  This paper presents an experimental study on c...
# 4  [En la primera parte del trabajo se estudia el...
# 5  Proyectos de investigación en los cuales colab...
# 6  [La Arquitectura Model Driven (MDA) promueve e...
# 7  [Centro de Investigación y Desarrollo en Tecno...
# 8  [Statistical analysis is fundamental to the fi...
#
#                                              subject  \
# 0  [{'@classid': 'keyword', '@classname': 'keywor...
# 1  [{'@classid': 'keyword', '@classname': 'keywor...
# 2  [{'@classid': 'keyword', '@classname': 'keywor...
# 3  [{'@classid': 'keyword', '@classname': 'keywor...
# 4  [{'@classid': 'keyword', '@classname': 'keywor...
# 5  [{'@classid': 'keyword', '@classname': 'keywor...
# 6  [{'@classid': 'keyword', '@classname': 'keywor...
# 7  [{'@classid': 'keyword', '@classname': 'keywor...
# 8  [{'@classid': 'keyword', '@classname': 'keywor...
#
#                                             language  \
# 0  {'@classid': 'Español', '@classname': 'Español...
# 1  {'@classid': 'Español', '@classname': 'Español...
# 2  {'@classid': 'esl/spa', '@classname': 'Spanish...
# 3  {'@classid': 'Inglés', '@classname': 'Inglés',...
# 4  {'@classid': 'Español', '@classname': 'Español...
# 5  {'@classid': 'Español', '@classname': 'Español...
# 6  {'@classid': 'esl/spa', '@classname': 'Spanish...
# 7  {'@classid': 'esl/spa', '@classname': 'Spanish...
# 8  {'@classid': 'und', '@classname': 'Undetermine...
#
#                         format  \
# 0      [application/pdf, 5 p.]
# 1     [application/pdf, 18 p.]
# 2     [application/pdf, 76-83]
# 3   [application/pdf, 649–658]
# 4     [application/pdf, 28 p.]
# 5     [application/pdf, 14 p.]
# 6     [application/pdf, 12 p.]
# 7      [application/pdf, 4 p.]
# 8  [application/pdf, p. 22-24]
#
#                                           resulttype  \
# 0  {'@classid': 'other', '@classname': 'other', '...
# 1  {'@classid': 'other', '@classname': 'other', '...
# 2  {'@classid': 'other', '@classname': 'other', '...
# 3  {'@classid': 'other', '@classname': 'other', '...
# 4  {'@classid': 'other', '@classname': 'other', '...
# 5  {'@classid': 'other', '@classname': 'other', '...
# 6  {'@classid': 'other', '@classname': 'other', '...
# 7  {'@classid': 'other', '@classname': 'other', '...
# 8  {'@classid': 'other', '@classname': 'other', '...
#
#                                         resourcetype  \
# 0  {'@classid': 'UNKNOWN', '@classname': 'UNKNOWN...
# 1  {'@classid': 'UNKNOWN', '@classname': 'UNKNOWN...
# 2  {'@classid': 'UNKNOWN', '@classname': 'UNKNOWN...
# 3  {'@classid': 'UNKNOWN', '@classname': 'UNKNOWN...
# 4  {'@classid': 'UNKNOWN', '@classname': 'UNKNOWN...
# 5  {'@classid': 'UNKNOWN', '@classname': 'UNKNOWN...
# 6  {'@classid': 'UNKNOWN', '@classname': 'UNKNOWN...
# 7  {'@classid': 'UNKNOWN', '@classname': 'UNKNOWN...
# 8  {'@classid': 'UNKNOWN', '@classname': 'UNKNOWN...
#
#                                             datainfo  \
# 0  {'inferred': 'false', 'deletedbyinference': 'f...
# 1  {'inferred': 'false', 'deletedbyinference': 'f...
# 2  {'inferred': 'true', 'deletedbyinference': 'fa...
# 3  {'inferred': 'false', 'deletedbyinference': 'f...
# 4  {'inferred': 'false', 'deletedbyinference': 'f...
# 5  {'inferred': 'false', 'deletedbyinference': 'f...
# 6  {'inferred': 'true', 'deletedbyinference': 'fa...
# 7  {'inferred': 'true', 'deletedbyinference': 'fa...
# 8  {'inferred': 'false', 'deletedbyinference': 'f...
#
#                                                 rels  \
# 0                                               None
# 1                                               None
# 2                                               None
# 3                                               None
# 4  {'rel': {'@inferred': 'true', '@trust': '0.9',...
# 5                                               None
# 6                                               None
# 7                                               None
# 8                                               None
#
#                                             children  \
# 0  {'instance': {'accessright': {'@classid': 'htt...
# 1  {'instance': {'accessright': {'@classid': 'OPE...
# 2  {'instance': [{'accessright': {'@classid': 'ht...
# 3  {'instance': {'accessright': {'@classid': 'htt...
# 4  {'instance': {'accessright': {'@classid': 'OPE...
# 5  {'instance': {'accessright': {'@classid': 'OPE...
# 6  {'instance': [{'accessright': {'@classid': 'ht...
# 7  {'instance': [{'accessright': {'@classid': 'ht...
# 8  {'instance': {'accessright': {'@classid': 'UNK...
#
#                                              country  \
# 0                                                NaN
# 1                                                NaN
# 2  {'@classid': 'AR', '@classname': 'Argentina', ...
# 3                                                NaN
# 4                                                NaN
# 5                                                NaN
# 6  {'@classid': 'AR', '@classname': 'Argentina', ...
# 7  {'@classid': 'AR', '@classname': 'Argentina', ...
# 8                                                NaN
#
#                                            publisher
# 0                                                NaN
# 1                                                NaN
# 2                                                NaN
# 3                                        Elsevier BV
# 4  Laboratorio de Entrenamiento Multidisciplinari...
# 5                                                NaN
# 6                                                NaN
# 7                                                NaN
# 8                                                NaN
