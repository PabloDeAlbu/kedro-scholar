# %%
from datetime import date
import ast
import pandas as pd

pd.set_option('display.max_columns', None)
df = catalog.load('raw/openaire/researchproduct')
# Out:
#                     INFO     Loading data from raw/openaire/researchproduct (CSVDataset)...     ]8;id=575247;file:///root/kedro-cic/.venv/lib/python3.10/site-packages/kedro/io/data_catalog.py\data_catalog.py]8;;\:]8;id=296458;file:///root/kedro-cic/.venv/lib/python3.10/site-packages/kedro/io/data_catalog.py#389\389]8;;\

# %% [markdown]
# ## Paso 0: Seleccionar columnas con identificador y 'relevantdate'

# %%
df_researchproduct = df.loc[:, ['dri:objIdentifier', 'relevantdate']]
df_researchproduct = df_researchproduct.convert_dtypes()

# %%
df_researchproduct.head(5)
# Out:
# <pre style="white-space:pre;overflow-x:auto;line-height:normal;font-family:Menlo,'DejaVu Sans Mono',consolas,'Courier New',monospace"></pre>
#                                 dri:objIdentifier  \
# 0  doi_dedup___::2577d684a839dc78be3e1307914cdfd5
# 1  doi_________::01bdfeebe25730711be433245a4426e7
# 2  doi_dedup___::fccba469c4dbc14c5cec34e69ab21625
# 3  doi_dedup___::000d1effb7dd214508cfa2db791e3814
# 4  doi_dedup___::387324dfb1abac93013eccfd545780c1
#
#                                         relevantdate
# 0  [{'@classid': 'created', '@classname': 'create...
# 1  [{'@classid': 'created', '@classname': 'create...
# 2  [{'@classid': 'created', '@classname': 'create...
# 3  [{'@classid': 'created', '@classname': 'create...
# 4  [{'@classid': 'created', '@classname': 'create...

# %% [markdown]
# ## Paso 1: Asegurarse de que 'relevantdate' sea un diccionario o lista

# %%
df_researchproduct['relevantdate'] = df_researchproduct['relevantdate'].apply(lambda x: ast.literal_eval(x) if isinstance(x, str) else x)
df_researchproduct['relevantdate'] = df_researchproduct['relevantdate'].apply(lambda x: [x] if not isinstance(x, list) else x)

# %%
df_researchproduct
# Out:
# <pre style="white-space:pre;overflow-x:auto;line-height:normal;font-family:Menlo,'DejaVu Sans Mono',consolas,'Courier New',monospace"></pre>
#                                    dri:objIdentifier  \
# 0     doi_dedup___::2577d684a839dc78be3e1307914cdfd5
# 1     doi_________::01bdfeebe25730711be433245a4426e7
# 2     doi_dedup___::fccba469c4dbc14c5cec34e69ab21625
# 3     doi_dedup___::000d1effb7dd214508cfa2db791e3814
# 4     doi_dedup___::387324dfb1abac93013eccfd545780c1
# ...                                              ...
# 3870  doi_dedup___::a901f8fcb7a8e4fd764da3fdbf42c064
# 3871  doi_dedup___::7d4824281cdafde3676552da1141877a
# 3872  doi_dedup___::acf6451bd9b42e6b944f84d81fe47232
# 3873  doi_dedup___::42f7f1f2a1e586ca7bb4942987b54b71
# 3874  doi_dedup___::10fb361856b54e85f1dd2a296b90d1ad
#
#                                            relevantdate
# 0     [{'@classid': 'created', '@classname': 'create...
# 1     [{'@classid': 'created', '@classname': 'create...
# 2     [{'@classid': 'created', '@classname': 'create...
# 3     [{'@classid': 'created', '@classname': 'create...
# 4     [{'@classid': 'created', '@classname': 'create...
# ...                                                 ...
# 3870  [{'@classid': 'created', '@classname': 'create...
# 3871  [{'@classid': 'created', '@classname': 'create...
# 3872  [{'@classid': 'created', '@classname': 'create...
# 3873  [{'@classid': 'created', '@classname': 'create...
# 3874  [{'@classid': 'created', '@classname': 'create...
#
# [3875 rows x 2 columns]

# %% [markdown]
# ## Paso 2: Explode la columna 'relevantdate' y reinicia el índice

# %%
df_researchproduct = df_researchproduct.explode('relevantdate').reset_index(drop=True)

# %%
df_researchproduct
# Out:
# <pre style="white-space:pre;overflow-x:auto;line-height:normal;font-family:Menlo,'DejaVu Sans Mono',consolas,'Courier New',monospace"></pre>
#                                     dri:objIdentifier  \
# 0      doi_dedup___::2577d684a839dc78be3e1307914cdfd5
# 1      doi_dedup___::2577d684a839dc78be3e1307914cdfd5
# 2      doi_________::01bdfeebe25730711be433245a4426e7
# 3      doi_________::01bdfeebe25730711be433245a4426e7
# 4      doi_________::01bdfeebe25730711be433245a4426e7
# ...                                               ...
# 11362  doi_dedup___::42f7f1f2a1e586ca7bb4942987b54b71
# 11363  doi_dedup___::10fb361856b54e85f1dd2a296b90d1ad
# 11364  doi_dedup___::10fb361856b54e85f1dd2a296b90d1ad
# 11365  doi_dedup___::10fb361856b54e85f1dd2a296b90d1ad
# 11366  doi_dedup___::10fb361856b54e85f1dd2a296b90d1ad
#
#                                             relevantdate
# 0      {'@classid': 'created', '@classname': 'created...
# 1      {'@classid': 'published-online', '@classname':...
# 2      {'@classid': 'created', '@classname': 'created...
# 3      {'@classid': 'published-online', '@classname':...
# 4      {'@classid': 'published-print', '@classname': ...
# ...                                                  ...
# 11362  {'@classid': 'published-online', '@classname':...
# 11363  {'@classid': 'created', '@classname': 'created...
# 11364  {'@classid': 'published-online', '@classname':...
# 11365  {'@classid': 'issued', '@classname': 'issued',...
# 11366  {'@classid': 'updated', '@classname': 'updated...
#
# [11367 rows x 2 columns]

# %% [markdown]
# ## Paso 3: Normalizar la columna 'measure' en nuevas columnas

# %%
relevantdate_expanded = pd.json_normalize(df_researchproduct["relevantdate"])

# %%
relevantdate_expanded
# Out:
# <pre style="white-space:pre;overflow-x:auto;line-height:normal;font-family:Menlo,'DejaVu Sans Mono',consolas,'Courier New',monospace"></pre>
#                @classid        @classname           @schemeid  \
# 0               created           created  dnet:dataCite_date
# 1      published-online  published-online  dnet:dataCite_date
# 2               created           created  dnet:dataCite_date
# 3      published-online  published-online  dnet:dataCite_date
# 4       published-print   published-print  dnet:dataCite_date
# ...                 ...               ...                 ...
# 11362  published-online  published-online  dnet:dataCite_date
# 11363           created           created  dnet:dataCite_date
# 11364  published-online  published-online  dnet:dataCite_date
# 11365            issued            issued  dnet:dataCite_date
# 11366           updated           updated  dnet:dataCite_date
#
#               @schemename       #text @inferred  \
# 0      dnet:dataCite_date  2022-02-23       NaN
# 1      dnet:dataCite_date  2022-02-22       NaN
# 2      dnet:dataCite_date  2024-02-02       NaN
# 3      dnet:dataCite_date  2024-02-16       NaN
# 4      dnet:dataCite_date  2024-05-08       NaN
# ...                   ...         ...       ...
# 11362  dnet:dataCite_date  2014-03-01       NaN
# 11363  dnet:dataCite_date  2017-04-25       NaN
# 11364  dnet:dataCite_date  2017-04-17       NaN
# 11365  dnet:dataCite_date  2017-04-17       NaN
# 11366  dnet:dataCite_date  2020-01-20     false
#
#                     @provenanceaction @trust
# 0                                 NaN    NaN
# 1                                 NaN    NaN
# 2                                 NaN    NaN
# 3                                 NaN    NaN
# 4                                 NaN    NaN
# ...                               ...    ...
# 11362                             NaN    NaN
# 11363                             NaN    NaN
# 11364                             NaN    NaN
# 11365                             NaN    NaN
# 11366  sysimport:crosswalk:repository    0.9
#
# [11367 rows x 8 columns]

# %% [markdown]
# ## Paso 4: Concatenar df_researchproduct con df_relevantdate asegurando que los índices están alineados

# %%
df_researchproduct2relevantdate = pd.concat([df_researchproduct, relevantdate_expanded], axis=1)
df_researchproduct2relevantdate.drop(columns='relevantdate', inplace=True)

# %%
df_researchproduct2relevantdate
# Out:
# <pre style="white-space:pre;overflow-x:auto;line-height:normal;font-family:Menlo,'DejaVu Sans Mono',consolas,'Courier New',monospace"></pre>
#                                     dri:objIdentifier          @classid  \
# 0      doi_dedup___::2577d684a839dc78be3e1307914cdfd5           created
# 1      doi_dedup___::2577d684a839dc78be3e1307914cdfd5  published-online
# 2      doi_________::01bdfeebe25730711be433245a4426e7           created
# 3      doi_________::01bdfeebe25730711be433245a4426e7  published-online
# 4      doi_________::01bdfeebe25730711be433245a4426e7   published-print
# ...                                               ...               ...
# 11362  doi_dedup___::42f7f1f2a1e586ca7bb4942987b54b71  published-online
# 11363  doi_dedup___::10fb361856b54e85f1dd2a296b90d1ad           created
# 11364  doi_dedup___::10fb361856b54e85f1dd2a296b90d1ad  published-online
# 11365  doi_dedup___::10fb361856b54e85f1dd2a296b90d1ad            issued
# 11366  doi_dedup___::10fb361856b54e85f1dd2a296b90d1ad           updated
#
#              @classname           @schemeid         @schemename       #text  \
# 0               created  dnet:dataCite_date  dnet:dataCite_date  2022-02-23
# 1      published-online  dnet:dataCite_date  dnet:dataCite_date  2022-02-22
# 2               created  dnet:dataCite_date  dnet:dataCite_date  2024-02-02
# 3      published-online  dnet:dataCite_date  dnet:dataCite_date  2024-02-16
# 4       published-print  dnet:dataCite_date  dnet:dataCite_date  2024-05-08
# ...                 ...                 ...                 ...         ...
# 11362  published-online  dnet:dataCite_date  dnet:dataCite_date  2014-03-01
# 11363           created  dnet:dataCite_date  dnet:dataCite_date  2017-04-25
# 11364  published-online  dnet:dataCite_date  dnet:dataCite_date  2017-04-17
# 11365            issued  dnet:dataCite_date  dnet:dataCite_date  2017-04-17
# 11366           updated  dnet:dataCite_date  dnet:dataCite_date  2020-01-20
#
#       @inferred               @provenanceaction @trust
# 0           NaN                             NaN    NaN
# 1           NaN                             NaN    NaN
# 2           NaN                             NaN    NaN
# 3           NaN                             NaN    NaN
# 4           NaN                             NaN    NaN
# ...         ...                             ...    ...
# 11362       NaN                             NaN    NaN
# 11363       NaN                             NaN    NaN
# 11364       NaN                             NaN    NaN
# 11365       NaN                             NaN    NaN
# 11366     false  sysimport:crosswalk:repository    0.9
#
# [11367 rows x 9 columns]

# %% [markdown]
# ## Paso 5: Agrego load_datetime

# %%
df_researchproduct2relevantdate['load_datetime'] = date.today()

# %%
df_researchproduct2relevantdate
# Out:
# <pre style="white-space:pre;overflow-x:auto;line-height:normal;font-family:Menlo,'DejaVu Sans Mono',consolas,'Courier New',monospace"></pre>
#                                     dri:objIdentifier          @classid  \
# 0      doi_dedup___::2577d684a839dc78be3e1307914cdfd5           created
# 1      doi_dedup___::2577d684a839dc78be3e1307914cdfd5  published-online
# 2      doi_________::01bdfeebe25730711be433245a4426e7           created
# 3      doi_________::01bdfeebe25730711be433245a4426e7  published-online
# 4      doi_________::01bdfeebe25730711be433245a4426e7   published-print
# ...                                               ...               ...
# 11362  doi_dedup___::42f7f1f2a1e586ca7bb4942987b54b71  published-online
# 11363  doi_dedup___::10fb361856b54e85f1dd2a296b90d1ad           created
# 11364  doi_dedup___::10fb361856b54e85f1dd2a296b90d1ad  published-online
# 11365  doi_dedup___::10fb361856b54e85f1dd2a296b90d1ad            issued
# 11366  doi_dedup___::10fb361856b54e85f1dd2a296b90d1ad           updated
#
#              @classname           @schemeid         @schemename       #text  \
# 0               created  dnet:dataCite_date  dnet:dataCite_date  2022-02-23
# 1      published-online  dnet:dataCite_date  dnet:dataCite_date  2022-02-22
# 2               created  dnet:dataCite_date  dnet:dataCite_date  2024-02-02
# 3      published-online  dnet:dataCite_date  dnet:dataCite_date  2024-02-16
# 4       published-print  dnet:dataCite_date  dnet:dataCite_date  2024-05-08
# ...                 ...                 ...                 ...         ...
# 11362  published-online  dnet:dataCite_date  dnet:dataCite_date  2014-03-01
# 11363           created  dnet:dataCite_date  dnet:dataCite_date  2017-04-25
# 11364  published-online  dnet:dataCite_date  dnet:dataCite_date  2017-04-17
# 11365            issued  dnet:dataCite_date  dnet:dataCite_date  2017-04-17
# 11366           updated  dnet:dataCite_date  dnet:dataCite_date  2020-01-20
#
#       @inferred               @provenanceaction @trust load_datetime
# 0           NaN                             NaN    NaN    2024-11-28
# 1           NaN                             NaN    NaN    2024-11-28
# 2           NaN                             NaN    NaN    2024-11-28
# 3           NaN                             NaN    NaN    2024-11-28
# 4           NaN                             NaN    NaN    2024-11-28
# ...         ...                             ...    ...           ...
# 11362       NaN                             NaN    NaN    2024-11-28
# 11363       NaN                             NaN    NaN    2024-11-28
# 11364       NaN                             NaN    NaN    2024-11-28
# 11365       NaN                             NaN    NaN    2024-11-28
# 11366     false  sysimport:crosswalk:repository    0.9    2024-11-28
#
# [11367 rows x 10 columns]
